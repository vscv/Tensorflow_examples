# %% [markdown]
# # 101 Course of transfer learning and Fine tune 2021-01-01

# %% [markdown]
# ## [How-to] 1. k-fold for cross validation
#
# #### Create a simple k-fold for train classification model.
#
# * In this short course you learned:
#
# * data pipline
#
# * transfer learning
#
# * fine tune
#
# * callbacks

# %% [markdown]
# todo: move to note.py

# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# plt.style.use("bmh")

import cv2
import tensorflow as tf

from datetime import datetime
import seaborn as sns

import errno

# albumentations
from functools import partial
# from albumentations import (
#     Compose, RandomBrightness, JpegCompression, HueSaturationValue, RandomContrast, HorizontalFlip,
#     Rotate
# )
import albumentations as A

# from adabelief_tf import AdaBeliefOptimizer

# %%
print(tf.__version__)
print(cv2.__version__)
# Out:
# 2.3.1
# 4.3.0

# %%
from pytictoc import TicToc

t_timer = TicToc() #create instance of class

t_timer.tic() #Start timer

# %% [markdown]
# ### 2. Parameters

# %% [markdown]
# #### Image size, Batch size, toe/heel-offset.

# %%
BATCH_SIZE = 64 # 16 #32 #64 #128 #32 #64 #todo: reduce the BS maybe help to reduce the loss
img_height = 120 #512 #224 #100
img_width = 120 #512 #224 #100

y_offset_toe = 80
y_offset_heel = 280 #400-120=280

# %% [markdown]
# #### tf MirroredStrategy seting

# %%
# tf MirroredStrategy seting
strategy = tf.distribute.MirroredStrategy()
REPLICAS = strategy.num_replicas_in_sync
print('\nNumber of REPLICAS: {}\n'.format(REPLICAS))


MULTI_BATCH_SIZE = BATCH_SIZE * strategy.num_replicas_in_sync
print('BATCH_SIZE: {}, MULTI_BATCH_SIZE: {}'.format(BATCH_SIZE, MULTI_BATCH_SIZE))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
#
# Number of REPLICAS: 1
#
# BATCH_SIZE: 64, MULTI_BATCH_SIZE: 64

# %%
# 自動調節tf.data管道
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %% [markdown]
# ### 3. Create the training dataset W/ croped

# %% [markdown]
# #### Load samples as data-farame

# %%
# # data-org #
# ann = 'annotation_1424_merge.csv'
# im_p = 'train/images/'
# CSVNAME = ""


# # data-org-augm#
# ann = 'annotation_2848_augm.csv'
# im_p = 'train_augm/images/'
# CSVNAME = ""


# data-train # # current best dataset.1424-79.
ann = 'annotation_1345_good.csv'
im_p = 'train/images/'
CSVNAME = "K1345"

# data-augm #
# ann = 'annotation_2690_augm.csv'
# im_p = 'train_augm/images/'
# CSVNAME = ""


# # data-train-HPL-1123
# ann = 'annotation_1123_HPL_Good.csv'
# im_p = 'train/images/'
# CSVNAME = ""


df = pd.read_csv(ann)
df[1120:]
# Out:
#               images  x1   y1  x2   y2
# 1120  image_6195.jpg  52  127  75  370
# 1121  image_6196.jpg  62  138  29  383
# 1122  image_6197.jpg  54  135  78  380
# 1123  image_6198.jpg  60  125  29  384
# 1124  image_6199.jpg  51  147  70  353
# ...              ...  ..  ...  ..  ...
# 1340  image_6419.jpg  60  135  70  381
# 1341  image_6421.jpg  53  157  76  376
# 1342  image_6422.jpg  49  154  33  375
# 1343  image_6423.jpg  64  149  76  381
# 1344  image_6424.jpg  55  147  36  385
#
# [225 rows x 5 columns]

# %%
len(df)
# Out:
# 1345

# %% [markdown]
# #### Shuffle and reset index

# %%
# reset index
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head(10)
# Out:
#            images  x1   y1  x2   y2
# 0  image_6284.jpg  62  137  34  383
# 1  image_0458.png  60  143  23  384
# 2  image_0106.png  62  120  37  380
# 3  image_6376.jpg  53  138  37  381
# 4  image_0812.png  50  152  96  384
# 5  image_0505.png  54  123  87  383
# 6  image_0957.png  58  140  25  380
# 7  image_6147.png  56  141  89  384
# 8  image_0294.png  56  139  29  366
# 9  image_0934.png  41  134  81  382

# %% [markdown]
# See, the image_####.jpg now are random.

# %% [markdown]
# #### Create tf.dataset (DS)

# %%
# from dataframe
list_ds = tf.data.Dataset.from_tensor_slices((df['images'], df['x1'], df['y1'], df['x2'], df['y2']))
# list_ds = list_ds.shuffle(image_count, reshuffle_each_iteration=True) #todo: move to ds_pre. see https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle

# %%
len(list_ds)#.shape() #take(1)
# Out:
# 1345

# %%
# check The type specification of an element of this dataset.
list_ds.element_spec
# Out:
# (TensorSpec(shape=(), dtype=tf.string, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None))

# %%
for f,x1,y1,x2,y2 in list_ds.take(5):
    print(f'take sample: {f} {x1} {y1} {x2} {y2}')
# Out:
# take sample: b'image_6284.jpg' 62 137 34 383
# take sample: b'image_0458.png' 60 143 23 384
# take sample: b'image_0106.png' 62 120 37 380
# take sample: b'image_6376.jpg' 53 138 37 381
# take sample: b'image_0812.png' 50 152 96 384

# %%
# use np decode to UTF-8
print(f.numpy().decode('UTF-8'))
# Out:
# image_0812.png

# %%
len(list_ds)
# Out:
# 1345

# %% [markdown]
# #### Check ds iterator for consuming

# %%
# create a Python iterator

it_list_ds = iter(list_ds) # Make sure iter ds only once.

# %%
# using iter and consuming its elements using next: every print different image name.

for i in range(4):
    image, x1, y1, x2, y2 = next(it_list_ds)
    print(image.numpy(), x1.numpy(), y1.numpy())
# Out:
# b'image_6284.jpg' 62 137
# b'image_0458.png' 60 143
# b'image_0106.png' 62 120
# b'image_6376.jpg' 53 138

# %%
# image_batch, label_batch = valid_ds_pre_s.as_numpy_iterator().next()
# pred = model.predict_on_batch(image_batch)


for i in range(4):
    image, x1, y1, x2, y2 = list_ds.as_numpy_iterator().next()# every time create a new iter, so need put iter out of above cell.
    print(image, x1, y1, x2, y2)
    
iter_test_list = list_ds.as_numpy_iterator()
print("===== Create iterator once and pull out to above cell. =====")
for i in range(4):
    image, x1, y1, x2, y2 = iter_test_list.next()
    print(image, x1, y1, x2, y2)
# Out:
# b'image_6284.jpg' 62 137 34 383
# b'image_6284.jpg' 62 137 34 383
# b'image_6284.jpg' 62 137 34 383
# b'image_6284.jpg' 62 137 34 383
# ===== Create iterator once and pull out to above cell. =====
# b'image_6284.jpg' 62 137 34 383
# b'image_0458.png' 60 143 23 384
# b'image_0106.png' 62 120 37 380
# b'image_6376.jpg' 53 138 37 381

# %% [markdown]
# #### Process path to image tensor in DS

# %%
'''
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    # The second to last is the class-directory
    boolen = parts[-2] == class_names
    #one_hot_num = np.array(boolen, dtype=np.int) not works should use tf.x repalced.
    one_hot_num = tf.dtypes.cast(boolen, tf.int64)
    one_num = tf.argmax(one_hot_num)
    print('one_num:', one_num)
    # Integer encode the label
    return one_num

def decode_img(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.io.decode_jpeg(img, channels=3)
    # resize the image to the desired size
#     return tf.image.resize(img, [img_height, img_width])# augment 已經resize過一次了 但這邊不先做會比較慢
    return tf.cast(tf.image.resize(img, [img_height, img_width]), tf.uint8)# 避免float over at augment
'''

#
# map list to ds, Toe part.
#

def decode_crop_png_toe(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.io.decode_png(img, channels=3)
    # crop the toe from top-left corner [image, offset_height y1, offset_width x1, target_height, target_width]
    y1=y_offset_toe;    x1=0;    h=img_height;    w=img_width # not the pp location
    img = tf.image.crop_to_bounding_box(img, int(y1), int(x1), h, w)
    #img = tf.image.crop_to_bounding_box(img, int(y1), int(x1), int(y2)-int(y1), int(x2)-int(x1))
    # resize the image to the desired size
    return img

def process_path_toe(file_path,x1,y1,x2,y2):
    file_path = im_p + file_path
    #label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)#can read the byte string paths b'image_0001.png'
    img = decode_crop_png_toe(img)
    return img, [x1,y1-y_offset_toe]#Original [0,120]
    #return img, x1, y1-y_offset_toe #Original [0,120] #貌似ed不用改，蛋mse變超大
    #return img, [x1/120,(y1-y_offset_toe)/120]#normalized [0,1] xy <dtype: 'float64'>, no help.
    #return img, [(x1-60)/60,((y1-y_offset_toe)-60)/60]#normalized [-1,1] , no help.

#
# map list to ds, Heel part.
#

def decode_crop_png_heel(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.io.decode_png(img, channels=3)
    # crop the toe from top-left corner [image, offset_height y1, offset_width x1, target_height, target_width]
    y2=y_offset_heel;    x2=0;    h=img_height;    w=img_width # not the pp location
    img = tf.image.crop_to_bounding_box(img, int(y2), int(x2), h, w)
    #img = tf.image.crop_to_bounding_box(img, int(y1), int(x1), int(y2)-int(y1), int(x2)-int(x1))
    # resize the image to the desired size
    return img

def process_path_heel(file_path,x1,y1,x2,y2):
    file_path = im_p + file_path
    #label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)#can read the byte string paths b'image_0001.png'
    img = decode_crop_png_heel(img)
    return img, [x2,y2-y_offset_heel]#Original [0,120]
    #return img, x2, y2-y_offset_heel #Original [0,120] #貌似ed不用改，蛋mse變超大
    #return img, [x2/120,(y2-y_offset_heel)/120]#normalized [0,1] xy <dtype: 'float64'>, no help.
    #return img, [(x2-60)/60,((y2-y_offset_heel)-60)/60]#normalized [-1,1] , no help.

#
# test how to put parameters to map
#

def t_ds_map(file_path,x1,y1,x2,y2):
#     img = get_img('train/images/' + str(file_path))
#     print(file_path)
    return file_path,x1,y1,x2,y2 #img, [x1,y1]

# %%
# Toe ds
train_ds_map_toe = list_ds.map(process_path_toe, num_parallel_calls=AUTOTUNE)

# Heel ds
train_ds_map_heel = list_ds.map(process_path_heel, num_parallel_calls=AUTOTUNE)

# %%
# for img, xy in train_ds_map_toe.take(1):
#     print(f'take sample: {xy}')
    
# print('f', f.dtype)
# print('xy', xy.dtype)

# for img, x, y in train_ds_map_toe.take(1):
#     print(f'take sample: {x} {y}')
    
# print('img', img.dtype)
# print('x', x.dtype)
# x

for img, [x, y] in train_ds_map_toe.take(1):
    print(f'take sample: {x} {y}')
    
print('f', f.dtype)
print('x', x.dtype)
# Out:
# take sample: 62 57
# f <dtype: 'string'>
# x <dtype: 'int64'>

# %%
x
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=62>

# %%
# for f,x1,y1,x2,y2 in train_ds_map.take(5):
#     print(f'take sample: {f} {x1} {y1} {x2} {y2}')

# %% [markdown]
# #### [new] Split train_ds_pre with ratio of validation %

# %% [markdown]
# [ToDo 20210201] keep orignal validation in 0.1, but augmenting train_ds in input layer or in the tf.ds.

# %% [markdown]
# [2021-02-23] New k-split ds

# %%
# # split Toe
# val_size = int(tf.data.experimental.cardinality(train_ds_map_toe).numpy() * 0.2)
# # val_size = int(tf.data.experimental.cardinality(train_ds_map_toe).numpy() * 0.1)#no help

# train_ds_map_toe_s = train_ds_map_toe.skip(val_size)
# valid_ds_map_toe_s = train_ds_map_toe.take(val_size)

# print(f'whole samples = {len(train_ds_map_toe)}')
# print(f'val_size = {val_size}')

# print('ds_train = ', tf.data.experimental.cardinality(train_ds_map_toe_s).numpy())
# print('ds_valid = ', tf.data.experimental.cardinality(valid_ds_map_toe_s).numpy())

# %%
# # split Heel
# val_size = int(tf.data.experimental.cardinality(train_ds_map_heel).numpy() * 0.2)
# # val_size = int(tf.data.experimental.cardinality(train_ds_map_heel).numpy() * 0.1)


# train_ds_map_heel_s = train_ds_map_heel.skip(val_size)
# valid_ds_map_heel_s = train_ds_map_heel.take(val_size)

# print(len(train_ds_map_heel))
# print(val_size)
# print(tf.data.experimental.cardinality(train_ds_map_heel_s).numpy())
# print(tf.data.experimental.cardinality(valid_ds_map_heel_s).numpy())

# %%
# ## testing cell
# kf = []
# for k in range(5):
#     kf.append(train_ds_map_heel.shard(num_shards=5, index=k))
#     print("k =", k,"num=", tf.data.experimental.cardinality(kf[k]).numpy())

# %%
# kf

# %%
# for img, [x,y] in kf[1].take(1):
#     print(f'take sample: {x} {y}')
    
# print('img', img.dtype)
# print('x', x.dtype)
# print('y', y.dtype)

# %%
# ## testing cell

# range_k_0 = train_ds_map_heel.window(5)

# print(len(range_k_0))
# print(tf.data.experimental.cardinality(range_k_0).numpy())

# %%
# ## testing cell

# def get_train_valid_k_split():
#     x = tf.data.Dataset.range(1000)
#     val_size = int(tf.data.experimental.cardinality(x).numpy() * 0.2)
    
#     for k in range(5):
#         train_num = x.take(val_size + k*val_size)
#         valid_num = x.skip(k*val_size)
        
#         print("k=", k)
#         print(tf.data.experimental.cardinality(train_num).numpy())
#         print(tf.data.experimental.cardinality(valid_num).numpy())
    
    
# get_train_valid_k_split()

# %%
## testing cell

# 
# tf.slice
# tf.data.experimental.choose_from_datasets


# x = list_ds
# val_size = int(tf.data.experimental.cardinality(list_ds).numpy() * 0.2)
x = tf.data.Dataset.range(10)

def check_KFold_ds(x, K=5):
    
    val_size = int(tf.data.experimental.cardinality(x).numpy() * 0.2)
    print("val_size=", val_size)
    
    for k in range(K):
#         k_train = x.take(val_size + k*val_size)
#         k_valid = x.skip(k*val_size)
#         k_train = tf.slice(x, k*val_size, val_size) #only for pure tensors not 
#         k_valid = x.skip(k*val_size)

        # may skip twicce to performe kflod
        t_take = x.take(k*val_size)
        t_skip = x.skip(k*val_size+val_size)
        k_train = t_take.concatenate(t_skip)
        
        v_skip = x.skip(k*val_size)
        k_valid = v_skip.take(val_size)

        print("k =", k,"k*val_size+val_size", k*val_size+val_size, "k_train num=", tf.data.experimental.cardinality(k_train).numpy())


        # x = tf.data.Dataset.range(10)
#         for n in k_train:
#             print(n.numpy())
#         for n in k_valid:
#             print(n.numpy())
        
        # list_ds
#         for img, x1, y1, x2, y2 in k_train:
#             print(x1, y1)

        # train_ds_map_toe
#         for img, (x, y) in k_train:
#             print(x.numpy(), y.numpy())

    
    
    
check_KFold_ds(x)
# check_KFold_ds(list_ds)    
# check_KFold_ds(train_ds_map_toe)
# Out:
# val_size= 2
# k = 0 k*val_size+val_size 2 k_train num= 8
# k = 1 k*val_size+val_size 4 k_train num= 8
# k = 2 k*val_size+val_size 6 k_train num= 8
# k = 3 k*val_size+val_size 8 k_train num= 8
# k = 4 k*val_size+val_size 10 k_train num= 8

# %%
# x = tf.data.Dataset.range(10)
# val_size = int(tf.data.experimental.cardinality(x).numpy() * 0.2)
# print("val_size=", val_size)

def get_KFold_ds(x, K=0):
        
    k = K
    # may skip twicce to perform kflod
    # train ds
    t_take = x.take(k*val_size)
    t_skip = x.skip(k*val_size+val_size)
    k_train = t_take.concatenate(t_skip)
    # val ds
    v_skip = x.skip(k*val_size)
    k_valid = v_skip.take(val_size)

    return k_train, k_valid

# %%
val_size = int(tf.data.experimental.cardinality(train_ds_map_toe).numpy() * 0.2)
t, v = get_KFold_ds(train_ds_map_toe, 1)

print(tf.data.experimental.cardinality(t).numpy())
print(tf.data.experimental.cardinality(v).numpy())

# for n in v:
#     print(n.numpy())
# Out:
# 1076
# 269

# %%
train_ds_map_toe
# Out:
# <ParallelMapDataset shapes: ((120, 120, 3), (2,)), types: (tf.uint8, tf.int64)>

# %%
v
# Out:
# <TakeDataset shapes: ((120, 120, 3), (2,)), types: (tf.uint8, tf.int64)>

# %% [markdown]
# # Albumentation pipeline

# %%
# # for NO keypoint augment
# transforms = A.Compose([
# #             A.RandomBrightness(limit=0.1, p=0.5),
#             A.JpegCompression(quality_lower=65, quality_upper=100, p=0.5),#A.JpegCompression(quality_lower=85, quality_upper=100, p=0.5)
#             A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
# #             A.RandomContrast(limit=0.2, p=0.5),
#             A.FancyPCA(alpha=0.1, always_apply=False, p=1),#A.FancyPCA(alpha=0.1, always_apply=False, p=0.5)
#             A.Downscale(scale_min=0.7, scale_max=0.9, interpolation=0, always_apply=False, p=0.5), #0.8~0.99 may better
#             A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, always_apply=False, p=0.5),
#             A.CLAHE(clip_limit=(1, 8), tile_grid_size=(8, 8), always_apply=False, p=0.5), #A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), always_apply=False, p=0.5)
# #             A.GlassBlur(sigma=0.9, max_delta=2, iterations=2, always_apply=False, mode='fast', p=0.5),
# #             A.GaussNoise(var_limit=(10.0, 50.0), mean=0, always_apply=False, p=0.5),
# #             A.GaussianBlur(blur_limit=(3, 7), sigma_limit=0, always_apply=False, p=0.5),
# #             A.HorizontalFlip(),
    
#             # try other augm, seems to strong...
#             A.RandomBrightnessContrast(always_apply=False, p=0.5, brightness_limit=(-0.2, 0.2), contrast_limit=(-0.2, 0.2), brightness_by_max=True),
#             A.Equalize(always_apply=False, p=0.5, mode='cv', by_channels=True),
#             A.MultiplicativeNoise(always_apply=False, p=0.5, multiplier=(0.8, 1.5), per_channel=False, elementwise=False),
#             A.RandomFog(always_apply=False, p=0.5, fog_coef_lower=0.2, fog_coef_upper=0.3, alpha_coef=0.25),

# ])


# def aug_fn(image, img_size):
#     data = {"image":image}
#     aug_data = transforms(**data)
#     aug_img = aug_data["image"]
# #     aug_img = tf.cast(aug_img/255.0, tf.float32)
#     aug_img = tf.cast(aug_img, tf.float32)
#     aug_img = tf.image.resize(aug_img, size=[img_size, img_size])
#     return aug_img

# def process_data(image, label, img_size):
#     aug_img = tf.numpy_function(func=aug_fn, inp=[image, img_size], Tout=tf.float32)
#     return aug_img, label

# def set_shapes(img, label, img_shape=(120,120,3)):
#     img.set_shape(img_shape)
# #     label.set_shape([]) # commited for go around error
#     return img, label





# # for NO keypoint augment AND for OneOf[] for better heel loss.
# transforms_oneof = A.Compose(A.OneOf([
#             A.RandomBrightness(limit=0.1, p=0.5),
#             A.JpegCompression(quality_lower=85, quality_upper=100, p=0.5),
#             A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
#             A.RandomContrast(limit=0.2, p=0.5),
#             A.FancyPCA(alpha=0.1, always_apply=False, p=0.5),
#             A.Downscale(scale_min=0.7, scale_max=0.9, interpolation=0, always_apply=False, p=0.5),
#             A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, always_apply=False, p=0.5),
#             A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), always_apply=False, p=0.5),
#             A.GlassBlur(sigma=0.9, max_delta=2, iterations=2, always_apply=False, mode='fast', p=0.5),
#             A.GaussNoise(var_limit=(10.0, 50.0), mean=0, always_apply=False, p=0.5),
#             A.GaussianBlur(blur_limit=(3, 7), sigma_limit=0, always_apply=False, p=.5)
# #             A.HorizontalFlip(),
#             ]),p=0.5)


# def aug_fn_oneof(image, img_size):
#     data = {"image":image}
#     aug_data = transforms_oneof(**data)
#     aug_img = aug_data["image"]
# #     aug_img = tf.cast(aug_img/255.0, tf.float32)
#     aug_img = tf.cast(aug_img, tf.float32)
#     aug_img = tf.image.resize(aug_img, size=[img_size, img_size])
#     return aug_img

# def process_data_oneof(image, label, img_size):
#     aug_img = tf.numpy_function(func=aug_fn_oneof, inp=[image, img_size], Tout=tf.float32)
#     return aug_img, label




# # Testing keypoints augment
# transforms = A.Compose([
#             A.RandomBrightness(limit=0.1, p=0.5),
#             A.JpegCompression(quality_lower=85, quality_upper=100, p=0.5),
#             A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
#             A.RandomContrast(limit=0.2, p=0.5),
#             A.FancyPCA (alpha=0.1, always_apply=False, p=1),
#             A.Downscale (scale_min=0.7, scale_max=0.9, interpolation=0, always_apply=False, p=0.5),
#             A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, always_apply=False, p=0.5),
#             A.CLAHE (clip_limit=4.0, tile_grid_size=(8, 8), always_apply=False, p=0.5),
#             A.HorizontalFlip(p=0.5),
#             ]
#             , 
#             keypoint_params=A.KeypointParams(format='xy'),  #currently not works for tf.ds yet.
#             )





# Testing keypoints augment
transforms = A.Compose([
            A.RandomBrightness(limit=0.1, p=0.2),
            A.JpegCompression(quality_lower=85, quality_upper=100, p=0.2),
            A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.2),
            A.RandomContrast(limit=0.2, p=0.2),
            A.FancyPCA(alpha=0.1, always_apply=False, p=1.0),
            A.Downscale(scale_min=0.7, scale_max=0.9, interpolation=0, always_apply=False, p=0.2),
            A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, always_apply=False, p=0.2),
            A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), always_apply=False, p=0.2),
    
            A.HorizontalFlip(p=0.2),
            A.RandomResizedCrop(always_apply=False, height=120, width=120, scale=(0.9, 0.99), ratio=(1.0, 1.0), interpolation=0, p=0.2),#xy become double need change dtype of label. # pp will outside the image.
            A.IAAAffine(scale=0.9, translate_percent=None, translate_px=None, rotate=0.0, shear=0.0, order=1, cval=0, mode='reflect', always_apply=False, p=0.2),
#             A.ShiftScaleRotate(always_apply=False, p=0.5, shift_limit=(0.06, 0.06), scale_limit=(-0.1, 0.1), rotate_limit=(-5, 5), interpolation=1, border_mode=2, value=(0, 0, 0), mask_value=None),
    #2021-02-26
#             A.IAAPerspective(scale=(0.05, 0.1), keep_size=True, always_apply=False, p=0.5),#fallout image make train stop. NOT support keypoints!!!!!
            ]
            , 
            keypoint_params=A.KeypointParams(format='xy',remove_invisible=True),  #currently not works for tf.ds yet.
            )

# Testing keypoints augment
# @tf.function
def aug_fn(image, keypoints, img_size):
#     print('Check keypoints aug_fun 00:', keypoints) # Check keypoints aug_fun 00: [[53 58]]
#     data = {"image":image}
    aug_data = transforms(image=image, keypoints=keypoints)
    aug_img = aug_data["image"]
    aug_xy  = aug_data["keypoints"]
#     aug_img = tf.cast(aug_img/255.0, tf.float32)
    aug_img = tf.cast(aug_img, tf.float32)
    aug_img = tf.image.resize(aug_img, size=[img_size, img_size])
    
    aug_xy = tf.cast(aug_xy, tf.float32) #有些變形輸出是double
#     print('Check aug_xy:', aug_xy) # Check aug_xy: [(95, 45)] #印到這邊都是對的
    return aug_img, aug_xy 

# @tf.function
def process_data(image, keypoints, img_size):
    
    print('Check keypoints process01:', keypoints, np.shape(keypoints), type(keypoints))
        
#     keypoints = tf.make_ndarray(keypoints)
#     keypoints = np.array(keypoints)
#     keypoints = list(keypoints)
#     keypoints = np.asarray(keypoints, dtype=np.float32)
#     keypoints = tf.make_ndarray(keypoints.op.get_attr('value'))

#     keypoints = tf.reshape(keypoints, [1, 2])
    keypoints = tf.reshape(keypoints, [1, 2]) # for 'convert_keypoint_to_albumentations'
#     keypoints = np.reshape(keypoints, (1, 2))#not support tensor with np.call.

    print('Check keypoints process02:', keypoints, np.shape(keypoints), type(keypoints))

#     aug_img, aug_xy = tf.numpy_function(func=aug_fn, inp=[image, img_size], Tout=tf.float32)
#     aug_img, aug_xy = tf.py_function(func=aug_fn, inp=[image, keypoints, img_size], Tout=[tf.float32, tf.int64])#for tensors.
    aug_img, aug_xy = tf.numpy_function(func=aug_fn, inp=[image, keypoints, img_size], Tout=[tf.float32, tf.float32])
    print('Check keypoints process03:', aug_xy)
    
    aug_xy = tf.reshape(aug_xy, [2,]) # for 'tf ds tarining'
    print('Check keypoints process04:', aug_xy)
        
    return aug_img, aug_xy 








###  for AToe ###
# some pp will outside of image bcs p2 is close to 400.



# Testing keypoints augment
transforms_AToe = A.Compose([
#             A.RandomBrightness(limit=0.1, p=0.5),
#             A.JpegCompression(quality_lower=85, quality_upper=100, p=0.5),
#             A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
#             A.RandomContrast(limit=0.2, p=0.5),
#             A.FancyPCA(alpha=0.1, always_apply=False, p=0.5),
#             A.Downscale(scale_min=0.7, scale_max=0.9, interpolation=0, always_apply=False, p=0.5),
#             A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, always_apply=False, p=0.5),
#             A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), always_apply=False, p=0.5),
    
#             A.RandomBrightness(limit=0.1, p=0.5),
            A.JpegCompression(quality_lower=65, quality_upper=100, p=0.2),#A.JpegCompression(quality_lower=85, quality_upper=100, p=0.5)
            A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.2),
#             A.RandomContrast(limit=0.2, p=0.5),
            A.FancyPCA(alpha=0.1, always_apply=False, p=1),#A.FancyPCA(alpha=0.1, always_apply=False, p=0.5)
            A.Downscale(scale_min=0.7, scale_max=0.9, interpolation=0, always_apply=False, p=0.2), #0.8~0.99 may better
            A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, always_apply=False, p=0.2),
            A.CLAHE(clip_limit=(1, 8), tile_grid_size=(8, 8), always_apply=False, p=0.2), #A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), always_apply=False, p=0.5)
    
            A.HorizontalFlip(p=0.2),
#             A.RandomResizedCrop(always_apply=False, height=120, width=120, scale=(0.75, 0.9), ratio=(1.0, 1.0), interpolation=0, p=0.5),#xy become double need change dtype of label. # pp will outside the image.
            A.IAAAffine (scale=0.9, translate_percent=None, translate_px=None, rotate=0.0, shear=0.0, order=1, cval=0, mode='reflect', always_apply=False, p=0.5),
#             A.ShiftScaleRotate(always_apply=False, p=0.5, shift_limit=(0.06, 0.06), scale_limit=(-0.1, 0.1), rotate_limit=(-5, 5), interpolation=1, border_mode=2, value=(0, 0, 0), mask_value=None),
            ]
            , 
            keypoint_params=A.KeypointParams(format='xy',remove_invisible=True),  #currently not works for tf.ds yet.
            )


# Testing keypoints augment
# @tf.function
def aug_fn_AToe(image, keypoints, img_size):
#     print('Check keypoints aug_fun 00:', keypoints) # Check keypoints aug_fun 00: [[53 58]]
#     data = {"image":image}
    aug_data = transforms_AToe(image=image, keypoints=keypoints)
    aug_img = aug_data["image"]
    aug_xy  = aug_data["keypoints"]
#     aug_img = tf.cast(aug_img/255.0, tf.float32)
    aug_img = tf.cast(aug_img, tf.float32)
    aug_img = tf.image.resize(aug_img, size=[img_size, img_size])
    
    aug_xy = tf.cast(aug_xy, tf.float32) #有些變形輸出是double
#     print('Check aug_xy:', aug_xy) # Check aug_xy: [(95, 45)] #印到這邊都是對的
    return aug_img, aug_xy 

# @tf.function
def process_data_AToe(image, keypoints, img_size):
    
    print('Check keypoints process01:', keypoints, np.shape(keypoints), type(keypoints))
        
#     keypoints = tf.make_ndarray(keypoints)
#     keypoints = np.array(keypoints)
#     keypoints = list(keypoints)
#     keypoints = np.asarray(keypoints, dtype=np.float32)
#     keypoints = tf.make_ndarray(keypoints.op.get_attr('value'))

#     keypoints = tf.reshape(keypoints, [1, 2])
    keypoints = tf.reshape(keypoints, [1, 2]) # for 'convert_keypoint_to_albumentations'
#     keypoints = np.reshape(keypoints, (1, 2))#not support tensor with np.call.

    print('Check keypoints process02:', keypoints, np.shape(keypoints), type(keypoints))

#     aug_img, aug_xy = tf.numpy_function(func=aug_fn, inp=[image, img_size], Tout=tf.float32)
#     aug_img, aug_xy = tf.py_function(func=aug_fn, inp=[image, keypoints, img_size], Tout=[tf.float32, tf.int64])#for tensors.
    aug_img, aug_xy = tf.numpy_function(func=aug_fn_AToe, inp=[image, keypoints, img_size], Tout=[tf.float32, tf.float32])
    print('Check keypoints process03:', aug_xy)
    
    aug_xy = tf.reshape(aug_xy, [2,]) # for 'tf ds tarining'
    print('Check keypoints process04:', aug_xy)
        
    return aug_img, aug_xy 




def set_shapes(img, label, img_shape=(120,120,3)):
    img.set_shape(img_shape)
#     label.set_shape([]) # commited for go around error
    return img, label

# %% [markdown]
# #### prepare train_ds_prefetch

# %%
def configure_for_performance_cache_train(ds, cache=True, augment=False):

    
    """#TODO: need to check the parse logic of ds.cache.
    if cache:
        print("Check cache-f1 to file:", cache)
        if isinstance(cache, str):
            ds = ds.cache(cache)
            print("Check cache-f2 to file:", cache)
    else:
        ds = ds.cache()
        print("Check cache in memory:", cache)
    """    
    if cache:
        ds = ds.cache()
        print("Check cache in memory:Y", cache)
    else:
        print("Check cache in memory:N", cache)
        
    if augment:
        ds = ds.map(partial(process_data, img_size=120),num_parallel_calls=AUTOTUNE)
        ds = ds.map(set_shapes, num_parallel_calls=AUTOTUNE)
        print("Check augment :Y", augment)
    else:
        print("Check augment :N", augment)
    
    #ds = ds.repeat()#TODO:2020-12-14: test
    #ds = ds.shuffle(buffer_size=MULTI_BATCH_SIZE*2) # (buffer_size=MULTI_BATCH_SIZE*5) 6sec,buffer_size=1000 take few sec. or buffer_size=image_count <- take too long # each take ds take 30~45 sec, TODO!!
    ds = ds.shuffle(len(list_ds), reshuffle_each_iteration=True) #todo: move to ds_pre. see https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle
    ds = ds.batch(MULTI_BATCH_SIZE)#MULTI_BATCH_SIZE for multi-GPUs
    ds = ds.prefetch(buffer_size=AUTOTUNE) #buffer_size=AUTOTUNE seem no speed improve
    
    print("Check ds cache[{}] and augment[{}]".format(cache, augment))
    
    return ds


def configure_for_performance_cache_train_AToe(ds, cache=True, augment=False):

    
    """#TODO: need to check the parse logic of ds.cache.
    if cache:
        print("Check cache-f1 to file:", cache)
        if isinstance(cache, str):
            ds = ds.cache(cache)
            print("Check cache-f2 to file:", cache)
    else:
        ds = ds.cache()
        print("Check cache in memory:", cache)
    """    
    if cache:
        ds = ds.cache()
        print("Check cache in memory:Y", cache)
    else:
        print("Check cache in memory:N", cache)
        
    if augment:
        ds = ds.map(partial(process_data_AToe, img_size=120),num_parallel_calls=AUTOTUNE)
        ds = ds.map(set_shapes, num_parallel_calls=AUTOTUNE)
        print("Check augment :Y", augment)
    else:
        print("Check augment :N", augment)
    
    #ds = ds.repeat()#TODO:2020-12-14: test
    #ds = ds.shuffle(buffer_size=MULTI_BATCH_SIZE*2) # (buffer_size=MULTI_BATCH_SIZE*5) 6sec,buffer_size=1000 take few sec. or buffer_size=image_count <- take too long # each take ds take 30~45 sec, TODO!!
    ds = ds.shuffle(len(list_ds), reshuffle_each_iteration=True) #todo: move to ds_pre. see https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle
    ds = ds.batch(MULTI_BATCH_SIZE)#MULTI_BATCH_SIZE for multi-GPUs
    ds = ds.prefetch(buffer_size=AUTOTUNE) #buffer_size=AUTOTUNE seem no speed improve
    
    print("Check ds cache[{}] and augment[{}]".format(cache, augment))
    
    return ds





# def configure_for_performance_cache_train_oneof(ds, cache=True, augment=False):

    
#     """#TODO: need to check the parse logic of ds.cache.
#     if cache:
#         print("Check cache-f1 to file:", cache)
#         if isinstance(cache, str):
#             ds = ds.cache(cache)
#             print("Check cache-f2 to file:", cache)
#     else:
#         ds = ds.cache()
#         print("Check cache in memory:", cache)
#     """    
#     if cache:
#         ds = ds.cache()
#         print("Check cache in memory:Y", cache)
#     else:
#         print("Check cache in memory:N", cache)
        
#     if augment:
#         ds = ds.map(partial(process_data_oneof, img_size=120),num_parallel_calls=AUTOTUNE)
#         ds = ds.map(set_shapes, num_parallel_calls=AUTOTUNE)
#         print("Check augment :Y", augment)
#     else:
#         print("Check augment :N", augment)
    
#     #ds = ds.repeat()#TODO:2020-12-14: test
#     #ds = ds.shuffle(buffer_size=MULTI_BATCH_SIZE*2) # (buffer_size=MULTI_BATCH_SIZE*5) 6sec,buffer_size=1000 take few sec. or buffer_size=image_count <- take too long # each take ds take 30~45 sec, TODO!!
#     ds = ds.shuffle(len(list_ds), reshuffle_each_iteration=True) #todo: move to ds_pre. see https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle
#     ds = ds.batch(MULTI_BATCH_SIZE)#MULTI_BATCH_SIZE for multi-GPUs
#     ds = ds.prefetch(buffer_size=AUTOTUNE) #buffer_size=AUTOTUNE seem no speed improve
    
#     print("Check ds cache[{}] and augment[{}]".format(cache, augment))
    
#     return ds




def configure_for_performance_cache_val(ds, cache=True, augment=False):

    
    """#TODO: need to check the parse logic of ds.cache
    TODO:test remove ds.shuffle from val_ds.
    .
    if cache:
        print("Check cache-f1 to file:", cache)
        if isinstance(cache, str):
            ds = ds.cache(cache)
            print("Check cache-f2 to file:", cache)
    else:
        ds = ds.cache()
        print("Check cache in memory:", cache)
    """    
    if cache:
        ds = ds.cache()
        print("Check cache in memory:Y", cache)
    else:
        print("Check cache in memory:N", cache)
        
    if augment:
#         ds = ds.map(data_augment, num_parallel_calls=AUTOTUNE)
        ds = ds.map(AA, num_parallel_calls=AUTOTUNE)
#         ds = ds.map(RA, num_parallel_calls=AUTOTUNE)
        print("Check augment :Y", augment)
    else:
        print("Check augment :N", augment)
    
    #ds = ds.repeat()#TODO:2020-12-14: test
    #ds = ds.shuffle(buffer_size=MULTI_BATCH_SIZE*2) # (buffer_size=MULTI_BATCH_SIZE*5) 6sec,buffer_size=1000 take few sec. or buffer_size=image_count <- take too long # each take ds take 30~45 sec, TODO!!
#     ds = ds.shuffle(len(list_ds), reshuffle_each_iteration=False) #todo: move to ds_pre. see https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle
    ds = ds.batch(MULTI_BATCH_SIZE)#MULTI_BATCH_SIZE for multi-GPUs
    ds = ds.prefetch(buffer_size=AUTOTUNE) #buffer_size=AUTOTUNE seem no speed improve
    
    print("Check ds cache[{}] and augment[{}]".format(cache, augment))
    
    return ds

# %%
# """
# Prepare the ds properties (cache, augment, bs, shuffle, prefetch, etc.) for better performance.
# """
# # Toe ds_pre
# train_ds_pre_toe = configure_for_performance_cache_train(train_ds_map_toe)

# # Heel ds_pre
# train_ds_pre_heel = configure_for_performance_cache_val(train_ds_map_heel)

# %% [markdown]
# #### All split ds_prefetch
# * train_ds_map_toe_s = train_ds_map_toe.skip(val_size)
# * valid_ds_map_toe_s = train_ds_map_toe.take(val_size)
#
# * train_ds_map_heel_s = train_ds_map_heel.skip(val_size)
# * valid_ds_map_heel_s = train_ds_map_heel.take(val_size)

# %%
# """
# Prepare the ds properties (cache, augment, bs, shuffle, prefetch, etc.) for better performance.
# """
# # Toe ds_pre
# train_ds_pre_toe_s = configure_for_performance_cache_train(train_ds_map_toe_s, augment=True)
# valid_ds_pre_toe_s = configure_for_performance_cache_val(valid_ds_map_toe_s)

# # Heel ds_pre
# train_ds_pre_heel_s = configure_for_performance_cache_train(train_ds_map_heel_s, augment=True)
# valid_ds_pre_heel_s = configure_for_performance_cache_val(valid_ds_map_heel_s)

# %% [markdown]
# #### Check ds_prefetch samples

# %%
# # create it_ds once
# it_train_ds_pre_toe_s = iter(train_ds_pre_toe_s)

# %%
# %%time

# # for albu keypoint

# # for original return aug_img, , aug_xy 


# image_batch, label_batch = next(it_train_ds_pre_toe_s)

# fig = plt.figure(figsize=(8, 8))
# print('batch * multi:', len(label_batch), ', MULTI_BATCH_SIZE=', MULTI_BATCH_SIZE)
# for i in range(16):
#     ax = plt.subplot(4, 4, i + 1)
#     plt.imshow(image_batch[i].numpy().astype("uint8"))
#     plt.title(label_batch[i].numpy())
#     plt.axis("off")

#     plt.plot(label_batch[i].numpy()[0], label_batch[i].numpy()[1], 'r+', markersize=13, mew=2.5)

#     print(f'Check lables: {label_batch[i]}')

# %%
# # create it_ds once
# it_train_ds_pre_heel_s = iter(train_ds_pre_heel_s)

# %%
# %%time

# # for albu keypoint

# # for original return aug_img, , aug_xy 


# image_batch, label_batch = next(it_train_ds_pre_heel_s)

# fig = plt.figure(figsize=(8, 8))
# print('batch * multi:', len(label_batch), ', MULTI_BATCH_SIZE=', MULTI_BATCH_SIZE)
# for i in range(16):
#     ax = plt.subplot(4, 4, i + 1)
#     plt.imshow(image_batch[i].numpy().astype("uint8"))
#     plt.title(label_batch[i].numpy())
#     plt.axis("off")

#     plt.plot(label_batch[i].numpy()[0], label_batch[i].numpy()[1], 'r+', markersize=13, mew=2.5)

#     print(f'Check lables: {label_batch[i]}')

# %%
# # create it_ds once
# it_valid_ds_pre_toe_s = iter(valid_ds_pre_toe_s)

# %%
# %%time

# # for albu keypoint

# # for return aug_img, aug_xy 


# image_batch, label_batch = next(it_valid_ds_pre_toe_s)

# plt.figure(figsize=(8, 8))
# # for images, labels in valid_ds_pre_toe_s.take(1):
# print('batch * multi:', len(label_batch), ', MULTI_BATCH_SIZE=', MULTI_BATCH_SIZE)
# for i in range(16):
#     ax = plt.subplot(4, 4, i + 1)
#     plt.imshow(image_batch[i].numpy().astype("uint8"))
#     plt.title(label_batch[i].numpy())
#     plt.axis("off")

#     plt.plot(label_batch[i].numpy()[0], label_batch[i].numpy()[1], 'r+', markersize=13, mew=2.5)

#     print(f'Check lables: {label_batch[i]}')

# %% [markdown]
# ### 3.Loss function
#
# * mae
# * euclidean distance
# * others
#
#
#         # 'x' is [[1, 1, 1]
#         #         [1, 1, 1]]
#         tf.reduce_sum(x) ==> 6
#         tf.reduce_sum(x, 0) ==> [2, 2, 2]
#         tf.reduce_sum(x, 1) ==> [3, 3]
#         the function is default for 2-D array, therefor, in our 1-D [x1,y1] to [x2,y2] the axis should be '0' or just leave it.
#
#         tf.sqrt need 	A tf.Tensor of type bfloat16, half, float32, float64, complex64, complex128
#         so, convert it first.

# %% [markdown]
# should be -> tf.Tensor([56 39], shape=(2,), dtype=int64)

# %%
y_true = [10, 10]
y_pred = [10, 20]

# y_true = [1.00000000000000000000123, 10]
# y_pred = [1.0, 10.000000000000000000000000001]

# y_true = [1.0000123, 10]
# y_pred = [1.0, 10.0000321]

# %%
# mae

loss_mae = tf.keras.losses.MAE(
    y_true, y_pred
)

loss_mae
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=5>

# %%
# ed

# loss_ed = tf.sqrt(tf.reduce_sum(tf.square(tf.constant(y_true) - tf.constant(y_pred)), 0))

# loss_ed = tf.sqrt(tf.reduce_sum(tf.square(tf.Variable(y_true) - tf.Variable(y_pred)), 0))

loss_ed = tf.sqrt(tf.reduce_sum(tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32)), 0))

loss_ed
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=10.0>

# %%
def ed_loss(y_true, y_pred):
    return tf.sqrt(tf.reduce_sum(tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32)), 0))

# fix NaN in euclidean distance
# tf.maximum(d, 1e-9), to keep atlease is 1e-9.
# def ed_loss(y_true, y_pred):
#     return tf.sqrt(tf.maximum(tf.reduce_sum(tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32)), 0), 1e-9))

# %%
# check the euclidean distance loss
ed_loss(y_true, y_pred).numpy()
# Out:
# 10.0

# %%
ed_loss(y_true, y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=10.0>

# %% [markdown]
# #### mean Euclidean distance
#
# * here the y_true and y_pred is 2-D array. the axis use 1.
#
#
# * NOTE: LB評分的mean euclidean distance功能，應該跟model.evaluate()一樣so不需重新寫。evaluate()會自動用loss (model.metrics_names)計算後在自動平均，而模型loss我們是用ed-loss取代。

# %%
# y_true = [[60, 76],
#        [58, 49 ],
#        [63, 67 ],
#        [58 , 57]]
# y_pred = [[59.927303, 76.471214],
#        [58.056904, 49.98754 ],
#        [63.067844, 67.03861 ],
#        [58.70202 , 57.372707]]

y_true = [[60, 70],
       [70, 80]]
y_pred = [[61, 71],
       [72, 82]]

# y_true = [(60, 70),
#        (70, 80)]
# y_pred = [(61, 71),
#        (72, 82)]

# %%
tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32))
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[1., 1.],
#        [4., 4.]], dtype=float32)>

# %%
tf.reduce_sum(tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32)), 1)
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([2., 8.], dtype=float32)>

# %%
def ed_metric_2d(y_true, y_pred):
    return tf.sqrt(tf.reduce_sum(tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32)), 1))

# %%
ed_metric_2d(y_true, y_pred).numpy()
# Out:
# array([1.4142135, 2.828427 ], dtype=float32)

# %%
ed_metric_2d(y_true, y_pred)
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([1.4142135, 2.828427 ], dtype=float32)>

# %%
# 等於true, pred點位ed的平均，LB評分方式。(toe/heel即p1,p2要個別算ed一次再相加)
def ed_metric_2d_mean(y_true, y_pred):
    return tf.reduce_mean(tf.sqrt(tf.reduce_sum(tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32)), 1)))

# %%
# for re-scale back xy 
# return img, [(x1-60)/60,((y1-y_offset_toe)-60)/60]#normalized [-1,1] 
# return img, [(x2-60)/60,((y2-y_offset_toe)-60)/60]#normalized [-1,1] 

# 等於true, pred點位ed的平均，LB評分方式。(toe/heel即p1,p2要個別算ed一次再相加)
def edRescal(y_true, y_pred):
    return tf.reduce_mean(tf.sqrt(tf.reduce_sum(tf.square(tf.cast((y_true*60)+60, tf.float32) - tf.cast((y_pred*60)+60, tf.float32)), 1)))

# %%
ed_metric_2d_mean(y_true, y_pred).numpy()
# Out:
# 2.1213202

# %%
ed_metric_2d_mean(y_true, y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=2.1213202>

# %% [markdown]
# # EFNE Training

# %% [markdown]
# maybe mae better than ed loss?

# %%
"""dump lr
"""
ep_num_transf = 500



def lrdump(epoch):
    
    #step_size = 100
    lr_max = 0.006
    lr_min = 0.001
    lr_start = 0.01

    lr_init_ep = 0
    lr_ramp_ep = 100
    lr_sus_ep  = 0
    lr_decay   = 0.8

    
    # warm up
    if epoch < lr_init_ep:
        lr = (lr_max - lr_min) / lr_ramp_ep * epoch + lr_min    
        
    elif lr_init_ep -1 < epoch < lr_ramp_ep:
        lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start

    elif epoch < lr_ramp_ep + lr_sus_ep:
        lr = lr_max

    else:
        lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min

    return lr

rng = [i for i in range(ep_num_transf)]
y = [lrdump(x) for x in rng]
sns.set(style='darkgrid')
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)

# %%
print('{} ~ {}'.format(min(y), max(y)))
# Out:
# 0.001 ~ 0.01

# %%
for e, lr in zip(rng,y):
    print('{}\t {}\n'.format(e, lr))
# Out:
# 0	 0.01
#
# 1	 0.00996
#
# 2	 0.00992
#
# 3	 0.00988
#
# 4	 0.00984
#
# 5	 0.0098
#
# 6	 0.00976
#
# 7	 0.00972
#
# 8	 0.00968
#
# 9	 0.009640000000000001
#
# 10	 0.009600000000000001
#
# 11	 0.00956
#
# 12	 0.00952
#
# 13	 0.00948
#
# 14	 0.00944
#
# 15	 0.0094
#
# 16	 0.00936
#
# 17	 0.00932
#
# 18	 0.00928
#
# 19	 0.00924
#
# 20	 0.0092
#
# 21	 0.00916
#
# 22	 0.00912
#
# 23	 0.00908
#
# 24	 0.00904
#
# 25	 0.009000000000000001
#
# 26	 0.00896
#
# 27	 0.00892
#
# 28	 0.00888
#
# 29	 0.00884
#
# 30	 0.0088
#
# 31	 0.00876
#
# 32	 0.00872
#
# 33	 0.00868
#
# 34	 0.00864
#
# 35	 0.0086
#
# 36	 0.00856
#
# 37	 0.00852
#
# 38	 0.00848
#
# 39	 0.00844
#
# 40	 0.0084
#
# 41	 0.00836
#
# 42	 0.008320000000000001
#
# 43	 0.00828
#
# 44	 0.00824
#
# 45	 0.0082
#
# 46	 0.00816
#
# 47	 0.00812
#
# 48	 0.00808
#
# 49	 0.00804
#
# 50	 0.008
#
# 51	 0.00796
#
# 52	 0.00792
#
# 53	 0.00788
#
# 54	 0.00784
#
# 55	 0.0078
#
# 56	 0.0077599999999999995
#
# 57	 0.007719999999999999
#
# 58	 0.00768
#
# 59	 0.00764
#
# 60	 0.0076
#
# 61	 0.00756
#
# 62	 0.007520000000000001
#
# 63	 0.0074800000000000005
#
# 64	 0.00744
#
# 65	 0.0074
#
# 66	 0.00736
#
# 67	 0.00732
#
# 68	 0.00728
#
# 69	 0.00724
#
# 70	 0.0072
#
# 71	 0.00716
#
# 72	 0.00712
#
# 73	 0.0070799999999999995
#
# 74	 0.007039999999999999
#
# 75	 0.007
#
# 76	 0.00696
#
# 77	 0.00692
#
# 78	 0.00688
#
# 79	 0.006840000000000001
#
# 80	 0.0068000000000000005
#
# 81	 0.00676
#
# 82	 0.00672
#
# 83	 0.00668
#
# 84	 0.00664
#
# 85	 0.0066
#
# 86	 0.00656
#
# 87	 0.00652
#
# 88	 0.00648
#
# 89	 0.0064399999999999995
#
# 90	 0.0063999999999999994
#
# 91	 0.006359999999999999
#
# 92	 0.00632
#
# 93	 0.00628
#
# 94	 0.00624
#
# 95	 0.0062
#
# 96	 0.00616
#
# 97	 0.0061200000000000004
#
# 98	 0.0060799999999999995
#
# 99	 0.00604
#
# 100	 0.006
#
# 101	 0.005
#
# 102	 0.004200000000000001
#
# 103	 0.0035600000000000007
#
# 104	 0.0030480000000000004
#
# 105	 0.0026384000000000004
#
# 106	 0.0023107200000000005
#
# 107	 0.0020485760000000007
#
# 108	 0.0018388608000000006
#
# 109	 0.0016710886400000003
#
# 110	 0.0015368709120000003
#
# 111	 0.0014294967296000004
#
# 112	 0.0013435973836800003
#
# 113	 0.0012748779069440002
#
# 114	 0.0012199023255552001
#
# 115	 0.0011759218604441603
#
# 116	 0.0011407374883553281
#
# 117	 0.0011125899906842625
#
# 118	 0.0010900719925474101
#
# 119	 0.001072057594037928
#
# 120	 0.0010576460752303425
#
# 121	 0.001046116860184274
#
# 122	 0.001036893488147419
#
# 123	 0.0010295147905179354
#
# 124	 0.0010236118324143482
#
# 125	 0.0010188894659314785
#
# 126	 0.0010151115727451828
#
# 127	 0.0010120892581961464
#
# 128	 0.001009671406556917
#
# 129	 0.0010077371252455336
#
# 130	 0.0010061897001964269
#
# 131	 0.0010049517601571415
#
# 132	 0.0010039614081257132
#
# 133	 0.0010031691265005706
#
# 134	 0.0010025353012004564
#
# 135	 0.0010020282409603652
#
# 136	 0.001001622592768292
#
# 137	 0.0010012980742146336
#
# 138	 0.001001038459371707
#
# 139	 0.0010008307674973657
#
# 140	 0.0010006646139978925
#
# 141	 0.001000531691198314
#
# 142	 0.0010004253529586511
#
# 143	 0.001000340282366921
#
# 144	 0.0010002722258935367
#
# 145	 0.0010002177807148294
#
# 146	 0.0010001742245718634
#
# 147	 0.001000139379657491
#
# 148	 0.0010001115037259927
#
# 149	 0.001000089202980794
#
# 150	 0.0010000713623846353
#
# 151	 0.0010000570899077082
#
# 152	 0.0010000456719261666
#
# 153	 0.0010000365375409334
#
# 154	 0.0010000292300327467
#
# 155	 0.0010000233840261974
#
# 156	 0.0010000187072209579
#
# 157	 0.0010000149657767663
#
# 158	 0.001000011972621413
#
# 159	 0.0010000095780971303
#
# 160	 0.0010000076624777044
#
# 161	 0.0010000061299821634
#
# 162	 0.0010000049039857308
#
# 163	 0.0010000039231885846
#
# 164	 0.0010000031385508678
#
# 165	 0.0010000025108406942
#
# 166	 0.0010000020086725553
#
# 167	 0.0010000016069380442
#
# 168	 0.0010000012855504354
#
# 169	 0.0010000010284403483
#
# 170	 0.0010000008227522787
#
# 171	 0.001000000658201823
#
# 172	 0.0010000005265614583
#
# 173	 0.0010000004212491666
#
# 174	 0.0010000003369993334
#
# 175	 0.0010000002695994667
#
# 176	 0.0010000002156795734
#
# 177	 0.0010000001725436586
#
# 178	 0.001000000138034927
#
# 179	 0.0010000001104279416
#
# 180	 0.0010000000883423532
#
# 181	 0.0010000000706738826
#
# 182	 0.001000000056539106
#
# 183	 0.0010000000452312849
#
# 184	 0.0010000000361850279
#
# 185	 0.0010000000289480224
#
# 186	 0.001000000023158418
#
# 187	 0.0010000000185267342
#
# 188	 0.0010000000148213874
#
# 189	 0.00100000001185711
#
# 190	 0.0010000000094856879
#
# 191	 0.0010000000075885505
#
# 192	 0.0010000000060708402
#
# 193	 0.0010000000048566722
#
# 194	 0.0010000000038853378
#
# 195	 0.0010000000031082702
#
# 196	 0.0010000000024866162
#
# 197	 0.0010000000019892929
#
# 198	 0.0010000000015914345
#
# 199	 0.0010000000012731474
#
# 200	 0.001000000001018518
#
# 201	 0.0010000000008148144
#
# 202	 0.0010000000006518516
#
# 203	 0.0010000000005214813
#
# 204	 0.001000000000417185
#
# 205	 0.001000000000333748
#
# 206	 0.0010000000002669985
#
# 207	 0.0010000000002135987
#
# 208	 0.001000000000170879
#
# 209	 0.0010000000001367032
#
# 210	 0.0010000000001093626
#
# 211	 0.0010000000000874901
#
# 212	 0.001000000000069992
#
# 213	 0.0010000000000559936
#
# 214	 0.001000000000044795
#
# 215	 0.001000000000035836
#
# 216	 0.0010000000000286687
#
# 217	 0.001000000000022935
#
# 218	 0.001000000000018348
#
# 219	 0.0010000000000146784
#
# 220	 0.0010000000000117428
#
# 221	 0.0010000000000093942
#
# 222	 0.0010000000000075153
#
# 223	 0.0010000000000060124
#
# 224	 0.0010000000000048098
#
# 225	 0.0010000000000038479
#
# 226	 0.0010000000000030783
#
# 227	 0.0010000000000024627
#
# 228	 0.00100000000000197
#
# 229	 0.001000000000001576
#
# 230	 0.001000000000001261
#
# 231	 0.0010000000000010088
#
# 232	 0.0010000000000008069
#
# 233	 0.0010000000000006456
#
# 234	 0.0010000000000005165
#
# 235	 0.001000000000000413
#
# 236	 0.0010000000000003305
#
# 237	 0.0010000000000002643
#
# 238	 0.0010000000000002117
#
# 239	 0.0010000000000001692
#
# 240	 0.0010000000000001353
#
# 241	 0.0010000000000001082
#
# 242	 0.0010000000000000868
#
# 243	 0.0010000000000000694
#
# 244	 0.0010000000000000555
#
# 245	 0.0010000000000000445
#
# 246	 0.0010000000000000356
#
# 247	 0.0010000000000000284
#
# 248	 0.0010000000000000228
#
# 249	 0.0010000000000000182
#
# 250	 0.0010000000000000145
#
# 251	 0.0010000000000000117
#
# 252	 0.0010000000000000093
#
# 253	 0.0010000000000000074
#
# 254	 0.0010000000000000059
#
# 255	 0.0010000000000000048
#
# 256	 0.001000000000000004
#
# 257	 0.001000000000000003
#
# 258	 0.0010000000000000024
#
# 259	 0.001000000000000002
#
# 260	 0.0010000000000000015
#
# 261	 0.0010000000000000013
#
# 262	 0.001000000000000001
#
# 263	 0.0010000000000000009
#
# 264	 0.0010000000000000007
#
# 265	 0.0010000000000000005
#
# 266	 0.0010000000000000005
#
# 267	 0.0010000000000000005
#
# 268	 0.0010000000000000002
#
# 269	 0.0010000000000000002
#
# 270	 0.0010000000000000002
#
# 271	 0.0010000000000000002
#
# 272	 0.001
#
# 273	 0.001
#
# 274	 0.001
#
# 275	 0.001
#
# 276	 0.001
#
# 277	 0.001
#
# 278	 0.001
#
# 279	 0.001
#
# 280	 0.001
#
# 281	 0.001
#
# 282	 0.001
#
# 283	 0.001
#
# 284	 0.001
#
# 285	 0.001
#
# 286	 0.001
#
# 287	 0.001
#
# 288	 0.001
#
# 289	 0.001
#
# 290	 0.001
#
# 291	 0.001
#
# 292	 0.001
#
# 293	 0.001
#
# 294	 0.001
#
# 295	 0.001
#
# 296	 0.001
#
# 297	 0.001
#
# 298	 0.001
#
# 299	 0.001
#
# 300	 0.001
#
# 301	 0.001
#
# 302	 0.001
#
# 303	 0.001
#
# 304	 0.001
#
# 305	 0.001
#
# 306	 0.001
#
# 307	 0.001
#
# 308	 0.001
#
# 309	 0.001
#
# 310	 0.001
#
# 311	 0.001
#
# 312	 0.001
#
# 313	 0.001
#
# 314	 0.001
#
# 315	 0.001
#
# 316	 0.001
#
# 317	 0.001
#
# 318	 0.001
#
# 319	 0.001
#
# 320	 0.001
#
# 321	 0.001
#
# 322	 0.001
#
# 323	 0.001
#
# 324	 0.001
#
# 325	 0.001
#
# 326	 0.001
#
# 327	 0.001
#
# 328	 0.001
#
# 329	 0.001
#
# 330	 0.001
#
# 331	 0.001
#
# 332	 0.001
#
# 333	 0.001
#
# 334	 0.001
#
# 335	 0.001
#
# 336	 0.001
#
# 337	 0.001
#
# 338	 0.001
#
# 339	 0.001
#
# 340	 0.001
#
# 341	 0.001
#
# 342	 0.001
#
# 343	 0.001
#
# 344	 0.001
#
# 345	 0.001
#
# 346	 0.001
#
# 347	 0.001
#
# 348	 0.001
#
# 349	 0.001
#
# 350	 0.001
#
# 351	 0.001
#
# 352	 0.001
#
# 353	 0.001
#
# 354	 0.001
#
# 355	 0.001
#
# 356	 0.001
#
# 357	 0.001
#
# 358	 0.001
#
# 359	 0.001
#
# 360	 0.001
#
# 361	 0.001
#
# 362	 0.001
#
# 363	 0.001
#
# 364	 0.001
#
# 365	 0.001
#
# 366	 0.001
#
# 367	 0.001
#
# 368	 0.001
#
# 369	 0.001
#
# 370	 0.001
#
# 371	 0.001
#
# 372	 0.001
#
# 373	 0.001
#
# 374	 0.001
#
# 375	 0.001
#
# 376	 0.001
#
# 377	 0.001
#
# 378	 0.001
#
# 379	 0.001
#
# 380	 0.001
#
# 381	 0.001
#
# 382	 0.001
#
# 383	 0.001
#
# 384	 0.001
#
# 385	 0.001
#
# 386	 0.001
#
# 387	 0.001
#
# 388	 0.001
#
# 389	 0.001
#
# 390	 0.001
#
# 391	 0.001
#
# 392	 0.001
#
# 393	 0.001
#
# 394	 0.001
#
# 395	 0.001
#
# 396	 0.001
#
# 397	 0.001
#
# 398	 0.001
#
# 399	 0.001
#
# 400	 0.001
#
# 401	 0.001
#
# 402	 0.001
#
# 403	 0.001
#
# 404	 0.001
#
# 405	 0.001
#
# 406	 0.001
#
# 407	 0.001
#
# 408	 0.001
#
# 409	 0.001
#
# 410	 0.001
#
# 411	 0.001
#
# 412	 0.001
#
# 413	 0.001
#
# 414	 0.001
#
# 415	 0.001
#
# 416	 0.001
#
# 417	 0.001
#
# 418	 0.001
#
# 419	 0.001
#
# 420	 0.001
#
# 421	 0.001
#
# 422	 0.001
#
# 423	 0.001
#
# 424	 0.001
#
# 425	 0.001
#
# 426	 0.001
#
# 427	 0.001
#
# 428	 0.001
#
# 429	 0.001
#
# 430	 0.001
#
# 431	 0.001
#
# 432	 0.001
#
# 433	 0.001
#
# 434	 0.001
#
# 435	 0.001
#
# 436	 0.001
#
# 437	 0.001
#
# 438	 0.001
#
# 439	 0.001
#
# 440	 0.001
#
# 441	 0.001
#
# 442	 0.001
#
# 443	 0.001
#
# 444	 0.001
#
# 445	 0.001
#
# 446	 0.001
#
# 447	 0.001
#
# 448	 0.001
#
# 449	 0.001
#
# 450	 0.001
#
# 451	 0.001
#
# 452	 0.001
#
# 453	 0.001
#
# 454	 0.001
#
# 455	 0.001
#
# 456	 0.001
#
# 457	 0.001
#
# 458	 0.001
#
# 459	 0.001
#
# 460	 0.001
#
# 461	 0.001
#
# 462	 0.001
#
# 463	 0.001
#
# 464	 0.001
#
# 465	 0.001
#
# 466	 0.001
#
# 467	 0.001
#
# 468	 0.001
#
# 469	 0.001
#
# 470	 0.001
#
# 471	 0.001
#
# 472	 0.001
#
# 473	 0.001
#
# 474	 0.001
#
# 475	 0.001
#
# 476	 0.001
#
# 477	 0.001
#
# 478	 0.001
#
# 479	 0.001
#
# 480	 0.001
#
# 481	 0.001
#
# 482	 0.001
#
# 483	 0.001
#
# 484	 0.001
#
# 485	 0.001
#
# 486	 0.001
#
# 487	 0.001
#
# 488	 0.001
#
# 489	 0.001
#
# 490	 0.001
#
# 491	 0.001
#
# 492	 0.001
#
# 493	 0.001
#
# 494	 0.001
#
# 495	 0.001
#
# 496	 0.001
#
# 497	 0.001
#
# 498	 0.001
#
# 499	 0.001

# %%
# clr3
# warm up 10% of epoch: it can reduce fall in local min in inital steps.


ep_num = 1000



def clr3(epoch):
    
    
    step_size = 25 # currently best for foot pp
    max_lr = 0.01 # currently best for foot pp
    base_lr = 1e-6 # 1e-6 1e-7

    # warm up
    lr_init_ep = 0
    lr_ramp_ep = 100
    lr_sus_ep  = 0
    lr_decay   = 0.5

    iterations = epoch
    cycle = np.floor(1+iterations/(2*step_size))
    x = np.abs(iterations/step_size - 2*cycle + 1)
    lr = base_lr + (max_lr-base_lr)*np.maximum(0, (1-x))
    
    #todo: boost the lr at initial setps.
#     initial_lr = lambda epoch: lr if epoch > step_size else max_lr
#     initial_lr = lambda epoch: lr if epoch > step_size else boost_lr
#     lr = initial_lr(epoch)
    #todo: boost the lr at fist step_size.
    
    # warm up
    if epoch < lr_ramp_ep:
        lr = (max_lr - base_lr) / lr_ramp_ep * epoch + base_lr
    
    decay = ((epoch+1)/ep_num)
    base_part = 1.001 #1.1
#     print(decay)
    return lr * (base_part-decay) * lr_decay # supressed the lr!


rng = [i for i in range(ep_num)]
y = [clr3(x) for x in rng]
sns.set(style='darkgrid')
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)

# %%
print('{} ~ {}'.format(min(y), max(y)))
# Out:
# 2.4999999999999966e-08 ~ 0.004459954505

# %%
# 2.4999999999999966e-08 ~ 0.004459954505 1e-2~1e-6

# %%
# %%time
# """
# cosine_decay_restarts是cosine_decay的cycle版本。
# first_decay_steps是指第一次完全下降的step數，
# t_mul是指每一次循環的步數都將乘以t_mul倍，
# m_mul指每一次循環重新開始時的初始lr是上一次循環初始值的m_mul倍。
# alpha
# """

# from matplotlib.ticker import FormatStrFormatter



# ep_num = 1000



# def CosineDecayCLRWarmUp(epoch):
    
#     #step_size = 25 # currently best for foot pp
#     max_lr = 1e-2 # currently best for foot pp
#     base_lr = 1e-8# 1e-6 1e-7

#     # warm up
#     lr_init_ep = 0
#     lr_ramp_ep = 100
#     lr_sus_ep  = 0
#     lr_decay   = 0.8


#     initial_learning_rate = 1e-2
#     first_decay_steps = 100


#     lr_decayed_fn = (
#       tf.keras.experimental.CosineDecayRestarts(
#           initial_learning_rate,
#           first_decay_steps,
#           t_mul=1.0,
#           m_mul=0.8,
#           alpha = 0.000001,
#           name="CCosineDecayRestarts"))
    
#     # warm up
#     if epoch < lr_ramp_ep:
#         lr = (max_lr - base_lr) / lr_ramp_ep * epoch + base_lr    
#     else:
#         lr = lr_decayed_fn(epoch)
#     return lr



# rng = [i for i in range(ep_num)]
# y = [CosineDecayCLRWarmUp(x) for x in rng]
# sns.set(style='darkgrid')
# fig, ax = plt.subplots(figsize=(20, 6))
# # plt.ylim(.0000000000000001, .01)# for too large loss
# ax.yaxis.set_major_formatter(FormatStrFormatter('%.12f'))# for too small loss
# plt.plot(rng, y)

# %%
# %%time
# """
# cosine_decay_restarts是cosine_decay的cycle版本。
# first_decay_steps是指第一次完全下降的step數，
# t_mul是指每一次循環的步數都將乘以t_mul倍，
# m_mul指每一次循環重新開始時的初始lr是上一次循環初始值的m_mul倍。
# alpha
# """

# from matplotlib.ticker import FormatStrFormatter



# ep_num = 1000



# def CosineDecayCLRWarmUpLSW(epoch):
    
#     #step_size = 25 # currently best for foot pp
#     max_lr = 1e-3 # currently best for foot pp
#     base_lr = 1e-6# 1e-6 1e-7

#     # warm up
#     lr_init_ep = 0
#     lr_ramp_ep = 20
#     lr_sus_ep  = 0
#     lr_decay   = 0.8


#     initial_learning_rate = 1e-3
#     first_decay_steps = 50


#     lr_decayed_fn = (
#       tf.keras.experimental.CosineDecayRestarts(
#           initial_learning_rate,
#           first_decay_steps,
#           t_mul=1.0,
#           m_mul=0.8,
#           alpha = 0.000001,
#           name="CCosineDecayRestarts"))
    
#     # warm up
#     if epoch < lr_ramp_ep:
#         lr = (max_lr - base_lr) / lr_ramp_ep * epoch + base_lr    
#     else:
#         lr = lr_decayed_fn(epoch-lr_ramp_ep)
#     return lr



# rng = [i for i in range(ep_num)]
# y = [CosineDecayCLRWarmUpLSW(x) for x in rng]
# sns.set(style='darkgrid')
# fig, ax = plt.subplots(figsize=(20, 6))
# # plt.ylim(.0000000000000001, .01)# for too large loss
# ax.yaxis.set_major_formatter(FormatStrFormatter('%.12f'))# for too small loss
# plt.plot(rng, y)

# %%
# %%time
# """
# cosine_decay_restarts是cosine_decay的cycle版本。
# first_decay_steps是指第一次完全下降的step數，
# t_mul是指每一次循環的步數都將乘以t_mul倍，
# m_mul指每一次循環重新開始時的初始lr是上一次循環初始值的m_mul倍。
# alpha
# """

# from matplotlib.ticker import FormatStrFormatter



# ep_num = 1000



# def CosineDecayCLRWarmUpLSW_2(epoch):
    
#     #step_size = 25 # currently best for foot pp
#     max_lr = 1e-2 # currently best for foot pp
#     base_lr = 1e-6# 1e-6 1e-7

#     # warm up
#     lr_init_ep = 0
#     lr_ramp_ep = 20
#     lr_sus_ep  = 0
#     #lr_decay   = 0.8


#     initial_learning_rate = 1e-2
#     first_decay_steps = 50


#     lr_decayed_fn = (
#       tf.keras.experimental.CosineDecayRestarts(
#           initial_learning_rate,
#           first_decay_steps,
#           t_mul=1,
#           m_mul=1,
#           alpha = 0.000001,
#           name="CCosineDecayRestarts"))
    
#     # warm up
#     if epoch < lr_ramp_ep:
#         lr = (max_lr - base_lr) / lr_ramp_ep * epoch + base_lr    
#     else:
#         lr = lr_decayed_fn(epoch-lr_ramp_ep)
#     return lr



# rng = [i for i in range(ep_num)]
# y = [CosineDecayCLRWarmUpLSW_2(x) for x in rng]
# sns.set(style='darkgrid')
# fig, ax = plt.subplots(figsize=(20, 6))
# # plt.ylim(.0000000000000001, .01)# for too large loss
# ax.yaxis.set_major_formatter(FormatStrFormatter('%.12f'))# for too small loss
# plt.plot(rng, y)

# %%
print('{} ~ {}'.format(min(y), max(y)))
# Out:
# 2.4999999999999966e-08 ~ 0.004459954505

# %%
# 1.8774175103430935e-08 ~ 0.0010000000474974513 1e-3 1e-6

# %%
# lr_reduceonplateau = tf.keras.callbacks.ReduceLROnPlateau(monitor=monitor, factor=0.1, patience=5, verbose=1, mode='auto', min_delta=0.0001, cooldown=0, min_lr=1e-12)

# %%
# Callback for printing the LR at the end of each epoch.
class PrintLRtoe(tf.keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
#     def on_epoch_end(self, epoch, logs=None):
#         print('\n[{}] Learning rate for epoch {} is {}'.format(
#             datetime.now().strftime("%Y%m%d-%H%M-%S"), 
#             epoch + 1,
#             self.model.optimizer.lr.numpy()))
        print('\n[{}] Learning rate for epoch {} is {}'.format(
        datetime.now().strftime("%Y%m%d-%H%M-%S"), 
        epoch + 1,
        model_toe.optimizer._decayed_lr(tf.float32).numpy()))

# %%
# Callback for printing the LR at the end of each epoch.
class PrintLRheel(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
#         print('\nLearning rate for epoch {} is {}'.format(epoch + 1,
#                                               model_heel.optimizer.lr.numpy()))
        print('\n[{}] Learning rate for epoch {} is {}'.format(
        datetime.now().strftime("%Y%m%d-%H%M-%S"), 
        epoch + 1,
        model_heel.optimizer._decayed_lr(tf.float32).numpy()))

# %% [markdown]
# ### Output dir and models

# %%
def mk_log_dir(log_dir_name):
    try:
        os.makedirs(log_dir_name)
    except OSError as e:
        print("This log dir exist.")
        if e.errno != errno.EEXIST:
            raise ValueError("we got problem.")

# %%
monitor = 'val_loss' #'val_loss' 'val_accuracy' if use ed_loss it still the loss here.

log_dir_name = datetime.now().strftime("%Y%m%d-%H%M%S") 

# mk_log_dir(datetime.now().strftime("%Y%m%d-%H%M%S") )

# %%
# use once at the time
mk_log_dir(log_dir_name)

# %% [markdown]
# # Toe

# %%
model_name = 'EfficientNetB0'

# %%
#get_best_model_name

# best_model_name = './' + model_name + '_bs-' + str(BATCH_SIZE) + '_s-' + str(img_height) + '_' + "ep-{epoch:02d}-vloss-{val_loss:.2f}" +'_best-weight.h5'
# best_model_name = '{model_name}-ep{epoch:03d}-loss{loss:.3f}-val_loss{val_loss:.3f}.h5'
#best_model_name = './' + model_name + '_bs' + str(BATCH_SIZE) + '_w' + str(img_width) + '_' + monitor + '_best.h5'
# best_model_name = './Leaf_' + model_name + '_bs' + str(BATCH_SIZE) + '_w' + str(img_width) + '_' + datetime.now().strftime("%Y%m%d-%H%M%S") + '_best_' + monitor + '.h5'

# best_model_name = './cop' + model_name + '_bs' + str(BATCH_SIZE) + '_w' + str(img_width) + '_' + datetime.now().strftime("%Y%m%d-%H%M%S") + '_best_' + monitor + '.h5'

def get_best_model_name(th, K):
    return './' + log_dir_name + '/' + th + '_K' + K + '_' + model_name + '_bs' + str(BATCH_SIZE) + '_w' + str(img_width) + '_best_' + monitor + '.h5'

# th = 'toe'
# # th = 'heel'

# # print(get_best_model_name(th,K))

# best_model_name = get_best_model_name(th, K)


# best_model_save = tf.keras.callbacks.ModelCheckpoint(filepath=best_model_name, 
#                              save_best_only = True, 
#                              save_weights_only = False,
#                              monitor = monitor, 
#                              mode = 'auto', verbose = 1)
# print('best_model_name:', best_model_name)

# %%
logdir = log_dir_name + "/logs/toe/"

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
# callbacks = [
# #     tensorboard_callback,
#     best_model_save,
#     tf.keras.callbacks.EarlyStopping(monitor=monitor, patience=20), #patience=step_size or ep_num
# #     lr_reduceonplateau,
#     tf.keras.callbacks.LearningRateScheduler(lrdump),#lrdump, decay or lrfn or lrfn2. clr
#     PrintLRtoe()
# ]

# %%
# Transfer learning from pre-trained weights
def build_efn_model(outputnum, top_dropout_rate, drop_connect_rate):
    base_model = tf.keras.applications.EfficientNetB0(include_top=False, weights="imagenet", input_shape=(120,120,3),drop_connect_rate=drop_connect_rate) #{'imagenet', None}

    # Freeze the pretrained weights
    base_model.trainable = False
    print("base_model.trainable : ", base_model.trainable)

    # Rebuild top
    gap2d = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
    BNL = tf.keras.layers.BatchNormalization()(gap2d) #tood: remove#
    dropout = tf.keras.layers.Dropout(top_dropout_rate)(BNL)#tood: remove# J add dropout, for flood 0.2 is ok. for leaf 0.4 is better.
    outputs = tf.keras.layers.Dense(outputnum)(dropout)# remove activation for regression output (to default, the linear), , activation = 'relu' no help

    # Compile new model
    model = tf.keras.Model(base_model.input, outputs, name=model_name)


#     # unfreeze the top #fine_tune_at# layers while leaving BatchNorm layers frozen
#     fine_tune_at = 20 #10 #241 #20
#     print('[Note] Now create model fine tuneing at Top-{} layers!'.format(fine_tune_at))
#     for layer in model_toe.layers[-fine_tune_at:]:
#         if not isinstance(layer, tf.keras.layers.BatchNormalization):
#             layer.trainable = True

    model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),#RMSprop , Adam, SGD Adadelta(learning_rate=0.001), if set lr_callback the learning_rate=0.001 will not effeced.
                    loss=ed_metric_2d_mean)

    
    return model

# %%
"""Supervised pre-training 減少每次fold都要重新train的時間
只先改toe"""

# Transfer learning from pre-trained weights
def load_pretrained_efn_model():
    pre_model_toe_name = "20210224-200728/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5"
    model = tf.keras.models.load_model(pre_model_toe_name,compile=False)

    # Freeze the pretrained weights
    model.trainable = False
#     print("base_model.trainable : ", base_model.trainable)

#     # Rebuild top
#     gap2d = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
#     BNL = tf.keras.layers.BatchNormalization()(gap2d) #tood: remove#
#     dropout = tf.keras.layers.Dropout(top_dropout_rate)(BNL)#tood: remove# J add dropout, for flood 0.2 is ok. for leaf 0.4 is better.
#     outputs = tf.keras.layers.Dense(outputnum)(dropout)# remove activation for regression output (to default, the linear), , activation = 'relu' no help

#     # Compile new model
#     model = tf.keras.Model(base_model.input, outputs, name=model_name)


#     # unfreeze the top #fine_tune_at# layers while leaving BatchNorm layers frozen
    fine_tune_at = 4 #10 #241 #20
    print('[Note] Now create model fine tuneing at Top-{} layers!'.format(fine_tune_at))
    for layer in model.layers[-fine_tune_at:]:
        if not isinstance(layer, tf.keras.layers.BatchNormalization):
            print('layer trainable +1', layer.name)
            layer.trainable = True

    model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),#RMSprop , Adam, SGD Adadelta(learning_rate=0.001), if set lr_callback the learning_rate=0.001 will not effeced.
                    loss=ed_metric_2d_mean)

    
    return model

# %%
def unfreeze_model(model):
#
#'block7a_expand_conv'20 'block6c_expand_conv'50 'block6a_expand_conv'79 'block5b_expand_conv'109 'block4a_expand_conv' 166 'block3a_expand_conv' 195
#
    model.trainable = True
    set_trainable = False
    for layer in model.layers:
        if layer.name == 'block3a_expand_conv': 
            set_trainable = True
        if set_trainable:
            layer.trainable = True
        else:
            layer.trainable = False

    model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),#RMSprop , Adam, SGD Adadelta(learning_rate=0.001), if set lr_callback the learning_rate=0.001 will not effeced.
                    loss=ed_metric_2d_mean)

# %%
# top_dropout_rate = 0.8 #less dp rate, say 0.1, train_loss will lower than val_loss
# drop_connect_rate = 0.9 #for efnet This parameter serves as a toggle for extra regularization in finetuning, but does not affect loaded weights.
# outputnum = 2
# with strategy.scope():
#     model_toe = build_efn_model(outputnum, top_dropout_rate, drop_connect_rate)

# %%
# len(model_toe.layers)

# %%
# tt = 0
# nt = 0
# for layer in model_toe.layers:
#     if layer.trainable:
#         tt +=1
#         print(f'{layer.name}')
#     else:
#         nt +=1
# print(f'tt: {tt}, nt:{nt}')

# %%
def count_model_trainOrNot_layers(model, printlayers=False):
    tt = 0
    nt = 0
    for layer in model.layers:
        if layer.trainable:
            tt +=1
            if printlayers:
                print(f'{layer.name}')
        else:
            nt +=1
    print('\n*********************************** Start fine tune ***********************************')
    print(f'tt: {tt}, nt:{nt}, total layers:{tt+nt}')
    print('*********************************** Start fine tune ***********************************')

# %%
# unfreeze_model(model_toe)
# count_model_trainOrNot_layers(model_toe)

# %%
# model_toe.summary()

# %%
# %%time

# # fit the model on all data
# history_toe = model_toe.fit(train_ds_pre_toe_s, 
#                       verbose=1, 
#                       epochs=ep_num_transf, 
#                       validation_data=valid_ds_pre_toe_s, 
#                       callbacks=callbacks)#, validation_split=0.1)

# %% [markdown]
# # K-Fold Training
#
# 2021-02-23 v1

# %% [markdown]
# ### Toe K-model

# %%
# %%time

# big K = 5 (fold 0 ~ 4) 
KFlodNum = 5



history_toe = []
history_toe_finetune = []

#above until 'train_ds_map_toe now' to 'train_ds_map_toe_s', 'valid_ds_map_toe_s'
for k in range(KFlodNum):
    
    
    # Split data to train/valid with K-Fold #
    print("\n \n K = ", k, "\n")
    # Toe split
    train_ds_map_toe_s, valid_ds_map_toe_s = get_KFold_ds(train_ds_map_toe, K=k)
    
    # Toe ds_pre
    train_ds_pre_toe_s = configure_for_performance_cache_train(train_ds_map_toe_s, augment=True)
    valid_ds_pre_toe_s = configure_for_performance_cache_val(valid_ds_map_toe_s)
    
    
#     # heel split
#     train_ds_map_heel_s, valid_ds_map_heel_s = get_KFold_ds(train_ds_map_heel, K=k)
#     # Heel ds_pre
#     train_ds_pre_heel_s = configure_for_performance_cache_train(train_ds_map_heel_s, augment=True)
#     valid_ds_pre_heel_s = configure_for_performance_cache_val(valid_ds_map_heel_s)
    
    
    # Train K-Model with transfer learnling #
    
    # Toe model, TL
    th = 'toe'
    # th = 'heel'
    best_model_name = get_best_model_name(th, K=str(k))
    best_model_save = tf.keras.callbacks.ModelCheckpoint(filepath=best_model_name, 
                                 save_best_only = True, 
                                 save_weights_only = False,
                                 monitor = monitor, 
                                 mode = 'auto', verbose = 1)
    callbacks_toe_tl = [
                    #     tensorboard_callback,
                        best_model_save,
                        tf.keras.callbacks.EarlyStopping(monitor=monitor, patience=40), #patience=step_size or ep_num
                    #     lr_reduceonplateau,
                        tf.keras.callbacks.LearningRateScheduler(lrdump),#lrdump, decay or lrfn or lrfn2. clr
                        PrintLRtoe()
                        ]
    callbacks_toe_fn = [
                    #     tensorboard_callback,
                        best_model_save,
                        tf.keras.callbacks.EarlyStopping(monitor=monitor, patience=200), #patience=step_size or ep_num
                    #     lr_reduceonplateau,
                        tf.keras.callbacks.LearningRateScheduler(clr3),#lrdump, decay or lrfn or lrfn2. clr, CosineDecayCLRWarmUp, CosineDecayCLRWarmUpLSW
                        PrintLRtoe()
                    ]
    print('best_model_name:', best_model_name)


    top_dropout_rate = 0.8 #less dp rate, say 0.1, train_loss will lower than val_loss
    drop_connect_rate = 0.9 #for efnet This parameter serves as a toggle for extra regularization in finetuning, but does not affect loaded weights.
    outputnum = 2
    with strategy.scope():
        model_toe = build_efn_model(outputnum, top_dropout_rate, drop_connect_rate)
#         model_toe = load_pretrained_efn_model() # from 20210224-200728 ed5.3
#         count_model_trainOrNot_layers(model_toe)
        
    # fit the model on all data
    hist = model_toe.fit(train_ds_pre_toe_s, 
                          verbose=1, 
                          epochs=ep_num_transf, 
                          validation_data=valid_ds_pre_toe_s, 
                          callbacks=callbacks_toe_tl)#, validation_split=0.1)
    history_toe.append(hist)
    
      
    # Train K-Model with fine tune #
    
    # Toe model, FT
    unfreeze_model(model_toe)
    count_model_trainOrNot_layers(model_toe)
    # fit the model on all data
    hist = model_toe.fit(train_ds_pre_toe_s, 
                          verbose=1, 
                          epochs=ep_num, 
                          validation_data=valid_ds_pre_toe_s, 
                          callbacks=callbacks_toe_fn)#, validation_split=0.1)
    history_toe_finetune.append(hist)
# Out:
#
#  K =  0
#
# Check cache in memory:Y True
# Check keypoints process01: Tensor("args_1:0", shape=(2,), dtype=int64) (2,) <class 'tensorflow.python.framework.ops.Tensor'>
# Check keypoints process02: Tensor("Reshape:0", shape=(1, 2), dtype=int64) (1, 2) <class 'tensorflow.python.framework.ops.Tensor'>
# Check keypoints process03: Tensor("PyFunc:1", dtype=float32, device=/job:localhost/replica:0/task:0)
# Check keypoints process04: Tensor("Reshape_1:0", shape=(2,), dtype=float32)
# Check augment :Y True
# Check ds cache[True] and augment[True]
# Check cache in memory:Y True
# Check augment :N False
# Check ds cache[True] and augment[False]
# best_model_name: ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# base_model.trainable :  False
#
# [20210228-2354-35] Learning rate for epoch 1 is 0.009999999776482582
# Epoch 1/500
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# 17/17 [==============================] - ETA: 0s - loss: 75.3871
# Epoch 00001: val_loss improved from inf to 62.14424, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 13s 788ms/step - loss: 75.3871 - val_loss: 62.1442
#
# [20210228-2355-00] Learning rate for epoch 2 is 0.009960000403225422
# Epoch 2/500
# 17/17 [==============================] - ETA: 0s - loss: 39.9209
# Epoch 00002: val_loss improved from 62.14424 to 16.07403, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 39.9209 - val_loss: 16.0740
#
# [20210228-2355-03] Learning rate for epoch 3 is 0.009920000098645687
# Epoch 3/500
# 17/17 [==============================] - ETA: 0s - loss: 22.3541
# Epoch 00003: val_loss improved from 16.07403 to 14.18830, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 11s 655ms/step - loss: 22.3541 - val_loss: 14.1883
#
# [20210228-2355-17] Learning rate for epoch 4 is 0.009879999794065952
# Epoch 4/500
# 17/17 [==============================] - ETA: 0s - loss: 18.8131
# Epoch 00004: val_loss improved from 14.18830 to 12.58203, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 18.8131 - val_loss: 12.5820
#
# [20210228-2355-20] Learning rate for epoch 5 is 0.009840000420808792
# Epoch 5/500
# 14/17 [=======================>......] - ETA: 0s - loss: 18.0457
# Epoch 00005: val_loss improved from 12.58203 to 11.58923, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 44ms/step - loss: 17.9261 - val_loss: 11.5892
#
# [20210228-2355-23] Learning rate for epoch 6 is 0.009800000116229057
# Epoch 6/500
# 16/17 [===========================>..] - ETA: 0s - loss: 17.5452
# Epoch 00006: val_loss improved from 11.58923 to 11.29798, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 17.5665 - val_loss: 11.2980
#
# [20210228-2355-26] Learning rate for epoch 7 is 0.009759999811649323
# Epoch 7/500
# 17/17 [==============================] - ETA: 0s - loss: 17.5060
# Epoch 00007: val_loss improved from 11.29798 to 11.14512, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 17.5060 - val_loss: 11.1451
#
# [20210228-2355-29] Learning rate for epoch 8 is 0.009720000438392162
# Epoch 8/500
# 17/17 [==============================] - ETA: 0s - loss: 16.7956
# Epoch 00008: val_loss improved from 11.14512 to 11.03272, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 45ms/step - loss: 16.7956 - val_loss: 11.0327
#
# [20210228-2355-32] Learning rate for epoch 9 is 0.009680000133812428
# Epoch 9/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.4292
# Epoch 00009: val_loss did not improve from 11.03272
# 17/17 [==============================] - 0s 24ms/step - loss: 16.3599 - val_loss: 11.4370
#
# [20210228-2355-35] Learning rate for epoch 10 is 0.009639999829232693
# Epoch 10/500
# 17/17 [==============================] - ETA: 0s - loss: 16.2297
# Epoch 00010: val_loss improved from 11.03272 to 10.81225, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 16.2297 - val_loss: 10.8123
#
# [20210228-2355-37] Learning rate for epoch 11 is 0.009600000455975533
# Epoch 11/500
# 17/17 [==============================] - ETA: 0s - loss: 16.3089
# Epoch 00011: val_loss improved from 10.81225 to 10.58389, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 16.3089 - val_loss: 10.5839
#
# [20210228-2355-40] Learning rate for epoch 12 is 0.009560000151395798
# Epoch 12/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.5184
# Epoch 00012: val_loss improved from 10.58389 to 10.52711, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 45ms/step - loss: 15.6404 - val_loss: 10.5271
#
# [20210228-2355-43] Learning rate for epoch 13 is 0.009519999846816063
# Epoch 13/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.7896
# Epoch 00013: val_loss improved from 10.52711 to 10.40569, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 15.8686 - val_loss: 10.4057
#
# [20210228-2355-46] Learning rate for epoch 14 is 0.009479999542236328
# Epoch 14/500
# 17/17 [==============================] - ETA: 0s - loss: 15.3209
# Epoch 00014: val_loss did not improve from 10.40569
# 17/17 [==============================] - 0s 24ms/step - loss: 15.3209 - val_loss: 10.4785
#
# [20210228-2355-49] Learning rate for epoch 15 is 0.009440000168979168
# Epoch 15/500
# 14/17 [=======================>......] - ETA: 0s - loss: 15.3289
# Epoch 00015: val_loss improved from 10.40569 to 10.29159, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 45ms/step - loss: 15.2553 - val_loss: 10.2916
#
# [20210228-2355-52] Learning rate for epoch 16 is 0.009399999864399433
# Epoch 16/500
# 14/17 [=======================>......] - ETA: 0s - loss: 14.4476
# Epoch 00016: val_loss improved from 10.29159 to 10.13718, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 45ms/step - loss: 14.4908 - val_loss: 10.1372
#
# [20210228-2355-55] Learning rate for epoch 17 is 0.009359999559819698
# Epoch 17/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.4457
# Epoch 00017: val_loss improved from 10.13718 to 10.06478, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 14.4119 - val_loss: 10.0648
#
# [20210228-2355-58] Learning rate for epoch 18 is 0.009320000186562538
# Epoch 18/500
# 14/17 [=======================>......] - ETA: 0s - loss: 14.6509
# Epoch 00018: val_loss did not improve from 10.06478
# 17/17 [==============================] - 0s 23ms/step - loss: 14.7680 - val_loss: 10.0844
#
# [20210228-2356-00] Learning rate for epoch 19 is 0.009279999881982803
# Epoch 19/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.9591
# Epoch 00019: val_loss did not improve from 10.06478
# 17/17 [==============================] - 0s 25ms/step - loss: 15.0022 - val_loss: 10.1563
#
# [20210228-2356-03] Learning rate for epoch 20 is 0.009239999577403069
# Epoch 20/500
# 14/17 [=======================>......] - ETA: 0s - loss: 14.6807
# Epoch 00020: val_loss did not improve from 10.06478
# 17/17 [==============================] - 0s 24ms/step - loss: 14.7999 - val_loss: 10.2231
#
# [20210228-2356-05] Learning rate for epoch 21 is 0.009200000204145908
# Epoch 21/500
# 17/17 [==============================] - ETA: 0s - loss: 14.4273
# Epoch 00021: val_loss did not improve from 10.06478
# 17/17 [==============================] - 0s 24ms/step - loss: 14.4273 - val_loss: 10.0976
#
# [20210228-2356-07] Learning rate for epoch 22 is 0.009159999899566174
# Epoch 22/500
# 17/17 [==============================] - ETA: 0s - loss: 14.8345
# Epoch 00022: val_loss did not improve from 10.06478
# 17/17 [==============================] - 0s 24ms/step - loss: 14.8345 - val_loss: 10.1338
#
# [20210228-2356-10] Learning rate for epoch 23 is 0.009119999594986439
# Epoch 23/500
# 14/17 [=======================>......] - ETA: 0s - loss: 14.6239
# Epoch 00023: val_loss improved from 10.06478 to 9.99956, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 54ms/step - loss: 14.5738 - val_loss: 9.9996
#
# [20210228-2356-13] Learning rate for epoch 24 is 0.009080000221729279
# Epoch 24/500
# 17/17 [==============================] - ETA: 0s - loss: 14.7452
# Epoch 00024: val_loss did not improve from 9.99956
# 17/17 [==============================] - 0s 24ms/step - loss: 14.7452 - val_loss: 10.2339
#
# [20210228-2356-15] Learning rate for epoch 25 is 0.009039999917149544
# Epoch 25/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.2318
# Epoch 00025: val_loss did not improve from 9.99956
# 17/17 [==============================] - 0s 25ms/step - loss: 14.2161 - val_loss: 10.2507
#
# [20210228-2356-18] Learning rate for epoch 26 is 0.008999999612569809
# Epoch 26/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.4764
# Epoch 00026: val_loss improved from 9.99956 to 9.77633, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 45ms/step - loss: 14.4342 - val_loss: 9.7763
#
# [20210228-2356-21] Learning rate for epoch 27 is 0.008960000239312649
# Epoch 27/500
# 17/17 [==============================] - ETA: 0s - loss: 14.2039
# Epoch 00027: val_loss did not improve from 9.77633
# 17/17 [==============================] - 0s 24ms/step - loss: 14.2039 - val_loss: 10.0897
#
# [20210228-2356-23] Learning rate for epoch 28 is 0.008919999934732914
# Epoch 28/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.8323
# Epoch 00028: val_loss improved from 9.77633 to 9.75665, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 45ms/step - loss: 13.7973 - val_loss: 9.7566
#
# [20210228-2356-26] Learning rate for epoch 29 is 0.00887999963015318
# Epoch 29/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.1889
# Epoch 00029: val_loss improved from 9.75665 to 9.69467, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 14.1861 - val_loss: 9.6947
#
# [20210228-2356-29] Learning rate for epoch 30 is 0.008840000256896019
# Epoch 30/500
# 14/17 [=======================>......] - ETA: 0s - loss: 13.9254
# Epoch 00030: val_loss did not improve from 9.69467
# 17/17 [==============================] - 0s 23ms/step - loss: 13.8770 - val_loss: 9.9554
#
# [20210228-2356-32] Learning rate for epoch 31 is 0.008799999952316284
# Epoch 31/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.3607
# Epoch 00031: val_loss did not improve from 9.69467
# 17/17 [==============================] - 0s 25ms/step - loss: 14.2984 - val_loss: 9.9673
#
# [20210228-2356-35] Learning rate for epoch 32 is 0.00875999964773655
# Epoch 32/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.2499
# Epoch 00032: val_loss did not improve from 9.69467
# 17/17 [==============================] - 0s 24ms/step - loss: 14.2253 - val_loss: 9.8781
#
# [20210228-2356-37] Learning rate for epoch 33 is 0.00872000027447939
# Epoch 33/500
# 17/17 [==============================] - ETA: 0s - loss: 14.1375
# Epoch 00033: val_loss did not improve from 9.69467
# 17/17 [==============================] - 0s 24ms/step - loss: 14.1375 - val_loss: 9.7299
#
# [20210228-2356-40] Learning rate for epoch 34 is 0.008679999969899654
# Epoch 34/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.5387
# Epoch 00034: val_loss did not improve from 9.69467
# 17/17 [==============================] - 0s 24ms/step - loss: 14.5209 - val_loss: 9.9505
#
# [20210228-2356-43] Learning rate for epoch 35 is 0.00863999966531992
# Epoch 35/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.2250
# Epoch 00035: val_loss improved from 9.69467 to 9.64507, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 14.2577 - val_loss: 9.6451
#
# [20210228-2356-46] Learning rate for epoch 36 is 0.00860000029206276
# Epoch 36/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.1942
# Epoch 00036: val_loss did not improve from 9.64507
# 17/17 [==============================] - 0s 24ms/step - loss: 14.1348 - val_loss: 9.8579
#
# [20210228-2356-48] Learning rate for epoch 37 is 0.008559999987483025
# Epoch 37/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.8494
# Epoch 00037: val_loss improved from 9.64507 to 9.54644, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 13.9221 - val_loss: 9.5464
#
# [20210228-2356-51] Learning rate for epoch 38 is 0.00851999968290329
# Epoch 38/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.2484
# Epoch 00038: val_loss improved from 9.54644 to 9.48692, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 14.2752 - val_loss: 9.4869
#
# [20210228-2356-54] Learning rate for epoch 39 is 0.00848000030964613
# Epoch 39/500
# 15/17 [=========================>....] - ETA: 0s - loss: 13.7843
# Epoch 00039: val_loss did not improve from 9.48692
# 17/17 [==============================] - 0s 23ms/step - loss: 13.7606 - val_loss: 9.5737
#
# [20210228-2356-57] Learning rate for epoch 40 is 0.008440000005066395
# Epoch 40/500
# 15/17 [=========================>....] - ETA: 0s - loss: 13.8328
# Epoch 00040: val_loss did not improve from 9.48692
# 17/17 [==============================] - 0s 23ms/step - loss: 13.8111 - val_loss: 9.7652
#
# [20210228-2356-59] Learning rate for epoch 41 is 0.00839999970048666
# Epoch 41/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.6688
# Epoch 00041: val_loss did not improve from 9.48692
# 17/17 [==============================] - 0s 24ms/step - loss: 13.7303 - val_loss: 9.5243
#
# [20210228-2357-02] Learning rate for epoch 42 is 0.0083600003272295
# Epoch 42/500
# 17/17 [==============================] - ETA: 0s - loss: 14.1653
# Epoch 00042: val_loss did not improve from 9.48692
# 17/17 [==============================] - 0s 24ms/step - loss: 14.1653 - val_loss: 9.7437
#
# [20210228-2357-05] Learning rate for epoch 43 is 0.008320000022649765
# Epoch 43/500
# 14/17 [=======================>......] - ETA: 0s - loss: 14.1362
# Epoch 00043: val_loss improved from 9.48692 to 9.48356, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 14.1229 - val_loss: 9.4836
#
# [20210228-2357-08] Learning rate for epoch 44 is 0.00827999971807003
# Epoch 44/500
# 17/17 [==============================] - ETA: 0s - loss: 13.7030
# Epoch 00044: val_loss did not improve from 9.48356
# 17/17 [==============================] - 0s 26ms/step - loss: 13.7030 - val_loss: 9.5891
#
# [20210228-2357-10] Learning rate for epoch 45 is 0.00824000034481287
# Epoch 45/500
# 17/17 [==============================] - ETA: 0s - loss: 13.9663
# Epoch 00045: val_loss did not improve from 9.48356
# 17/17 [==============================] - 0s 24ms/step - loss: 13.9663 - val_loss: 9.5232
#
# [20210228-2357-13] Learning rate for epoch 46 is 0.008200000040233135
# Epoch 46/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.6341
# Epoch 00046: val_loss did not improve from 9.48356
# 17/17 [==============================] - 0s 24ms/step - loss: 13.6192 - val_loss: 9.5357
#
# [20210228-2357-16] Learning rate for epoch 47 is 0.0081599997356534
# Epoch 47/500
# 15/17 [=========================>....] - ETA: 0s - loss: 13.5679
# Epoch 00047: val_loss did not improve from 9.48356
# 17/17 [==============================] - 0s 24ms/step - loss: 13.6381 - val_loss: 9.7192
#
# [20210228-2357-19] Learning rate for epoch 48 is 0.00812000036239624
# Epoch 48/500
# 17/17 [==============================] - ETA: 0s - loss: 14.0096
# Epoch 00048: val_loss did not improve from 9.48356
# 17/17 [==============================] - 0s 24ms/step - loss: 14.0096 - val_loss: 9.5586
#
# [20210228-2357-21] Learning rate for epoch 49 is 0.008080000057816505
# Epoch 49/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.5001
# Epoch 00049: val_loss improved from 9.48356 to 9.35473, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 13.4047 - val_loss: 9.3547
#
# [20210228-2357-25] Learning rate for epoch 50 is 0.00803999975323677
# Epoch 50/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.7387
# Epoch 00050: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 26ms/step - loss: 13.7338 - val_loss: 9.7104
#
# [20210228-2357-27] Learning rate for epoch 51 is 0.00800000037997961
# Epoch 51/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.8566
# Epoch 00051: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.9277 - val_loss: 10.1886
#
# [20210228-2357-30] Learning rate for epoch 52 is 0.007960000075399876
# Epoch 52/500
# 14/17 [=======================>......] - ETA: 0s - loss: 13.6730
# Epoch 00052: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.6385 - val_loss: 9.7412
#
# [20210228-2357-33] Learning rate for epoch 53 is 0.00791999977082014
# Epoch 53/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.8514
# Epoch 00053: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 25ms/step - loss: 13.7996 - val_loss: 9.5234
#
# [20210228-2357-35] Learning rate for epoch 54 is 0.00788000039756298
# Epoch 54/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.1207
# Epoch 00054: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 23ms/step - loss: 13.1783 - val_loss: 9.9170
#
# [20210228-2357-38] Learning rate for epoch 55 is 0.007840000092983246
# Epoch 55/500
# 17/17 [==============================] - ETA: 0s - loss: 13.8285
# Epoch 00055: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.8285 - val_loss: 9.5987
#
# [20210228-2357-41] Learning rate for epoch 56 is 0.007799999788403511
# Epoch 56/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.6077
# Epoch 00056: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 25ms/step - loss: 13.6501 - val_loss: 9.9193
#
# [20210228-2357-44] Learning rate for epoch 57 is 0.0077599999494850636
# Epoch 57/500
# 17/17 [==============================] - ETA: 0s - loss: 13.6514
# Epoch 00057: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 23ms/step - loss: 13.6514 - val_loss: 9.6700
#
# [20210228-2357-46] Learning rate for epoch 58 is 0.007720000110566616
# Epoch 58/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.4433
# Epoch 00058: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.4468 - val_loss: 9.4630
#
# [20210228-2357-49] Learning rate for epoch 59 is 0.007679999805986881
# Epoch 59/500
# 17/17 [==============================] - ETA: 0s - loss: 13.1991
# Epoch 00059: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 25ms/step - loss: 13.1991 - val_loss: 9.9511
#
# [20210228-2357-51] Learning rate for epoch 60 is 0.007639999967068434
# Epoch 60/500
# 17/17 [==============================] - ETA: 0s - loss: 13.5776
# Epoch 00060: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.5776 - val_loss: 10.1922
#
# [20210228-2357-54] Learning rate for epoch 61 is 0.007600000128149986
# Epoch 61/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.4891
# Epoch 00061: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.4624 - val_loss: 9.8260
#
# [20210228-2357-57] Learning rate for epoch 62 is 0.0075599998235702515
# Epoch 62/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.4188
# Epoch 00062: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.4073 - val_loss: 10.6015
#
# [20210228-2357-59] Learning rate for epoch 63 is 0.007519999984651804
# Epoch 63/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.3037
# Epoch 00063: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 23ms/step - loss: 13.2974 - val_loss: 9.4498
#
# [20210228-2358-02] Learning rate for epoch 64 is 0.0074800001457333565
# Epoch 64/500
# 17/17 [==============================] - ETA: 0s - loss: 13.6379
# Epoch 00064: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.6379 - val_loss: 9.4173
#
# [20210228-2358-04] Learning rate for epoch 65 is 0.007439999841153622
# Epoch 65/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.2075
# Epoch 00065: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.2379 - val_loss: 9.5078
#
# [20210228-2358-07] Learning rate for epoch 66 is 0.007400000002235174
# Epoch 66/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.4052
# Epoch 00066: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.4435 - val_loss: 9.5563
#
# [20210228-2358-09] Learning rate for epoch 67 is 0.007360000163316727
# Epoch 67/500
# 17/17 [==============================] - ETA: 0s - loss: 13.5244
# Epoch 00067: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 23ms/step - loss: 13.5244 - val_loss: 9.6745
#
# [20210228-2358-12] Learning rate for epoch 68 is 0.007319999858736992
# Epoch 68/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.3338
# Epoch 00068: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.3843 - val_loss: 9.5617
#
# [20210228-2358-14] Learning rate for epoch 69 is 0.007280000019818544
# Epoch 69/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.2703
# Epoch 00069: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.2969 - val_loss: 9.4415
#
# [20210228-2358-17] Learning rate for epoch 70 is 0.007240000180900097
# Epoch 70/500
# 17/17 [==============================] - ETA: 0s - loss: 13.4935
# Epoch 00070: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.4935 - val_loss: 9.5915
#
# [20210228-2358-20] Learning rate for epoch 71 is 0.007199999876320362
# Epoch 71/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.3304
# Epoch 00071: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.3151 - val_loss: 9.6386
#
# [20210228-2358-22] Learning rate for epoch 72 is 0.007160000037401915
# Epoch 72/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.4689
# Epoch 00072: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.4339 - val_loss: 9.4680
#
# [20210228-2358-25] Learning rate for epoch 73 is 0.007120000198483467
# Epoch 73/500
# 14/17 [=======================>......] - ETA: 0s - loss: 13.5040
# Epoch 00073: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 23ms/step - loss: 13.5148 - val_loss: 9.6301
#
# [20210228-2358-27] Learning rate for epoch 74 is 0.007079999893903732
# Epoch 74/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.8059
# Epoch 00074: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.7236 - val_loss: 9.5985
#
# [20210228-2358-30] Learning rate for epoch 75 is 0.007040000054985285
# Epoch 75/500
# 17/17 [==============================] - ETA: 0s - loss: 13.4609
# Epoch 00075: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.4609 - val_loss: 9.6045
#
# [20210228-2358-33] Learning rate for epoch 76 is 0.007000000216066837
# Epoch 76/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.2306
# Epoch 00076: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 25ms/step - loss: 13.3105 - val_loss: 10.2918
#
# [20210228-2358-35] Learning rate for epoch 77 is 0.0069599999114871025
# Epoch 77/500
# 15/17 [=========================>....] - ETA: 0s - loss: 13.5144
# Epoch 00077: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 23ms/step - loss: 13.5201 - val_loss: 9.5118
#
# [20210228-2358-38] Learning rate for epoch 78 is 0.006920000072568655
# Epoch 78/500
# 17/17 [==============================] - ETA: 0s - loss: 13.3370
# Epoch 00078: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 25ms/step - loss: 13.3370 - val_loss: 9.6311
#
# [20210228-2358-41] Learning rate for epoch 79 is 0.00687999976798892
# Epoch 79/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.1391
# Epoch 00079: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 25ms/step - loss: 13.1208 - val_loss: 9.9111
#
# [20210228-2358-43] Learning rate for epoch 80 is 0.006839999929070473
# Epoch 80/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.4792
# Epoch 00080: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 25ms/step - loss: 13.3540 - val_loss: 9.6002
#
# [20210228-2358-46] Learning rate for epoch 81 is 0.006800000090152025
# Epoch 81/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.2349
# Epoch 00081: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.1888 - val_loss: 9.6264
#
# [20210228-2358-49] Learning rate for epoch 82 is 0.00675999978557229
# Epoch 82/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.6498
# Epoch 00082: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 25ms/step - loss: 13.5157 - val_loss: 9.9451
#
# [20210228-2358-51] Learning rate for epoch 83 is 0.006719999946653843
# Epoch 83/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.2260
# Epoch 00083: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 25ms/step - loss: 13.2258 - val_loss: 9.5868
#
# [20210228-2358-54] Learning rate for epoch 84 is 0.006680000107735395
# Epoch 84/500
# 15/17 [=========================>....] - ETA: 0s - loss: 13.5629
# Epoch 00084: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 23ms/step - loss: 13.4715 - val_loss: 9.5685
#
# [20210228-2358-57] Learning rate for epoch 85 is 0.006639999803155661
# Epoch 85/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.7214
# Epoch 00085: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 25ms/step - loss: 13.7263 - val_loss: 9.4565
#
# [20210228-2358-59] Learning rate for epoch 86 is 0.006599999964237213
# Epoch 86/500
# 17/17 [==============================] - ETA: 0s - loss: 13.4131
# Epoch 00086: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.4131 - val_loss: 9.6083
#
# [20210228-2359-02] Learning rate for epoch 87 is 0.006560000125318766
# Epoch 87/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.3596
# Epoch 00087: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 25ms/step - loss: 13.4320 - val_loss: 9.7238
#
# [20210228-2359-04] Learning rate for epoch 88 is 0.006519999820739031
# Epoch 88/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.4360
# Epoch 00088: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.3389 - val_loss: 9.6230
#
# [20210228-2359-07] Learning rate for epoch 89 is 0.006479999981820583
# Epoch 89/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.1286
# Epoch 00089: val_loss did not improve from 9.35473
# 17/17 [==============================] - 0s 24ms/step - loss: 13.1510 - val_loss: 9.6158
#
# *********************************** Start fine tune ***********************************
# tt: 195, nt:46, total layers:241
# *********************************** Start fine tune ***********************************
#
# [20210228-2359-10] Learning rate for epoch 1 is 4.999999987376214e-07
# Epoch 1/1000
# 17/17 [==============================] - ETA: 0s - loss: 15.0057
# Epoch 00001: val_loss did not improve from 9.35473
# 17/17 [==============================] - 36s 2s/step - loss: 15.0057 - val_loss: 9.5751
#
# [20210301-0000-02] Learning rate for epoch 2 is 5.044450517743826e-05
# Epoch 2/1000
# 17/17 [==============================] - ETA: 0s - loss: 14.7674
# Epoch 00002: val_loss did not improve from 9.35473
# 17/17 [==============================] - 1s 74ms/step - loss: 14.7674 - val_loss: 9.6033
#
# [20210301-0000-06] Learning rate for epoch 3 is 0.00010028902033809572
# Epoch 3/1000
# 17/17 [==============================] - ETA: 0s - loss: 14.5329
# Epoch 00003: val_loss did not improve from 9.35473
# 17/17 [==============================] - 31s 2s/step - loss: 14.5329 - val_loss: 10.0629
#
# [20210301-0000-39] Learning rate for epoch 4 is 0.00015003354928921908
# Epoch 4/1000
# 17/17 [==============================] - ETA: 0s - loss: 14.3085
# Epoch 00004: val_loss did not improve from 9.35473
# 17/17 [==============================] - 1s 71ms/step - loss: 14.3085 - val_loss: 11.2587
#
# [20210301-0000-43] Learning rate for epoch 5 is 0.0001996780774788931
# Epoch 5/1000
# 17/17 [==============================] - ETA: 0s - loss: 12.9735
# Epoch 00005: val_loss did not improve from 9.35473
# 17/17 [==============================] - 1s 72ms/step - loss: 12.9735 - val_loss: 12.5691
#
# [20210301-0000-46] Learning rate for epoch 6 is 0.000249222619459033
# Epoch 6/1000
# 17/17 [==============================] - ETA: 0s - loss: 12.2976
# Epoch 00006: val_loss did not improve from 9.35473
# 17/17 [==============================] - 1s 71ms/step - loss: 12.2976 - val_loss: 12.5135
#
# [20210301-0000-50] Learning rate for epoch 7 is 0.0002986671752296388
# Epoch 7/1000
# 17/17 [==============================] - ETA: 0s - loss: 12.0298
# Epoch 00007: val_loss did not improve from 9.35473
# 17/17 [==============================] - 1s 72ms/step - loss: 12.0298 - val_loss: 10.3073
#
# [20210301-0000-54] Learning rate for epoch 8 is 0.00034801175934262574
# Epoch 8/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.8611
# Epoch 00008: val_loss improved from 9.35473 to 9.29794, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 105ms/step - loss: 11.8611 - val_loss: 9.2979
#
# [20210301-0000-58] Learning rate for epoch 9 is 0.00039725631359033287
# Epoch 9/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.4514
# Epoch 00009: val_loss improved from 9.29794 to 9.04074, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 103ms/step - loss: 11.4514 - val_loss: 9.0407
#
# [20210301-0001-02] Learning rate for epoch 10 is 0.0004464008961804211
# Epoch 10/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.0439
# Epoch 00010: val_loss improved from 9.04074 to 8.32174, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 101ms/step - loss: 11.0439 - val_loss: 8.3217
#
# [20210301-0001-06] Learning rate for epoch 11 is 0.0004954455071128905
# Epoch 11/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.2492
# Epoch 00011: val_loss did not improve from 8.32174
# 17/17 [==============================] - 1s 70ms/step - loss: 11.2492 - val_loss: 9.2842
#
# [20210301-0001-09] Learning rate for epoch 12 is 0.0005443901172839105
# Epoch 12/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.0182
# Epoch 00012: val_loss did not improve from 8.32174
# 17/17 [==============================] - 1s 73ms/step - loss: 11.0182 - val_loss: 8.5504
#
# [20210301-0001-13] Learning rate for epoch 13 is 0.0005932347266934812
# Epoch 13/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.7097
# Epoch 00013: val_loss did not improve from 8.32174
# 17/17 [==============================] - 1s 71ms/step - loss: 10.7097 - val_loss: 9.7302
#
# [20210301-0001-16] Learning rate for epoch 14 is 0.0006419793353416026
# Epoch 14/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.6972
# Epoch 00014: val_loss did not improve from 8.32174
# 17/17 [==============================] - 1s 71ms/step - loss: 10.6972 - val_loss: 9.4424
#
# [20210301-0001-20] Learning rate for epoch 15 is 0.0006906240014359355
# Epoch 15/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.9904
# Epoch 00015: val_loss improved from 8.32174 to 8.00181, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 102ms/step - loss: 10.9904 - val_loss: 8.0018
#
# [20210301-0001-24] Learning rate for epoch 16 is 0.0007391686085611582
# Epoch 16/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.4391
# Epoch 00016: val_loss did not improve from 8.00181
# 17/17 [==============================] - 1s 70ms/step - loss: 10.4391 - val_loss: 10.1216
#
# [20210301-0001-28] Learning rate for epoch 17 is 0.0007876132731325924
# Epoch 17/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.3323
# Epoch 00017: val_loss did not improve from 8.00181
# 17/17 [==============================] - 1s 71ms/step - loss: 10.3323 - val_loss: 8.3111
#
# [20210301-0001-31] Learning rate for epoch 18 is 0.0008359579369425774
# Epoch 18/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.2709
# Epoch 00018: val_loss did not improve from 8.00181
# 17/17 [==============================] - 1s 70ms/step - loss: 10.2709 - val_loss: 9.7704
#
# [20210301-0001-35] Learning rate for epoch 19 is 0.000884202599991113
# Epoch 19/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.2019
# Epoch 00019: val_loss improved from 8.00181 to 7.65395, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 103ms/step - loss: 10.2019 - val_loss: 7.6540
#
# [20210301-0001-39] Learning rate for epoch 20 is 0.0009323473204858601
# Epoch 20/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.0705
# Epoch 00020: val_loss did not improve from 7.65395
# 17/17 [==============================] - 1s 70ms/step - loss: 10.0705 - val_loss: 9.7645
#
# [20210301-0001-42] Learning rate for epoch 21 is 0.000980391982011497
# Epoch 21/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.0561
# Epoch 00021: val_loss did not improve from 7.65395
# 17/17 [==============================] - 1s 72ms/step - loss: 10.0561 - val_loss: 7.6731
#
# [20210301-0001-46] Learning rate for epoch 22 is 0.0010283367009833455
# Epoch 22/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.9103
# Epoch 00022: val_loss did not improve from 7.65395
# 17/17 [==============================] - 1s 71ms/step - loss: 9.9103 - val_loss: 8.8234
#
# [20210301-0001-49] Learning rate for epoch 23 is 0.0010761814191937447
# Epoch 23/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.5762
# Epoch 00023: val_loss did not improve from 7.65395
# 17/17 [==============================] - 1s 69ms/step - loss: 9.5762 - val_loss: 8.6734
#
# [20210301-0001-53] Learning rate for epoch 24 is 0.0011239261366426945
# Epoch 24/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.5275
# Epoch 00024: val_loss did not improve from 7.65395
# 17/17 [==============================] - 1s 70ms/step - loss: 9.5275 - val_loss: 7.9382
#
# [20210301-0001-56] Learning rate for epoch 25 is 0.001171570853330195
# Epoch 25/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.4446
# Epoch 00025: val_loss did not improve from 7.65395
# 17/17 [==============================] - 1s 70ms/step - loss: 9.4446 - val_loss: 8.9224
#
# [20210301-0002-00] Learning rate for epoch 26 is 0.001219115569256246
# Epoch 26/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.6014
# Epoch 00026: val_loss did not improve from 7.65395
# 17/17 [==============================] - 1s 72ms/step - loss: 9.6014 - val_loss: 9.2549
#
# [20210301-0002-04] Learning rate for epoch 27 is 0.0012665604008361697
# Epoch 27/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.4598
# Epoch 00027: val_loss did not improve from 7.65395
# 17/17 [==============================] - 1s 71ms/step - loss: 9.4598 - val_loss: 12.1284
#
# [20210301-0002-07] Learning rate for epoch 28 is 0.0013139051152393222
# Epoch 28/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.3696
# Epoch 00028: val_loss did not improve from 7.65395
# 17/17 [==============================] - 1s 70ms/step - loss: 9.3696 - val_loss: 10.5711
#
# [20210301-0002-11] Learning rate for epoch 29 is 0.0013611499452963471
# Epoch 29/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.1162
# Epoch 00029: val_loss did not improve from 7.65395
# 17/17 [==============================] - 1s 71ms/step - loss: 9.1162 - val_loss: 11.5961
#
# [20210301-0002-14] Learning rate for epoch 30 is 0.001408294658176601
# Epoch 30/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.2067
# Epoch 00030: val_loss did not improve from 7.65395
# 17/17 [==============================] - 1s 69ms/step - loss: 9.2067 - val_loss: 11.1654
#
# [20210301-0002-17] Learning rate for epoch 31 is 0.0014553394867107272
# Epoch 31/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.3665
# Epoch 00039: val_loss did not improve from 7.65395
# 17/17 [==============================] - 1s 70ms/step - loss: 8.3665 - val_loss: 9.1885
#
# [20210301-0002-49] Learning rate for epoch 40 is 0.0018742431420832872
# Epoch 40/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.4703
# Epoch 00040: val_loss did not improve from 7.65395
# 17/17 [==============================] - 1s 71ms/step - loss: 8.4703 - val_loss: 9.2324
#
# [20210301-0002-53] Learning rate for epoch 41 is 0.0019202879630029202
# Epoch 41/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.2724
# Epoch 00041: val_loss did not improve from 7.65395
# 17/17 [==============================] - 1s 72ms/step - loss: 8.2724 - val_loss: 8.6895
#
# [20210301-0002-56] Learning rate for epoch 42 is 0.0019662328995764256
# Epoch 42/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.1695
# Epoch 00042: val_loss did not improve from 7.65395
# 17/17 [==============================] - 1s 71ms/step - loss: 8.1695 - val_loss: 8.7630
#
# [20210301-0002-59] Learning rate for epoch 43 is 0.00201207771897316
# Epoch 43/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.0245
# Epoch 00043: val_loss did not improve from 7.65395
# 17/17 [==============================] - 1s 71ms/step - loss: 8.0245 - val_loss: 7.9898
#
# [20210301-0003-03] Learning rate for epoch 44 is 0.0020578226540237665
# Epoch 44/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.3268
# Epoch 00044: val_loss did not improve from 7.65395
# 17/17 [==============================] - 1s 70ms/step - loss: 8.3268 - val_loss: 7.6834
#
# [20210301-0003-06] Learning rate for epoch 45 is 0.0021034677047282457
# Epoch 45/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.1716
# Epoch 00045: val_loss did not improve from 7.65395
# 17/17 [==============================] - 1s 72ms/step - loss: 8.1716 - val_loss: 7.7773
#
# [20210301-0003-10] Learning rate for epoch 46 is 0.002149012638255954
# Epoch 46/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.9821
# Epoch 00046: val_loss improved from 7.65395 to 7.40803, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 104ms/step - loss: 7.9821 - val_loss: 7.4080
#
# [20210301-0003-14] Learning rate for epoch 47 is 0.0021944576874375343
# Epoch 47/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.9169
# Epoch 00047: val_loss did not improve from 7.40803
# 17/17 [==============================] - 1s 70ms/step - loss: 7.9169 - val_loss: 7.7427
#
# [20210301-0003-17] Learning rate for epoch 48 is 0.0022398026194423437
# Epoch 48/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.6118
# Epoch 00048: val_loss did not improve from 7.40803
# 17/17 [==============================] - 1s 71ms/step - loss: 7.6118 - val_loss: 7.6766
#
# [20210301-0003-21] Learning rate for epoch 49 is 0.002285047434270382
# Epoch 49/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.9497
# Epoch 00049: val_loss improved from 7.40803 to 7.23297, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 103ms/step - loss: 7.9497 - val_loss: 7.2330
#
# [20210301-0003-25] Learning rate for epoch 50 is 0.0023301925975829363
# Epoch 50/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.7024
# Epoch 00050: val_loss did not improve from 7.23297
# 17/17 [==============================] - 1s 71ms/step - loss: 7.7024 - val_loss: 8.8321
#
# [20210301-0003-28] Learning rate for epoch 51 is 0.002375237410888076
# Epoch 51/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.5999
# Epoch 00051: val_loss did not improve from 7.23297
# 17/17 [==============================] - 1s 70ms/step - loss: 7.5999 - val_loss: 7.3288
#
# [20210301-0003-32] Learning rate for epoch 52 is 0.0024201825726777315
# Epoch 52/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.6682
# Epoch 00052: val_loss did not improve from 7.23297
# 17/17 [==============================] - 1s 72ms/step - loss: 7.6682 - val_loss: 8.4552
#
# [20210301-0003-35] Learning rate for epoch 53 is 0.002465027617290616
# Epoch 53/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.5938
# Epoch 00053: val_loss did not improve from 7.23297
# 17/17 [==============================] - 1s 70ms/step - loss: 7.5938 - val_loss: 8.5392
#
# [20210301-0003-39] Learning rate for epoch 54 is 0.0025097725447267294
# Epoch 54/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.5426
# Epoch 00054: val_loss improved from 7.23297 to 7.11583, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 102ms/step - loss: 7.5426 - val_loss: 7.1158
#
# [20210301-0003-43] Learning rate for epoch 55 is 0.0025544175878167152
# Epoch 55/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.3863
# Epoch 00055: val_loss improved from 7.11583 to 6.87625, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 103ms/step - loss: 7.3863 - val_loss: 6.8762
#
# [20210301-0003-47] Learning rate for epoch 56 is 0.00259896251372993
# Epoch 56/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.6429
# Epoch 00056: val_loss did not improve from 6.87625
# 17/17 [==============================] - 1s 71ms/step - loss: 7.6429 - val_loss: 7.0765
#
# [20210301-0003-50] Learning rate for epoch 57 is 0.0026434077881276608
# Epoch 57/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.4668
# Epoch 00057: val_loss improved from 6.87625 to 6.18689, saving model to ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 103ms/step - loss: 7.4668 - val_loss: 6.1869
#
# [20210301-0003-54] Learning rate for epoch 58 is 0.0026877527125179768
# Epoch 58/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.3488
# Epoch 00058: val_loss did not improve from 6.18689
# 17/17 [==============================] - 1s 70ms/step - loss: 7.3488 - val_loss: 6.3776
#
# [20210301-0003-57] Learning rate for epoch 59 is 0.0027319977525621653
# Epoch 59/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.3433
# Epoch 00059: val_loss did not improve from 6.18689
# 17/17 [==============================] - 1s 72ms/step - loss: 7.3433 - val_loss: 6.7724
#
# [20210301-0004-01] Learning rate for epoch 60 is 0.0027761429082602262
# Epoch 60/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.5712
# Epoch 00060: val_loss did not improve from 6.18689
# 17/17 [==============================] - 1s 70ms/step - loss: 7.5712 - val_loss: 6.9372
#
# [20210301-0004-04] Learning rate for epoch 61 is 0.002820187946781516
# Epoch 61/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.2847
# Epoch 00061: val_loss did not improve from 6.18689
# 17/17 [==============================] - 1s 71ms/step - loss: 7.2847 - val_loss: 7.3221
#
# [20210301-0004-08] Learning rate for epoch 62 is 0.0028641331009566784
# Epoch 62/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.2116
# Epoch 00062: val_loss did not improve from 6.18689
# 17/17 [==============================] - 1s 72ms/step - loss: 7.2116 - val_loss: 7.4583
#
# [20210301-0004-11] Learning rate for epoch 63 is 0.0029079781379550695
# Epoch 63/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.3623
# Epoch 00063: val_loss did not improve from 6.18689
# 17/17 [==============================] - 1s 71ms/step - loss: 7.3623 - val_loss: 7.2488
#
# [20210301-0004-15] Learning rate for epoch 64 is 0.002951723290607333
# Epoch 64/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.1859
# Epoch 00064: val_loss did not improve from 6.18689
# 17/17 [==============================] - 1s 72ms/step - loss: 7.1859 - val_loss: 6.5594
#
# [20210301-0004-18] Learning rate for epoch 65 is 0.0029953685589134693
# Epoch 65/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.3323
# Epoch 00065: val_loss did not improve from 6.18689
# 17/17 [==============================] - 1s 71ms/step - loss: 7.3323 - val_loss: 6.8923
#
# [20210301-0004-22] Learning rate for epoch 66 is 0.0030389137100428343
# ...
#
# [20210301-0228-44] Learning rate for epoch 73 is 0.0033409299794584513
# Epoch 73/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.1555
# Epoch 00073: val_loss did not improve from 5.94380
# 17/17 [==============================] - 1s 71ms/step - loss: 7.1555 - val_loss: 6.6480
#
# [20210301-0228-48] Learning rate for epoch 74 is 0.0033836751244962215
# Epoch 74/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.1666
# Epoch 00074: val_loss did not improve from 5.94380
# 17/17 [==============================] - 1s 69ms/step - loss: 7.1666 - val_loss: 7.7263
#
# [20210301-0228-51] Learning rate for epoch 75 is 0.0034263203851878643
# Epoch 75/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.1038
# Epoch 00075: val_loss did not improve from 5.94380
# 17/17 [==============================] - 1s 70ms/step - loss: 7.1038 - val_loss: 6.1846
#
# [20210301-0228-55] Learning rate for epoch 76 is 0.003468865528702736
# Epoch 76/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.4799
# Epoch 00076: val_loss did not improve from 5.94380
# 17/17 [==============================] - 1s 70ms/step - loss: 7.4799 - val_loss: 8.1523
#
# [20210301-0228-58] Learning rate for epoch 77 is 0.00351131078787148
# Epoch 77/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.2663
# Epoch 00077: val_loss did not improve from 5.94380
# 17/17 [==============================] - 1s 70ms/step - loss: 7.2663 - val_loss: 6.6039
#
# [20210301-0229-01] Learning rate for epoch 78 is 0.0035536561626940966
# Epoch 78/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.1477
# Epoch 00078: val_loss did not improve from 5.94380
# 17/17 [==============================] - 1s 70ms/step - loss: 7.1477 - val_loss: 7.1476
#
# [20210301-0229-05] Learning rate for epoch 79 is 0.003595901420339942
# Epoch 79/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.3413
# Epoch 00079: val_loss did not improve from 5.94380
# 17/17 [==============================] - 1s 69ms/step - loss: 7.3413 - val_loss: 7.8123
#
# [20210301-0229-08] Learning rate for epoch 80 is 0.00363804679363966
# Epoch 80/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.7955
# Epoch 00080: val_loss did not improve from 5.94380
# 17/17 [==============================] - 1s 71ms/step - loss: 6.7955 - val_loss: 7.5587
#
# [20210301-0229-12] Learning rate for epoch 81 is 0.0036800920497626066
# Epoch 81/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.0426
# Epoch 00081: val_loss did not improve from 5.94380
# 17/17 [==============================] - 1s 70ms/step - loss: 7.0426 - val_loss: 6.6603
#
# [20210301-0229-15] Learning rate for epoch 82 is 0.003722037188708782
# Epoch 82/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.9969
# Epoch 00082: val_loss did not improve from 5.94380
# 17/17 [==============================] - 1s 69ms/step - loss: 6.9969 - val_loss: 6.4607
#
# [20210301-0229-18] Learning rate for epoch 83 is 0.003763882676139474
# Epoch 83/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.8887
# Epoch 00083: val_loss did not improve from 5.94380
# 17/17 [==============================] - 1s 71ms/step - loss: 6.8887 - val_loss: 6.2671
#
# [20210301-0229-22] Learning rate for epoch 84 is 0.0038056280463933945
# Epoch 84/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.8926
# Epoch 00084: val_loss did not improve from 5.94380
# 17/17 [==============================] - 1s 68ms/step - loss: 6.8926 - val_loss: 7.8369
#
# [20210301-0229-25] Learning rate for epoch 85 is 0.003847273299470544
# Epoch 85/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.3506
# Epoch 00085: val_loss improved from 5.94380 to 5.90024, saving model to ./20210228-235432/toe_K4_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 106ms/step - loss: 7.3506 - val_loss: 5.9002
#
# [20210301-0229-29] Learning rate for epoch 86 is 0.0038888186682015657
# Epoch 86/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.7894
# Epoch 00086: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 70ms/step - loss: 6.7894 - val_loss: 7.4293
#
# [20210301-0229-33] Learning rate for epoch 87 is 0.00393026415258646
# Epoch 87/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.0695
# Epoch 00087: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 70ms/step - loss: 7.0695 - val_loss: 6.5790
#
# [20210301-0229-36] Learning rate for epoch 88 is 0.00397160928696394
# Epoch 88/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.0510
# Epoch 00088: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 70ms/step - loss: 7.0510 - val_loss: 6.2407
#
# [20210301-0229-40] Learning rate for epoch 89 is 0.004012854769825935
# Epoch 89/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.7989
# Epoch 00089: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 70ms/step - loss: 6.7989 - val_loss: 6.3963
#
# [20210301-0229-43] Learning rate for epoch 90 is 0.00405400013551116
# Epoch 90/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.9846
# Epoch 00090: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 70ms/step - loss: 6.9846 - val_loss: 7.3140
#
# [20210301-0229-46] Learning rate for epoch 91 is 0.004095045384019613
# Epoch 91/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.9932
# Epoch 00091: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 69ms/step - loss: 6.9932 - val_loss: 6.3573
#
# [20210301-0229-50] Learning rate for epoch 92 is 0.004135990981012583
# Epoch 92/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.9306
# Epoch 00092: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 71ms/step - loss: 6.9306 - val_loss: 6.7025
#
# [20210301-0229-53] Learning rate for epoch 93 is 0.004176836460828781
# Epoch 93/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.9397
# Epoch 00093: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 70ms/step - loss: 6.9397 - val_loss: 7.3058
#
# [20210301-0229-56] Learning rate for epoch 94 is 0.004217581823468208
# Epoch 94/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.1508
# Epoch 00094: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 72ms/step - loss: 7.1508 - val_loss: 6.5272
#
# [20210301-0230-00] Learning rate for epoch 95 is 0.004258227068930864
# Epoch 95/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.8896
# Epoch 00095: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 72ms/step - loss: 6.8896 - val_loss: 6.7679
#
# [20210301-0230-04] Learning rate for epoch 96 is 0.0042987726628780365
# Epoch 96/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.0185
# Epoch 00096: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 68ms/step - loss: 7.0185 - val_loss: 7.1450
#
# [20210301-0230-07] Learning rate for epoch 97 is 0.0043392181396484375
# Epoch 97/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.9217
# Epoch 00097: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 71ms/step - loss: 6.9217 - val_loss: 6.6472
#
# [20210301-0230-10] Learning rate for epoch 98 is 0.004379563499242067
# Epoch 98/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.7085
# Epoch 00098: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 70ms/step - loss: 6.7085 - val_loss: 6.2986
#
# [20210301-0230-14] Learning rate for epoch 99 is 0.004419809207320213
# Epoch 99/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.7756
# Epoch 00099: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 70ms/step - loss: 6.7756 - val_loss: 6.5979
#
# [20210301-0230-17] Learning rate for epoch 100 is 0.004459954332560301
# Epoch 100/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.0932
# Epoch 00100: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 70ms/step - loss: 7.0932 - val_loss: 7.6619
#
# [20210301-0230-21] Learning rate for epoch 101 is 4.4999998749517545e-07
# Epoch 101/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.6999
# Epoch 00101: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 72ms/step - loss: 6.6999 - val_loss: 7.3235
#
# [20210301-0230-24] Learning rate for epoch 102 is 0.00018023152370005846
# Epoch 102/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.7055
# Epoch 00102: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 71ms/step - loss: 6.7055 - val_loss: 6.5387
#
# [20210301-0230-28] Learning rate for epoch 103 is 0.000359613070031628
# Epoch 103/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.3343
# Epoch 00103: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 69ms/step - loss: 6.3343 - val_loss: 6.0188
#
# [20210301-0230-31] Learning rate for epoch 104 is 0.0005385946715250611
# Epoch 104/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.3372
# Epoch 00104: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 71ms/step - loss: 6.3372 - val_loss: 5.9077
#
# [20210301-0230-35] Learning rate for epoch 105 is 0.0007171762990765274
# Epoch 105/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.5983
# Epoch 00105: val_loss did not improve from 5.90024
# 17/17 [==============================] - 1s 68ms/step - loss: 6.5983 - val_loss: 5.9813
#
# [20210301-0230-38] Learning rate for epoch 106 is 0.0008953579817898571
# Epoch 106/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.4721
# Epoch 00106: val_loss improved from 5.90024 to 5.79069, saving model to ./20210228-235432/toe_K4_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 104ms/step - loss: 6.4721 - val_loss: 5.7907
#
# [20210301-0230-42] Learning rate for epoch 107 is 0.0010731397196650505
# Epoch 107/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.3948
# Epoch 00107: val_loss did not improve from 5.79069
# 17/17 [==============================] - 1s 71ms/step - loss: 6.3948 - val_loss: 6.1086
#
# [20210301-0230-45] Learning rate for epoch 108 is 0.0012505215127021074
# Epoch 108/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.2723
# Epoch 00108: val_loss did not improve from 5.79069
# 17/17 [==============================] - 1s 69ms/step - loss: 6.2723 - val_loss: 5.8608
#
# [20210301-0230-49] Learning rate for epoch 109 is 0.001427503302693367
# Epoch 109/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.1624
# Epoch 00109: val_loss did not improve from 5.79069
# 17/17 [==============================] - 1s 69ms/step - loss: 6.1624 - val_loss: 6.0255
#
# [20210301-0230-52] Learning rate for epoch 110 is 0.0016040850896388292
# Epoch 110/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.2278
# Epoch 00110: val_loss did not improve from 5.79069
# 17/17 [==============================] - 1s 69ms/step - loss: 6.2278 - val_loss: 5.9457
#
# [20210301-0230-56] Learning rate for epoch 111 is 0.001780266989953816
# Epoch 111/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.1990
# Epoch 00111: val_loss did not improve from 5.79069
# 17/17 [==============================] - 1s 68ms/step - loss: 6.1990 - val_loss: 6.1243
#
# [20210301-0230-59] Learning rate for epoch 112 is 0.0019560488872230053
# Epoch 112/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.3171
# Epoch 00112: val_loss did not improve from 5.79069
# 17/17 [==============================] - 1s 70ms/step - loss: 6.3171 - val_loss: 6.0289
#
# [20210301-0231-02] Learning rate for epoch 113 is 0.002131430897861719
# Epoch 113/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.3475
# Epoch 00113: val_loss did not improve from 5.79069
# 17/17 [==============================] - 1s 69ms/step - loss: 6.3475 - val_loss: 6.7411
#
# [20210301-0231-06] Learning rate for epoch 114 is 0.0023064129054546356
# Epoch 114/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.5694
# Epoch 00114: val_loss did not improve from 5.79069
# 17/17 [==============================] - 1s 72ms/step - loss: 6.5694 - val_loss: 5.8868
#
# [20210301-0231-09] Learning rate for epoch 115 is 0.0024809949100017548
# Epoch 115/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.4045
# Epoch 00115: val_loss did not improve from 5.79069
# 17/17 [==============================] - 1s 71ms/step - loss: 6.4045 - val_loss: 6.0345
#
# [20210301-0231-12] Learning rate for epoch 116 is 0.0026551769115030766
# Epoch 116/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.2447
# Epoch 00116: val_loss did not improve from 5.79069
# 17/17 [==============================] - 1s 69ms/step - loss: 6.2447 - val_loss: 6.1852
#
# [20210301-0231-16] Learning rate for epoch 117 is 0.0028289591427892447
# Epoch 117/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.5060
# Epoch 00117: val_loss did not improve from 5.79069
# 17/17 [==============================] - 1s 71ms/step - loss: 6.5060 - val_loss: 6.1530
#
# [20210301-0231-20] Learning rate for epoch 118 is 0.0030023413710296154
# Epoch 118/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.4137
# Epoch 00118: val_loss did not improve from 5.79069
# 17/17 [==============================] - 1s 69ms/step - loss: 6.4137 - val_loss: 6.1613
#
# [20210301-0231-23] Learning rate for epoch 119 is 0.003175323596224189
# Epoch 119/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.3933
# Epoch 00119: val_loss did not improve from 5.79069
# 17/17 [==============================] - 1s 71ms/step - loss: 6.3933 - val_loss: 7.2500
#
# [20210301-0231-27] Learning rate for epoch 120 is 0.003347905818372965
# Epoch 120/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.5201
# Epoch 00120: val_loss did not improve from 5.79069
# 17/17 [==============================] - 1s 69ms/step - loss: 6.5201 - val_loss: 6.4335
#
# [20210301-0231-30] Learning rate for epoch 121 is 0.0035200880374759436
# Epoch 121/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.3854
# Epoch 00121: val_loss did not improve from 5.79069
# 17/17 [==============================] - 1s 70ms/step - loss: 6.3854 - val_loss: 6.3339
#
# [20210301-0231-34] Learning rate for epoch 122 is 0.003691870253533125
# Epoch 122/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.3976
# Epoch 00122: val_loss did not improve from 5.79069
# 17/17 [==============================] - 1s 70ms/step - loss: 6.3976 - val_loss: 6.0851
#
# [20210301-0231-37] Learning rate for epoch 123 is 0.0038632526993751526
# Epoch 123/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.6178
# Epoch 00123: val_loss did not improve from 5.79069
# 17/17 [==============================] - 1s 69ms/step - loss: 6.6178 - val_loss: 8.2750
#
# [20210301-0231-40] Learning rate for epoch 124 is 0.004034235142171383
# Epoch 124/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.6050
# Epoch 00124: val_loss did not improve from 5.79069
# 17/17 [==============================] - 1s 71ms/step - loss: 6.6050 - val_loss: 6.1034
#
# [20210301-0231-44] Learning rate for epoch 125 is 0.004204817581921816
# Epoch 125/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.4104
# Epoch 00125: val_loss did not improve from 5.79069
# 17/17 [==============================] - 1s 70ms/step - loss: 6.4104 - val_loss: 6.5972
#
# [20210301-0231-47] Learning rate for epoch 126 is 0.0043750000186264515
# Epoch 126/1000
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#ED sum
def get_valloss(his_v_l):  
    return np.min(his_v_l), np.argmin(his_v_l)

t_vl = []
# h_vl = []
for k in range(KFlodNum):
    print(f'K:{k}')
    t_v, _ = get_valloss(history_toe_finetune[k].history['val_loss'])
#     h_v, _ = get_valloss(history_heel_finetune[k].history['val_loss'])
    
    t_vl.append(t_v)
#     h_vl.append(h_v)

# t_vl = np.mean(t_vl, axis=0)
# h_vl = np.mean(h_vl, axis=0)
# print(f'{round(t_vl,5)} + {round(h_vl,5)} = {round(t_vl + h_vl,5)}')

t_vl
# Out:
# K:0
# K:1
# K:2
# K:3
# K:4
# [5.383011341094971,
#  5.7076239585876465,
#  5.339352130889893,
#  5.177703857421875,
#  5.674964904785156]

# %%
np.savetxt(f'{log_dir_name}/toe_FNED.txt', t_vl)

# %%
# Sum plot losses toe-tl

plt.figure(figsize=(25, 10))

for k in range(KFlodNum):

    plt.plot(history_toe[k].history['loss'])
    plt.plot(history_toe[k].history['val_loss'])

    
plt.title('K-model ed loss toe-TL')
plt.ylabel('ed loss'), plt.ylim(5, 80)# for too large loss
plt.xlabel('epoch')
plt.legend(['k0 loss', 'k0 val_loss', 'k1 loss', 'k1 val_loss', 'k2 loss', 'k2 val_loss', 
            'k3 loss', 'k3 val_loss', 'k4 loss', 'k4 val_loss'], loc='upper left') 
# plt.show()

# save plot : comment plo.show in jupyter notebook.
plt.savefig(f'{log_dir_name}/{log_dir_name}_toe_Ksum_TL.png', bbox_inches = 'tight')

# %%
# Single plot loss toe-tl

for k in range(KFlodNum):
    plt.figure(figsize=(25, 10))
    plt.plot(history_toe[k].history['loss'])
    plt.plot(history_toe[k].history['val_loss'])
    plt.title('K-model ed loss toe-TL')
    plt.ylabel('ed loss'), plt.ylim(5, 20)# for too large loss
    plt.xlabel('epoch')
    plt.legend(['loss', 'val_loss'], loc='upper left') 
    # plt.show()

    # save plot : comment plo.show in jupyter notebook.
    def get_valloss(his_v_l):   
        return np.min(his_v_l), np.argmin(his_v_l)

    vl, ep = get_valloss(history_toe[k].history['val_loss'])
    plt.savefig(f'{log_dir_name}/{log_dir_name}_toe_K{k}_TL_clr_ed{round(vl,4)}@{ep}.png', bbox_inches = 'tight')

# %%
# check the loos the model trained.

def get_valloss(his_v_l):  
    return np.min(his_v_l), np.argmin(his_v_l)

t_vl = []
# h_vl = []
for k in range(KFlodNum):
    print(f'K:{k}')
    t_v, _ = get_valloss(history_toe_finetune[k].history['val_loss'])
#     h_v, _ = get_valloss(history_heel_finetune[k].history['val_loss'])
    
    t_vl.append(t_v)
    
# for different scales (different Y-axes)
# fig, ax1 = plt.subplots()
fig, ax1 = plt.subplots(figsize=(25, 10))

# nice to have this colorful tip.
color = 'tab:red'

ax1.set_title('[ toe_finetune ] \n ED loss')

ax1.set_xlabel('epoch')
ax1.set_ylabel('ed loss', color=color)

for k in range(KFlodNum):

    plt.plot(history_toe_finetune[k].history['loss'])
    plt.plot(history_toe_finetune[k].history['val_loss'])

ax1.tick_params(axis='y', labelcolor=color)
# ax1.legend(['loss', 'val_loss'], loc='upper center') # legend may ocvered by next ax ploting. moved to end.
ax1.legend(['k0 loss', 'k0 val_loss', 'k1 loss', 'k1 val_loss', 'k2 loss', 'k2 val_loss', 
            'k3 loss', 'k3 val_loss', 'k4 loss', 'k4 val_loss'], loc='upper left') 

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('learning rate', color=color)
ax2.plot(history_toe_finetune[0].history['lr'], color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.legend(['lr'], loc='upper right') 

# plt.show()

# # save plot : comment plo.show in jupyter notebook.
# def get_valloss(his_v_l):   
#     return np.min(his_v_l), np.argmin(his_v_l)

# vl, ep = get_valloss(history_toe_finetune.history['val_loss'])


t_vl = np.mean(t_vl, axis=0)
plt.savefig(f'{log_dir_name}/{log_dir_name}_toe_ft_Ksum-clr_ed{round(t_vl,4)}.png', bbox_inches = 'tight')
# Out:
# K:0
# K:1
# K:2
# K:3
# K:4

# %%
# Sum plot losses toe-ft

plt.figure(figsize=(25, 10))

for k in range(KFlodNum):

    plt.plot(history_toe_finetune[k].history['loss'])
    plt.plot(history_toe_finetune[k].history['val_loss'])

    
plt.title('K-model ed loss toe-FT')
plt.ylabel('ed loss'), plt.ylim(4, 20)# for too large loss
plt.xlabel('epoch')
plt.legend(['k0 loss', 'k0 val_loss', 'k1 loss', 'k1 val_loss', 'k2 loss', 'k2 val_loss', 
            'k3 loss', 'k3 val_loss', 'k4 loss', 'k4 val_loss'], loc='upper left') 
# plt.show()

# save plot : comment plo.show in jupyter notebook.
plt.savefig(f'{log_dir_name}/{log_dir_name}_toe_Ksum_FT.png', bbox_inches = 'tight')

# %%
# Single plot loss toe-FT

for k in range(KFlodNum):
    plt.figure(figsize=(25, 10))
    plt.plot(history_toe_finetune[k].history['loss'])
    plt.plot(history_toe_finetune[k].history['val_loss'])
    plt.title('K-model ed loss toe-FT')
    plt.ylabel('ed loss'), plt.ylim(4, 20)# for too large loss
    plt.xlabel('epoch')
    plt.legend(['loss', 'val_loss'], loc='upper left') 
    # plt.show()

    # save plot : comment plo.show in jupyter notebook.
    def get_valloss(his_v_l):   
        return np.min(his_v_l), np.argmin(his_v_l)

    vl, ep = get_valloss(history_toe_finetune[k].history['val_loss'])
    plt.savefig(f'{log_dir_name}/{log_dir_name}_toe_K{k}_FT_clr_ed{round(vl,4)}@{ep}.png', bbox_inches = 'tight')

# %% [markdown]
# ### Heel K-model

# %%
# %%time

# big K = 5 (fold 0 ~ 4) 
# KFlodNum = 5 # follow Toe's K.



history_heel = []
history_heel_finetune = []

#above until 'train_ds_map_toe now' to 'train_ds_map_toe_s', 'valid_ds_map_toe_s'
for k in range(KFlodNum):
    
    
    # Split data to train/valid with K-Fold #
    print("K=", k)
#     # Toe split
#     train_ds_map_toe_s, valid_ds_map_toe_s = get_KFold_ds(train_ds_map_toe, K=k)
    
#     # Toe ds_pre
#     train_ds_pre_toe_s = configure_for_performance_cache_train(train_ds_map_toe_s, augment=True)
#     valid_ds_pre_toe_s = configure_for_performance_cache_val(valid_ds_map_toe_s)
    
    
    # heel split
    train_ds_map_heel_s, valid_ds_map_heel_s = get_KFold_ds(train_ds_map_heel, K=k)
    # Heel ds_pre
    train_ds_pre_heel_s = configure_for_performance_cache_train_AToe(train_ds_map_heel_s, augment=True)
    valid_ds_pre_heel_s = configure_for_performance_cache_val(valid_ds_map_heel_s)
    
    
    # Train K-Model with transfer learnling #
    
    # Toe model, TL
    #th = 'toe'
    th = 'heel'
    best_model_name = get_best_model_name(th, K=str(k))
    best_model_save = tf.keras.callbacks.ModelCheckpoint(filepath=best_model_name, 
                                 save_best_only = True, 
                                 save_weights_only = False,
                                 monitor = monitor, 
                                 mode = 'auto', verbose = 1)
    callbacks_heel_tl = [
                    #     tensorboard_callback,
                        best_model_save,
                        tf.keras.callbacks.EarlyStopping(monitor=monitor, patience=40), #patience=step_size or ep_num
                    #     lr_reduceonplateau,
                        tf.keras.callbacks.LearningRateScheduler(lrdump),#lrdump, decay or lrfn or lrfn2. clr
                        PrintLRtoe()
                        ]
    callbacks_heel_fn = [
                    #     tensorboard_callback,
                        best_model_save,
                        tf.keras.callbacks.EarlyStopping(monitor=monitor, patience=200), #patience=step_size or ep_num
                    #     lr_reduceonplateau,
                        tf.keras.callbacks.LearningRateScheduler(clr3),#lrdump, decay or lrfn or lrfn2. clr, CosineDecayCLRWarmUp, CosineDecayCLRWarmUpLSW
                        PrintLRheel()
                    ]
    print('best_model_name:', best_model_name)


    top_dropout_rate = 0.4 #less dp rate, say 0.1, train_loss will lower than val_loss
    drop_connect_rate = 0.4 #for efnet This parameter serves as a toggle for extra regularization in finetuning, but does not affect loaded weights.
    outputnum = 2
    with strategy.scope():
        model_heel = build_efn_model(outputnum, top_dropout_rate, drop_connect_rate)
    # fit the model on all data
    hist = model_heel.fit(train_ds_pre_heel_s, 
                          verbose=1, 
                          epochs=ep_num_transf, 
                          validation_data=valid_ds_pre_heel_s, 
                          callbacks=callbacks_heel_tl)#, validation_split=0.1)
    history_heel.append(hist)
    
      
    # Train K-Model with fine tune #
    
    # Toe model, FT
    unfreeze_model(model_heel)
    count_model_trainOrNot_layers(model_heel)
    # fit the model on all data
    hist = model_heel.fit(train_ds_pre_heel_s, 
                          verbose=1, 
                          epochs=ep_num, 
                          validation_data=valid_ds_pre_heel_s, 
                          callbacks=callbacks_heel_fn)#, validation_split=0.1)
    history_heel_finetune.append(hist)
# Out:
# K= 0
# Check cache in memory:Y True
# Check keypoints process01: Tensor("args_1:0", shape=(2,), dtype=int64) (2,) <class 'tensorflow.python.framework.ops.Tensor'>
# Check keypoints process02: Tensor("Reshape:0", shape=(1, 2), dtype=int64) (1, 2) <class 'tensorflow.python.framework.ops.Tensor'>
# Check keypoints process03: Tensor("PyFunc:1", dtype=float32, device=/job:localhost/replica:0/task:0)
# Check keypoints process04: Tensor("Reshape_1:0", shape=(2,), dtype=float32)
# Check augment :Y True
# Check ds cache[True] and augment[True]
# Check cache in memory:Y True
# Check augment :N False
# Check ds cache[True] and augment[False]
# best_model_name: ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# base_model.trainable :  False
#
# [20210301-0256-24] Learning rate for epoch 1 is 0.000455181987490505
# Epoch 1/500
# 15/17 [=========================>....] - ETA: 0s - loss: 107.2289
# Epoch 00001: val_loss improved from inf to 87.60158, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 11s 641ms/step - loss: 105.7845 - val_loss: 87.6016
#
# [20210301-0256-48] Learning rate for epoch 2 is 0.000455181987490505
# Epoch 2/500
# 17/17 [==============================] - ETA: 0s - loss: 51.2303
# Epoch 00002: val_loss improved from 87.60158 to 29.49579, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 51.2303 - val_loss: 29.4958
#
# [20210301-0256-52] Learning rate for epoch 3 is 0.000455181987490505
# Epoch 3/500
# 17/17 [==============================] - ETA: 0s - loss: 24.2951
# Epoch 00003: val_loss improved from 29.49579 to 23.63378, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 8s 496ms/step - loss: 24.2951 - val_loss: 23.6338
#
# [20210301-0257-03] Learning rate for epoch 4 is 0.000455181987490505
# Epoch 4/500
# 16/17 [===========================>..] - ETA: 0s - loss: 18.6831
# Epoch 00004: val_loss improved from 23.63378 to 19.79912, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 18.7212 - val_loss: 19.7991
#
# [20210301-0257-06] Learning rate for epoch 5 is 0.000455181987490505
# Epoch 5/500
# 16/17 [===========================>..] - ETA: 0s - loss: 17.6150
# Epoch 00005: val_loss improved from 19.79912 to 19.19138, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 17.5179 - val_loss: 19.1914
#
# [20210301-0257-10] Learning rate for epoch 6 is 0.000455181987490505
# Epoch 6/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.8610
# Epoch 00006: val_loss did not improve from 19.19138
# 17/17 [==============================] - 0s 25ms/step - loss: 16.8093 - val_loss: 19.3709
#
# [20210301-0257-13] Learning rate for epoch 7 is 0.000455181987490505
# Epoch 7/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.9754
# Epoch 00007: val_loss improved from 19.19138 to 18.84160, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 15.9521 - val_loss: 18.8416
#
# [20210301-0257-17] Learning rate for epoch 8 is 0.000455181987490505
# Epoch 8/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.0704
# Epoch 00008: val_loss improved from 18.84160 to 18.21152, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 15.9887 - val_loss: 18.2115
#
# [20210301-0257-21] Learning rate for epoch 9 is 0.000455181987490505
# Epoch 9/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.6364
# Epoch 00009: val_loss improved from 18.21152 to 17.77584, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 15.5889 - val_loss: 17.7758
#
# [20210301-0257-24] Learning rate for epoch 10 is 0.000455181987490505
# Epoch 10/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.3098
# Epoch 00010: val_loss improved from 17.77584 to 17.57749, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 15.2902 - val_loss: 17.5775
#
# [20210301-0257-28] Learning rate for epoch 11 is 0.000455181987490505
# Epoch 11/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.4402
# Epoch 00011: val_loss improved from 17.57749 to 16.77369, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 15.5586 - val_loss: 16.7737
#
# [20210301-0257-31] Learning rate for epoch 12 is 0.000455181987490505
# Epoch 12/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.5090
# Epoch 00012: val_loss did not improve from 16.77369
# 17/17 [==============================] - 0s 25ms/step - loss: 15.5336 - val_loss: 17.1004
#
# [20210301-0257-35] Learning rate for epoch 13 is 0.000455181987490505
# Epoch 13/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.1741
# Epoch 00013: val_loss did not improve from 16.77369
# 17/17 [==============================] - 0s 24ms/step - loss: 15.1947 - val_loss: 17.3009
#
# [20210301-0257-38] Learning rate for epoch 14 is 0.000455181987490505
# Epoch 14/500
# 17/17 [==============================] - ETA: 0s - loss: 15.0978
# Epoch 00014: val_loss improved from 16.77369 to 15.78780, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 48ms/step - loss: 15.0978 - val_loss: 15.7878
#
# [20210301-0257-41] Learning rate for epoch 15 is 0.000455181987490505
# Epoch 15/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.2208
# Epoch 00015: val_loss improved from 15.78780 to 15.18803, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 15.3123 - val_loss: 15.1880
#
# [20210301-0257-45] Learning rate for epoch 16 is 0.000455181987490505
# Epoch 16/500
# 17/17 [==============================] - ETA: 0s - loss: 14.6543
# Epoch 00016: val_loss improved from 15.18803 to 14.61421, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 14.6543 - val_loss: 14.6142
#
# [20210301-0257-48] Learning rate for epoch 17 is 0.000455181987490505
# Epoch 17/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.2642
# Epoch 00017: val_loss improved from 14.61421 to 14.60318, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 15.1599 - val_loss: 14.6032
#
# [20210301-0257-52] Learning rate for epoch 18 is 0.000455181987490505
# Epoch 18/500
# 17/17 [==============================] - ETA: 0s - loss: 14.7541
# Epoch 00018: val_loss improved from 14.60318 to 13.51113, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 14.7541 - val_loss: 13.5111
#
# [20210301-0257-55] Learning rate for epoch 19 is 0.000455181987490505
# Epoch 19/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.3705
# Epoch 00019: val_loss did not improve from 13.51113
# 17/17 [==============================] - 0s 25ms/step - loss: 14.4047 - val_loss: 13.8269
#
# [20210301-0257-59] Learning rate for epoch 20 is 0.000455181987490505
# Epoch 20/500
# 17/17 [==============================] - ETA: 0s - loss: 14.3845
# Epoch 00020: val_loss improved from 13.51113 to 13.28795, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 14.3845 - val_loss: 13.2880
#
# [20210301-0258-02] Learning rate for epoch 21 is 0.000455181987490505
# Epoch 21/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.6638
# Epoch 00021: val_loss improved from 13.28795 to 13.25194, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 14.6872 - val_loss: 13.2519
#
# [20210301-0258-05] Learning rate for epoch 22 is 0.000455181987490505
# Epoch 22/500
# 17/17 [==============================] - ETA: 0s - loss: 14.5878
# Epoch 00022: val_loss improved from 13.25194 to 12.48049, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 14.5878 - val_loss: 12.4805
#
# [20210301-0258-08] Learning rate for epoch 23 is 0.000455181987490505
# Epoch 23/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.5700
# Epoch 00023: val_loss improved from 12.48049 to 12.20986, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 14.6227 - val_loss: 12.2099
#
# [20210301-0258-12] Learning rate for epoch 24 is 0.000455181987490505
# Epoch 24/500
# 14/17 [=======================>......] - ETA: 0s - loss: 13.6256
# Epoch 00024: val_loss improved from 12.20986 to 12.17707, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 13.7321 - val_loss: 12.1771
#
# [20210301-0258-15] Learning rate for epoch 25 is 0.000455181987490505
# Epoch 25/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.4797
# Epoch 00025: val_loss improved from 12.17707 to 11.90483, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 14.5318 - val_loss: 11.9048
#
# [20210301-0258-18] Learning rate for epoch 26 is 0.000455181987490505
# Epoch 26/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.6421
# Epoch 00026: val_loss improved from 11.90483 to 11.12800, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 14.5703 - val_loss: 11.1280
#
# [20210301-0258-21] Learning rate for epoch 27 is 0.000455181987490505
# Epoch 27/500
# 17/17 [==============================] - ETA: 0s - loss: 13.7369
# Epoch 00027: val_loss improved from 11.12800 to 9.96317, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 13.7369 - val_loss: 9.9632
#
# [20210301-0258-25] Learning rate for epoch 28 is 0.000455181987490505
# Epoch 28/500
# 15/17 [=========================>....] - ETA: 0s - loss: 13.5394
# Epoch 00028: val_loss did not improve from 9.96317
# 17/17 [==============================] - 0s 23ms/step - loss: 13.6709 - val_loss: 11.0075
#
# [20210301-0258-28] Learning rate for epoch 29 is 0.000455181987490505
# Epoch 29/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.7826
# Epoch 00029: val_loss did not improve from 9.96317
# 17/17 [==============================] - 0s 25ms/step - loss: 14.7747 - val_loss: 10.3937
#
# [20210301-0258-30] Learning rate for epoch 30 is 0.000455181987490505
# Epoch 30/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.5020
# Epoch 00030: val_loss did not improve from 9.96317
# 17/17 [==============================] - 0s 25ms/step - loss: 14.5696 - val_loss: 10.1458
#
# [20210301-0258-33] Learning rate for epoch 31 is 0.000455181987490505
# Epoch 31/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.2025
# Epoch 00031: val_loss did not improve from 9.96317
# 17/17 [==============================] - 0s 24ms/step - loss: 14.2464 - val_loss: 10.7512
#
# [20210301-0258-36] Learning rate for epoch 32 is 0.000455181987490505
# Epoch 32/500
# 14/17 [=======================>......] - ETA: 0s - loss: 14.4009
# Epoch 00032: val_loss did not improve from 9.96317
# 17/17 [==============================] - 0s 24ms/step - loss: 14.1790 - val_loss: 9.9696
#
# [20210301-0258-39] Learning rate for epoch 33 is 0.000455181987490505
# Epoch 33/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.9032
# Epoch 00033: val_loss did not improve from 9.96317
# 17/17 [==============================] - 0s 25ms/step - loss: 13.9306 - val_loss: 10.6699
#
# [20210301-0258-42] Learning rate for epoch 34 is 0.000455181987490505
# Epoch 34/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.7082
# Epoch 00034: val_loss improved from 9.96317 to 8.79511, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 13.6965 - val_loss: 8.7951
#
# [20210301-0258-45] Learning rate for epoch 35 is 0.000455181987490505
# Epoch 35/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.0418
# Epoch 00035: val_loss improved from 8.79511 to 8.51985, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 14.0009 - val_loss: 8.5199
#
# [20210301-0258-48] Learning rate for epoch 36 is 0.000455181987490505
# Epoch 36/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.7507
# Epoch 00036: val_loss did not improve from 8.51985
# 17/17 [==============================] - 0s 25ms/step - loss: 13.8646 - val_loss: 8.7841
#
# [20210301-0258-51] Learning rate for epoch 37 is 0.000455181987490505
# Epoch 37/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.1605
# Epoch 00037: val_loss did not improve from 8.51985
# 17/17 [==============================] - 0s 24ms/step - loss: 14.2973 - val_loss: 8.9504
#
# [20210301-0258-54] Learning rate for epoch 38 is 0.000455181987490505
# Epoch 38/500
# 17/17 [==============================] - ETA: 0s - loss: 14.1428
# Epoch 00038: val_loss did not improve from 8.51985
# 17/17 [==============================] - 0s 25ms/step - loss: 14.1428 - val_loss: 8.7663
#
# [20210301-0258-57] Learning rate for epoch 39 is 0.000455181987490505
# Epoch 39/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.8429
# Epoch 00039: val_loss did not improve from 8.51985
# 17/17 [==============================] - 0s 26ms/step - loss: 14.7415 - val_loss: 10.2593
#
# [20210301-0259-00] Learning rate for epoch 40 is 0.000455181987490505
# Epoch 40/500
# 17/17 [==============================] - ETA: 0s - loss: 14.3342
# Epoch 00040: val_loss did not improve from 8.51985
# 17/17 [==============================] - 0s 24ms/step - loss: 14.3342 - val_loss: 10.8026
#
# [20210301-0259-02] Learning rate for epoch 41 is 0.000455181987490505
# Epoch 41/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.5027
# Epoch 00041: val_loss did not improve from 8.51985
# 17/17 [==============================] - 0s 25ms/step - loss: 14.4555 - val_loss: 9.9977
#
# [20210301-0259-05] Learning rate for epoch 42 is 0.000455181987490505
# Epoch 42/500
# 17/17 [==============================] - ETA: 0s - loss: 14.4627
# Epoch 00042: val_loss did not improve from 8.51985
# 17/17 [==============================] - 0s 25ms/step - loss: 14.4627 - val_loss: 10.5202
#
# [20210301-0259-08] Learning rate for epoch 43 is 0.000455181987490505
# Epoch 43/500
# 17/17 [==============================] - ETA: 0s - loss: 13.8837
# Epoch 00043: val_loss improved from 8.51985 to 7.94959, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 48ms/step - loss: 13.8837 - val_loss: 7.9496
#
# [20210301-0259-11] Learning rate for epoch 44 is 0.000455181987490505
# Epoch 44/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.9171
# Epoch 00044: val_loss did not improve from 7.94959
# 17/17 [==============================] - 0s 25ms/step - loss: 13.9798 - val_loss: 8.0045
#
# [20210301-0259-14] Learning rate for epoch 45 is 0.000455181987490505
# Epoch 45/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.8880
# Epoch 00045: val_loss did not improve from 7.94959
# 17/17 [==============================] - 0s 25ms/step - loss: 13.9175 - val_loss: 8.5084
#
# [20210301-0259-17] Learning rate for epoch 46 is 0.000455181987490505
# Epoch 46/500
# 17/17 [==============================] - ETA: 0s - loss: 14.1020
# Epoch 00046: val_loss improved from 7.94959 to 7.78745, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 14.1020 - val_loss: 7.7874
#
# [20210301-0259-21] Learning rate for epoch 47 is 0.000455181987490505
# Epoch 47/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.0233
# Epoch 00047: val_loss did not improve from 7.78745
# 17/17 [==============================] - 0s 25ms/step - loss: 14.1136 - val_loss: 9.3433
#
# [20210301-0259-23] Learning rate for epoch 48 is 0.000455181987490505
# Epoch 48/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.7029
# Epoch 00048: val_loss did not improve from 7.78745
# 17/17 [==============================] - 0s 25ms/step - loss: 13.7011 - val_loss: 7.9143
#
# [20210301-0259-26] Learning rate for epoch 49 is 0.000455181987490505
# Epoch 49/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.7444
# Epoch 00049: val_loss did not improve from 7.78745
# 17/17 [==============================] - 0s 24ms/step - loss: 13.6896 - val_loss: 8.3866
#
# [20210301-0259-29] Learning rate for epoch 50 is 0.000455181987490505
# Epoch 50/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.0358
# Epoch 00050: val_loss did not improve from 7.78745
# 17/17 [==============================] - 0s 24ms/step - loss: 14.0604 - val_loss: 9.2133
#
# [20210301-0259-32] Learning rate for epoch 51 is 0.000455181987490505
# Epoch 51/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.8121
# Epoch 00051: val_loss did not improve from 7.78745
# 17/17 [==============================] - 0s 25ms/step - loss: 13.8104 - val_loss: 9.9476
#
# [20210301-0259-35] Learning rate for epoch 52 is 0.000455181987490505
# Epoch 52/500
# 17/17 [==============================] - ETA: 0s - loss: 13.6500
# Epoch 00052: val_loss did not improve from 7.78745
# 17/17 [==============================] - 0s 24ms/step - loss: 13.6500 - val_loss: 8.3892
#
# [20210301-0259-38] Learning rate for epoch 53 is 0.000455181987490505
# Epoch 53/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.6562
# Epoch 00053: val_loss did not improve from 7.78745
# 17/17 [==============================] - 0s 25ms/step - loss: 13.6037 - val_loss: 8.5032
#
# [20210301-0259-41] Learning rate for epoch 54 is 0.000455181987490505
# Epoch 54/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.7432
# Epoch 00054: val_loss did not improve from 7.78745
# 17/17 [==============================] - 0s 25ms/step - loss: 13.8005 - val_loss: 8.0548
#
# [20210301-0259-43] Learning rate for epoch 55 is 0.000455181987490505
# Epoch 55/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.0758
# Epoch 00055: val_loss improved from 7.78745 to 7.68722, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 48ms/step - loss: 13.1131 - val_loss: 7.6872
#
# [20210301-0259-47] Learning rate for epoch 56 is 0.000455181987490505
# Epoch 56/500
# 17/17 [==============================] - ETA: 0s - loss: 13.7571
# Epoch 00056: val_loss did not improve from 7.68722
# 17/17 [==============================] - 0s 24ms/step - loss: 13.7571 - val_loss: 7.8217
#
# [20210301-0259-50] Learning rate for epoch 57 is 0.000455181987490505
# Epoch 57/500
# 15/17 [=========================>....] - ETA: 0s - loss: 13.5593
# Epoch 00057: val_loss did not improve from 7.68722
# 17/17 [==============================] - 0s 25ms/step - loss: 13.6359 - val_loss: 8.2110
#
# [20210301-0259-52] Learning rate for epoch 58 is 0.000455181987490505
# Epoch 58/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.7078
# Epoch 00058: val_loss did not improve from 7.68722
# 17/17 [==============================] - 0s 24ms/step - loss: 13.8061 - val_loss: 9.7259
#
# [20210301-0259-55] Learning rate for epoch 59 is 0.000455181987490505
# Epoch 59/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.4788
# Epoch 00059: val_loss did not improve from 7.68722
# 17/17 [==============================] - 0s 25ms/step - loss: 13.3535 - val_loss: 8.0604
#
# [20210301-0259-58] Learning rate for epoch 60 is 0.000455181987490505
# Epoch 60/500
# 14/17 [=======================>......] - ETA: 0s - loss: 13.1422
# Epoch 00060: val_loss did not improve from 7.68722
# 17/17 [==============================] - 0s 24ms/step - loss: 13.1659 - val_loss: 8.9730
#
# [20210301-0300-01] Learning rate for epoch 61 is 0.000455181987490505
# Epoch 61/500
# 17/17 [==============================] - ETA: 0s - loss: 13.4803
# Epoch 00061: val_loss did not improve from 7.68722
# 17/17 [==============================] - 0s 24ms/step - loss: 13.4803 - val_loss: 8.0642
#
# [20210301-0300-04] Learning rate for epoch 62 is 0.000455181987490505
# Epoch 62/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.5154
# Epoch 00062: val_loss did not improve from 7.68722
# 17/17 [==============================] - 0s 25ms/step - loss: 14.4868 - val_loss: 8.6760
#
# [20210301-0300-07] Learning rate for epoch 63 is 0.000455181987490505
# Epoch 63/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.9291
# Epoch 00063: val_loss did not improve from 7.68722
# 17/17 [==============================] - 0s 24ms/step - loss: 13.9207 - val_loss: 7.8095
#
# [20210301-0300-10] Learning rate for epoch 64 is 0.000455181987490505
# Epoch 64/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.9763
# Epoch 00064: val_loss improved from 7.68722 to 7.55090, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 14.0146 - val_loss: 7.5509
#
# [20210301-0300-13] Learning rate for epoch 65 is 0.000455181987490505
# Epoch 65/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.0812
# Epoch 00065: val_loss did not improve from 7.55090
# 17/17 [==============================] - 0s 25ms/step - loss: 14.0030 - val_loss: 7.8426
#
# [20210301-0300-16] Learning rate for epoch 66 is 0.000455181987490505
# Epoch 66/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.5794
# Epoch 00066: val_loss did not improve from 7.55090
# 17/17 [==============================] - 0s 24ms/step - loss: 13.5027 - val_loss: 8.0604
#
# [20210301-0300-19] Learning rate for epoch 67 is 0.000455181987490505
# Epoch 67/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.1158
# Epoch 00067: val_loss did not improve from 7.55090
# 17/17 [==============================] - 0s 25ms/step - loss: 14.0838 - val_loss: 8.4370
#
# [20210301-0300-22] Learning rate for epoch 68 is 0.000455181987490505
# Epoch 68/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.9806
# Epoch 00068: val_loss improved from 7.55090 to 7.53494, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 14.0192 - val_loss: 7.5349
#
# [20210301-0300-25] Learning rate for epoch 69 is 0.000455181987490505
# Epoch 69/500
# 17/17 [==============================] - ETA: 0s - loss: 13.3485
# Epoch 00069: val_loss did not improve from 7.53494
# 17/17 [==============================] - 0s 24ms/step - loss: 13.3485 - val_loss: 7.7717
#
# [20210301-0300-29] Learning rate for epoch 70 is 0.000455181987490505
# Epoch 70/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.3270
# Epoch 00070: val_loss did not improve from 7.53494
# 17/17 [==============================] - 0s 26ms/step - loss: 13.3304 - val_loss: 7.6316
#
# [20210301-0300-32] Learning rate for epoch 71 is 0.000455181987490505
# Epoch 71/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.3722
# Epoch 00071: val_loss did not improve from 7.53494
# 17/17 [==============================] - 0s 25ms/step - loss: 14.2759 - val_loss: 9.3053
#
# [20210301-0300-35] Learning rate for epoch 72 is 0.000455181987490505
# Epoch 72/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.3265
# Epoch 00072: val_loss did not improve from 7.53494
# 17/17 [==============================] - 0s 24ms/step - loss: 14.2936 - val_loss: 7.6355
#
# [20210301-0300-38] Learning rate for epoch 73 is 0.000455181987490505
# Epoch 73/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.2545
# Epoch 00073: val_loss did not improve from 7.53494
# 17/17 [==============================] - 0s 25ms/step - loss: 14.1583 - val_loss: 7.5936
#
# [20210301-0300-41] Learning rate for epoch 74 is 0.000455181987490505
# Epoch 74/500
# 17/17 [==============================] - ETA: 0s - loss: 13.6376
# Epoch 00074: val_loss did not improve from 7.53494
# 17/17 [==============================] - 0s 24ms/step - loss: 13.6376 - val_loss: 8.2857
#
# [20210301-0300-44] Learning rate for epoch 75 is 0.000455181987490505
# Epoch 75/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.1920
# Epoch 00075: val_loss did not improve from 7.53494
# 17/17 [==============================] - 0s 25ms/step - loss: 14.1334 - val_loss: 10.4667
#
# [20210301-0300-47] Learning rate for epoch 76 is 0.000455181987490505
# Epoch 76/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.1303
# Epoch 00076: val_loss did not improve from 7.53494
# 17/17 [==============================] - 0s 25ms/step - loss: 14.1137 - val_loss: 8.1986
#
# [20210301-0300-50] Learning rate for epoch 77 is 0.000455181987490505
# Epoch 77/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.5278
# Epoch 00077: val_loss did not improve from 7.53494
# 17/17 [==============================] - 0s 25ms/step - loss: 13.4884 - val_loss: 7.5566
#
# [20210301-0300-53] Learning rate for epoch 78 is 0.000455181987490505
# Epoch 78/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.5138
# Epoch 00078: val_loss did not improve from 7.53494
# 17/17 [==============================] - 0s 25ms/step - loss: 13.5909 - val_loss: 7.5650
#
# [20210301-0300-56] Learning rate for epoch 79 is 0.000455181987490505
# Epoch 79/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.3430
# Epoch 00079: val_loss improved from 7.53494 to 7.32481, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 45ms/step - loss: 13.4724 - val_loss: 7.3248
#
# [20210301-0301-00] Learning rate for epoch 80 is 0.000455181987490505
# Epoch 80/500
# 17/17 [==============================] - ETA: 0s - loss: 13.6707
# Epoch 00080: val_loss improved from 7.32481 to 7.25370, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 13.6707 - val_loss: 7.2537
#
# [20210301-0301-03] Learning rate for epoch 81 is 0.000455181987490505
# Epoch 81/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.3473
# Epoch 00081: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 25ms/step - loss: 13.3204 - val_loss: 7.3625
#
# [20210301-0301-06] Learning rate for epoch 82 is 0.000455181987490505
# Epoch 82/500
# 17/17 [==============================] - ETA: 0s - loss: 13.5218
# Epoch 00082: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 24ms/step - loss: 13.5218 - val_loss: 7.8815
#
# [20210301-0301-10] Learning rate for epoch 83 is 0.000455181987490505
# Epoch 83/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.9396
# Epoch 00083: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 26ms/step - loss: 13.9089 - val_loss: 8.3572
#
# [20210301-0301-13] Learning rate for epoch 84 is 0.000455181987490505
# Epoch 84/500
# 17/17 [==============================] - ETA: 0s - loss: 13.2741
# Epoch 00084: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 24ms/step - loss: 13.2741 - val_loss: 7.6055
#
# [20210301-0301-16] Learning rate for epoch 85 is 0.000455181987490505
# Epoch 85/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.4436
# Epoch 00085: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 26ms/step - loss: 13.6539 - val_loss: 9.0789
#
# [20210301-0301-19] Learning rate for epoch 86 is 0.000455181987490505
# Epoch 86/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.0043
# Epoch 00086: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 26ms/step - loss: 13.0696 - val_loss: 7.6909
#
# [20210301-0301-22] Learning rate for epoch 87 is 0.000455181987490505
# Epoch 87/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.1221
# Epoch 00087: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 25ms/step - loss: 13.1142 - val_loss: 7.6471
#
# [20210301-0301-25] Learning rate for epoch 88 is 0.000455181987490505
# Epoch 88/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.7383
# Epoch 00088: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 26ms/step - loss: 13.7054 - val_loss: 7.3807
#
# [20210301-0301-28] Learning rate for epoch 89 is 0.000455181987490505
# Epoch 89/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.1208
# Epoch 00089: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 25ms/step - loss: 13.2622 - val_loss: 8.4485
#
# [20210301-0301-31] Learning rate for epoch 90 is 0.000455181987490505
# Epoch 90/500
# 17/17 [==============================] - ETA: 0s - loss: 13.5842
# Epoch 00090: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 24ms/step - loss: 13.5842 - val_loss: 7.5156
#
# [20210301-0301-34] Learning rate for epoch 91 is 0.000455181987490505
# Epoch 91/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.4403
# Epoch 00091: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 24ms/step - loss: 13.4641 - val_loss: 8.2745
#
# [20210301-0301-37] Learning rate for epoch 92 is 0.000455181987490505
# Epoch 92/500
# 14/17 [=======================>......] - ETA: 0s - loss: 13.5093
# Epoch 00092: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 23ms/step - loss: 13.4391 - val_loss: 7.6196
#
# [20210301-0301-40] Learning rate for epoch 93 is 0.000455181987490505
# Epoch 93/500
# 14/17 [=======================>......] - ETA: 0s - loss: 13.4091
# Epoch 00093: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 23ms/step - loss: 13.3394 - val_loss: 7.7772
#
# [20210301-0301-43] Learning rate for epoch 94 is 0.000455181987490505
# Epoch 94/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.0078
# Epoch 00094: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 25ms/step - loss: 13.0140 - val_loss: 7.6990
#
# [20210301-0301-46] Learning rate for epoch 95 is 0.000455181987490505
# Epoch 95/500
# 15/17 [=========================>....] - ETA: 0s - loss: 13.5378
# Epoch 00095: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 23ms/step - loss: 13.4634 - val_loss: 8.0809
#
# [20210301-0301-49] Learning rate for epoch 96 is 0.000455181987490505
# Epoch 96/500
# 14/17 [=======================>......] - ETA: 0s - loss: 13.3312
# Epoch 00096: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 23ms/step - loss: 13.1936 - val_loss: 8.1019
#
# [20210301-0301-52] Learning rate for epoch 97 is 0.000455181987490505
# Epoch 97/500
# 17/17 [==============================] - ETA: 0s - loss: 13.1530
# Epoch 00097: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 24ms/step - loss: 13.1530 - val_loss: 8.3068
#
# [20210301-0301-55] Learning rate for epoch 98 is 0.000455181987490505
# Epoch 98/500
# 14/17 [=======================>......] - ETA: 0s - loss: 13.5483
# Epoch 00098: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 23ms/step - loss: 13.4367 - val_loss: 7.8588
#
# [20210301-0301-58] Learning rate for epoch 99 is 0.000455181987490505
# Epoch 99/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.4634
# Epoch 00099: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 22ms/step - loss: 13.4976 - val_loss: 7.9388
#
# [20210301-0302-01] Learning rate for epoch 100 is 0.000455181987490505
# Epoch 100/500
# 17/17 [==============================] - ETA: 0s - loss: 13.2628
# Epoch 00100: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 24ms/step - loss: 13.2628 - val_loss: 8.5635
#
# [20210301-0302-05] Learning rate for epoch 101 is 0.000455181987490505
# Epoch 101/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.5930
# Epoch 00101: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 25ms/step - loss: 13.5742 - val_loss: 8.4263
#
# [20210301-0302-08] Learning rate for epoch 102 is 0.000455181987490505
# Epoch 102/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.2553
# Epoch 00102: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 25ms/step - loss: 13.2678 - val_loss: 7.9414
#
# [20210301-0302-11] Learning rate for epoch 103 is 0.000455181987490505
# Epoch 103/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.4966
# Epoch 00103: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 25ms/step - loss: 13.4465 - val_loss: 8.2210
#
# [20210301-0302-14] Learning rate for epoch 104 is 0.000455181987490505
# Epoch 104/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.6400
# Epoch 00104: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 24ms/step - loss: 13.7069 - val_loss: 7.5647
#
# [20210301-0302-17] Learning rate for epoch 105 is 0.000455181987490505
# Epoch 105/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.4816
# Epoch 00105: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 25ms/step - loss: 13.4481 - val_loss: 7.8712
#
# [20210301-0302-20] Learning rate for epoch 106 is 0.000455181987490505
# Epoch 106/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.4031
# Epoch 00106: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 24ms/step - loss: 13.3816 - val_loss: 7.7628
#
# [20210301-0302-23] Learning rate for epoch 107 is 0.000455181987490505
# Epoch 107/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.7175
# Epoch 00107: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 25ms/step - loss: 13.6965 - val_loss: 7.7571
#
# [20210301-0302-26] Learning rate for epoch 108 is 0.000455181987490505
# Epoch 108/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.5199
# Epoch 00108: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 25ms/step - loss: 13.3922 - val_loss: 7.3917
#
# [20210301-0302-29] Learning rate for epoch 109 is 0.000455181987490505
# Epoch 109/500
# 17/17 [==============================] - ETA: 0s - loss: 13.7677
# Epoch 00109: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 25ms/step - loss: 13.7677 - val_loss: 7.6229
#
# [20210301-0302-32] Learning rate for epoch 110 is 0.000455181987490505
# Epoch 110/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.1772
# Epoch 00110: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 25ms/step - loss: 13.1167 - val_loss: 7.5498
#
# [20210301-0302-35] Learning rate for epoch 111 is 0.000455181987490505
# Epoch 111/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.4275
# Epoch 00111: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 24ms/step - loss: 13.4334 - val_loss: 8.0361
#
# [20210301-0302-39] Learning rate for epoch 112 is 0.000455181987490505
# Epoch 112/500
# 16/17 [===========================>..] - ETA: 0s - loss: 12.9691
# Epoch 00112: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 25ms/step - loss: 13.0548 - val_loss: 7.5877
#
# [20210301-0302-42] Learning rate for epoch 113 is 0.000455181987490505
# Epoch 113/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.2918
# Epoch 00113: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 25ms/step - loss: 13.2603 - val_loss: 7.8706
#
# [20210301-0302-45] Learning rate for epoch 114 is 0.000455181987490505
# Epoch 114/500
# 17/17 [==============================] - ETA: 0s - loss: 12.8844
# Epoch 00114: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 24ms/step - loss: 12.8844 - val_loss: 8.1270
#
# [20210301-0302-48] Learning rate for epoch 115 is 0.000455181987490505
# Epoch 115/500
# 17/17 [==============================] - ETA: 0s - loss: 13.4324
# Epoch 00115: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 25ms/step - loss: 13.4324 - val_loss: 7.9117
#
# [20210301-0302-51] Learning rate for epoch 116 is 0.000455181987490505
# Epoch 116/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.1256
# Epoch 00116: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 25ms/step - loss: 13.2039 - val_loss: 7.4476
#
# [20210301-0302-54] Learning rate for epoch 117 is 0.000455181987490505
# Epoch 117/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.4577
# Epoch 00117: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 25ms/step - loss: 13.3904 - val_loss: 7.5772
#
# [20210301-0302-57] Learning rate for epoch 118 is 0.000455181987490505
# Epoch 118/500
# 17/17 [==============================] - ETA: 0s - loss: 13.2851
# Epoch 00118: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 24ms/step - loss: 13.2851 - val_loss: 7.4893
#
# [20210301-0303-00] Learning rate for epoch 119 is 0.000455181987490505
# Epoch 119/500
# 16/17 [===========================>..] - ETA: 0s - loss: 12.9039
# Epoch 00119: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 25ms/step - loss: 12.9435 - val_loss: 7.5698
#
# [20210301-0303-03] Learning rate for epoch 120 is 0.000455181987490505
# Epoch 120/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.3467
# Epoch 00120: val_loss did not improve from 7.25370
# 17/17 [==============================] - 0s 26ms/step - loss: 13.5040 - val_loss: 7.7827
#
# *********************************** Start fine tune ***********************************
# tt: 195, nt:46, total layers:241
# *********************************** Start fine tune ***********************************
# Epoch 1/1000
# 17/17 [==============================] - ETA: 0s - loss: 25.2253
# Epoch 00001: val_loss did not improve from 7.25370
#
# [20210301-0303-44] Learning rate for epoch 1 is 4.999999987376214e-07
# 17/17 [==============================] - 20s 1s/step - loss: 25.2253 - val_loss: 12.8802
# Epoch 2/1000
# 17/17 [==============================] - ETA: 0s - loss: 21.6558
# Epoch 00002: val_loss did not improve from 7.25370
#
# [20210301-0303-48] Learning rate for epoch 2 is 5.044450517743826e-05
# 17/17 [==============================] - 1s 74ms/step - loss: 21.6558 - val_loss: 12.3700
# Epoch 3/1000
# 17/17 [==============================] - ETA: 0s - loss: 16.5589
# Epoch 00003: val_loss did not improve from 7.25370
#
# [20210301-0304-10] Learning rate for epoch 3 is 0.00010028902033809572
# 17/17 [==============================] - 19s 1s/step - loss: 16.5589 - val_loss: 9.9568
# Epoch 4/1000
# 17/17 [==============================] - ETA: 0s - loss: 14.1958
# Epoch 00004: val_loss did not improve from 7.25370
#
# [20210301-0304-14] Learning rate for epoch 4 is 0.00015003354928921908
# 17/17 [==============================] - 1s 73ms/step - loss: 14.1958 - val_loss: 10.0781
# Epoch 5/1000
# 17/17 [==============================] - ETA: 0s - loss: 12.7960
# Epoch 00005: val_loss did not improve from 7.25370
#
# [20210301-0304-18] Learning rate for epoch 5 is 0.0001996780774788931
# 17/17 [==============================] - 1s 73ms/step - loss: 12.7960 - val_loss: 8.1243
# Epoch 6/1000
# 17/17 [==============================] - ETA: 0s - loss: 12.7313
# Epoch 00006: val_loss did not improve from 7.25370
#
# [20210301-0304-22] Learning rate for epoch 6 is 0.000249222619459033
# 17/17 [==============================] - 1s 72ms/step - loss: 12.7313 - val_loss: 8.0952
# Epoch 7/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.8816
# Epoch 00007: val_loss did not improve from 7.25370
#
# [20210301-0304-26] Learning rate for epoch 7 is 0.0002986671752296388
# 17/17 [==============================] - 1s 72ms/step - loss: 11.8816 - val_loss: 8.6224
# Epoch 8/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.4867
# Epoch 00008: val_loss improved from 7.25370 to 6.87401, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
#
# [20210301-0304-30] Learning rate for epoch 8 is 0.00034801175934262574
# 17/17 [==============================] - 2s 105ms/step - loss: 11.4867 - val_loss: 6.8740
# Epoch 9/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.2530
# Epoch 00009: val_loss improved from 6.87401 to 6.79682, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
#
# [20210301-0304-35] Learning rate for epoch 9 is 0.00039725631359033287
# 17/17 [==============================] - 2s 106ms/step - loss: 11.2530 - val_loss: 6.7968
# Epoch 10/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.2349
# Epoch 00010: val_loss did not improve from 6.79682
#
# [20210301-0304-39] Learning rate for epoch 10 is 0.0004464008961804211
# 17/17 [==============================] - 1s 73ms/step - loss: 11.2349 - val_loss: 7.6836
# Epoch 11/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.7624
# Epoch 00011: val_loss did not improve from 6.79682
#
# [20210301-0304-43] Learning rate for epoch 11 is 0.0004954455071128905
# 17/17 [==============================] - 1s 73ms/step - loss: 10.7624 - val_loss: 7.3420
# Epoch 12/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.6071
# Epoch 00012: val_loss did not improve from 6.79682
#
# [20210301-0304-47] Learning rate for epoch 12 is 0.0005443901172839105
# 17/17 [==============================] - 1s 72ms/step - loss: 10.6071 - val_loss: 9.5305
# Epoch 13/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.7354
# Epoch 00013: val_loss improved from 6.79682 to 6.74128, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
#
# [20210301-0304-52] Learning rate for epoch 13 is 0.0005932347266934812
# 17/17 [==============================] - 2s 106ms/step - loss: 10.7354 - val_loss: 6.7413
# Epoch 14/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.6122
# Epoch 00014: val_loss improved from 6.74128 to 5.67627, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
#
# [20210301-0304-56] Learning rate for epoch 14 is 0.0006419793353416026
# 17/17 [==============================] - 2s 105ms/step - loss: 10.6122 - val_loss: 5.6763
# Epoch 15/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.7664
# Epoch 00015: val_loss did not improve from 5.67627
#
# [20210301-0305-00] Learning rate for epoch 15 is 0.0006906240014359355
# 17/17 [==============================] - 1s 69ms/step - loss: 9.7664 - val_loss: 5.8952
# Epoch 16/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.1346
# Epoch 00016: val_loss did not improve from 5.67627
#
# [20210301-0305-04] Learning rate for epoch 16 is 0.0007391686085611582
# 17/17 [==============================] - 1s 71ms/step - loss: 10.1346 - val_loss: 6.4490
# Epoch 17/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.0859
# Epoch 00017: val_loss did not improve from 5.67627
#
# [20210301-0305-08] Learning rate for epoch 17 is 0.0007876132731325924
# 17/17 [==============================] - 1s 72ms/step - loss: 9.0859 - val_loss: 7.9163
# Epoch 18/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.2178
# Epoch 00018: val_loss did not improve from 5.67627
#
# [20210301-0305-12] Learning rate for epoch 18 is 0.0008359579369425774
# 17/17 [==============================] - 1s 71ms/step - loss: 9.2178 - val_loss: 9.0943
# Epoch 19/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.5942
# Epoch 00019: val_loss did not improve from 5.67627
#
# [20210301-0305-16] Learning rate for epoch 19 is 0.000884202599991113
# 17/17 [==============================] - 1s 73ms/step - loss: 8.5942 - val_loss: 8.2850
# Epoch 20/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.6319
# Epoch 00020: val_loss did not improve from 5.67627
#
# [20210301-0305-20] Learning rate for epoch 20 is 0.0009323473204858601
# 17/17 [==============================] - 1s 71ms/step - loss: 8.6319 - val_loss: 6.2460
# Epoch 21/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.2706
# Epoch 00021: val_loss did not improve from 5.67627
#
# [20210301-0305-23] Learning rate for epoch 21 is 0.000980391982011497
# 17/17 [==============================] - 1s 72ms/step - loss: 8.2706 - val_loss: 6.9388
# Epoch 22/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.0159
# Epoch 00022: val_loss did not improve from 5.67627
#
# [20210301-0305-27] Learning rate for epoch 22 is 0.0010283367009833455
# 17/17 [==============================] - 1s 71ms/step - loss: 8.0159 - val_loss: 11.9642
# Epoch 23/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.4334
# Epoch 00023: val_loss did not improve from 5.67627
#
# [20210301-0305-31] Learning rate for epoch 23 is 0.0010761814191937447
# 17/17 [==============================] - 1s 71ms/step - loss: 7.4334 - val_loss: 9.4457
# Epoch 24/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.2525
# Epoch 00024: val_loss did not improve from 5.67627
#
# [20210301-0305-35] Learning rate for epoch 24 is 0.0011239261366426945
# 17/17 [==============================] - 1s 72ms/step - loss: 7.2525 - val_loss: 7.4484
# Epoch 25/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.4383
# Epoch 00025: val_loss did not improve from 5.67627
#
# [20210301-0305-39] Learning rate for epoch 25 is 0.001171570853330195
# 17/17 [==============================] - 1s 72ms/step - loss: 7.4383 - val_loss: 14.8058
# Epoch 26/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.3220
# Epoch 00026: val_loss did not improve from 5.67627
#
# [20210301-0305-43] Learning rate for epoch 26 is 0.001219115569256246
# 17/17 [==============================] - 1s 72ms/step - loss: 7.3220 - val_loss: 10.2642
# Epoch 27/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.4782
# Epoch 00027: val_loss did not improve from 5.67627
#
# [20210301-0305-47] Learning rate for epoch 27 is 0.0012665604008361697
# 17/17 [==============================] - 1s 72ms/step - loss: 7.4782 - val_loss: 8.2281
# Epoch 28/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.1117
# Epoch 00028: val_loss improved from 5.67627 to 4.94808, saving model to ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
#
# [20210301-0305-52] Learning rate for epoch 28 is 0.0013139051152393222
# 17/17 [==============================] - 2s 106ms/step - loss: 7.1117 - val_loss: 4.9481
# Epoch 29/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.5136
# Epoch 00029: val_loss did not improve from 4.94808
#
# [20210301-0305-56] Learning rate for epoch 29 is 0.0013611499452963471
# 17/17 [==============================] - 1s 73ms/step - loss: 7.5136 - val_loss: 9.4760
# Epoch 30/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.3005
# Epoch 00030: val_loss did not improve from 4.94808
#
# [20210301-0305-59] Learning rate for epoch 30 is 0.001408294658176601
# 17/17 [==============================] - 1s 72ms/step - loss: 7.3005 - val_loss: 9.3078
# Epoch 31/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.8817
# Epoch 00031: val_loss did not improve from 4.94808
#
# [20210301-0306-03] Learning rate for epoch 31 is 0.0014553394867107272
# ...
#
# [20210301-0554-15] Learning rate for epoch 249 is 0.00030114591936580837
# 17/17 [==============================] - 1s 71ms/step - loss: 5.7058 - val_loss: 3.4072
# Epoch 250/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.4955
# Epoch 00250: val_loss did not improve from 3.06814
#
# [20210301-0554-19] Learning rate for epoch 250 is 0.00015056047413963825
# 17/17 [==============================] - 1s 70ms/step - loss: 5.4955 - val_loss: 3.2945
# Epoch 251/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.1022
# Epoch 00251: val_loss did not improve from 3.06814
#
# [20210301-0554-23] Learning rate for epoch 251 is 3.7500001326407073e-07
# 17/17 [==============================] - 1s 70ms/step - loss: 5.1022 - val_loss: 3.2990
# Epoch 252/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.3772
# Epoch 00252: val_loss did not improve from 3.06814
#
# [20210301-0554-27] Learning rate for epoch 252 is 0.00015015952521935105
# 17/17 [==============================] - 1s 71ms/step - loss: 5.3772 - val_loss: 3.2679
# Epoch 253/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.4106
# Epoch 00253: val_loss did not improve from 3.06814
#
# [20210301-0554-31] Learning rate for epoch 253 is 0.0002995440736413002
# 17/17 [==============================] - 1s 69ms/step - loss: 5.4106 - val_loss: 3.2776
# Epoch 254/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.2975
# Epoch 00254: val_loss did not improve from 3.06814
#
# [20210301-0554-35] Learning rate for epoch 254 is 0.0004485286772251129
# 17/17 [==============================] - 1s 71ms/step - loss: 5.2975 - val_loss: 3.2976
# Epoch 255/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.2049
# Epoch 00255: val_loss did not improve from 3.06814
#
# [20210301-0554-39] Learning rate for epoch 255 is 0.0005971133359707892
# 17/17 [==============================] - 1s 70ms/step - loss: 5.2049 - val_loss: 3.2756
# Epoch 256/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.0758
# Epoch 00256: val_loss did not improve from 3.06814
#
# [20210301-0554-43] Learning rate for epoch 256 is 0.0007452979916706681
# 17/17 [==============================] - 1s 70ms/step - loss: 5.0758 - val_loss: 3.4542
# Epoch 257/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.1563
# Epoch 00257: val_loss did not improve from 3.06814
#
# [20210301-0554-47] Learning rate for epoch 257 is 0.0008930827025324106
# 17/17 [==============================] - 1s 71ms/step - loss: 5.1563 - val_loss: 3.3914
# Epoch 258/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.6081
# Epoch 00258: val_loss did not improve from 3.06814
#
# [20210301-0554-51] Learning rate for epoch 258 is 0.0010404675267636776
# 17/17 [==============================] - 1s 71ms/step - loss: 5.6081 - val_loss: 3.7933
# Epoch 259/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.1248
# Epoch 00259: val_loss did not improve from 3.06814
#
# [20210301-0554-55] Learning rate for epoch 259 is 0.0011874522315338254
# 17/17 [==============================] - 1s 70ms/step - loss: 6.1248 - val_loss: 3.2829
# Epoch 260/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.6229
# Epoch 00260: val_loss did not improve from 3.06814
#
# [20210301-0554-59] Learning rate for epoch 260 is 0.0013340371660888195
# 17/17 [==============================] - 1s 70ms/step - loss: 5.6229 - val_loss: 3.6410
# Epoch 261/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.6528
# Epoch 00261: val_loss did not improve from 3.06814
#
# [20210301-0555-02] Learning rate for epoch 261 is 0.0014802219811826944
# 17/17 [==============================] - 1s 70ms/step - loss: 5.6528 - val_loss: 3.6060
# Epoch 262/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.2595
# Epoch 00262: val_loss did not improve from 3.06814
#
# [20210301-0555-06] Learning rate for epoch 262 is 0.0016260069096460938
# 17/17 [==============================] - 1s 70ms/step - loss: 5.2595 - val_loss: 3.9235
# Epoch 263/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.1811
# Epoch 00263: val_loss did not improve from 3.06814
#
# [20210301-0555-10] Learning rate for epoch 263 is 0.001771391835063696
# 17/17 [==============================] - 1s 71ms/step - loss: 5.1811 - val_loss: 3.4760
# Epoch 264/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.2954
# Epoch 00264: val_loss did not improve from 3.06814
#
# [20210301-0555-14] Learning rate for epoch 264 is 0.0019163768738508224
# 17/17 [==============================] - 1s 69ms/step - loss: 5.2954 - val_loss: 3.3318
# Epoch 265/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.2814
# Epoch 00265: val_loss did not improve from 3.06814
#
# [20210301-0555-18] Learning rate for epoch 265 is 0.0020609619095921516
# 17/17 [==============================] - 1s 70ms/step - loss: 5.2814 - val_loss: 3.3232
# Epoch 266/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.1398
# Epoch 00266: val_loss did not improve from 3.06814
#
# [20210301-0555-22] Learning rate for epoch 266 is 0.0022051469422876835
# 17/17 [==============================] - 1s 70ms/step - loss: 5.1398 - val_loss: 3.4923
# Epoch 267/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.7343
# Epoch 00267: val_loss did not improve from 3.06814
#
# [20210301-0555-26] Learning rate for epoch 267 is 0.0023489322047680616
# 17/17 [==============================] - 1s 69ms/step - loss: 5.7343 - val_loss: 4.7888
# Epoch 268/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.1852
# Epoch 00268: val_loss did not improve from 3.06814
#
# [20210301-0555-30] Learning rate for epoch 268 is 0.002492317231371999
# 17/17 [==============================] - 1s 70ms/step - loss: 5.1852 - val_loss: 3.5529
# Epoch 269/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.6289
# Epoch 00269: val_loss did not improve from 3.06814
#
# [20210301-0555-34] Learning rate for epoch 269 is 0.0026353024877607822
# 17/17 [==============================] - 1s 69ms/step - loss: 5.6289 - val_loss: 3.9751
# Epoch 270/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.4011
# Epoch 00270: val_loss did not improve from 3.06814
#
# [20210301-0555-38] Learning rate for epoch 270 is 0.0027778877411037683
# 17/17 [==============================] - 1s 70ms/step - loss: 5.4011 - val_loss: 3.9936
# Epoch 271/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.5689
# Epoch 00271: val_loss did not improve from 3.06814
#
# [20210301-0555-41] Learning rate for epoch 271 is 0.002920072991400957
# 17/17 [==============================] - 1s 70ms/step - loss: 5.5689 - val_loss: 4.6796
# Epoch 272/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.2078
# Epoch 00272: val_loss did not improve from 3.06814
#
# [20210301-0555-45] Learning rate for epoch 272 is 0.0030618582386523485
# 17/17 [==============================] - 1s 70ms/step - loss: 5.2078 - val_loss: 4.7948
# Epoch 273/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.6449
# Epoch 00273: val_loss did not improve from 3.06814
#
# [20210301-0555-49] Learning rate for epoch 273 is 0.0032032437156885862
# 17/17 [==============================] - 1s 68ms/step - loss: 5.6449 - val_loss: 4.6233
# Epoch 274/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.5421
# Epoch 00274: val_loss did not improve from 3.06814
#
# [20210301-0555-53] Learning rate for epoch 274 is 0.0033442291896790266
# 17/17 [==============================] - 1s 69ms/step - loss: 5.5421 - val_loss: 4.1632
# Epoch 275/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.4784
# Epoch 00275: val_loss did not improve from 3.06814
#
# [20210301-0555-57] Learning rate for epoch 275 is 0.003484814427793026
# 17/17 [==============================] - 1s 69ms/step - loss: 5.4784 - val_loss: 4.6808
# Epoch 276/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.2684
# Epoch 00276: val_loss did not improve from 3.06814
#
# [20210301-0556-00] Learning rate for epoch 276 is 0.0036249998956918716
# 17/17 [==============================] - 1s 68ms/step - loss: 6.2684 - val_loss: 4.8007
# Epoch 277/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.5632
# Epoch 00277: val_loss did not improve from 3.06814
#
# [20210301-0556-04] Learning rate for epoch 277 is 0.0034752145875245333
# 17/17 [==============================] - 1s 69ms/step - loss: 5.5632 - val_loss: 4.7061
# Epoch 278/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.2623
# Epoch 00278: val_loss did not improve from 3.06814
#
# [20210301-0556-08] Learning rate for epoch 278 is 0.003325828816741705
# 17/17 [==============================] - 1s 69ms/step - loss: 5.2623 - val_loss: 5.4511
# Epoch 279/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.5208
# Epoch 00279: val_loss did not improve from 3.06814
#
# [20210301-0556-12] Learning rate for epoch 279 is 0.0031768432818353176
# 17/17 [==============================] - 1s 70ms/step - loss: 5.5208 - val_loss: 5.9664
# Epoch 280/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.6322
# Epoch 00280: val_loss did not improve from 3.06814
#
# [20210301-0556-16] Learning rate for epoch 280 is 0.0030282577499747276
# 17/17 [==============================] - 1s 68ms/step - loss: 5.6322 - val_loss: 3.8439
# Epoch 281/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.6063
# Epoch 00281: val_loss did not improve from 3.06814
#
# [20210301-0556-20] Learning rate for epoch 281 is 0.0028800719883292913
# 17/17 [==============================] - 1s 70ms/step - loss: 5.6063 - val_loss: 3.5196
# Epoch 282/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.0076
# Epoch 00282: val_loss did not improve from 3.06814
#
# [20210301-0556-24] Learning rate for epoch 282 is 0.0027322862297296524
# 17/17 [==============================] - 1s 70ms/step - loss: 6.0076 - val_loss: 5.8798
# Epoch 283/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.3249
# Epoch 00283: val_loss did not improve from 3.06814
#
# [20210301-0556-27] Learning rate for epoch 283 is 0.002584900474175811
# 17/17 [==============================] - 1s 70ms/step - loss: 5.3249 - val_loss: 5.3706
# Epoch 284/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.3532
# Epoch 00284: val_loss did not improve from 3.06814
#
# [20210301-0556-31] Learning rate for epoch 284 is 0.0024379147216677666
# 17/17 [==============================] - 1s 67ms/step - loss: 5.3532 - val_loss: 13.9268
# Epoch 285/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.2803
# Epoch 00285: val_loss did not improve from 3.06814
#
# [20210301-0556-35] Learning rate for epoch 285 is 0.0022913289722055197
# 17/17 [==============================] - 1s 69ms/step - loss: 5.2803 - val_loss: 70.4671
# Epoch 286/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.4462
# Epoch 00286: val_loss did not improve from 3.06814
#
# [20210301-0556-39] Learning rate for epoch 286 is 0.0021451429929584265
# 17/17 [==============================] - 1s 67ms/step - loss: 5.4462 - val_loss: 160.8184
# Epoch 287/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.3993
# Epoch 00287: val_loss did not improve from 3.06814
#
# [20210301-0556-43] Learning rate for epoch 287 is 0.0019993570167571306
# 17/17 [==============================] - 1s 69ms/step - loss: 5.3993 - val_loss: 27.0756
# Epoch 288/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.2538
# Epoch 00288: val_loss did not improve from 3.06814
#
# [20210301-0556-47] Learning rate for epoch 288 is 0.001853971160016954
# 17/17 [==============================] - 1s 67ms/step - loss: 5.2538 - val_loss: 9.4197
# Epoch 289/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.5267
# Epoch 00289: val_loss did not improve from 3.06814
#
# [20210301-0556-51] Learning rate for epoch 289 is 0.001708985073491931
# 17/17 [==============================] - 1s 68ms/step - loss: 5.5267 - val_loss: 3.6077
# Epoch 290/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.0346
# Epoch 00290: val_loss did not improve from 3.06814
#
# [20210301-0556-55] Learning rate for epoch 290 is 0.0015643991064280272
# 17/17 [==============================] - 1s 70ms/step - loss: 5.0346 - val_loss: 3.5424
# Epoch 291/1000
# 17/17 [==============================] - ETA: 0s - loss: 4.8007
# Epoch 00291: val_loss did not improve from 3.06814
#
# [20210301-0556-59] Learning rate for epoch 291 is 0.0014202130259945989
# 17/17 [==============================] - 1s 70ms/step - loss: 4.8007 - val_loss: 3.4854
# Epoch 292/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.5380
# Epoch 00292: val_loss did not improve from 3.06814
#
# [20210301-0557-03] Learning rate for epoch 292 is 0.001276426832191646
# 17/17 [==============================] - 1s 70ms/step - loss: 5.5380 - val_loss: 3.8512
# Epoch 293/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.1998
# Epoch 00293: val_loss did not improve from 3.06814
#
# [20210301-0557-07] Learning rate for epoch 293 is 0.0011330407578498125
# 17/17 [==============================] - 1s 70ms/step - loss: 5.1998 - val_loss: 3.4602
# Epoch 294/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.5388
# Epoch 00294: val_loss did not improve from 3.06814
#
# [20210301-0557-11] Learning rate for epoch 294 is 0.0009900545701384544
# 17/17 [==============================] - 1s 71ms/step - loss: 5.5388 - val_loss: 3.6363
# Epoch 295/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.1827
# Epoch 00295: val_loss did not improve from 3.06814
#
# [20210301-0557-15] Learning rate for epoch 295 is 0.0008474682690575719
# 17/17 [==============================] - 1s 70ms/step - loss: 5.1827 - val_loss: 3.4968
# Epoch 296/1000
# 17/17 [==============================] - ETA: 0s - loss: 4.9267
# Epoch 00296: val_loss did not improve from 3.06814
#
# [20210301-0557-19] Learning rate for epoch 296 is 0.0007052819710224867
# 17/17 [==============================] - 1s 70ms/step - loss: 4.9267 - val_loss: 3.2893
# Epoch 297/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.0800
# Epoch 00297: val_loss did not improve from 3.06814
#
# [20210301-0557-23] Learning rate for epoch 297 is 0.0005634956760331988
# 17/17 [==============================] - 1s 71ms/step - loss: 5.0800 - val_loss: 3.2870
# Epoch 298/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.3041
# Epoch 00298: val_loss did not improve from 3.06814
#
# [20210301-0557-26] Learning rate for epoch 298 is 0.0004221093258820474
# 17/17 [==============================] - 1s 70ms/step - loss: 5.3041 - val_loss: 3.2709
# Epoch 299/1000
# 17/17 [==============================] - ETA: 0s - loss: 4.7581
# Epoch 00299: val_loss did not improve from 3.06814
#
# [20210301-0557-30] Learning rate for epoch 299 is 0.00028112292056903243
# 17/17 [==============================] - 1s 69ms/step - loss: 4.7581 - val_loss: 3.3803
# Epoch 300/1000
# 17/17 [==============================] - ETA: 0s - loss: 4.7906
# Epoch 00300: val_loss did not improve from 3.06814
#
# [20210301-0557-34] Learning rate for epoch 300 is 0.0001405364746460691
# 17/17 [==============================] - 1s 71ms/step - loss: 4.7906 - val_loss: 3.3738
# Epoch 301/1000
# 17/17 [==============================] - ETA: 0s - loss: 4.8187
# Epoch 00301: val_loss did not improve from 3.06814
#
# [20210301-0557-38] Learning rate for epoch 301 is 3.4999999343199306e-07
# 17/17 [==============================] - 1s 70ms/step - loss: 4.8187 - val_loss: 3.3401
# Epoch 302/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.3800
# Epoch 00302: val_loss did not improve from 3.06814
#
# [20210301-0557-42] Learning rate for epoch 302 is 0.00014013552572578192
# 17/17 [==============================] - 1s 70ms/step - loss: 5.3800 - val_loss: 3.2901
# Epoch 303/1000
# 17/17 [==============================] - ETA: 0s - loss: 4.9018
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#ED sum
def get_valloss(his_v_l):  
    return np.min(his_v_l), np.argmin(his_v_l)

# t_vl = []
h_vl = []
for k in range(KFlodNum):
    print(f'K:{k}')
#     t_v, _ = get_valloss(history_toe_finetune[k].history['val_loss'])
    h_v, _ = get_valloss(history_heel_finetune[k].history['val_loss'])
    
#     t_vl.append(t_v)
    h_vl.append(h_v)

# t_vl = np.mean(t_vl, axis=0)
# h_vl = np.mean(h_vl, axis=0)
# print(f'{round(t_vl,5)} + {round(h_vl,5)} = {round(t_vl + h_vl,5)}')

# t_vl
h_vl
# Out:
# K:0
# K:1
# K:2
# K:3
# K:4
# [3.442877769470215,
#  3.323098659515381,
#  3.246387243270874,
#  3.1792702674865723,
#  3.068143844604492]

# %%
np.savetxt(f'{log_dir_name}/heel_FNED.txt', h_vl)

# %%
# Sum plot losses heel-tl

plt.figure(figsize=(25, 10))

for k in range(KFlodNum):

    plt.plot(history_heel[k].history['loss'])
    plt.plot(history_heel[k].history['val_loss'])

    
plt.title('K-model ed loss heel-TL')
plt.ylabel('ed loss'), plt.ylim(5, 50)# for too large loss
plt.xlabel('epoch')
plt.legend(['k0 loss', 'k0 val_loss', 'k1 loss', 'k1 val_loss', 'k2 loss', 'k2 val_loss', 
            'k3 loss', 'k3 val_loss', 'k4 loss', 'k4 val_loss'], loc='upper left') 
# plt.show()

# save plot : comment plo.show in jupyter notebook.
plt.savefig(f'{log_dir_name}/{log_dir_name}_heel_Ksum_TL.png', bbox_inches = 'tight')

# %%
# Single plot loss heel-tl

for k in range(KFlodNum):
    plt.figure(figsize=(25, 10))
    plt.plot(history_heel[k].history['loss'])
    plt.plot(history_heel[k].history['val_loss'])
    plt.title('K-model ed loss heel-TL')
    plt.ylabel('ed loss'), plt.ylim(5, 80)# for too large loss
    plt.xlabel('epoch')
    plt.legend(['loss', 'val_loss'], loc='upper left') 
    # plt.show()

    # save plot : comment plo.show in jupyter notebook.
    def get_valloss(his_v_l):   
        return np.min(his_v_l), np.argmin(his_v_l)

    vl, ep = get_valloss(history_heel[k].history['val_loss'])
    plt.savefig(f'{log_dir_name}/{log_dir_name}_heel_K{k}_TL_clr_ed{round(vl,4)}@{ep}.png', bbox_inches = 'tight')

# %%
# check the loos the model trained.

def get_valloss(his_v_l):  
    return np.min(his_v_l), np.argmin(his_v_l)

# t_vl = []
h_vl = []
for k in range(KFlodNum):
    print(f'K:{k}')
#     t_v, _ = get_valloss(history_toe_finetune[k].history['val_loss'])
    h_v, _ = get_valloss(history_heel_finetune[k].history['val_loss'])
    
    h_vl.append(h_v)
    
# for different scales (different Y-axes)
# fig, ax1 = plt.subplots()
fig, ax1 = plt.subplots(figsize=(25, 10))

# nice to have this colorful tip.
color = 'tab:red'

ax1.set_title('[ heel_finetune ] \n ED loss')

ax1.set_xlabel('epoch')
ax1.set_ylabel('ed loss', color=color)

for k in range(KFlodNum):

    plt.plot(history_heel_finetune[k].history['loss'])
    plt.plot(history_heel_finetune[k].history['val_loss'])

ax1.tick_params(axis='y', labelcolor=color)
# ax1.legend(['loss', 'val_loss'], loc='upper center') # legend may ocvered by next ax ploting. moved to end.
ax1.legend(['k0 loss', 'k0 val_loss', 'k1 loss', 'k1 val_loss', 'k2 loss', 'k2 val_loss', 
            'k3 loss', 'k3 val_loss', 'k4 loss', 'k4 val_loss'], loc='upper right') 

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('learning rate', color=color)
ax2.plot(history_heel_finetune[0].history['lr'], color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.legend(['lr'], loc='upper right') 

# plt.show()

# # save plot : comment plo.show in jupyter notebook.
# def get_valloss(his_v_l):   
#     return np.min(his_v_l), np.argmin(his_v_l)

# vl, ep = get_valloss(history_toe_finetune.history['val_loss'])


# t_vl = np.mean(t_vl, axis=0)
h_vl = np.mean(h_vl, axis=0)
plt.savefig(f'{log_dir_name}/{log_dir_name}_heel_ft_Ksum-clr_ed{round(h_vl,4)}.png', bbox_inches = 'tight')
# Out:
# K:0
# K:1
# K:2
# K:3
# K:4

# %%
# Sum plot losses heel-ft

plt.figure(figsize=(25, 10))

for k in range(KFlodNum):

    plt.plot(history_heel_finetune[k].history['loss'])
    plt.plot(history_heel_finetune[k].history['val_loss'])

    
plt.title('K-model ed loss heel-FT')
plt.ylabel('ed loss'), plt.ylim(2, 20)# for too large loss
plt.xlabel('epoch')
plt.legend(['k0 loss', 'k0 val_loss', 'k1 loss', 'k1 val_loss', 'k2 loss', 'k2 val_loss', 
            'k3 loss', 'k3 val_loss', 'k4 loss', 'k4 val_loss'], loc='upper left') 
# plt.show()

# save plot : comment plo.show in jupyter notebook.
plt.savefig(f'{log_dir_name}/{log_dir_name}_heel_Ksum_FT.png', bbox_inches = 'tight')

# %%
# Single plot loss heel-FT

for k in range(KFlodNum):
    plt.figure(figsize=(25, 10))
    plt.plot(history_heel_finetune[k].history['loss'])
    plt.plot(history_heel_finetune[k].history['val_loss'])
    plt.title('K-model ed loss heel-FT')
    plt.ylabel('ed loss'), plt.ylim(2, 20)# for too large loss
    plt.xlabel('epoch')
    plt.legend(['loss', 'val_loss'], loc='upper left') 
    # plt.show()

    # save plot : comment plo.show in jupyter notebook.
    def get_valloss(his_v_l):   
        return np.min(his_v_l), np.argmin(his_v_l)

    vl, ep = get_valloss(history_heel_finetune[k].history['val_loss'])
    plt.savefig(f'{log_dir_name}/{log_dir_name}_heel_K{k}_FT_clr_ed{round(vl,4)}@{ep}.png', bbox_inches = 'tight')

# %% [markdown]
# ### Ploting your model

# %%
# model_toe.summary()

# %%
# # show after modl.fit
# model_toe.metrics_names

# %%
# # check metrics the model have.
# history_toe.history.keys()

# %%
# tf.keras.utils.plot_model(model_toe, show_shapes=True)

# %%
# from tensorflow.keras.utils import plot_model
# plot_model(model_toe, to_file='model_toe_conv_layer_blocks.png', show_shapes=True)
# from IPython.display import Image
# Image(filename='model_toe_conv_layer_blocks.png')

# %% [markdown]
# ## show pp pred
#
# * we can switch toe/hell by comment it

# %% [markdown]
# ### EFN Toe

# %%
# it_valid_ds_pre_toe_s = iter(valid_ds_pre_toe_s)
# # it_valid_ds_pre_heel_s = iter(valid_ds_pre_heel_s)

# %%
# %%time

# # image_batch, label_batch = next(valid_ds_pre_toe_s)

# image_batch, label_batch = next(it_valid_ds_pre_toe_s)
# # image_batch, label_batch = next(it_valid_ds_pre_heel_s)


# pred = model_toe.predict_on_batch(image_batch) #predictions
# # pred = model.predict_on_batch(image_batch) #Simple 2D CNN model predictions

# plt.figure(figsize=(20, 20))
# for i in range(64):
#     ax = plt.subplot(8, 8, i + 1)
#     plt.imshow(image_batch[i])
#     plt.title(label_batch[i].numpy())
#     plt.axis("off")
    
#     # note: y_offset_toe for ds image
    
#     #ground truth
#     plt.plot(label_batch[i].numpy()[0], label_batch[i].numpy()[1], 'r+', markersize=15, mew=2)

#     #pred
#     plt.plot(pred[i][0], pred[i][1], 'k+', markersize=15, mew=2)

# %%
# #test_ds一次做完即可不用分batch
# neg = label_batch - pred
# neg[:5]

# %%
# np.abs(neg)[:5]

# %%
# neg_abs = np.abs(neg)
# neg_abs.mean(axis=0)#所有x 所有y個別平均  neg.mean(axis=0)#所有x 所有y個別平均

# %% [markdown]
# #### ED 2D

# %%
# # y_pred = neg_abs.mean(axis=0)
# ed_metric_2d([0,0], [neg_abs.mean(axis=0)]).numpy()

# %% [markdown]
# ### EFN Heel

# %%
# # it_valid_ds_pre_toe_s = iter(valid_ds_pre_toe_s)
# it_valid_ds_pre_heel_s = iter(valid_ds_pre_heel_s)

# %%
# %%time

# # image_batch, label_batch = next(valid_ds_pre_toe_s)

# # image_batch, label_batch = next(it_valid_ds_pre_toe_s)
# image_batch, label_batch = next(it_valid_ds_pre_heel_s)


# pred = model_heel.predict_on_batch(image_batch) #predictions
# # pred = model.predict_on_batch(image_batch) #Simple 2D CNN model predictions

# plt.figure(figsize=(20, 20))
# for i in range(64):
#     ax = plt.subplot(8, 8, i + 1)
#     plt.imshow(image_batch[i])
#     plt.title(label_batch[i].numpy())
#     plt.axis("off")
    
#     # note: y_offset_toe for ds image
    
#     #ground truth
#     plt.plot(label_batch[i].numpy()[0], label_batch[i].numpy()[1], 'r+', markersize=15, mew=2)

#     #pred
#     plt.plot(pred[i][0], pred[i][1], 'k+', markersize=15, mew=2)

# %%
# pred[:5]

# %%
# label_batch[:5]

# %%
# #test_ds一次做完即可不用分batch
# neg = label_batch - pred
# neg[:10]

# %%
# np.abs(neg)[:10]

# %%
# neg_abs = np.abs(neg)
# neg_abs.mean(axis=0)#所有x 所有y個別平均  neg.mean(axis=0)#所有x 所有y個別平均

# %% [markdown]
# #### ED 2d

# %%
# # y_pred = neg_abs.mean(axis=0)
# ed_metric_2d([0,0], [neg_abs.mean(axis=0)]).numpy()

# %% [markdown]
# # Merg Toe/Heel model and predict the Test data at once

# %% [markdown]
# ### Create TEST DS

# %%
ts = 'test_submission.csv'
df_ts = pd.read_csv(ts)
df_ts.head(5)
# Out:
#            images  x1  y1  x2  y2
# 0  image_0001.png NaN NaN NaN NaN
# 1  image_0002.png NaN NaN NaN NaN
# 2  image_0003.png NaN NaN NaN NaN
# 3  image_0004.png NaN NaN NaN NaN
# 4  image_0005.png NaN NaN NaN NaN

# %%
df_ts['images']
# Out:
# 0      image_0001.png
# 1      image_0002.png
# 2      image_0003.png
# 3      image_0004.png
# 4      image_0005.png
#             ...
# 995    image_0996.png
# 996    image_0997.png
# 997    image_0998.png
# 998    image_0999.png
# 999    image_1000.png
# Name: images, Length: 1000, dtype: object

# %%
# from dataframe
list_ds_test = tf.data.Dataset.from_tensor_slices(df_ts['images'])

# %%
len(list_ds_test)#.shape() #take(1)
# Out:
# 1000

# %%
# check The type specification of an element of this dataset.
list_ds_test.element_spec
# Out:
# TensorSpec(shape=(), dtype=tf.string, name=None)

# %%
for f in list_ds_test.take(5):
    print(f'take test sample: {f}')
# Out:
# take test sample: b'image_0001.png'
# take test sample: b'image_0002.png'
# take test sample: b'image_0003.png'
# take test sample: b'image_0004.png'
# take test sample: b'image_0005.png'

# %% [markdown]
# ### TEST DS: Process TEST path to image tensor

# %%
## TEST-DS: re-used from train/val-ds

im_test = 'test_images/'

'''
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    # The second to last is the class-directory
    boolen = parts[-2] == class_names
    #one_hot_num = np.array(boolen, dtype=np.int) not works should use tf.x repalced.
    one_hot_num = tf.dtypes.cast(boolen, tf.int64)
    one_num = tf.argmax(one_hot_num)
    print('one_num:', one_num)
    # Integer encode the label
    return one_num

def decode_img(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.io.decode_jpeg(img, channels=3)
    # resize the image to the desired size
#     return tf.image.resize(img, [img_height, img_width])# augment 已經resize過一次了 但這邊不先做會比較慢
    return tf.cast(tf.image.resize(img, [img_height, img_width]), tf.uint8)# 避免float over at augment
'''

#
# map list to ds, Toe part.
#

def decode_crop_png_toe_test(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.io.decode_png(img, channels=3)
    # crop the toe from top-left corner [image, offset_height y1, offset_width x1, target_height, target_width]
    y1=y_offset_toe;    x1=0;    h=img_height;    w=img_width # not the pp location
    img = tf.image.crop_to_bounding_box(img, int(y1), int(x1), h, w)
    #img = tf.image.crop_to_bounding_box(img, int(y1), int(x1), int(y2)-int(y1), int(x2)-int(x1))
    # resize the image to the desired size
    return img

def process_path_toe_test(file_name):
    file_path = im_test + file_name
    #label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)#can read the byte string paths b'image_0001.png'
    img = decode_crop_png_toe_test(img)
    return img, file_name

#
# map list to ds, Heel part.
#

def decode_crop_png_heel_test(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.io.decode_png(img, channels=3)
    # crop the toe from top-left corner [image, offset_height y1, offset_width x1, target_height, target_width]
    y2=y_offset_heel;    x2=0;    h=img_height;    w=img_width # not the pp location
    img = tf.image.crop_to_bounding_box(img, int(y2), int(x2), h, w)
    #img = tf.image.crop_to_bounding_box(img, int(y1), int(x1), int(y2)-int(y1), int(x2)-int(x1))
    # resize the image to the desired size
    return img

def process_path_heel_test(file_name):
    file_path = im_test + file_name
    #label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)#can read the byte string paths b'image_0001.png'
    img = decode_crop_png_heel_test(img)
    return img, file_name


#
# test how to put parameters to map
#

def t_ds_map(file_path,x1,y1,x2,y2):
#     img = get_img('train/images/' + str(file_path))
#     print(file_path)
    return file_path,x1,y1,x2,y2 #img, [x1,y1]

# %%
# TEST Toe ds
test_ds_map_toe = list_ds_test.map(process_path_toe_test, num_parallel_calls=AUTOTUNE)

# TEST Heel ds
test_ds_map_heel = list_ds_test.map(process_path_heel_test, num_parallel_calls=AUTOTUNE)

# %%
for img, file_name in test_ds_map_toe.take(5):
    print(f'take sample: {img.shape} {file_name}')
    
# print('f', f.dtype)
# print('xy', xy.dtype)
# Out:
# take sample: (120, 120, 3) b'image_0001.png'
# take sample: (120, 120, 3) b'image_0002.png'
# take sample: (120, 120, 3) b'image_0003.png'
# take sample: (120, 120, 3) b'image_0004.png'
# take sample: (120, 120, 3) b'image_0005.png'

# %% [markdown]
# ### prepare TEST_ds_pre

# %%
def configure_for_performance_cache_test(ds, cache=True):

    if cache:
        ds = ds.cache()
        print("Check cache in memory:Y", cache)
    else:
        print("Check cache in memory:N", cache)
        
#     if augment:
# #         ds = ds.map(data_augment, num_parallel_calls=AUTOTUNE)
#         ds = ds.map(AA, num_parallel_calls=AUTOTUNE)
# #         ds = ds.map(RA, num_parallel_calls=AUTOTUNE)
#         print("Check augment :Y", augment)
#     else:
#         print("Check augment :N", augment)
    
#     #ds = ds.repeat()#TODO:2020-12-14: test
#     ds = ds.shuffle(buffer_size=MULTI_BATCH_SIZE*2) # (buffer_size=MULTI_BATCH_SIZE*5) 6sec,buffer_size=1000 take few sec. or buffer_size=image_count <- take too long # each take ds take 30~45 sec, TODO!!
#     ds = ds.shuffle(len(list_ds), reshuffle_each_iteration=False) #todo: move to ds_pre. see https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle
    ds = ds.batch(1000)# 1k for foot test images #MULTI_BATCH_SIZE for multi-GPUs
    ds = ds.prefetch(buffer_size=AUTOTUNE) #buffer_size=AUTOTUNE seem no speed improve
    
    return ds

# %%
"""
Prepare the ds properties (cache, augment, bs, shuffle, prefetch, etc.) for better performance.
"""
# TEST Toe ds_pre
test_ds_pre_toe = configure_for_performance_cache_test(test_ds_map_toe)

# TEST Heel ds_pre
test_ds_pre_heel = configure_for_performance_cache_test(test_ds_map_heel)
# Out:
# Check cache in memory:Y True
# Check cache in memory:Y True

# %% [markdown]
# # Load Best-K-models

# %%
# if K-models are in last time frame
# best_model_name = get_best_model_name(th, K=str(k))

predictions_toe = []
predictions_heel = []

for k in range(KFlodNum):
    print(f'K:{k}')
    best_model_toe_name = get_best_model_name('toe', K=str(k))
    best_model_heel_name = get_best_model_name('heel', K=str(k))

# # if models are in last time frame
# best_model_toe_name = get_best_model_name('toe')
# best_model_heel_name = get_best_model_name('heel')

# # if toe/heel are in different time frame
# best_model_toe_name = '20210118-212454/toe_EfficientNetB0_bs64_w120_best_val_loss.h5'#6.3318 @e393
# best_model_heel_name = '20210122-084854/heel_EfficientNetB0_bs64_w120_best_val_loss.h5'#3.27979@152




    print(best_model_toe_name)
    print(best_model_heel_name)
    # log_dir_name + '/' + 'leaf-2020-12-01-EfficientNetB7_top-layer50_lr_lrfn_val-acc.8352_wh512_e37.h5'

    best_model_toe = tf.keras.models.load_model(best_model_toe_name,compile=False)
    best_model_heel = tf.keras.models.load_model(best_model_heel_name,compile=False)
    
    best_model_toe.compile(optimizer = tf.keras.optimizers.Adam(),#RMSprop , Adam
                loss=ed_metric_2d_mean)#, ed_loss ed_metric_2d ed_metric_2d_mean            
                #metrics=['mae', 'accuracy'])
    best_model_heel.compile(optimizer = tf.keras.optimizers.Adam(),#RMSprop , Adam
                loss=ed_metric_2d_mean)#, ed_loss ed_metric_2d ed_metric_2d_mean            
                #metrics=['mae', 'accuracy'])
        
        
    pred_toe = best_model_toe.predict(test_ds_pre_toe)
    pred_toe[:,1] = pred_toe[:,1] + y_offset_toe
    predictions_toe.append(pred_toe)
    
    pred_heel = best_model_heel.predict(test_ds_pre_heel)
    pred_heel[:,1] = pred_heel[:,1] + y_offset_heel
    predictions_heel.append(pred_heel)
# Out:
# K:0
# ./20210228-235432/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# ./20210228-235432/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# K:1
# ./20210228-235432/toe_K1_EfficientNetB0_bs64_w120_best_val_loss.h5
# ./20210228-235432/heel_K1_EfficientNetB0_bs64_w120_best_val_loss.h5
# K:2
# ./20210228-235432/toe_K2_EfficientNetB0_bs64_w120_best_val_loss.h5
# ./20210228-235432/heel_K2_EfficientNetB0_bs64_w120_best_val_loss.h5
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efab9d142f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efab9d14ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# K:3
# ./20210228-235432/toe_K3_EfficientNetB0_bs64_w120_best_val_loss.h5
# ./20210228-235432/heel_K3_EfficientNetB0_bs64_w120_best_val_loss.h5
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efab36c8ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efab873eae8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# K:4
# ./20210228-235432/toe_K4_EfficientNetB0_bs64_w120_best_val_loss.h5
# ./20210228-235432/heel_K4_EfficientNetB0_bs64_w120_best_val_loss.h5
# WARNING:tensorflow:9 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efab1046ae8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:10 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efab29e3ea0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
len(predictions_toe[0])
# Out:
# 1000

# %%
# make sure we got the k-pred as k models.
for i, _ in enumerate(predictions_toe):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
np.shape(predictions_toe)
# Out:
# (5, 1000, 2)

# %%
predictions_toe[0]
# Out:
# array([[ 57.581474, 134.9496  ],
#        [ 55.42893 , 140.50253 ],
#        [ 54.462456, 149.91003 ],
#        ...,
#        [ 65.31471 , 132.94818 ],
#        [ 62.019955, 121.664055],
#        [ 59.88344 , 120.376   ]], dtype=float32)

# %%
predictions_toe[1]
# Out:
# array([[ 55.57295 , 135.57959 ],
#        [ 54.010754, 142.12994 ],
#        [ 52.996742, 147.89676 ],
#        ...,
#        [ 63.277866, 135.43936 ],
#        [ 61.855045, 117.81388 ],
#        [ 60.191654, 121.21503 ]], dtype=float32)

# %%
predictions_heel[0]
# Out:
# array([[ 82.23718 , 380.68903 ],
#        [ 22.615507, 376.2312  ],
#        [ 79.4764  , 383.94492 ],
#        ...,
#        [ 29.116955, 381.30374 ],
#        [ 76.69635 , 382.7251  ],
#        [ 34.285034, 381.18536 ]], dtype=float32)

# %%
predictions_heel[1]
# Out:
# array([[ 80.10301 , 379.22943 ],
#        [ 24.452322, 376.00992 ],
#        [ 78.94403 , 382.98654 ],
#        ...,
#        [ 30.802248, 381.58917 ],
#        [ 76.35219 , 380.92966 ],
#        [ 34.66249 , 381.35272 ]], dtype=float32)

# %%
# mean the k-predictions
k_predictions_toe = np.mean(predictions_toe, axis=0)
k_predictions_toe
# Out:
# array([[ 56.643627, 134.90054 ],
#        [ 56.71586 , 141.38503 ],
#        [ 55.07531 , 147.73015 ],
#        ...,
#        [ 63.797455, 134.2787  ],
#        [ 62.15647 , 120.85283 ],
#        [ 59.849262, 120.61005 ]], dtype=float32)

# %%
np.shape(k_predictions_toe)
# Out:
# (1000, 2)

# %%
# mean the k-predictions
k_predictions_heel = np.mean(predictions_heel, axis=0)
k_predictions_heel
# Out:
# array([[ 80.8524  , 379.53534 ],
#        [ 24.405033, 375.58655 ],
#        [ 78.88818 , 383.1762  ],
#        ...,
#        [ 29.053707, 381.4146  ],
#        [ 75.87119 , 381.69122 ],
#        [ 34.05477 , 381.27243 ]], dtype=float32)

# %% [markdown]
# ### Merge toe/hell pred

# %%
predictions_th = np.append(k_predictions_toe, k_predictions_heel, axis=1)#左右接
predictions_th.shape
# Out:
# (1000, 4)

# %%
images_name = np.expand_dims(df_ts['images'], axis=1)
images_name.shape
# Out:
# (1000, 1)

# %%
predictions_merge = np.append(images_name, predictions_th, axis=1)#左右接
predictions_merge.shape
# Out:
# (1000, 5)

# %%
df_submission = pd.DataFrame(predictions_merge)
df_submission.columns = ['images','x1','y1','x2','y2']

# %%
submi_name = CSVNAME + '.' + log_dir_name +'.csv'

df_submission.to_csv(submi_name, index=False)
print('Save {} as submission CSV.'.format(submi_name))
# Out:
# Save K1345.20210228-235432.csv as submission CSV.

# %%
df_submission.head()
# Out:
#            images       x1       y1       x2       y2
# 0  image_0001.png  56.6436  134.901  80.8524  379.535
# 1  image_0002.png  56.7159  141.385   24.405  375.587
# 2  image_0003.png  55.0753   147.73  78.8882  383.176
# 3  image_0004.png     57.4  138.856  29.1667  373.511
# 4  image_0005.png  60.5104  150.674  67.4114  370.769

# %%
#ED sum
def get_valloss(his_v_l):  
    return np.min(his_v_l), np.argmin(his_v_l)

t_vl = []
h_vl = []
for k in range(KFlodNum):
    print(f'K:{k}')
    t_v, _ = get_valloss(history_toe_finetune[k].history['val_loss'])
    h_v, _ = get_valloss(history_heel_finetune[k].history['val_loss'])
    
    t_vl.append(t_v)
    h_vl.append(h_v)

t_vl = np.mean(t_vl, axis=0)
h_vl = np.mean(h_vl, axis=0)
print(f'{round(t_vl,5)} + {round(h_vl,5)} = {round(t_vl + h_vl,5)}')
# Out:
# K:0
# K:1
# K:2
# K:3
# K:4
# 5.45653 + 3.25196 = 8.70849

# %%
# K134520210224-114845.csv
# 5.63922 + 3.34466 = 8.98389 LB:8.4890610

# %%
t_vl
# Out:
# 5.456531238555908

# %%
h_vl
# Out:
# 3.2519555568695067

# %%
t_timer.toc() #Time elapsed since t.tic()
# Out:
# Elapsed time is 35237.999549 seconds.

# %% [markdown]
# ### compile the model separately afterwards. to load model with custom loss function
#
# * https://github.com/tensorflow/tensorflow/issues/32348

# %%
# best_model_toe.compile(optimizer = tf.keras.optimizers.Adam(),#RMSprop , Adam
#                 loss=ed_metric_2d_mean)#, ed_loss ed_metric_2d ed_metric_2d_mean            
#                 #metrics=['mae', 'accuracy'])
# best_model_heel.compile(optimizer = tf.keras.optimizers.Adam(),#RMSprop , Adam
#                 loss=ed_metric_2d_mean)#, ed_loss ed_metric_2d ed_metric_2d_mean            
#                 #metrics=['mae', 'accuracy'])

# best_model_toe.compile(optimizer = tf.keras.optimizers.Adam(),#RMSprop , Adam
#                 loss=tf.keras.losses.MeanSquaredError())#, ed_loss ed_metric_2d ed_metric_2d_mean            
#                 #metrics=['mae', 'accuracy'])
# best_model_heel.compile(optimizer = tf.keras.optimizers.Adam(),#RMSprop , Adam
#                 loss=tf.keras.losses.MeanSquaredError())#, ed_loss ed_metric_2d ed_metric_2d_mean            
#                 #metrics=['mae', 'accuracy'])

# %%
# %%time
# # inference all test_ds once
# predictions_toe = best_model_toe.predict(test_ds_pre_toe)
# predictions_toe.shape

# %% [markdown]
# ### Offset Toe

# %%
# predictions_toe[:,1] = predictions_toe[:,1] + y_offset_toe

# # for [0,1]
# # predictions_toe[:,0] = predictions_toe[:,0]*120
# # predictions_toe[:,1] = predictions_toe[:,1]*120 + y_offset_toe

# # # for [-1,1]
# # # for re-scale back xy 
# # # return img, [(x1-60)/60,((y1-y_offset_toe)-60)/60]#normalized [-1,1] 
# # # return img, [(x2-60)/60,((y2-y_offset_heel)-60)/60]#normalized [-1,1] 
# # predictions_toe[:,0] = (predictions_toe[:,0]*60)+60
# # predictions_toe[:,1] = (predictions_toe[:,1]*60)+60 + y_offset_toe

# predictions_toe

# %%
# %%time
# # inference all test_ds once
# predictions_heel = best_model_heel.predict(test_ds_pre_heel)
# predictions_heel.shape

# %% [markdown]
# ### Offset Heel

# %%
# predictions_heel[:,1] = predictions_heel[:,1] + y_offset_heel

# # for [0,1]
# # predictions_heel[:,0] = predictions_heel[:,0]*120
# # predictions_heel[:,1] = predictions_heel[:,1]*120 + y_offset_heel

# # # for [-1,1]
# # predictions_heel[:,0] = (predictions_heel[:,0]*60)+60
# # predictions_heel[:,1] = (predictions_heel[:,1]*60)+60 + y_offset_heel

# predictions_heel

# %% [markdown]
# ### Merge toe/hell pred

# %%
# predictions_th = np.append(predictions_toe, predictions_heel, axis=1)#左右接
# predictions_th.shape

# %%
# images_name = np.expand_dims(df_ts['images'], axis=1)
# images_name.shape

# %%
# predictions_merge = np.append(images_name, predictions_th, axis=1)#左右接
# predictions_merge.shape

# %%
# df_submission = pd.DataFrame(predictions_merge)
# df_submission.columns = ['images','x1','y1','x2','y2']

# %%
# submi_name = '0000_ft_' + log_dir_name +'.csv'
# # submi_name = 'Bth_clr3_2690_XYnorm[0-1]_' + log_dir_name +'.csv'
# df_submission.to_csv(submi_name, index=False)
# print('Save {} as submission CSV.'.format(submi_name))

# %%
#Bth_clr3_2690_ed_findtune_20210202-141718.csv

#toe.9.9/heel.4.4 109 trainable LB:9.3411759 比heel保持top-20略高0.04 (9.3084957)

# %%
# df_submission.head()

# %%
# #ED sum
# def get_valloss(his_v_l):  
#     return np.min(his_v_l), np.argmin(his_v_l)

# t_vl, _ = get_valloss(history_toe_finetune.history['val_loss'])
# h_vl, _ = get_valloss(history_heel_finetune.history['val_loss'])

# print(f'{round(t_vl,5)} + {round(h_vl,5)} = {round(t_vl + h_vl,5)}')

# %%
#

# %% [markdown]
# ## save model

# %%
# best_model_name = './cop_' + model_name + '_bs' + str(BATCH_SIZE) + '_w' + str(img_width) + '_e' + str(ep_num) + '_' + datetime.now().strftime("%Y%m%d-%H%M%S") + '_.h5'
# # model.save(best_model_name)
# print("Save model: ", best_model_name)

# %% [markdown]
# ## Reference
#
# multi output model:
# https://navoshta.com/end-to-end-deep-learning/
