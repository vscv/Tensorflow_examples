# %% [markdown]
# # 4rd p30/50 PCA1/1 Crop.7 Affine.7 + Toe HPLv2

# %% [markdown]
# ## annotation_1307_HPLv2Toe_Good.csv

# %% [markdown]
# # 20210302-142936

# %% [markdown]
# # 101 Course of transfer learning and Fine tune 2021-01-01

# %% [markdown]
# ## [How-to] 1. k-fold for cross validation
#
# #### Create a simple k-fold for train classification model.
#
# * In this short course you learned:
#
# * data pipline
#
# * transfer learning
#
# * fine tune
#
# * callbacks

# %% [markdown]
# todo: move to note.py

# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# plt.style.use("bmh")

import cv2
import tensorflow as tf

from datetime import datetime
import seaborn as sns

import errno

# albumentations
from functools import partial
# from albumentations import (
#     Compose, RandomBrightness, JpegCompression, HueSaturationValue, RandomContrast, HorizontalFlip,
#     Rotate
# )
import albumentations as A

# from adabelief_tf import AdaBeliefOptimizer

# %%
print(tf.__version__)
print(cv2.__version__)
# Out:
# 2.3.1
# 4.3.0

# %%
from pytictoc import TicToc

t_timer = TicToc() #create instance of class

t_timer.tic() #Start timer

# %% [markdown]
# ### 2. Parameters

# %% [markdown]
# #### Image size, Batch size, toe/heel-offset.

# %%
BATCH_SIZE = 64 # 16 #32 #64 #128 #32 #64 #todo: reduce the BS maybe help to reduce the loss
img_height = 120 #512 #224 #100
img_width = 120 #512 #224 #100

y_offset_toe = 80
y_offset_heel = 280 #400-120=280

# %% [markdown]
# #### tf MirroredStrategy seting

# %%
# tf MirroredStrategy seting
strategy = tf.distribute.MirroredStrategy()
REPLICAS = strategy.num_replicas_in_sync
print('\nNumber of REPLICAS: {}\n'.format(REPLICAS))


MULTI_BATCH_SIZE = BATCH_SIZE * strategy.num_replicas_in_sync
print('BATCH_SIZE: {}, MULTI_BATCH_SIZE: {}'.format(BATCH_SIZE, MULTI_BATCH_SIZE))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
#
# Number of REPLICAS: 1
#
# BATCH_SIZE: 64, MULTI_BATCH_SIZE: 64

# %%
# 自動調節tf.data管道
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %% [markdown]
# ### 3. Create the training dataset W/ croped

# %% [markdown]
# #### Load samples as data-farame

# %%
# # data-org #
# ann = 'annotation_1424_merge.csv'
# im_p = 'train/images/'
# CSVNAME = ""


# # data-org-augm#
# ann = 'annotation_2848_augm.csv'
# im_p = 'train_augm/images/'
# CSVNAME = ""


# # data-train # # current best dataset.1424-79.
# ann = 'annotation_1345_good.csv'
# im_p = 'train/images/'
# CSVNAME = "K1345K10L195"

# data-augm #
# ann = 'annotation_2690_augm.csv'
# im_p = 'train_augm/images/'
# CSVNAME = ""


# # data-train-HPL-1123
# ann = 'annotation_1123_HPL_Good.csv'
# im_p = 'train/images/'
# CSVNAME = ""

# data-train # # HPLv2Toe
ann = 'annotation_1307_HPLv2Toe_Good.csv'
im_p = 'train/images/'
CSVNAME = "HPLv2toeK10L195"


df = pd.read_csv(ann)
df[1120:]
# Out:
#               images  x1   y1  x2   y2
# 1120  image_6232.jpg  57  144  79  383
# 1121  image_6233.jpg  52  146  30  384
# 1122  image_6234.jpg  47  127  77  381
# 1123  image_6235.jpg  64  133  25  384
# 1124  image_6236.jpg  55  145  72  375
# ...              ...  ..  ...  ..  ...
# 1302  image_6419.jpg  60  135  70  381
# 1303  image_6421.jpg  53  157  76  376
# 1304  image_6422.jpg  49  154  33  375
# 1305  image_6423.jpg  64  149  76  381
# 1306  image_6424.jpg  55  147  36  385
#
# [187 rows x 5 columns]

# %%
len(df)
# Out:
# 1307

# %% [markdown]
# #### Shuffle and reset index

# %%
# reset index
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head(10)
# Out:
#            images  x1   y1  x2   y2
# 0  image_0819.png  62  136  25  382
# 1  image_0643.jpg  57  135  33  369
# 2  image_6323.jpg  60  101  89  383
# 3  image_0442.png  48  138  30  380
# 4  image_6272.jpg  51  159  31  383
# 5  image_6163.jpg  54  142  84  384
# 6  image_0159.png  72  142  77  383
# 7  image_0805.png  40  136  28  382
# 8  image_0390.png  59  121  35  383
# 9  image_0771.png  52  140  33  381

# %% [markdown]
# See, the image_####.jpg now are random.

# %% [markdown]
# #### Create tf.dataset (DS)

# %%
# from dataframe
list_ds = tf.data.Dataset.from_tensor_slices((df['images'], df['x1'], df['y1'], df['x2'], df['y2']))
# list_ds = list_ds.shuffle(image_count, reshuffle_each_iteration=True) #todo: move to ds_pre. see https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle

# %%
len(list_ds)#.shape() #take(1)
# Out:
# 1307

# %%
# check The type specification of an element of this dataset.
list_ds.element_spec
# Out:
# (TensorSpec(shape=(), dtype=tf.string, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None))

# %%
for f,x1,y1,x2,y2 in list_ds.take(5):
    print(f'take sample: {f} {x1} {y1} {x2} {y2}')
# Out:
# take sample: b'image_0819.png' 62 136 25 382
# take sample: b'image_0643.jpg' 57 135 33 369
# take sample: b'image_6323.jpg' 60 101 89 383
# take sample: b'image_0442.png' 48 138 30 380
# take sample: b'image_6272.jpg' 51 159 31 383

# %%
# use np decode to UTF-8
print(f.numpy().decode('UTF-8'))
# Out:
# image_6272.jpg

# %%
len(list_ds)
# Out:
# 1307

# %% [markdown]
# #### Check ds iterator for consuming

# %%
# create a Python iterator

it_list_ds = iter(list_ds) # Make sure iter ds only once.

# %%
# using iter and consuming its elements using next: every print different image name.

for i in range(4):
    image, x1, y1, x2, y2 = next(it_list_ds)
    print(image.numpy(), x1.numpy(), y1.numpy())
# Out:
# b'image_0819.png' 62 136
# b'image_0643.jpg' 57 135
# b'image_6323.jpg' 60 101
# b'image_0442.png' 48 138

# %%
# image_batch, label_batch = valid_ds_pre_s.as_numpy_iterator().next()
# pred = model.predict_on_batch(image_batch)


for i in range(4):
    image, x1, y1, x2, y2 = list_ds.as_numpy_iterator().next()# every time create a new iter, so need put iter out of above cell.
    print(image, x1, y1, x2, y2)
    
iter_test_list = list_ds.as_numpy_iterator()
print("===== Create iterator once and pull out to above cell. =====")
for i in range(4):
    image, x1, y1, x2, y2 = iter_test_list.next()
    print(image, x1, y1, x2, y2)
# Out:
# b'image_0819.png' 62 136 25 382
# b'image_0819.png' 62 136 25 382
# b'image_0819.png' 62 136 25 382
# b'image_0819.png' 62 136 25 382
# ===== Create iterator once and pull out to above cell. =====
# b'image_0819.png' 62 136 25 382
# b'image_0643.jpg' 57 135 33 369
# b'image_6323.jpg' 60 101 89 383
# b'image_0442.png' 48 138 30 380

# %% [markdown]
# #### Process path to image tensor in DS

# %%
'''
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    # The second to last is the class-directory
    boolen = parts[-2] == class_names
    #one_hot_num = np.array(boolen, dtype=np.int) not works should use tf.x repalced.
    one_hot_num = tf.dtypes.cast(boolen, tf.int64)
    one_num = tf.argmax(one_hot_num)
    print('one_num:', one_num)
    # Integer encode the label
    return one_num

def decode_img(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.io.decode_jpeg(img, channels=3)
    # resize the image to the desired size
#     return tf.image.resize(img, [img_height, img_width])# augment 已經resize過一次了 但這邊不先做會比較慢
    return tf.cast(tf.image.resize(img, [img_height, img_width]), tf.uint8)# 避免float over at augment
'''

#
# map list to ds, Toe part.
#

def decode_crop_png_toe(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.io.decode_png(img, channels=3)
    # crop the toe from top-left corner [image, offset_height y1, offset_width x1, target_height, target_width]
    y1=y_offset_toe;    x1=0;    h=img_height;    w=img_width # not the pp location
    img = tf.image.crop_to_bounding_box(img, int(y1), int(x1), h, w)
    #img = tf.image.crop_to_bounding_box(img, int(y1), int(x1), int(y2)-int(y1), int(x2)-int(x1))
    # resize the image to the desired size
    return img

def process_path_toe(file_path,x1,y1,x2,y2):
    file_path = im_p + file_path
    #label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)#can read the byte string paths b'image_0001.png'
    img = decode_crop_png_toe(img)
    return img, [x1,y1-y_offset_toe]#Original [0,120]
    #return img, x1, y1-y_offset_toe #Original [0,120] #貌似ed不用改，蛋mse變超大
    #return img, [x1/120,(y1-y_offset_toe)/120]#normalized [0,1] xy <dtype: 'float64'>, no help.
    #return img, [(x1-60)/60,((y1-y_offset_toe)-60)/60]#normalized [-1,1] , no help.

#
# map list to ds, Heel part.
#

def decode_crop_png_heel(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.io.decode_png(img, channels=3)
    # crop the toe from top-left corner [image, offset_height y1, offset_width x1, target_height, target_width]
    y2=y_offset_heel;    x2=0;    h=img_height;    w=img_width # not the pp location
    img = tf.image.crop_to_bounding_box(img, int(y2), int(x2), h, w)
    #img = tf.image.crop_to_bounding_box(img, int(y1), int(x1), int(y2)-int(y1), int(x2)-int(x1))
    # resize the image to the desired size
    return img

def process_path_heel(file_path,x1,y1,x2,y2):
    file_path = im_p + file_path
    #label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)#can read the byte string paths b'image_0001.png'
    img = decode_crop_png_heel(img)
    return img, [x2,y2-y_offset_heel]#Original [0,120]
    #return img, x2, y2-y_offset_heel #Original [0,120] #貌似ed不用改，蛋mse變超大
    #return img, [x2/120,(y2-y_offset_heel)/120]#normalized [0,1] xy <dtype: 'float64'>, no help.
    #return img, [(x2-60)/60,((y2-y_offset_heel)-60)/60]#normalized [-1,1] , no help.

#
# test how to put parameters to map
#

def t_ds_map(file_path,x1,y1,x2,y2):
#     img = get_img('train/images/' + str(file_path))
#     print(file_path)
    return file_path,x1,y1,x2,y2 #img, [x1,y1]

# %%
# Toe ds
train_ds_map_toe = list_ds.map(process_path_toe, num_parallel_calls=AUTOTUNE)

# Heel ds
train_ds_map_heel = list_ds.map(process_path_heel, num_parallel_calls=AUTOTUNE)

# %%
# for img, xy in train_ds_map_toe.take(1):
#     print(f'take sample: {xy}')
    
# print('f', f.dtype)
# print('xy', xy.dtype)

# for img, x, y in train_ds_map_toe.take(1):
#     print(f'take sample: {x} {y}')
    
# print('img', img.dtype)
# print('x', x.dtype)
# x

for img, [x, y] in train_ds_map_toe.take(1):
    print(f'take sample: {x} {y}')
    
print('f', f.dtype)
print('x', x.dtype)
# Out:
# take sample: 62 56
# f <dtype: 'string'>
# x <dtype: 'int64'>

# %%
x
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=62>

# %%
# for f,x1,y1,x2,y2 in train_ds_map.take(5):
#     print(f'take sample: {f} {x1} {y1} {x2} {y2}')

# %% [markdown]
# #### [new] Split train_ds_pre with ratio of validation %

# %% [markdown]
# [ToDo 20210201] keep orignal validation in 0.1, but augmenting train_ds in input layer or in the tf.ds.

# %% [markdown]
# [2021-02-23] New k-split ds

# %%
# # split Toe
# val_size = int(tf.data.experimental.cardinality(train_ds_map_toe).numpy() * 0.2)
# # val_size = int(tf.data.experimental.cardinality(train_ds_map_toe).numpy() * 0.1)#no help

# train_ds_map_toe_s = train_ds_map_toe.skip(val_size)
# valid_ds_map_toe_s = train_ds_map_toe.take(val_size)

# print(f'whole samples = {len(train_ds_map_toe)}')
# print(f'val_size = {val_size}')

# print('ds_train = ', tf.data.experimental.cardinality(train_ds_map_toe_s).numpy())
# print('ds_valid = ', tf.data.experimental.cardinality(valid_ds_map_toe_s).numpy())

# %%
# # split Heel
# val_size = int(tf.data.experimental.cardinality(train_ds_map_heel).numpy() * 0.2)
# # val_size = int(tf.data.experimental.cardinality(train_ds_map_heel).numpy() * 0.1)


# train_ds_map_heel_s = train_ds_map_heel.skip(val_size)
# valid_ds_map_heel_s = train_ds_map_heel.take(val_size)

# print(len(train_ds_map_heel))
# print(val_size)
# print(tf.data.experimental.cardinality(train_ds_map_heel_s).numpy())
# print(tf.data.experimental.cardinality(valid_ds_map_heel_s).numpy())

# %%
# ## testing cell
# kf = []
# for k in range(5):
#     kf.append(train_ds_map_heel.shard(num_shards=5, index=k))
#     print("k =", k,"num=", tf.data.experimental.cardinality(kf[k]).numpy())

# %%
# kf

# %%
# for img, [x,y] in kf[1].take(1):
#     print(f'take sample: {x} {y}')
    
# print('img', img.dtype)
# print('x', x.dtype)
# print('y', y.dtype)

# %%
# ## testing cell

# range_k_0 = train_ds_map_heel.window(5)

# print(len(range_k_0))
# print(tf.data.experimental.cardinality(range_k_0).numpy())

# %%
# ## testing cell

# def get_train_valid_k_split():
#     x = tf.data.Dataset.range(1000)
#     val_size = int(tf.data.experimental.cardinality(x).numpy() * 0.2)
    
#     for k in range(5):
#         train_num = x.take(val_size + k*val_size)
#         valid_num = x.skip(k*val_size)
        
#         print("k=", k)
#         print(tf.data.experimental.cardinality(train_num).numpy())
#         print(tf.data.experimental.cardinality(valid_num).numpy())
    
    
# get_train_valid_k_split()

# %%
## testing cell

# 
# tf.slice
# tf.data.experimental.choose_from_datasets


# x = list_ds
# val_size = int(tf.data.experimental.cardinality(list_ds).numpy() * 0.2)
x = tf.data.Dataset.range(10)

def check_KFold_ds(x, K=5):
    
    val_size = int(tf.data.experimental.cardinality(x).numpy() * 0.2)
    print("val_size=", val_size)
    
    for k in range(K):
#         k_train = x.take(val_size + k*val_size)
#         k_valid = x.skip(k*val_size)
#         k_train = tf.slice(x, k*val_size, val_size) #only for pure tensors not 
#         k_valid = x.skip(k*val_size)

        # may skip twicce to performe kflod
        t_take = x.take(k*val_size)
        t_skip = x.skip(k*val_size+val_size)
        k_train = t_take.concatenate(t_skip)
        
        v_skip = x.skip(k*val_size)
        k_valid = v_skip.take(val_size)

        print("k =", k,"k*val_size+val_size", k*val_size+val_size, "k_train num=", tf.data.experimental.cardinality(k_train).numpy())


        # x = tf.data.Dataset.range(10)
#         for n in k_train:
#             print(n.numpy())
#         for n in k_valid:
#             print(n.numpy())
        
        # list_ds
#         for img, x1, y1, x2, y2 in k_train:
#             print(x1, y1)

        # train_ds_map_toe
#         for img, (x, y) in k_train:
#             print(x.numpy(), y.numpy())

    
    
    
check_KFold_ds(x)
# check_KFold_ds(list_ds)    
# check_KFold_ds(train_ds_map_toe)
# Out:
# val_size= 2
# k = 0 k*val_size+val_size 2 k_train num= 8
# k = 1 k*val_size+val_size 4 k_train num= 8
# k = 2 k*val_size+val_size 6 k_train num= 8
# k = 3 k*val_size+val_size 8 k_train num= 8
# k = 4 k*val_size+val_size 10 k_train num= 8

# %%
# x = tf.data.Dataset.range(10)
# val_size = int(tf.data.experimental.cardinality(x).numpy() * 0.2)
# print("val_size=", val_size)

def get_KFold_ds(x, K=0):
        
    k = K
    # may skip twicce to perform kflod
    # train ds
    t_take = x.take(k*val_size)
    t_skip = x.skip(k*val_size+val_size)
    k_train = t_take.concatenate(t_skip)
    # val ds
    v_skip = x.skip(k*val_size)
    k_valid = v_skip.take(val_size)

    return k_train, k_valid

# %%
# val_size = int(tf.data.experimental.cardinality(train_ds_map_toe).numpy() * 0.2)
val_size = int(tf.data.experimental.cardinality(train_ds_map_toe).numpy() * 0.1)
t, v = get_KFold_ds(train_ds_map_toe, 1)

print(tf.data.experimental.cardinality(t).numpy())
print(tf.data.experimental.cardinality(v).numpy())

# for n in v:
#     print(n.numpy())
# Out:
# 1177
# 130

# %%
train_ds_map_toe
# Out:
# <ParallelMapDataset shapes: ((120, 120, 3), (2,)), types: (tf.uint8, tf.int64)>

# %%
v
# Out:
# <TakeDataset shapes: ((120, 120, 3), (2,)), types: (tf.uint8, tf.int64)>

# %% [markdown]
# # Albumentation pipeline

# %%
# # for NO keypoint augment
# transforms = A.Compose([
# #             A.RandomBrightness(limit=0.1, p=0.5),
#             A.JpegCompression(quality_lower=65, quality_upper=100, p=0.5),#A.JpegCompression(quality_lower=85, quality_upper=100, p=0.5)
#             A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
# #             A.RandomContrast(limit=0.2, p=0.5),
#             A.FancyPCA(alpha=0.1, always_apply=False, p=1),#A.FancyPCA(alpha=0.1, always_apply=False, p=0.5)
#             A.Downscale(scale_min=0.7, scale_max=0.9, interpolation=0, always_apply=False, p=0.5), #0.8~0.99 may better
#             A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, always_apply=False, p=0.5),
#             A.CLAHE(clip_limit=(1, 8), tile_grid_size=(8, 8), always_apply=False, p=0.5), #A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), always_apply=False, p=0.5)
# #             A.GlassBlur(sigma=0.9, max_delta=2, iterations=2, always_apply=False, mode='fast', p=0.5),
# #             A.GaussNoise(var_limit=(10.0, 50.0), mean=0, always_apply=False, p=0.5),
# #             A.GaussianBlur(blur_limit=(3, 7), sigma_limit=0, always_apply=False, p=0.5),
# #             A.HorizontalFlip(),
    
#             # try other augm, seems to strong...
#             A.RandomBrightnessContrast(always_apply=False, p=0.5, brightness_limit=(-0.2, 0.2), contrast_limit=(-0.2, 0.2), brightness_by_max=True),
#             A.Equalize(always_apply=False, p=0.5, mode='cv', by_channels=True),
#             A.MultiplicativeNoise(always_apply=False, p=0.5, multiplier=(0.8, 1.5), per_channel=False, elementwise=False),
#             A.RandomFog(always_apply=False, p=0.5, fog_coef_lower=0.2, fog_coef_upper=0.3, alpha_coef=0.25),

# ])


# def aug_fn(image, img_size):
#     data = {"image":image}
#     aug_data = transforms(**data)
#     aug_img = aug_data["image"]
# #     aug_img = tf.cast(aug_img/255.0, tf.float32)
#     aug_img = tf.cast(aug_img, tf.float32)
#     aug_img = tf.image.resize(aug_img, size=[img_size, img_size])
#     return aug_img

# def process_data(image, label, img_size):
#     aug_img = tf.numpy_function(func=aug_fn, inp=[image, img_size], Tout=tf.float32)
#     return aug_img, label

# def set_shapes(img, label, img_shape=(120,120,3)):
#     img.set_shape(img_shape)
# #     label.set_shape([]) # commited for go around error
#     return img, label





# # for NO keypoint augment AND for OneOf[] for better heel loss.
# transforms_oneof = A.Compose(A.OneOf([
#             A.RandomBrightness(limit=0.1, p=0.5),
#             A.JpegCompression(quality_lower=85, quality_upper=100, p=0.5),
#             A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
#             A.RandomContrast(limit=0.2, p=0.5),
#             A.FancyPCA(alpha=0.1, always_apply=False, p=0.5),
#             A.Downscale(scale_min=0.7, scale_max=0.9, interpolation=0, always_apply=False, p=0.5),
#             A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, always_apply=False, p=0.5),
#             A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), always_apply=False, p=0.5),
#             A.GlassBlur(sigma=0.9, max_delta=2, iterations=2, always_apply=False, mode='fast', p=0.5),
#             A.GaussNoise(var_limit=(10.0, 50.0), mean=0, always_apply=False, p=0.5),
#             A.GaussianBlur(blur_limit=(3, 7), sigma_limit=0, always_apply=False, p=.5)
# #             A.HorizontalFlip(),
#             ]),p=0.5)


# def aug_fn_oneof(image, img_size):
#     data = {"image":image}
#     aug_data = transforms_oneof(**data)
#     aug_img = aug_data["image"]
# #     aug_img = tf.cast(aug_img/255.0, tf.float32)
#     aug_img = tf.cast(aug_img, tf.float32)
#     aug_img = tf.image.resize(aug_img, size=[img_size, img_size])
#     return aug_img

# def process_data_oneof(image, label, img_size):
#     aug_img = tf.numpy_function(func=aug_fn_oneof, inp=[image, img_size], Tout=tf.float32)
#     return aug_img, label




# # Testing keypoints augment
# transforms = A.Compose([
#             A.RandomBrightness(limit=0.1, p=0.5),
#             A.JpegCompression(quality_lower=85, quality_upper=100, p=0.5),
#             A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
#             A.RandomContrast(limit=0.2, p=0.5),
#             A.FancyPCA (alpha=0.1, always_apply=False, p=1),
#             A.Downscale (scale_min=0.7, scale_max=0.9, interpolation=0, always_apply=False, p=0.5),
#             A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, always_apply=False, p=0.5),
#             A.CLAHE (clip_limit=4.0, tile_grid_size=(8, 8), always_apply=False, p=0.5),
#             A.HorizontalFlip(p=0.5),
#             ]
#             , 
#             keypoint_params=A.KeypointParams(format='xy'),  #currently not works for tf.ds yet.
#             )





# Testing keypoints augment
transforms = A.Compose([
            A.RandomBrightness(limit=0.1, p=0.5),
            A.JpegCompression(quality_lower=85, quality_upper=100, p=0.5),
            A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
            A.RandomContrast(limit=0.2, p=0.5),
            A.FancyPCA(alpha=0.1, always_apply=False, p=1.0),
            A.Downscale(scale_min=0.7, scale_max=0.9, interpolation=0, always_apply=False, p=0.5),
            A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, always_apply=False, p=0.5),
            A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), always_apply=False, p=0.5),
    
            A.HorizontalFlip(p=0.5),
            A.RandomResizedCrop(always_apply=False, height=120, width=120, scale=(0.9, 0.99), ratio=(1.0, 1.0), interpolation=0, p=0.7),#xy become double need change dtype of label. # pp will outside the image.
            A.IAAAffine(scale=0.9, translate_percent=None, translate_px=None, rotate=0.0, shear=0.0, order=1, cval=0, mode='reflect', always_apply=False, p=0.7),
#             A.ShiftScaleRotate(always_apply=False, p=0.5, shift_limit=(0.06, 0.06), scale_limit=(-0.1, 0.1), rotate_limit=(-5, 5), interpolation=1, border_mode=2, value=(0, 0, 0), mask_value=None),
    #2021-02-26
#             A.IAAPerspective(scale=(0.05, 0.1), keep_size=True, always_apply=False, p=0.5),#fallout image make train stop. NOT support keypoints!!!!!
            ]
            , 
            keypoint_params=A.KeypointParams(format='xy',remove_invisible=True),  #currently not works for tf.ds yet.
            )

# Testing keypoints augment
# @tf.function
def aug_fn(image, keypoints, img_size):
#     print('Check keypoints aug_fun 00:', keypoints) # Check keypoints aug_fun 00: [[53 58]]
#     data = {"image":image}
    aug_data = transforms(image=image, keypoints=keypoints)
    aug_img = aug_data["image"]
    aug_xy  = aug_data["keypoints"]
#     aug_img = tf.cast(aug_img/255.0, tf.float32)
    aug_img = tf.cast(aug_img, tf.float32)
    aug_img = tf.image.resize(aug_img, size=[img_size, img_size])
    
    aug_xy = tf.cast(aug_xy, tf.float32) #有些變形輸出是double
#     print('Check aug_xy:', aug_xy) # Check aug_xy: [(95, 45)] #印到這邊都是對的
    return aug_img, aug_xy 

# @tf.function
def process_data(image, keypoints, img_size):
    
    print('Check keypoints process01:', keypoints, np.shape(keypoints), type(keypoints))
        
#     keypoints = tf.make_ndarray(keypoints)
#     keypoints = np.array(keypoints)
#     keypoints = list(keypoints)
#     keypoints = np.asarray(keypoints, dtype=np.float32)
#     keypoints = tf.make_ndarray(keypoints.op.get_attr('value'))

#     keypoints = tf.reshape(keypoints, [1, 2])
    keypoints = tf.reshape(keypoints, [1, 2]) # for 'convert_keypoint_to_albumentations'
#     keypoints = np.reshape(keypoints, (1, 2))#not support tensor with np.call.

    print('Check keypoints process02:', keypoints, np.shape(keypoints), type(keypoints))

#     aug_img, aug_xy = tf.numpy_function(func=aug_fn, inp=[image, img_size], Tout=tf.float32)
#     aug_img, aug_xy = tf.py_function(func=aug_fn, inp=[image, keypoints, img_size], Tout=[tf.float32, tf.int64])#for tensors.
    aug_img, aug_xy = tf.numpy_function(func=aug_fn, inp=[image, keypoints, img_size], Tout=[tf.float32, tf.float32])
    print('Check keypoints process03:', aug_xy)
    
    aug_xy = tf.reshape(aug_xy, [2,]) # for 'tf ds tarining'
    print('Check keypoints process04:', aug_xy)
        
    return aug_img, aug_xy 








###  for AToe ###
# some pp will outside of image bcs p2 is close to 400.



# Testing keypoints augment
transforms_AToe = A.Compose([
#             A.RandomBrightness(limit=0.1, p=0.5),
#             A.JpegCompression(quality_lower=85, quality_upper=100, p=0.5),
#             A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
#             A.RandomContrast(limit=0.2, p=0.5),
#             A.FancyPCA(alpha=0.1, always_apply=False, p=0.5),
#             A.Downscale(scale_min=0.7, scale_max=0.9, interpolation=0, always_apply=False, p=0.5),
#             A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, always_apply=False, p=0.5),
#             A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), always_apply=False, p=0.5),
    
#             A.RandomBrightness(limit=0.1, p=0.5),
            A.JpegCompression(quality_lower=65, quality_upper=100, p=0.5),#A.JpegCompression(quality_lower=85, quality_upper=100, p=0.5)
            A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
#             A.RandomContrast(limit=0.2, p=0.5),
            A.FancyPCA(alpha=0.1, always_apply=False, p=1),#A.FancyPCA(alpha=0.1, always_apply=False, p=0.5)
            A.Downscale(scale_min=0.7, scale_max=0.9, interpolation=0, always_apply=False, p=0.5), #0.8~0.99 may better
            A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, always_apply=False, p=0.5),
            A.CLAHE(clip_limit=(1, 8), tile_grid_size=(8, 8), always_apply=False, p=0.5), #A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), always_apply=False, p=0.5)
    
            A.HorizontalFlip(p=0.5),
#             A.RandomResizedCrop(always_apply=False, height=120, width=120, scale=(0.75, 0.9), ratio=(1.0, 1.0), interpolation=0, p=0.5),#xy become double need change dtype of label. # pp will outside the image.
            A.IAAAffine (scale=0.9, translate_percent=None, translate_px=None, rotate=0.0, shear=0.0, order=1, cval=0, mode='reflect', always_apply=False, p=0.7),
#             A.ShiftScaleRotate(always_apply=False, p=0.5, shift_limit=(0.06, 0.06), scale_limit=(-0.1, 0.1), rotate_limit=(-5, 5), interpolation=1, border_mode=2, value=(0, 0, 0), mask_value=None),
            ]
            , 
            keypoint_params=A.KeypointParams(format='xy',remove_invisible=True),  #currently not works for tf.ds yet.
            )


# Testing keypoints augment
# @tf.function
def aug_fn_AToe(image, keypoints, img_size):
#     print('Check keypoints aug_fun 00:', keypoints) # Check keypoints aug_fun 00: [[53 58]]
#     data = {"image":image}
    aug_data = transforms_AToe(image=image, keypoints=keypoints)
    aug_img = aug_data["image"]
    aug_xy  = aug_data["keypoints"]
#     aug_img = tf.cast(aug_img/255.0, tf.float32)
    aug_img = tf.cast(aug_img, tf.float32)
    aug_img = tf.image.resize(aug_img, size=[img_size, img_size])
    
    aug_xy = tf.cast(aug_xy, tf.float32) #有些變形輸出是double
#     print('Check aug_xy:', aug_xy) # Check aug_xy: [(95, 45)] #印到這邊都是對的
    return aug_img, aug_xy 

# @tf.function
def process_data_AToe(image, keypoints, img_size):
    
    print('Check keypoints process01:', keypoints, np.shape(keypoints), type(keypoints))
        
#     keypoints = tf.make_ndarray(keypoints)
#     keypoints = np.array(keypoints)
#     keypoints = list(keypoints)
#     keypoints = np.asarray(keypoints, dtype=np.float32)
#     keypoints = tf.make_ndarray(keypoints.op.get_attr('value'))

#     keypoints = tf.reshape(keypoints, [1, 2])
    keypoints = tf.reshape(keypoints, [1, 2]) # for 'convert_keypoint_to_albumentations'
#     keypoints = np.reshape(keypoints, (1, 2))#not support tensor with np.call.

    print('Check keypoints process02:', keypoints, np.shape(keypoints), type(keypoints))

#     aug_img, aug_xy = tf.numpy_function(func=aug_fn, inp=[image, img_size], Tout=tf.float32)
#     aug_img, aug_xy = tf.py_function(func=aug_fn, inp=[image, keypoints, img_size], Tout=[tf.float32, tf.int64])#for tensors.
    aug_img, aug_xy = tf.numpy_function(func=aug_fn_AToe, inp=[image, keypoints, img_size], Tout=[tf.float32, tf.float32])
    print('Check keypoints process03:', aug_xy)
    
    aug_xy = tf.reshape(aug_xy, [2,]) # for 'tf ds tarining'
    print('Check keypoints process04:', aug_xy)
        
    return aug_img, aug_xy 




def set_shapes(img, label, img_shape=(120,120,3)):
    img.set_shape(img_shape)
#     label.set_shape([]) # commited for go around error
    return img, label

# %% [markdown]
# #### prepare train_ds_prefetch

# %%
def configure_for_performance_cache_train(ds, cache=True, augment=False):

    
    """#TODO: need to check the parse logic of ds.cache.
    if cache:
        print("Check cache-f1 to file:", cache)
        if isinstance(cache, str):
            ds = ds.cache(cache)
            print("Check cache-f2 to file:", cache)
    else:
        ds = ds.cache()
        print("Check cache in memory:", cache)
    """    
    if cache:
        ds = ds.cache()
        print("Check cache in memory:Y", cache)
    else:
        print("Check cache in memory:N", cache)
        
    if augment:
        ds = ds.map(partial(process_data, img_size=120),num_parallel_calls=AUTOTUNE)
        ds = ds.map(set_shapes, num_parallel_calls=AUTOTUNE)
        print("Check augment :Y", augment)
    else:
        print("Check augment :N", augment)
    
    #ds = ds.repeat()#TODO:2020-12-14: test
    #ds = ds.shuffle(buffer_size=MULTI_BATCH_SIZE*2) # (buffer_size=MULTI_BATCH_SIZE*5) 6sec,buffer_size=1000 take few sec. or buffer_size=image_count <- take too long # each take ds take 30~45 sec, TODO!!
    ds = ds.shuffle(len(list_ds), reshuffle_each_iteration=True) #todo: move to ds_pre. see https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle
    ds = ds.batch(MULTI_BATCH_SIZE)#MULTI_BATCH_SIZE for multi-GPUs
    ds = ds.prefetch(buffer_size=AUTOTUNE) #buffer_size=AUTOTUNE seem no speed improve
    
    print("Check ds cache[{}] and augment[{}]".format(cache, augment))
    
    return ds


def configure_for_performance_cache_train_AToe(ds, cache=True, augment=False):

    
    """#TODO: need to check the parse logic of ds.cache.
    if cache:
        print("Check cache-f1 to file:", cache)
        if isinstance(cache, str):
            ds = ds.cache(cache)
            print("Check cache-f2 to file:", cache)
    else:
        ds = ds.cache()
        print("Check cache in memory:", cache)
    """    
    if cache:
        ds = ds.cache()
        print("Check cache in memory:Y", cache)
    else:
        print("Check cache in memory:N", cache)
        
    if augment:
        ds = ds.map(partial(process_data_AToe, img_size=120),num_parallel_calls=AUTOTUNE)
        ds = ds.map(set_shapes, num_parallel_calls=AUTOTUNE)
        print("Check augment :Y", augment)
    else:
        print("Check augment :N", augment)
    
    #ds = ds.repeat()#TODO:2020-12-14: test
    #ds = ds.shuffle(buffer_size=MULTI_BATCH_SIZE*2) # (buffer_size=MULTI_BATCH_SIZE*5) 6sec,buffer_size=1000 take few sec. or buffer_size=image_count <- take too long # each take ds take 30~45 sec, TODO!!
    ds = ds.shuffle(len(list_ds), reshuffle_each_iteration=True) #todo: move to ds_pre. see https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle
    ds = ds.batch(MULTI_BATCH_SIZE)#MULTI_BATCH_SIZE for multi-GPUs
    ds = ds.prefetch(buffer_size=AUTOTUNE) #buffer_size=AUTOTUNE seem no speed improve
    
    print("Check ds cache[{}] and augment[{}]".format(cache, augment))
    
    return ds





# def configure_for_performance_cache_train_oneof(ds, cache=True, augment=False):

    
#     """#TODO: need to check the parse logic of ds.cache.
#     if cache:
#         print("Check cache-f1 to file:", cache)
#         if isinstance(cache, str):
#             ds = ds.cache(cache)
#             print("Check cache-f2 to file:", cache)
#     else:
#         ds = ds.cache()
#         print("Check cache in memory:", cache)
#     """    
#     if cache:
#         ds = ds.cache()
#         print("Check cache in memory:Y", cache)
#     else:
#         print("Check cache in memory:N", cache)
        
#     if augment:
#         ds = ds.map(partial(process_data_oneof, img_size=120),num_parallel_calls=AUTOTUNE)
#         ds = ds.map(set_shapes, num_parallel_calls=AUTOTUNE)
#         print("Check augment :Y", augment)
#     else:
#         print("Check augment :N", augment)
    
#     #ds = ds.repeat()#TODO:2020-12-14: test
#     #ds = ds.shuffle(buffer_size=MULTI_BATCH_SIZE*2) # (buffer_size=MULTI_BATCH_SIZE*5) 6sec,buffer_size=1000 take few sec. or buffer_size=image_count <- take too long # each take ds take 30~45 sec, TODO!!
#     ds = ds.shuffle(len(list_ds), reshuffle_each_iteration=True) #todo: move to ds_pre. see https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle
#     ds = ds.batch(MULTI_BATCH_SIZE)#MULTI_BATCH_SIZE for multi-GPUs
#     ds = ds.prefetch(buffer_size=AUTOTUNE) #buffer_size=AUTOTUNE seem no speed improve
    
#     print("Check ds cache[{}] and augment[{}]".format(cache, augment))
    
#     return ds




def configure_for_performance_cache_val(ds, cache=True, augment=False):

    
    """#TODO: need to check the parse logic of ds.cache
    TODO:test remove ds.shuffle from val_ds.
    .
    if cache:
        print("Check cache-f1 to file:", cache)
        if isinstance(cache, str):
            ds = ds.cache(cache)
            print("Check cache-f2 to file:", cache)
    else:
        ds = ds.cache()
        print("Check cache in memory:", cache)
    """    
    if cache:
        ds = ds.cache()
        print("Check cache in memory:Y", cache)
    else:
        print("Check cache in memory:N", cache)
        
    if augment:
#         ds = ds.map(data_augment, num_parallel_calls=AUTOTUNE)
        ds = ds.map(AA, num_parallel_calls=AUTOTUNE)
#         ds = ds.map(RA, num_parallel_calls=AUTOTUNE)
        print("Check augment :Y", augment)
    else:
        print("Check augment :N", augment)
    
    #ds = ds.repeat()#TODO:2020-12-14: test
    #ds = ds.shuffle(buffer_size=MULTI_BATCH_SIZE*2) # (buffer_size=MULTI_BATCH_SIZE*5) 6sec,buffer_size=1000 take few sec. or buffer_size=image_count <- take too long # each take ds take 30~45 sec, TODO!!
#     ds = ds.shuffle(len(list_ds), reshuffle_each_iteration=False) #todo: move to ds_pre. see https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle
    ds = ds.batch(MULTI_BATCH_SIZE)#MULTI_BATCH_SIZE for multi-GPUs
    ds = ds.prefetch(buffer_size=AUTOTUNE) #buffer_size=AUTOTUNE seem no speed improve
    
    print("Check ds cache[{}] and augment[{}]".format(cache, augment))
    
    return ds

# %%
# """
# Prepare the ds properties (cache, augment, bs, shuffle, prefetch, etc.) for better performance.
# """
# # Toe ds_pre
# train_ds_pre_toe = configure_for_performance_cache_train(train_ds_map_toe)

# # Heel ds_pre
# train_ds_pre_heel = configure_for_performance_cache_val(train_ds_map_heel)

# %% [markdown]
# #### All split ds_prefetch
# * train_ds_map_toe_s = train_ds_map_toe.skip(val_size)
# * valid_ds_map_toe_s = train_ds_map_toe.take(val_size)
#
# * train_ds_map_heel_s = train_ds_map_heel.skip(val_size)
# * valid_ds_map_heel_s = train_ds_map_heel.take(val_size)

# %%
# """
# Prepare the ds properties (cache, augment, bs, shuffle, prefetch, etc.) for better performance.
# """
# # Toe ds_pre
# train_ds_pre_toe_s = configure_for_performance_cache_train(train_ds_map_toe_s, augment=True)
# valid_ds_pre_toe_s = configure_for_performance_cache_val(valid_ds_map_toe_s)

# # Heel ds_pre
# train_ds_pre_heel_s = configure_for_performance_cache_train(train_ds_map_heel_s, augment=True)
# valid_ds_pre_heel_s = configure_for_performance_cache_val(valid_ds_map_heel_s)

# %% [markdown]
# #### Check ds_prefetch samples

# %%
# # create it_ds once
# it_train_ds_pre_toe_s = iter(train_ds_pre_toe_s)

# %%
# %%time

# # for albu keypoint

# # for original return aug_img, , aug_xy 


# image_batch, label_batch = next(it_train_ds_pre_toe_s)

# fig = plt.figure(figsize=(8, 8))
# print('batch * multi:', len(label_batch), ', MULTI_BATCH_SIZE=', MULTI_BATCH_SIZE)
# for i in range(16):
#     ax = plt.subplot(4, 4, i + 1)
#     plt.imshow(image_batch[i].numpy().astype("uint8"))
#     plt.title(label_batch[i].numpy())
#     plt.axis("off")

#     plt.plot(label_batch[i].numpy()[0], label_batch[i].numpy()[1], 'r+', markersize=13, mew=2.5)

#     print(f'Check lables: {label_batch[i]}')

# %%
# # create it_ds once
# it_train_ds_pre_heel_s = iter(train_ds_pre_heel_s)

# %%
# %%time

# # for albu keypoint

# # for original return aug_img, , aug_xy 


# image_batch, label_batch = next(it_train_ds_pre_heel_s)

# fig = plt.figure(figsize=(8, 8))
# print('batch * multi:', len(label_batch), ', MULTI_BATCH_SIZE=', MULTI_BATCH_SIZE)
# for i in range(16):
#     ax = plt.subplot(4, 4, i + 1)
#     plt.imshow(image_batch[i].numpy().astype("uint8"))
#     plt.title(label_batch[i].numpy())
#     plt.axis("off")

#     plt.plot(label_batch[i].numpy()[0], label_batch[i].numpy()[1], 'r+', markersize=13, mew=2.5)

#     print(f'Check lables: {label_batch[i]}')

# %%
# # create it_ds once
# it_valid_ds_pre_toe_s = iter(valid_ds_pre_toe_s)

# %%
# %%time

# # for albu keypoint

# # for return aug_img, aug_xy 


# image_batch, label_batch = next(it_valid_ds_pre_toe_s)

# plt.figure(figsize=(8, 8))
# # for images, labels in valid_ds_pre_toe_s.take(1):
# print('batch * multi:', len(label_batch), ', MULTI_BATCH_SIZE=', MULTI_BATCH_SIZE)
# for i in range(16):
#     ax = plt.subplot(4, 4, i + 1)
#     plt.imshow(image_batch[i].numpy().astype("uint8"))
#     plt.title(label_batch[i].numpy())
#     plt.axis("off")

#     plt.plot(label_batch[i].numpy()[0], label_batch[i].numpy()[1], 'r+', markersize=13, mew=2.5)

#     print(f'Check lables: {label_batch[i]}')

# %% [markdown]
# ### 3.Loss function
#
# * mae
# * euclidean distance
# * others
#
#
#         # 'x' is [[1, 1, 1]
#         #         [1, 1, 1]]
#         tf.reduce_sum(x) ==> 6
#         tf.reduce_sum(x, 0) ==> [2, 2, 2]
#         tf.reduce_sum(x, 1) ==> [3, 3]
#         the function is default for 2-D array, therefor, in our 1-D [x1,y1] to [x2,y2] the axis should be '0' or just leave it.
#
#         tf.sqrt need 	A tf.Tensor of type bfloat16, half, float32, float64, complex64, complex128
#         so, convert it first.

# %% [markdown]
# should be -> tf.Tensor([56 39], shape=(2,), dtype=int64)

# %%
y_true = [10, 10]
y_pred = [10, 20]

# y_true = [1.00000000000000000000123, 10]
# y_pred = [1.0, 10.000000000000000000000000001]

# y_true = [1.0000123, 10]
# y_pred = [1.0, 10.0000321]

# %%
# mae

loss_mae = tf.keras.losses.MAE(
    y_true, y_pred
)

loss_mae
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=5>

# %%
# ed

# loss_ed = tf.sqrt(tf.reduce_sum(tf.square(tf.constant(y_true) - tf.constant(y_pred)), 0))

# loss_ed = tf.sqrt(tf.reduce_sum(tf.square(tf.Variable(y_true) - tf.Variable(y_pred)), 0))

loss_ed = tf.sqrt(tf.reduce_sum(tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32)), 0))

loss_ed
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=10.0>

# %%
def ed_loss(y_true, y_pred):
    return tf.sqrt(tf.reduce_sum(tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32)), 0))

# fix NaN in euclidean distance
# tf.maximum(d, 1e-9), to keep atlease is 1e-9.
# def ed_loss(y_true, y_pred):
#     return tf.sqrt(tf.maximum(tf.reduce_sum(tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32)), 0), 1e-9))

# %%
# check the euclidean distance loss
ed_loss(y_true, y_pred).numpy()
# Out:
# 10.0

# %%
ed_loss(y_true, y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=10.0>

# %% [markdown]
# #### mean Euclidean distance
#
# * here the y_true and y_pred is 2-D array. the axis use 1.
#
#
# * NOTE: LB評分的mean euclidean distance功能，應該跟model.evaluate()一樣so不需重新寫。evaluate()會自動用loss (model.metrics_names)計算後在自動平均，而模型loss我們是用ed-loss取代。

# %%
# y_true = [[60, 76],
#        [58, 49 ],
#        [63, 67 ],
#        [58 , 57]]
# y_pred = [[59.927303, 76.471214],
#        [58.056904, 49.98754 ],
#        [63.067844, 67.03861 ],
#        [58.70202 , 57.372707]]

y_true = [[60, 70],
       [70, 80]]
y_pred = [[61, 71],
       [72, 82]]

# y_true = [(60, 70),
#        (70, 80)]
# y_pred = [(61, 71),
#        (72, 82)]

# %%
tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32))
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[1., 1.],
#        [4., 4.]], dtype=float32)>

# %%
tf.reduce_sum(tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32)), 1)
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([2., 8.], dtype=float32)>

# %%
def ed_metric_2d(y_true, y_pred):
    return tf.sqrt(tf.reduce_sum(tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32)), 1))

# %%
ed_metric_2d(y_true, y_pred).numpy()
# Out:
# array([1.4142135, 2.828427 ], dtype=float32)

# %%
ed_metric_2d(y_true, y_pred)
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([1.4142135, 2.828427 ], dtype=float32)>

# %%
# 等於true, pred點位ed的平均，LB評分方式。(toe/heel即p1,p2要個別算ed一次再相加)
def ed_metric_2d_mean(y_true, y_pred):
    return tf.reduce_mean(tf.sqrt(tf.reduce_sum(tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32)), 1)))

# %%
# for re-scale back xy 
# return img, [(x1-60)/60,((y1-y_offset_toe)-60)/60]#normalized [-1,1] 
# return img, [(x2-60)/60,((y2-y_offset_toe)-60)/60]#normalized [-1,1] 

# 等於true, pred點位ed的平均，LB評分方式。(toe/heel即p1,p2要個別算ed一次再相加)
def edRescal(y_true, y_pred):
    return tf.reduce_mean(tf.sqrt(tf.reduce_sum(tf.square(tf.cast((y_true*60)+60, tf.float32) - tf.cast((y_pred*60)+60, tf.float32)), 1)))

# %%
ed_metric_2d_mean(y_true, y_pred).numpy()
# Out:
# 2.1213202

# %%
ed_metric_2d_mean(y_true, y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=2.1213202>

# %% [markdown]
# # EFNE Training

# %% [markdown]
# maybe mae better than ed loss?

# %%
"""dump lr
"""
ep_num_transf = 500



def lrdump(epoch):
    
    #step_size = 100
    lr_max = 0.006
    lr_min = 0.001
    lr_start = 0.01

    lr_init_ep = 0
    lr_ramp_ep = 100
    lr_sus_ep  = 0
    lr_decay   = 0.8

    
    # warm up
    if epoch < lr_init_ep:
        lr = (lr_max - lr_min) / lr_ramp_ep * epoch + lr_min    
        
    elif lr_init_ep -1 < epoch < lr_ramp_ep:
        lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start

    elif epoch < lr_ramp_ep + lr_sus_ep:
        lr = lr_max

    else:
        lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min

    return lr

rng = [i for i in range(ep_num_transf)]
y = [lrdump(x) for x in rng]
sns.set(style='darkgrid')
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)

# %%
print('{} ~ {}'.format(min(y), max(y)))
# Out:
# 0.001 ~ 0.01

# %%
for e, lr in zip(rng,y):
    print('{}\t {}\n'.format(e, lr))
# Out:
# 0	 0.01
#
# 1	 0.00996
#
# 2	 0.00992
#
# 3	 0.00988
#
# 4	 0.00984
#
# 5	 0.0098
#
# 6	 0.00976
#
# 7	 0.00972
#
# 8	 0.00968
#
# 9	 0.009640000000000001
#
# 10	 0.009600000000000001
#
# 11	 0.00956
#
# 12	 0.00952
#
# 13	 0.00948
#
# 14	 0.00944
#
# 15	 0.0094
#
# 16	 0.00936
#
# 17	 0.00932
#
# 18	 0.00928
#
# 19	 0.00924
#
# 20	 0.0092
#
# 21	 0.00916
#
# 22	 0.00912
#
# 23	 0.00908
#
# 24	 0.00904
#
# 25	 0.009000000000000001
#
# 26	 0.00896
#
# 27	 0.00892
#
# 28	 0.00888
#
# 29	 0.00884
#
# 30	 0.0088
#
# 31	 0.00876
#
# 32	 0.00872
#
# 33	 0.00868
#
# 34	 0.00864
#
# 35	 0.0086
#
# 36	 0.00856
#
# 37	 0.00852
#
# 38	 0.00848
#
# 39	 0.00844
#
# 40	 0.0084
#
# 41	 0.00836
#
# 42	 0.008320000000000001
#
# 43	 0.00828
#
# 44	 0.00824
#
# 45	 0.0082
#
# 46	 0.00816
#
# 47	 0.00812
#
# 48	 0.00808
#
# 49	 0.00804
#
# 50	 0.008
#
# 51	 0.00796
#
# 52	 0.00792
#
# 53	 0.00788
#
# 54	 0.00784
#
# 55	 0.0078
#
# 56	 0.0077599999999999995
#
# 57	 0.007719999999999999
#
# 58	 0.00768
#
# 59	 0.00764
#
# 60	 0.0076
#
# 61	 0.00756
#
# 62	 0.007520000000000001
#
# 63	 0.0074800000000000005
#
# 64	 0.00744
#
# 65	 0.0074
#
# 66	 0.00736
#
# 67	 0.00732
#
# 68	 0.00728
#
# 69	 0.00724
#
# 70	 0.0072
#
# 71	 0.00716
#
# 72	 0.00712
#
# 73	 0.0070799999999999995
#
# 74	 0.007039999999999999
#
# 75	 0.007
#
# 76	 0.00696
#
# 77	 0.00692
#
# 78	 0.00688
#
# 79	 0.006840000000000001
#
# 80	 0.0068000000000000005
#
# 81	 0.00676
#
# 82	 0.00672
#
# 83	 0.00668
#
# 84	 0.00664
#
# 85	 0.0066
#
# 86	 0.00656
#
# 87	 0.00652
#
# 88	 0.00648
#
# 89	 0.0064399999999999995
#
# 90	 0.0063999999999999994
#
# 91	 0.006359999999999999
#
# 92	 0.00632
#
# 93	 0.00628
#
# 94	 0.00624
#
# 95	 0.0062
#
# 96	 0.00616
#
# 97	 0.0061200000000000004
#
# 98	 0.0060799999999999995
#
# 99	 0.00604
#
# 100	 0.006
#
# 101	 0.005
#
# 102	 0.004200000000000001
#
# 103	 0.0035600000000000007
#
# 104	 0.0030480000000000004
#
# 105	 0.0026384000000000004
#
# 106	 0.0023107200000000005
#
# 107	 0.0020485760000000007
#
# 108	 0.0018388608000000006
#
# 109	 0.0016710886400000003
#
# 110	 0.0015368709120000003
#
# 111	 0.0014294967296000004
#
# 112	 0.0013435973836800003
#
# 113	 0.0012748779069440002
#
# 114	 0.0012199023255552001
#
# 115	 0.0011759218604441603
#
# 116	 0.0011407374883553281
#
# 117	 0.0011125899906842625
#
# 118	 0.0010900719925474101
#
# 119	 0.001072057594037928
#
# 120	 0.0010576460752303425
#
# 121	 0.001046116860184274
#
# 122	 0.001036893488147419
#
# 123	 0.0010295147905179354
#
# 124	 0.0010236118324143482
#
# 125	 0.0010188894659314785
#
# 126	 0.0010151115727451828
#
# 127	 0.0010120892581961464
#
# 128	 0.001009671406556917
#
# 129	 0.0010077371252455336
#
# 130	 0.0010061897001964269
#
# 131	 0.0010049517601571415
#
# 132	 0.0010039614081257132
#
# 133	 0.0010031691265005706
#
# 134	 0.0010025353012004564
#
# 135	 0.0010020282409603652
#
# 136	 0.001001622592768292
#
# 137	 0.0010012980742146336
#
# 138	 0.001001038459371707
#
# 139	 0.0010008307674973657
#
# 140	 0.0010006646139978925
#
# 141	 0.001000531691198314
#
# 142	 0.0010004253529586511
#
# 143	 0.001000340282366921
#
# 144	 0.0010002722258935367
#
# 145	 0.0010002177807148294
#
# 146	 0.0010001742245718634
#
# 147	 0.001000139379657491
#
# 148	 0.0010001115037259927
#
# 149	 0.001000089202980794
#
# 150	 0.0010000713623846353
#
# 151	 0.0010000570899077082
#
# 152	 0.0010000456719261666
#
# 153	 0.0010000365375409334
#
# 154	 0.0010000292300327467
#
# 155	 0.0010000233840261974
#
# 156	 0.0010000187072209579
#
# 157	 0.0010000149657767663
#
# 158	 0.001000011972621413
#
# 159	 0.0010000095780971303
#
# 160	 0.0010000076624777044
#
# 161	 0.0010000061299821634
#
# 162	 0.0010000049039857308
#
# 163	 0.0010000039231885846
#
# 164	 0.0010000031385508678
#
# 165	 0.0010000025108406942
#
# 166	 0.0010000020086725553
#
# 167	 0.0010000016069380442
#
# 168	 0.0010000012855504354
#
# 169	 0.0010000010284403483
#
# 170	 0.0010000008227522787
#
# 171	 0.001000000658201823
#
# 172	 0.0010000005265614583
#
# 173	 0.0010000004212491666
#
# 174	 0.0010000003369993334
#
# 175	 0.0010000002695994667
#
# 176	 0.0010000002156795734
#
# 177	 0.0010000001725436586
#
# 178	 0.001000000138034927
#
# 179	 0.0010000001104279416
#
# 180	 0.0010000000883423532
#
# 181	 0.0010000000706738826
#
# 182	 0.001000000056539106
#
# 183	 0.0010000000452312849
#
# 184	 0.0010000000361850279
#
# 185	 0.0010000000289480224
#
# 186	 0.001000000023158418
#
# 187	 0.0010000000185267342
#
# 188	 0.0010000000148213874
#
# 189	 0.00100000001185711
#
# 190	 0.0010000000094856879
#
# 191	 0.0010000000075885505
#
# 192	 0.0010000000060708402
#
# 193	 0.0010000000048566722
#
# 194	 0.0010000000038853378
#
# 195	 0.0010000000031082702
#
# 196	 0.0010000000024866162
#
# 197	 0.0010000000019892929
#
# 198	 0.0010000000015914345
#
# 199	 0.0010000000012731474
#
# 200	 0.001000000001018518
#
# 201	 0.0010000000008148144
#
# 202	 0.0010000000006518516
#
# 203	 0.0010000000005214813
#
# 204	 0.001000000000417185
#
# 205	 0.001000000000333748
#
# 206	 0.0010000000002669985
#
# 207	 0.0010000000002135987
#
# 208	 0.001000000000170879
#
# 209	 0.0010000000001367032
#
# 210	 0.0010000000001093626
#
# 211	 0.0010000000000874901
#
# 212	 0.001000000000069992
#
# 213	 0.0010000000000559936
#
# 214	 0.001000000000044795
#
# 215	 0.001000000000035836
#
# 216	 0.0010000000000286687
#
# 217	 0.001000000000022935
#
# 218	 0.001000000000018348
#
# 219	 0.0010000000000146784
#
# 220	 0.0010000000000117428
#
# 221	 0.0010000000000093942
#
# 222	 0.0010000000000075153
#
# 223	 0.0010000000000060124
#
# 224	 0.0010000000000048098
#
# 225	 0.0010000000000038479
#
# 226	 0.0010000000000030783
#
# 227	 0.0010000000000024627
#
# 228	 0.00100000000000197
#
# 229	 0.001000000000001576
#
# 230	 0.001000000000001261
#
# 231	 0.0010000000000010088
#
# 232	 0.0010000000000008069
#
# 233	 0.0010000000000006456
#
# 234	 0.0010000000000005165
#
# 235	 0.001000000000000413
#
# 236	 0.0010000000000003305
#
# 237	 0.0010000000000002643
#
# 238	 0.0010000000000002117
#
# 239	 0.0010000000000001692
#
# 240	 0.0010000000000001353
#
# 241	 0.0010000000000001082
#
# 242	 0.0010000000000000868
#
# 243	 0.0010000000000000694
#
# 244	 0.0010000000000000555
#
# 245	 0.0010000000000000445
#
# 246	 0.0010000000000000356
#
# 247	 0.0010000000000000284
#
# 248	 0.0010000000000000228
#
# 249	 0.0010000000000000182
#
# 250	 0.0010000000000000145
#
# 251	 0.0010000000000000117
#
# 252	 0.0010000000000000093
#
# 253	 0.0010000000000000074
#
# 254	 0.0010000000000000059
#
# 255	 0.0010000000000000048
#
# 256	 0.001000000000000004
#
# 257	 0.001000000000000003
#
# 258	 0.0010000000000000024
#
# 259	 0.001000000000000002
#
# 260	 0.0010000000000000015
#
# 261	 0.0010000000000000013
#
# 262	 0.001000000000000001
#
# 263	 0.0010000000000000009
#
# 264	 0.0010000000000000007
#
# 265	 0.0010000000000000005
#
# 266	 0.0010000000000000005
#
# 267	 0.0010000000000000005
#
# 268	 0.0010000000000000002
#
# 269	 0.0010000000000000002
#
# 270	 0.0010000000000000002
#
# 271	 0.0010000000000000002
#
# 272	 0.001
#
# 273	 0.001
#
# 274	 0.001
#
# 275	 0.001
#
# 276	 0.001
#
# 277	 0.001
#
# 278	 0.001
#
# 279	 0.001
#
# 280	 0.001
#
# 281	 0.001
#
# 282	 0.001
#
# 283	 0.001
#
# 284	 0.001
#
# 285	 0.001
#
# 286	 0.001
#
# 287	 0.001
#
# 288	 0.001
#
# 289	 0.001
#
# 290	 0.001
#
# 291	 0.001
#
# 292	 0.001
#
# 293	 0.001
#
# 294	 0.001
#
# 295	 0.001
#
# 296	 0.001
#
# 297	 0.001
#
# 298	 0.001
#
# 299	 0.001
#
# 300	 0.001
#
# 301	 0.001
#
# 302	 0.001
#
# 303	 0.001
#
# 304	 0.001
#
# 305	 0.001
#
# 306	 0.001
#
# 307	 0.001
#
# 308	 0.001
#
# 309	 0.001
#
# 310	 0.001
#
# 311	 0.001
#
# 312	 0.001
#
# 313	 0.001
#
# 314	 0.001
#
# 315	 0.001
#
# 316	 0.001
#
# 317	 0.001
#
# 318	 0.001
#
# 319	 0.001
#
# 320	 0.001
#
# 321	 0.001
#
# 322	 0.001
#
# 323	 0.001
#
# 324	 0.001
#
# 325	 0.001
#
# 326	 0.001
#
# 327	 0.001
#
# 328	 0.001
#
# 329	 0.001
#
# 330	 0.001
#
# 331	 0.001
#
# 332	 0.001
#
# 333	 0.001
#
# 334	 0.001
#
# 335	 0.001
#
# 336	 0.001
#
# 337	 0.001
#
# 338	 0.001
#
# 339	 0.001
#
# 340	 0.001
#
# 341	 0.001
#
# 342	 0.001
#
# 343	 0.001
#
# 344	 0.001
#
# 345	 0.001
#
# 346	 0.001
#
# 347	 0.001
#
# 348	 0.001
#
# 349	 0.001
#
# 350	 0.001
#
# 351	 0.001
#
# 352	 0.001
#
# 353	 0.001
#
# 354	 0.001
#
# 355	 0.001
#
# 356	 0.001
#
# 357	 0.001
#
# 358	 0.001
#
# 359	 0.001
#
# 360	 0.001
#
# 361	 0.001
#
# 362	 0.001
#
# 363	 0.001
#
# 364	 0.001
#
# 365	 0.001
#
# 366	 0.001
#
# 367	 0.001
#
# 368	 0.001
#
# 369	 0.001
#
# 370	 0.001
#
# 371	 0.001
#
# 372	 0.001
#
# 373	 0.001
#
# 374	 0.001
#
# 375	 0.001
#
# 376	 0.001
#
# 377	 0.001
#
# 378	 0.001
#
# 379	 0.001
#
# 380	 0.001
#
# 381	 0.001
#
# 382	 0.001
#
# 383	 0.001
#
# 384	 0.001
#
# 385	 0.001
#
# 386	 0.001
#
# 387	 0.001
#
# 388	 0.001
#
# 389	 0.001
#
# 390	 0.001
#
# 391	 0.001
#
# 392	 0.001
#
# 393	 0.001
#
# 394	 0.001
#
# 395	 0.001
#
# 396	 0.001
#
# 397	 0.001
#
# 398	 0.001
#
# 399	 0.001
#
# 400	 0.001
#
# 401	 0.001
#
# 402	 0.001
#
# 403	 0.001
#
# 404	 0.001
#
# 405	 0.001
#
# 406	 0.001
#
# 407	 0.001
#
# 408	 0.001
#
# 409	 0.001
#
# 410	 0.001
#
# 411	 0.001
#
# 412	 0.001
#
# 413	 0.001
#
# 414	 0.001
#
# 415	 0.001
#
# 416	 0.001
#
# 417	 0.001
#
# 418	 0.001
#
# 419	 0.001
#
# 420	 0.001
#
# 421	 0.001
#
# 422	 0.001
#
# 423	 0.001
#
# 424	 0.001
#
# 425	 0.001
#
# 426	 0.001
#
# 427	 0.001
#
# 428	 0.001
#
# 429	 0.001
#
# 430	 0.001
#
# 431	 0.001
#
# 432	 0.001
#
# 433	 0.001
#
# 434	 0.001
#
# 435	 0.001
#
# 436	 0.001
#
# 437	 0.001
#
# 438	 0.001
#
# 439	 0.001
#
# 440	 0.001
#
# 441	 0.001
#
# 442	 0.001
#
# 443	 0.001
#
# 444	 0.001
#
# 445	 0.001
#
# 446	 0.001
#
# 447	 0.001
#
# 448	 0.001
#
# 449	 0.001
#
# 450	 0.001
#
# 451	 0.001
#
# 452	 0.001
#
# 453	 0.001
#
# 454	 0.001
#
# 455	 0.001
#
# 456	 0.001
#
# 457	 0.001
#
# 458	 0.001
#
# 459	 0.001
#
# 460	 0.001
#
# 461	 0.001
#
# 462	 0.001
#
# 463	 0.001
#
# 464	 0.001
#
# 465	 0.001
#
# 466	 0.001
#
# 467	 0.001
#
# 468	 0.001
#
# 469	 0.001
#
# 470	 0.001
#
# 471	 0.001
#
# 472	 0.001
#
# 473	 0.001
#
# 474	 0.001
#
# 475	 0.001
#
# 476	 0.001
#
# 477	 0.001
#
# 478	 0.001
#
# 479	 0.001
#
# 480	 0.001
#
# 481	 0.001
#
# 482	 0.001
#
# 483	 0.001
#
# 484	 0.001
#
# 485	 0.001
#
# 486	 0.001
#
# 487	 0.001
#
# 488	 0.001
#
# 489	 0.001
#
# 490	 0.001
#
# 491	 0.001
#
# 492	 0.001
#
# 493	 0.001
#
# 494	 0.001
#
# 495	 0.001
#
# 496	 0.001
#
# 497	 0.001
#
# 498	 0.001
#
# 499	 0.001

# %%
# clr3
# warm up 10% of epoch: it can reduce fall in local min in inital steps.


ep_num = 1000



def clr3(epoch):
    
    
    step_size = 25 # currently best for foot pp
    max_lr = 0.01 # currently best for foot pp
    base_lr = 1e-6 # 1e-6 1e-7

    # warm up
    lr_init_ep = 0
    lr_ramp_ep = 100
    lr_sus_ep  = 0
    lr_decay   = 0.5

    iterations = epoch
    cycle = np.floor(1+iterations/(2*step_size))
    x = np.abs(iterations/step_size - 2*cycle + 1)
    lr = base_lr + (max_lr-base_lr)*np.maximum(0, (1-x))
    
    #todo: boost the lr at initial setps.
#     initial_lr = lambda epoch: lr if epoch > step_size else max_lr
#     initial_lr = lambda epoch: lr if epoch > step_size else boost_lr
#     lr = initial_lr(epoch)
    #todo: boost the lr at fist step_size.
    
    # warm up
    if epoch < lr_ramp_ep:
        lr = (max_lr - base_lr) / lr_ramp_ep * epoch + base_lr
    
    decay = ((epoch+1)/ep_num)
    base_part = 1.001 #1.1
#     print(decay)
    return lr * (base_part-decay) * lr_decay # supressed the lr!


rng = [i for i in range(ep_num)]
y = [clr3(x) for x in rng]
sns.set(style='darkgrid')
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)

# %%
print('{} ~ {}'.format(min(y), max(y)))
# Out:
# 2.4999999999999966e-08 ~ 0.004459954505

# %%
# 2.4999999999999966e-08 ~ 0.004459954505 1e-2~1e-6

# %%
# %%time
# """
# cosine_decay_restarts是cosine_decay的cycle版本。
# first_decay_steps是指第一次完全下降的step數，
# t_mul是指每一次循環的步數都將乘以t_mul倍，
# m_mul指每一次循環重新開始時的初始lr是上一次循環初始值的m_mul倍。
# alpha
# """

# from matplotlib.ticker import FormatStrFormatter



# ep_num = 1000



# def CosineDecayCLRWarmUp(epoch):
    
#     #step_size = 25 # currently best for foot pp
#     max_lr = 1e-2 # currently best for foot pp
#     base_lr = 1e-8# 1e-6 1e-7

#     # warm up
#     lr_init_ep = 0
#     lr_ramp_ep = 100
#     lr_sus_ep  = 0
#     lr_decay   = 0.8


#     initial_learning_rate = 1e-2
#     first_decay_steps = 100


#     lr_decayed_fn = (
#       tf.keras.experimental.CosineDecayRestarts(
#           initial_learning_rate,
#           first_decay_steps,
#           t_mul=1.0,
#           m_mul=0.8,
#           alpha = 0.000001,
#           name="CCosineDecayRestarts"))
    
#     # warm up
#     if epoch < lr_ramp_ep:
#         lr = (max_lr - base_lr) / lr_ramp_ep * epoch + base_lr    
#     else:
#         lr = lr_decayed_fn(epoch)
#     return lr



# rng = [i for i in range(ep_num)]
# y = [CosineDecayCLRWarmUp(x) for x in rng]
# sns.set(style='darkgrid')
# fig, ax = plt.subplots(figsize=(20, 6))
# # plt.ylim(.0000000000000001, .01)# for too large loss
# ax.yaxis.set_major_formatter(FormatStrFormatter('%.12f'))# for too small loss
# plt.plot(rng, y)

# %%
# %%time
# """
# cosine_decay_restarts是cosine_decay的cycle版本。
# first_decay_steps是指第一次完全下降的step數，
# t_mul是指每一次循環的步數都將乘以t_mul倍，
# m_mul指每一次循環重新開始時的初始lr是上一次循環初始值的m_mul倍。
# alpha
# """

# from matplotlib.ticker import FormatStrFormatter



# ep_num = 1000



# def CosineDecayCLRWarmUpLSW(epoch):
    
#     #step_size = 25 # currently best for foot pp
#     max_lr = 1e-3 # currently best for foot pp
#     base_lr = 1e-6# 1e-6 1e-7

#     # warm up
#     lr_init_ep = 0
#     lr_ramp_ep = 20
#     lr_sus_ep  = 0
#     lr_decay   = 0.8


#     initial_learning_rate = 1e-3
#     first_decay_steps = 50


#     lr_decayed_fn = (
#       tf.keras.experimental.CosineDecayRestarts(
#           initial_learning_rate,
#           first_decay_steps,
#           t_mul=1.0,
#           m_mul=0.8,
#           alpha = 0.000001,
#           name="CCosineDecayRestarts"))
    
#     # warm up
#     if epoch < lr_ramp_ep:
#         lr = (max_lr - base_lr) / lr_ramp_ep * epoch + base_lr    
#     else:
#         lr = lr_decayed_fn(epoch-lr_ramp_ep)
#     return lr



# rng = [i for i in range(ep_num)]
# y = [CosineDecayCLRWarmUpLSW(x) for x in rng]
# sns.set(style='darkgrid')
# fig, ax = plt.subplots(figsize=(20, 6))
# # plt.ylim(.0000000000000001, .01)# for too large loss
# ax.yaxis.set_major_formatter(FormatStrFormatter('%.12f'))# for too small loss
# plt.plot(rng, y)

# %%
# %%time
"""
cosine_decay_restarts是cosine_decay的cycle版本。
first_decay_steps是指第一次完全下降的step數，
t_mul是指每一次循環的步數都將乘以t_mul倍，
m_mul指每一次循環重新開始時的初始lr是上一次循環初始值的m_mul倍。
alpha
"""

from matplotlib.ticker import FormatStrFormatter



ep_num = 1000



def CosineDecayCLRWarmUpLSW_2(epoch):
    
    #step_size = 25 # currently best for foot pp
    max_lr = 1e-2 # currently best for foot pp
    base_lr = 1e-6# 1e-6 1e-7

    # warm up
    lr_init_ep = 0
    lr_ramp_ep = 20
    lr_sus_ep  = 0
    #lr_decay   = 0.8


    initial_learning_rate = 1e-2
    first_decay_steps = 50


    lr_decayed_fn = (
      tf.keras.experimental.CosineDecayRestarts(
          initial_learning_rate,
          first_decay_steps,
          t_mul=1,
          m_mul=1,
          alpha = 0.000001,
          name="CCosineDecayRestarts"))
    
    # warm up
    if epoch < lr_ramp_ep:
        lr = (max_lr - base_lr) / lr_ramp_ep * epoch + base_lr    
    else:
        lr = lr_decayed_fn(epoch-lr_ramp_ep)
    return lr



rng = [i for i in range(ep_num)]
y = [CosineDecayCLRWarmUpLSW_2(x) for x in rng]
sns.set(style='darkgrid')
fig, ax = plt.subplots(figsize=(20, 6))
# plt.ylim(.0000000000000001, .01)# for too large loss
ax.yaxis.set_major_formatter(FormatStrFormatter('%.12f'))# for too small loss
plt.plot(rng, y)
# Out:
# CPU times: user 588 ms, sys: 68.2 ms, total: 656 ms
# Wall time: 560 ms

# %%
print('{} ~ {}'.format(min(y), max(y)))
# Out:
# 1e-06 ~ 0.009999999776482582

# %%
# 1.8774175103430935e-08 ~ 0.0010000000474974513 1e-3 1e-6

# %%
# lr_reduceonplateau = tf.keras.callbacks.ReduceLROnPlateau(monitor=monitor, factor=0.1, patience=5, verbose=1, mode='auto', min_delta=0.0001, cooldown=0, min_lr=1e-12)

# %%
# Callback for printing the LR at the end of each epoch.
class PrintLRtoe(tf.keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
#     def on_epoch_end(self, epoch, logs=None):
#         print('\n[{}] Learning rate for epoch {} is {}'.format(
#             datetime.now().strftime("%Y%m%d-%H%M-%S"), 
#             epoch + 1,
#             self.model.optimizer.lr.numpy()))
        print('\n[{}] Learning rate for epoch {} is {}'.format(
        datetime.now().strftime("%Y%m%d-%H%M-%S"), 
        epoch + 1,
        model_toe.optimizer._decayed_lr(tf.float32).numpy()))

# %%
# Callback for printing the LR at the end of each epoch.
class PrintLRheel(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
#         print('\nLearning rate for epoch {} is {}'.format(epoch + 1,
#                                               model_heel.optimizer.lr.numpy()))
        print('\n[{}] Learning rate for epoch {} is {}'.format(
        datetime.now().strftime("%Y%m%d-%H%M-%S"), 
        epoch + 1,
        model_heel.optimizer._decayed_lr(tf.float32).numpy()))

# %% [markdown]
# ### Output dir and models

# %%
def mk_log_dir(log_dir_name):
    try:
        os.makedirs(log_dir_name)
    except OSError as e:
        print("This log dir exist.")
        if e.errno != errno.EEXIST:
            raise ValueError("we got problem.")

# %%
monitor = 'val_loss' #'val_loss' 'val_accuracy' if use ed_loss it still the loss here.

log_dir_name = datetime.now().strftime("%Y%m%d-%H%M%S") 

# mk_log_dir(datetime.now().strftime("%Y%m%d-%H%M%S") )

# %%
# use once at the time
mk_log_dir(log_dir_name)

# %% [markdown]
# # Toe

# %%
model_name = 'EfficientNetB0'

# %%
#get_best_model_name

# best_model_name = './' + model_name + '_bs-' + str(BATCH_SIZE) + '_s-' + str(img_height) + '_' + "ep-{epoch:02d}-vloss-{val_loss:.2f}" +'_best-weight.h5'
# best_model_name = '{model_name}-ep{epoch:03d}-loss{loss:.3f}-val_loss{val_loss:.3f}.h5'
#best_model_name = './' + model_name + '_bs' + str(BATCH_SIZE) + '_w' + str(img_width) + '_' + monitor + '_best.h5'
# best_model_name = './Leaf_' + model_name + '_bs' + str(BATCH_SIZE) + '_w' + str(img_width) + '_' + datetime.now().strftime("%Y%m%d-%H%M%S") + '_best_' + monitor + '.h5'

# best_model_name = './cop' + model_name + '_bs' + str(BATCH_SIZE) + '_w' + str(img_width) + '_' + datetime.now().strftime("%Y%m%d-%H%M%S") + '_best_' + monitor + '.h5'

def get_best_model_name(th, K):
    return './' + log_dir_name + '/' + th + '_K' + K + '_' + model_name + '_bs' + str(BATCH_SIZE) + '_w' + str(img_width) + '_best_' + monitor + '.h5'

# th = 'toe'
# # th = 'heel'

# # print(get_best_model_name(th,K))

# best_model_name = get_best_model_name(th, K)


# best_model_save = tf.keras.callbacks.ModelCheckpoint(filepath=best_model_name, 
#                              save_best_only = True, 
#                              save_weights_only = False,
#                              monitor = monitor, 
#                              mode = 'auto', verbose = 1)
# print('best_model_name:', best_model_name)

# %%
logdir = log_dir_name + "/logs/toe/"

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
# callbacks = [
# #     tensorboard_callback,
#     best_model_save,
#     tf.keras.callbacks.EarlyStopping(monitor=monitor, patience=20), #patience=step_size or ep_num
# #     lr_reduceonplateau,
#     tf.keras.callbacks.LearningRateScheduler(lrdump),#lrdump, decay or lrfn or lrfn2. clr
#     PrintLRtoe()
# ]

# %%
# Transfer learning from pre-trained weights
def build_efn_model(outputnum, top_dropout_rate, drop_connect_rate):
    base_model = tf.keras.applications.EfficientNetB0(include_top=False, weights="imagenet", input_shape=(120,120,3),drop_connect_rate=drop_connect_rate) #{'imagenet', None}

    # Freeze the pretrained weights
    base_model.trainable = False
    print("base_model.trainable : ", base_model.trainable)

    # Rebuild top
    gap2d = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
    BNL = tf.keras.layers.BatchNormalization()(gap2d) #tood: remove#
    dropout = tf.keras.layers.Dropout(top_dropout_rate)(BNL)#tood: remove# J add dropout, for flood 0.2 is ok. for leaf 0.4 is better.
    outputs = tf.keras.layers.Dense(outputnum)(dropout)# remove activation for regression output (to default, the linear), , activation = 'relu' no help

    # Compile new model
    model = tf.keras.Model(base_model.input, outputs, name=model_name)


#     # unfreeze the top #fine_tune_at# layers while leaving BatchNorm layers frozen
#     fine_tune_at = 20 #10 #241 #20
#     print('[Note] Now create model fine tuneing at Top-{} layers!'.format(fine_tune_at))
#     for layer in model_toe.layers[-fine_tune_at:]:
#         if not isinstance(layer, tf.keras.layers.BatchNormalization):
#             layer.trainable = True

    model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),#RMSprop , Adam, SGD Adadelta(learning_rate=0.001), if set lr_callback the learning_rate=0.001 will not effeced.
                    loss=ed_metric_2d_mean)

    
    return model

# %%
# """Supervised pre-training 減少每次fold都要重新train的時間
# 只先改toe"""

# # Transfer learning from pre-trained weights
# def load_pretrained_efn_model():
#     pre_model_toe_name = "20210224-200728/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5"
#     model = tf.keras.models.load_model(pre_model_toe_name,compile=False)

#     # Freeze the pretrained weights
#     model.trainable = False
# #     print("base_model.trainable : ", base_model.trainable)

# #     # Rebuild top
# #     gap2d = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
# #     BNL = tf.keras.layers.BatchNormalization()(gap2d) #tood: remove#
# #     dropout = tf.keras.layers.Dropout(top_dropout_rate)(BNL)#tood: remove# J add dropout, for flood 0.2 is ok. for leaf 0.4 is better.
# #     outputs = tf.keras.layers.Dense(outputnum)(dropout)# remove activation for regression output (to default, the linear), , activation = 'relu' no help

# #     # Compile new model
# #     model = tf.keras.Model(base_model.input, outputs, name=model_name)


# #     # unfreeze the top #fine_tune_at# layers while leaving BatchNorm layers frozen
#     fine_tune_at = 4 #10 #241 #20
#     print('[Note] Now create model fine tuneing at Top-{} layers!'.format(fine_tune_at))
#     for layer in model.layers[-fine_tune_at:]:
#         if not isinstance(layer, tf.keras.layers.BatchNormalization):
#             print('layer trainable +1', layer.name)
#             layer.trainable = True

#     model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),#RMSprop , Adam, SGD Adadelta(learning_rate=0.001), if set lr_callback the learning_rate=0.001 will not effeced.
#                     loss=ed_metric_2d_mean)

    
#     return model

# %%
def unfreeze_model(model):
#
#'block7a_expand_conv'20 'block6c_expand_conv'50 'block6a_expand_conv'79 'block5b_expand_conv'109 'block4a_expand_conv' 166  block3a_expand_conv 195
#
    model.trainable = True
    set_trainable = False
    for layer in model.layers:
        if layer.name == 'block3a_expand_conv': 
            set_trainable = True
        if set_trainable:
            layer.trainable = True
        else:
            layer.trainable = False

    model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),#RMSprop , Adam, SGD Adadelta(learning_rate=0.001), if set lr_callback the learning_rate=0.001 will not effeced.
                    loss=ed_metric_2d_mean)

# %%
# top_dropout_rate = 0.8 #less dp rate, say 0.1, train_loss will lower than val_loss
# drop_connect_rate = 0.9 #for efnet This parameter serves as a toggle for extra regularization in finetuning, but does not affect loaded weights.
# outputnum = 2
# with strategy.scope():
#     model_toe = build_efn_model(outputnum, top_dropout_rate, drop_connect_rate)

# %%
# len(model_toe.layers)

# %%
# tt = 0
# nt = 0
# for layer in model_toe.layers:
#     if layer.trainable:
#         tt +=1
#         print(f'{layer.name}')
#     else:
#         nt +=1
# print(f'tt: {tt}, nt:{nt}')

# %%
def count_model_trainOrNot_layers(model, printlayers=False):
    tt = 0
    nt = 0
    for layer in model.layers:
        if layer.trainable:
            tt +=1
            if printlayers:
                print(f'{layer.name}')
        else:
            nt +=1
    print('\n*********************************** Start fine tune ***********************************')
    print(f'tt: {tt}, nt:{nt}, total layers:{tt+nt}')
    print('*********************************** Start fine tune ***********************************')

# %%
# count_model_trainOrNot_layers(model_toe)

# %%
# model_toe.summary()

# %%
# %%time

# # fit the model on all data
# history_toe = model_toe.fit(train_ds_pre_toe_s, 
#                       verbose=1, 
#                       epochs=ep_num_transf, 
#                       validation_data=valid_ds_pre_toe_s, 
#                       callbacks=callbacks)#, validation_split=0.1)

# %% [markdown]
# # K-Fold Training
#
# 2021-02-23 v1

# %% [markdown]
# ### Toe K-model

# %%
# %%time

# big K = 5 (fold 0 ~ 4) 
KFlodNum = 10



history_toe = []
history_toe_finetune = []

#above until 'train_ds_map_toe now' to 'train_ds_map_toe_s', 'valid_ds_map_toe_s'
for k in range(KFlodNum):
    
    
    # Split data to train/valid with K-Fold #
    print("\n \n K = ", k, "\n")
    # Toe split
    train_ds_map_toe_s, valid_ds_map_toe_s = get_KFold_ds(train_ds_map_toe, K=k)
    
    # Toe ds_pre
    train_ds_pre_toe_s = configure_for_performance_cache_train(train_ds_map_toe_s, augment=True)
    valid_ds_pre_toe_s = configure_for_performance_cache_val(valid_ds_map_toe_s)
    
    
#     # heel split
#     train_ds_map_heel_s, valid_ds_map_heel_s = get_KFold_ds(train_ds_map_heel, K=k)
#     # Heel ds_pre
#     train_ds_pre_heel_s = configure_for_performance_cache_train(train_ds_map_heel_s, augment=True)
#     valid_ds_pre_heel_s = configure_for_performance_cache_val(valid_ds_map_heel_s)
    
    
    # Train K-Model with transfer learnling #
    
    # Toe model, TL
    th = 'toe'
    # th = 'heel'
    best_model_name = get_best_model_name(th, K=str(k))
    best_model_save = tf.keras.callbacks.ModelCheckpoint(filepath=best_model_name, 
                                 save_best_only = True, 
                                 save_weights_only = False,
                                 monitor = monitor, 
                                 mode = 'auto', verbose = 1)
    callbacks_toe_tl = [
                    #     tensorboard_callback,
                        best_model_save,
                        tf.keras.callbacks.EarlyStopping(monitor=monitor, patience=30), #patience=step_size or ep_num
                    #     lr_reduceonplateau,
                        tf.keras.callbacks.LearningRateScheduler(lrdump),#lrdump, decay or lrfn or lrfn2. clr
                        PrintLRtoe()
                        ]
    callbacks_toe_fn = [
                    #     tensorboard_callback,
                        best_model_save,
                        tf.keras.callbacks.EarlyStopping(monitor=monitor, patience=150), #patience=step_size or ep_num
                    #     lr_reduceonplateau,
                        tf.keras.callbacks.LearningRateScheduler(clr3),#lrdump, decay or lrfn or lrfn2. clr, CosineDecayCLRWarmUp, CosineDecayCLRWarmUpLSW
                        PrintLRtoe()
                    ]
    print('best_model_name:', best_model_name)


    top_dropout_rate = 0.8 #less dp rate, say 0.1, train_loss will lower than val_loss
    drop_connect_rate = 0.9 #for efnet This parameter serves as a toggle for extra regularization in finetuning, but does not affect loaded weights.
    outputnum = 2
    with strategy.scope():
        model_toe = build_efn_model(outputnum, top_dropout_rate, drop_connect_rate)
#         model_toe = load_pretrained_efn_model() # from 20210224-200728 ed5.3
#         count_model_trainOrNot_layers(model_toe)
        
    # fit the model on all data
    hist = model_toe.fit(train_ds_pre_toe_s, 
                          verbose=1, 
                          epochs=ep_num_transf, 
                          validation_data=valid_ds_pre_toe_s, 
                          callbacks=callbacks_toe_tl)#, validation_split=0.1)
    history_toe.append(hist)
    
      
    # Train K-Model with fine tune #
    
    # Toe model, FT
    unfreeze_model(model_toe)
    count_model_trainOrNot_layers(model_toe)
    # fit the model on all data
    hist = model_toe.fit(train_ds_pre_toe_s, 
                          verbose=1, 
                          epochs=ep_num, 
                          validation_data=valid_ds_pre_toe_s, 
                          callbacks=callbacks_toe_fn)#, validation_split=0.1)
    history_toe_finetune.append(hist)
# Out:
#
#  K =  0
#
# Check cache in memory:Y True
# Check keypoints process01: Tensor("args_1:0", shape=(2,), dtype=int64) (2,) <class 'tensorflow.python.framework.ops.Tensor'>
# Check keypoints process02: Tensor("Reshape:0", shape=(1, 2), dtype=int64) (1, 2) <class 'tensorflow.python.framework.ops.Tensor'>
# Check keypoints process03: Tensor("PyFunc:1", dtype=float32, device=/job:localhost/replica:0/task:0)
# Check keypoints process04: Tensor("Reshape_1:0", shape=(2,), dtype=float32)
# Check augment :Y True
# Check ds cache[True] and augment[True]
# Check cache in memory:Y True
# Check augment :N False
# Check ds cache[True] and augment[False]
# best_model_name: ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# base_model.trainable :  False
#
# [20210302-1429-39] Learning rate for epoch 1 is 0.009999999776482582
# Epoch 1/500
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# 19/19 [==============================] - ETA: 0s - loss: 75.6881
# Epoch 00001: val_loss improved from inf to 57.48642, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 11s 572ms/step - loss: 75.6881 - val_loss: 57.4864
#
# [20210302-1430-05] Learning rate for epoch 2 is 0.009960000403225422
# Epoch 2/500
# 16/19 [========================>.....] - ETA: 0s - loss: 37.6319
# Epoch 00002: val_loss improved from 57.48642 to 21.00217, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 3s 159ms/step - loss: 35.6313 - val_loss: 21.0022
#
# [20210302-1430-12] Learning rate for epoch 3 is 0.009920000098645687
# Epoch 3/500
# 19/19 [==============================] - ETA: 0s - loss: 21.7537
# Epoch 00003: val_loss improved from 21.00217 to 13.43676, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 10s 529ms/step - loss: 21.7537 - val_loss: 13.4368
#
# [20210302-1430-26] Learning rate for epoch 4 is 0.009879999794065952
# Epoch 4/500
# 16/19 [========================>.....] - ETA: 0s - loss: 19.1611
# Epoch 00004: val_loss improved from 13.43676 to 11.94858, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 1s 41ms/step - loss: 19.1962 - val_loss: 11.9486
#
# [20210302-1430-31] Learning rate for epoch 5 is 0.009840000420808792
# Epoch 5/500
# 16/19 [========================>.....] - ETA: 0s - loss: 17.9333
# Epoch 00005: val_loss improved from 11.94858 to 11.83239, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 1s 44ms/step - loss: 18.1519 - val_loss: 11.8324
#
# [20210302-1430-36] Learning rate for epoch 6 is 0.009800000116229057
# Epoch 6/500
# 16/19 [========================>.....] - ETA: 0s - loss: 17.4409
# Epoch 00006: val_loss did not improve from 11.83239
# 19/19 [==============================] - 0s 22ms/step - loss: 17.2307 - val_loss: 11.8616
#
# [20210302-1430-41] Learning rate for epoch 7 is 0.009759999811649323
# Epoch 7/500
# 16/19 [========================>.....] - ETA: 0s - loss: 17.0494
# Epoch 00007: val_loss improved from 11.83239 to 11.16090, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 1s 41ms/step - loss: 17.0167 - val_loss: 11.1609
#
# [20210302-1430-46] Learning rate for epoch 8 is 0.009720000438392162
# Epoch 8/500
# 16/19 [========================>.....] - ETA: 0s - loss: 16.4016
# Epoch 00008: val_loss did not improve from 11.16090
# 19/19 [==============================] - 0s 22ms/step - loss: 16.3839 - val_loss: 11.3846
#
# [20210302-1430-50] Learning rate for epoch 9 is 0.009680000133812428
# Epoch 9/500
# 16/19 [========================>.....] - ETA: 0s - loss: 16.0359
# Epoch 00009: val_loss improved from 11.16090 to 10.98348, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 1s 42ms/step - loss: 16.1278 - val_loss: 10.9835
#
# [20210302-1430-55] Learning rate for epoch 10 is 0.009639999829232693
# Epoch 10/500
# 16/19 [========================>.....] - ETA: 0s - loss: 15.7620
# Epoch 00010: val_loss improved from 10.98348 to 10.94841, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 1s 41ms/step - loss: 15.7005 - val_loss: 10.9484
#
# [20210302-1431-00] Learning rate for epoch 11 is 0.009600000455975533
# Epoch 11/500
# 16/19 [========================>.....] - ETA: 0s - loss: 15.5185
# Epoch 00011: val_loss improved from 10.94841 to 10.87102, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 1s 42ms/step - loss: 15.7831 - val_loss: 10.8710
#
# [20210302-1431-05] Learning rate for epoch 12 is 0.009560000151395798
# Epoch 12/500
# 16/19 [========================>.....] - ETA: 0s - loss: 15.4014
# Epoch 00012: val_loss did not improve from 10.87102
# 19/19 [==============================] - 0s 22ms/step - loss: 15.4590 - val_loss: 10.9245
#
# [20210302-1431-10] Learning rate for epoch 13 is 0.009519999846816063
# Epoch 13/500
# 16/19 [========================>.....] - ETA: 0s - loss: 15.0715
# Epoch 00013: val_loss did not improve from 10.87102
# 19/19 [==============================] - 0s 22ms/step - loss: 15.0914 - val_loss: 11.6918
#
# [20210302-1431-14] Learning rate for epoch 14 is 0.009479999542236328
# Epoch 14/500
# 16/19 [========================>.....] - ETA: 0s - loss: 15.4453
# Epoch 00014: val_loss did not improve from 10.87102
# 19/19 [==============================] - 0s 22ms/step - loss: 15.4794 - val_loss: 11.2855
#
# [20210302-1431-19] Learning rate for epoch 15 is 0.009440000168979168
# Epoch 15/500
# 17/19 [=========================>....] - ETA: 0s - loss: 15.1740
# Epoch 00015: val_loss did not improve from 10.87102
# 19/19 [==============================] - 0s 21ms/step - loss: 15.2358 - val_loss: 11.2248
#
# [20210302-1431-23] Learning rate for epoch 16 is 0.009399999864399433
# Epoch 16/500
# 17/19 [=========================>....] - ETA: 0s - loss: 15.0646
# Epoch 00016: val_loss did not improve from 10.87102
# 19/19 [==============================] - 0s 21ms/step - loss: 15.1424 - val_loss: 11.5210
#
# [20210302-1431-28] Learning rate for epoch 17 is 0.009359999559819698
# Epoch 17/500
# 18/19 [===========================>..] - ETA: 0s - loss: 15.1038
# Epoch 00017: val_loss improved from 10.87102 to 10.62233, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 1s 41ms/step - loss: 15.0718 - val_loss: 10.6223
#
# [20210302-1431-32] Learning rate for epoch 18 is 0.009320000186562538
# Epoch 18/500
# 16/19 [========================>.....] - ETA: 0s - loss: 14.7226
# Epoch 00018: val_loss did not improve from 10.62233
# 19/19 [==============================] - 0s 22ms/step - loss: 14.9367 - val_loss: 11.9991
#
# [20210302-1431-37] Learning rate for epoch 19 is 0.009279999881982803
# Epoch 19/500
# 19/19 [==============================] - ETA: 0s - loss: 14.5271
# Epoch 00019: val_loss did not improve from 10.62233
# 19/19 [==============================] - 0s 21ms/step - loss: 14.5271 - val_loss: 11.1898
#
# [20210302-1431-42] Learning rate for epoch 20 is 0.009239999577403069
# Epoch 20/500
# 16/19 [========================>.....] - ETA: 0s - loss: 14.7341
# Epoch 00020: val_loss did not improve from 10.62233
# 19/19 [==============================] - 0s 23ms/step - loss: 14.6127 - val_loss: 10.7884
#
# [20210302-1431-46] Learning rate for epoch 21 is 0.009200000204145908
# Epoch 21/500
# 17/19 [=========================>....] - ETA: 0s - loss: 14.6127
# Epoch 00021: val_loss improved from 10.62233 to 10.45783, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 1s 42ms/step - loss: 14.5549 - val_loss: 10.4578
#
# [20210302-1431-51] Learning rate for epoch 22 is 0.009159999899566174
# Epoch 22/500
# 16/19 [========================>.....] - ETA: 0s - loss: 14.3153
# Epoch 00022: val_loss improved from 10.45783 to 10.34901, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 1s 43ms/step - loss: 14.4045 - val_loss: 10.3490
#
# [20210302-1431-56] Learning rate for epoch 23 is 0.009119999594986439
# Epoch 23/500
# 16/19 [========================>.....] - ETA: 0s - loss: 14.3079
# Epoch 00023: val_loss did not improve from 10.34901
# 19/19 [==============================] - 0s 23ms/step - loss: 14.2454 - val_loss: 10.7302
#
# [20210302-1432-01] Learning rate for epoch 24 is 0.009080000221729279
# Epoch 24/500
# 16/19 [========================>.....] - ETA: 0s - loss: 14.6729
# Epoch 00024: val_loss improved from 10.34901 to 10.32288, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 1s 42ms/step - loss: 14.5573 - val_loss: 10.3229
#
# [20210302-1432-06] Learning rate for epoch 25 is 0.009039999917149544
# Epoch 25/500
# 17/19 [=========================>....] - ETA: 0s - loss: 14.2380
# Epoch 00025: val_loss did not improve from 10.32288
# 19/19 [==============================] - 0s 22ms/step - loss: 14.2817 - val_loss: 11.0126
#
# [20210302-1432-11] Learning rate for epoch 26 is 0.008999999612569809
# Epoch 26/500
# 17/19 [=========================>....] - ETA: 0s - loss: 14.4553
# Epoch 00026: val_loss did not improve from 10.32288
# 19/19 [==============================] - 0s 22ms/step - loss: 14.4115 - val_loss: 10.7397
#
# [20210302-1432-15] Learning rate for epoch 27 is 0.008960000239312649
# Epoch 27/500
# 16/19 [========================>.....] - ETA: 0s - loss: 14.1720
# Epoch 00027: val_loss improved from 10.32288 to 10.11838, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 1s 42ms/step - loss: 14.2215 - val_loss: 10.1184
#
# [20210302-1432-20] Learning rate for epoch 28 is 0.008919999934732914
# Epoch 28/500
# 16/19 [========================>.....] - ETA: 0s - loss: 14.0880
# Epoch 00028: val_loss did not improve from 10.11838
# 19/19 [==============================] - 0s 23ms/step - loss: 14.1541 - val_loss: 10.5700
#
# [20210302-1432-24] Learning rate for epoch 29 is 0.00887999963015318
# Epoch 29/500
# 16/19 [========================>.....] - ETA: 0s - loss: 14.0984
# Epoch 00029: val_loss did not improve from 10.11838
# 19/19 [==============================] - 0s 24ms/step - loss: 14.1244 - val_loss: 10.2723
#
# [20210302-1432-28] Learning rate for epoch 30 is 0.008840000256896019
# Epoch 30/500
# 16/19 [========================>.....] - ETA: 0s - loss: 14.5605
# Epoch 00030: val_loss did not improve from 10.11838
# 19/19 [==============================] - 0s 22ms/step - loss: 14.5364 - val_loss: 10.5390
#
# [20210302-1432-33] Learning rate for epoch 31 is 0.008799999952316284
# Epoch 31/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.9099
# Epoch 00031: val_loss did not improve from 10.11838
# 19/19 [==============================] - 0s 23ms/step - loss: 13.9683 - val_loss: 10.4393
#
# [20210302-1432-37] Learning rate for epoch 32 is 0.00875999964773655
# Epoch 32/500
# 17/19 [=========================>....] - ETA: 0s - loss: 14.0603
# Epoch 00032: val_loss did not improve from 10.11838
# 19/19 [==============================] - 0s 22ms/step - loss: 14.0198 - val_loss: 11.3119
#
# [20210302-1432-42] Learning rate for epoch 33 is 0.00872000027447939
# Epoch 33/500
# 16/19 [========================>.....] - ETA: 0s - loss: 14.2087
# Epoch 00033: val_loss did not improve from 10.11838
# 19/19 [==============================] - 0s 23ms/step - loss: 14.3456 - val_loss: 10.9664
#
# [20210302-1432-47] Learning rate for epoch 34 is 0.008679999969899654
# Epoch 34/500
# 16/19 [========================>.....] - ETA: 0s - loss: 14.0763
# Epoch 00034: val_loss did not improve from 10.11838
# 19/19 [==============================] - 0s 22ms/step - loss: 14.0747 - val_loss: 10.4291
#
# [20210302-1432-51] Learning rate for epoch 35 is 0.00863999966531992
# Epoch 35/500
# 16/19 [========================>.....] - ETA: 0s - loss: 14.1507
# Epoch 00035: val_loss did not improve from 10.11838
# 19/19 [==============================] - 0s 22ms/step - loss: 14.1535 - val_loss: 10.1977
#
# [20210302-1432-55] Learning rate for epoch 36 is 0.00860000029206276
# Epoch 36/500
# 17/19 [=========================>....] - ETA: 0s - loss: 13.9936
# Epoch 00036: val_loss did not improve from 10.11838
# 19/19 [==============================] - 0s 22ms/step - loss: 14.0205 - val_loss: 10.5004
#
# [20210302-1433-00] Learning rate for epoch 37 is 0.008559999987483025
# Epoch 37/500
# 16/19 [========================>.....] - ETA: 0s - loss: 14.0184
# Epoch 00037: val_loss did not improve from 10.11838
# 19/19 [==============================] - 0s 22ms/step - loss: 13.9566 - val_loss: 10.8114
#
# [20210302-1433-04] Learning rate for epoch 38 is 0.00851999968290329
# Epoch 38/500
# 17/19 [=========================>....] - ETA: 0s - loss: 14.2691
# Epoch 00038: val_loss did not improve from 10.11838
# 19/19 [==============================] - 0s 22ms/step - loss: 14.1957 - val_loss: 10.2511
#
# [20210302-1433-09] Learning rate for epoch 39 is 0.00848000030964613
# Epoch 39/500
# 16/19 [========================>.....] - ETA: 0s - loss: 14.2682
# Epoch 00039: val_loss improved from 10.11838 to 10.09571, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 1s 41ms/step - loss: 14.1251 - val_loss: 10.0957
#
# [20210302-1433-14] Learning rate for epoch 40 is 0.008440000005066395
# Epoch 40/500
# 16/19 [========================>.....] - ETA: 0s - loss: 14.0710
# Epoch 00040: val_loss did not improve from 10.09571
# 19/19 [==============================] - 0s 22ms/step - loss: 13.9965 - val_loss: 10.8252
#
# [20210302-1433-19] Learning rate for epoch 41 is 0.00839999970048666
# Epoch 41/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.9819
# Epoch 00041: val_loss did not improve from 10.09571
# 19/19 [==============================] - 0s 22ms/step - loss: 13.9074 - val_loss: 10.1888
#
# [20210302-1433-23] Learning rate for epoch 42 is 0.0083600003272295
# Epoch 42/500
# 16/19 [========================>.....] - ETA: 0s - loss: 14.3626
# Epoch 00042: val_loss did not improve from 10.09571
# 19/19 [==============================] - 0s 22ms/step - loss: 14.2652 - val_loss: 10.4705
#
# [20210302-1433-28] Learning rate for epoch 43 is 0.008320000022649765
# Epoch 43/500
# 16/19 [========================>.....] - ETA: 0s - loss: 14.1776
# Epoch 00043: val_loss improved from 10.09571 to 9.90694, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 1s 43ms/step - loss: 13.9773 - val_loss: 9.9069
#
# [20210302-1433-33] Learning rate for epoch 44 is 0.00827999971807003
# Epoch 44/500
# 17/19 [=========================>....] - ETA: 0s - loss: 13.9709
# Epoch 00044: val_loss did not improve from 9.90694
# 19/19 [==============================] - 0s 22ms/step - loss: 13.9648 - val_loss: 9.9668
#
# [20210302-1433-37] Learning rate for epoch 45 is 0.00824000034481287
# Epoch 45/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.7334
# Epoch 00045: val_loss improved from 9.90694 to 9.89899, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 1s 51ms/step - loss: 13.6505 - val_loss: 9.8990
#
# [20210302-1433-42] Learning rate for epoch 46 is 0.008200000040233135
# Epoch 46/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.7249
# Epoch 00046: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 22ms/step - loss: 13.7209 - val_loss: 10.0986
#
# [20210302-1433-47] Learning rate for epoch 47 is 0.0081599997356534
# Epoch 47/500
# 17/19 [=========================>....] - ETA: 0s - loss: 14.2368
# Epoch 00047: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 22ms/step - loss: 14.1522 - val_loss: 10.2937
#
# [20210302-1433-51] Learning rate for epoch 48 is 0.00812000036239624
# Epoch 48/500
# 17/19 [=========================>....] - ETA: 0s - loss: 13.4020
# Epoch 00048: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 22ms/step - loss: 13.3156 - val_loss: 10.3032
#
# [20210302-1433-56] Learning rate for epoch 49 is 0.008080000057816505
# Epoch 49/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.9932
# Epoch 00049: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 22ms/step - loss: 14.0494 - val_loss: 10.8827
#
# [20210302-1434-01] Learning rate for epoch 50 is 0.00803999975323677
# Epoch 50/500
# 17/19 [=========================>....] - ETA: 0s - loss: 13.9309
# Epoch 00050: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 22ms/step - loss: 14.0088 - val_loss: 9.9873
#
# [20210302-1434-05] Learning rate for epoch 51 is 0.00800000037997961
# Epoch 51/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.4946
# Epoch 00051: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 22ms/step - loss: 13.5267 - val_loss: 10.0556
#
# [20210302-1434-09] Learning rate for epoch 52 is 0.007960000075399876
# Epoch 52/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.7834
# Epoch 00052: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 21ms/step - loss: 13.5022 - val_loss: 10.1165
#
# [20210302-1434-14] Learning rate for epoch 53 is 0.00791999977082014
# Epoch 53/500
# 19/19 [==============================] - ETA: 0s - loss: 13.3263
# Epoch 00053: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 23ms/step - loss: 13.3263 - val_loss: 10.1242
#
# [20210302-1434-18] Learning rate for epoch 54 is 0.00788000039756298
# Epoch 54/500
# 17/19 [=========================>....] - ETA: 0s - loss: 13.4858
# Epoch 00054: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 21ms/step - loss: 13.6018 - val_loss: 10.4243
#
# [20210302-1434-23] Learning rate for epoch 55 is 0.007840000092983246
# Epoch 55/500
# 17/19 [=========================>....] - ETA: 0s - loss: 14.0528
# Epoch 00055: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 21ms/step - loss: 13.8692 - val_loss: 10.5858
#
# [20210302-1434-27] Learning rate for epoch 56 is 0.007799999788403511
# Epoch 56/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.5692
# Epoch 00056: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 23ms/step - loss: 13.5863 - val_loss: 11.2824
#
# [20210302-1434-32] Learning rate for epoch 57 is 0.0077599999494850636
# Epoch 57/500
# 17/19 [=========================>....] - ETA: 0s - loss: 13.5896
# Epoch 00057: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 22ms/step - loss: 13.5734 - val_loss: 10.3405
#
# [20210302-1434-36] Learning rate for epoch 58 is 0.007720000110566616
# Epoch 58/500
# 17/19 [=========================>....] - ETA: 0s - loss: 13.3963
# Epoch 00058: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 21ms/step - loss: 13.4836 - val_loss: 10.2130
#
# [20210302-1434-41] Learning rate for epoch 59 is 0.007679999805986881
# Epoch 59/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.7222
# Epoch 00059: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 23ms/step - loss: 13.5504 - val_loss: 10.8004
#
# [20210302-1434-45] Learning rate for epoch 60 is 0.007639999967068434
# Epoch 60/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.4587
# Epoch 00060: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 22ms/step - loss: 13.4818 - val_loss: 10.6957
#
# [20210302-1434-50] Learning rate for epoch 61 is 0.007600000128149986
# Epoch 61/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.5794
# Epoch 00061: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 21ms/step - loss: 13.6379 - val_loss: 10.0843
#
# [20210302-1434-54] Learning rate for epoch 62 is 0.0075599998235702515
# Epoch 62/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.3213
# Epoch 00062: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 22ms/step - loss: 13.3616 - val_loss: 10.0764
#
# [20210302-1434-59] Learning rate for epoch 63 is 0.007519999984651804
# Epoch 63/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.4977
# Epoch 00063: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 23ms/step - loss: 13.4419 - val_loss: 10.1572
#
# [20210302-1435-04] Learning rate for epoch 64 is 0.0074800001457333565
# Epoch 64/500
# 17/19 [=========================>....] - ETA: 0s - loss: 13.4078
# Epoch 00064: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 22ms/step - loss: 13.3230 - val_loss: 10.1221
#
# [20210302-1435-09] Learning rate for epoch 65 is 0.007439999841153622
# Epoch 65/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.4365
# Epoch 00065: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 22ms/step - loss: 13.4601 - val_loss: 10.6571
#
# [20210302-1435-13] Learning rate for epoch 66 is 0.007400000002235174
# Epoch 66/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.3350
# Epoch 00066: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 22ms/step - loss: 13.4942 - val_loss: 11.0757
#
# [20210302-1435-18] Learning rate for epoch 67 is 0.007360000163316727
# Epoch 67/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.3553
# Epoch 00067: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 22ms/step - loss: 13.2930 - val_loss: 10.0574
#
# [20210302-1435-22] Learning rate for epoch 68 is 0.007319999858736992
# Epoch 68/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.3946
# Epoch 00068: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 21ms/step - loss: 13.4822 - val_loss: 10.3374
#
# [20210302-1435-27] Learning rate for epoch 69 is 0.007280000019818544
# Epoch 69/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.0854
# Epoch 00069: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 22ms/step - loss: 13.1531 - val_loss: 10.1781
#
# [20210302-1435-32] Learning rate for epoch 70 is 0.007240000180900097
# Epoch 70/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.2569
# Epoch 00070: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 22ms/step - loss: 13.2986 - val_loss: 10.3824
#
# [20210302-1435-36] Learning rate for epoch 71 is 0.007199999876320362
# Epoch 71/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.4093
# Epoch 00071: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 22ms/step - loss: 13.3319 - val_loss: 10.2152
#
# [20210302-1435-41] Learning rate for epoch 72 is 0.007160000037401915
# Epoch 72/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.2037
# Epoch 00072: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 22ms/step - loss: 13.0104 - val_loss: 10.2964
#
# [20210302-1435-46] Learning rate for epoch 73 is 0.007120000198483467
# Epoch 73/500
# 17/19 [=========================>....] - ETA: 0s - loss: 13.6633
# Epoch 00073: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 22ms/step - loss: 13.5746 - val_loss: 10.2716
#
# [20210302-1435-50] Learning rate for epoch 74 is 0.007079999893903732
# Epoch 74/500
# 16/19 [========================>.....] - ETA: 0s - loss: 13.0263
# Epoch 00074: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 22ms/step - loss: 13.1309 - val_loss: 10.5546
#
# [20210302-1435-55] Learning rate for epoch 75 is 0.007040000054985285
# Epoch 75/500
# 17/19 [=========================>....] - ETA: 0s - loss: 13.3431
# Epoch 00075: val_loss did not improve from 9.89899
# 19/19 [==============================] - 0s 21ms/step - loss: 13.4169 - val_loss: 10.2432
#
# *********************************** Start fine tune ***********************************
# tt: 195, nt:46, total layers:241
# *********************************** Start fine tune ***********************************
#
# [20210302-1436-00] Learning rate for epoch 1 is 4.999999987376214e-07
# Epoch 1/1000
# 19/19 [==============================] - ETA: 0s - loss: 14.8842
# Epoch 00001: val_loss did not improve from 9.89899
# 19/19 [==============================] - 32s 2s/step - loss: 14.8842 - val_loss: 10.3702
#
# [20210302-1436-50] Learning rate for epoch 2 is 5.044450517743826e-05
# Epoch 2/1000
# 19/19 [==============================] - ETA: 0s - loss: 14.8753
# Epoch 00002: val_loss did not improve from 9.89899
# 19/19 [==============================] - 4s 190ms/step - loss: 14.8753 - val_loss: 10.7960
#
# [20210302-1436-58] Learning rate for epoch 3 is 0.00010028902033809572
# Epoch 3/1000
# 19/19 [==============================] - ETA: 0s - loss: 14.6626
# Epoch 00003: val_loss did not improve from 9.89899
# 19/19 [==============================] - 32s 2s/step - loss: 14.6626 - val_loss: 11.1991
#
# [20210302-1437-35] Learning rate for epoch 4 is 0.00015003354928921908
# Epoch 4/1000
# 19/19 [==============================] - ETA: 0s - loss: 13.8976
# Epoch 00004: val_loss did not improve from 9.89899
# 19/19 [==============================] - 1s 69ms/step - loss: 13.8976 - val_loss: 11.7898
#
# [20210302-1437-40] Learning rate for epoch 5 is 0.0001996780774788931
# Epoch 5/1000
# 19/19 [==============================] - ETA: 0s - loss: 13.4902
# Epoch 00005: val_loss did not improve from 9.89899
# 19/19 [==============================] - 1s 63ms/step - loss: 13.4902 - val_loss: 12.0089
#
# [20210302-1437-46] Learning rate for epoch 6 is 0.000249222619459033
# Epoch 6/1000
# 19/19 [==============================] - ETA: 0s - loss: 13.0383
# Epoch 00006: val_loss improved from 9.89899 to 9.85949, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 2s 98ms/step - loss: 13.0383 - val_loss: 9.8595
#
# [20210302-1437-52] Learning rate for epoch 7 is 0.0002986671752296388
# Epoch 7/1000
# 19/19 [==============================] - ETA: 0s - loss: 12.2398
# Epoch 00007: val_loss improved from 9.85949 to 8.83442, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 2s 97ms/step - loss: 12.2398 - val_loss: 8.8344
#
# [20210302-1437-58] Learning rate for epoch 8 is 0.00034801175934262574
# Epoch 8/1000
# 19/19 [==============================] - ETA: 0s - loss: 11.9250
# Epoch 00008: val_loss did not improve from 8.83442
# 19/19 [==============================] - 1s 69ms/step - loss: 11.9250 - val_loss: 9.1092
#
# [20210302-1438-03] Learning rate for epoch 9 is 0.00039725631359033287
# Epoch 9/1000
# 19/19 [==============================] - ETA: 0s - loss: 11.6730
# Epoch 00009: val_loss did not improve from 8.83442
# 19/19 [==============================] - 1s 69ms/step - loss: 11.6730 - val_loss: 8.8553
#
# [20210302-1438-09] Learning rate for epoch 10 is 0.0004464008961804211
# Epoch 10/1000
# 19/19 [==============================] - ETA: 0s - loss: 11.3148
# Epoch 00010: val_loss improved from 8.83442 to 8.48333, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 2s 98ms/step - loss: 11.3148 - val_loss: 8.4833
#
# [20210302-1438-15] Learning rate for epoch 11 is 0.0004954455071128905
# Epoch 11/1000
# 19/19 [==============================] - ETA: 0s - loss: 11.4804
# Epoch 00011: val_loss improved from 8.48333 to 8.25643, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 2s 97ms/step - loss: 11.4804 - val_loss: 8.2564
#
# [20210302-1438-21] Learning rate for epoch 12 is 0.0005443901172839105
# Epoch 12/1000
# 19/19 [==============================] - ETA: 0s - loss: 11.3567
# Epoch 00012: val_loss improved from 8.25643 to 7.99337, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 2s 94ms/step - loss: 11.3567 - val_loss: 7.9934
#
# [20210302-1438-27] Learning rate for epoch 13 is 0.0005932347266934812
# Epoch 13/1000
# 19/19 [==============================] - ETA: 0s - loss: 10.9969
# Epoch 00013: val_loss did not improve from 7.99337
# 19/19 [==============================] - 1s 63ms/step - loss: 10.9969 - val_loss: 8.4676
#
# [20210302-1438-32] Learning rate for epoch 14 is 0.0006419793353416026
# Epoch 14/1000
# 19/19 [==============================] - ETA: 0s - loss: 10.9389
# Epoch 00014: val_loss did not improve from 7.99337
# 19/19 [==============================] - 1s 67ms/step - loss: 10.9389 - val_loss: 8.1473
#
# [20210302-1438-38] Learning rate for epoch 15 is 0.0006906240014359355
# Epoch 15/1000
# 19/19 [==============================] - ETA: 0s - loss: 10.9436
# Epoch 00015: val_loss did not improve from 7.99337
# 19/19 [==============================] - 1s 66ms/step - loss: 10.9436 - val_loss: 8.7073
#
# [20210302-1438-43] Learning rate for epoch 16 is 0.0007391686085611582
# Epoch 16/1000
# 19/19 [==============================] - ETA: 0s - loss: 10.7078
# Epoch 00016: val_loss did not improve from 7.99337
# 19/19 [==============================] - 1s 69ms/step - loss: 10.7078 - val_loss: 8.6165
#
# [20210302-1438-49] Learning rate for epoch 17 is 0.0007876132731325924
# Epoch 17/1000
# 19/19 [==============================] - ETA: 0s - loss: 10.7932
# Epoch 00017: val_loss improved from 7.99337 to 7.77990, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 2s 98ms/step - loss: 10.7932 - val_loss: 7.7799
#
# [20210302-1438-55] Learning rate for epoch 18 is 0.0008359579369425774
# Epoch 18/1000
# 19/19 [==============================] - ETA: 0s - loss: 10.4935
# Epoch 00018: val_loss improved from 7.77990 to 7.34982, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 2s 92ms/step - loss: 10.4935 - val_loss: 7.3498
#
# [20210302-1439-01] Learning rate for epoch 19 is 0.000884202599991113
# Epoch 19/1000
# 19/19 [==============================] - ETA: 0s - loss: 10.4663
# Epoch 00019: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 68ms/step - loss: 10.4663 - val_loss: 8.0867
#
# [20210302-1439-06] Learning rate for epoch 20 is 0.0009323473204858601
# Epoch 20/1000
# 19/19 [==============================] - ETA: 0s - loss: 10.1535
# Epoch 00020: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 68ms/step - loss: 10.1535 - val_loss: 9.0116
#
# [20210302-1439-12] Learning rate for epoch 21 is 0.000980391982011497
# Epoch 21/1000
# 19/19 [==============================] - ETA: 0s - loss: 9.7829
# Epoch 00021: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 66ms/step - loss: 9.7829 - val_loss: 8.7043
#
# [20210302-1439-17] Learning rate for epoch 22 is 0.0010283367009833455
# Epoch 22/1000
# 19/19 [==============================] - ETA: 0s - loss: 9.9133
# Epoch 00022: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 67ms/step - loss: 9.9133 - val_loss: 9.0670
#
# [20210302-1439-23] Learning rate for epoch 23 is 0.0010761814191937447
# Epoch 23/1000
# 19/19 [==============================] - ETA: 0s - loss: 9.8779
# Epoch 00023: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 68ms/step - loss: 9.8779 - val_loss: 9.1958
#
# [20210302-1439-28] Learning rate for epoch 24 is 0.0011239261366426945
# Epoch 24/1000
# 19/19 [==============================] - ETA: 0s - loss: 9.8360
# Epoch 00024: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 68ms/step - loss: 9.8360 - val_loss: 8.4691
#
# [20210302-1439-33] Learning rate for epoch 25 is 0.001171570853330195
# Epoch 25/1000
# 19/19 [==============================] - ETA: 0s - loss: 9.6919
# Epoch 00025: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 68ms/step - loss: 9.6919 - val_loss: 8.5856
#
# [20210302-1439-39] Learning rate for epoch 26 is 0.001219115569256246
# Epoch 26/1000
# 19/19 [==============================] - ETA: 0s - loss: 9.5855
# Epoch 00026: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 69ms/step - loss: 9.5855 - val_loss: 7.9503
#
# [20210302-1439-45] Learning rate for epoch 27 is 0.0012665604008361697
# Epoch 27/1000
# 19/19 [==============================] - ETA: 0s - loss: 9.3499
# Epoch 00027: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 68ms/step - loss: 9.3499 - val_loss: 9.5951
#
# [20210302-1439-50] Learning rate for epoch 28 is 0.0013139051152393222
# Epoch 28/1000
# 19/19 [==============================] - ETA: 0s - loss: 9.6464
# Epoch 00028: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 68ms/step - loss: 9.6464 - val_loss: 8.1816
#
# [20210302-1439-56] Learning rate for epoch 29 is 0.0013611499452963471
# Epoch 29/1000
# 19/19 [==============================] - ETA: 0s - loss: 9.6855
# Epoch 00029: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 67ms/step - loss: 9.6855 - val_loss: 9.0289
#
# [20210302-1440-01] Learning rate for epoch 30 is 0.001408294658176601
# Epoch 30/1000
# 19/19 [==============================] - ETA: 0s - loss: 9.2933
# Epoch 00030: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 69ms/step - loss: 9.2933 - val_loss: 8.9908
#
# [20210302-1440-07] Learning rate for epoch 31 is 0.0014553394867107272
# Epoch 31/1000
# 19/19 [==============================] - ETA: 0s - loss: 9.4201
# Epoch 00031: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 67ms/step - loss: 9.4201 - val_loss: 9.2216
#
# [20210302-1440-12] Learning rate for epoch 32 is 0.0015022843144834042
# Epoch 32/1000
# 19/19 [==============================] - ETA: 0s - loss: 9.0346
# Epoch 00032: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 68ms/step - loss: 9.0346 - val_loss: 8.6277
#
# [20210302-1440-18] Learning rate for epoch 33 is 0.0015491291414946318
# Epoch 33/1000
# 19/19 [==============================] - ETA: 0s - loss: 9.0439
# Epoch 00033: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 68ms/step - loss: 9.0439 - val_loss: 8.8638
#
# [20210302-1440-23] Learning rate for epoch 34 is 0.00159587396774441
# Epoch 34/1000
# 19/19 [==============================] - ETA: 0s - loss: 8.7874
# Epoch 00034: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 67ms/step - loss: 8.7874 - val_loss: 7.9030
#
# [20210302-1440-29] Learning rate for epoch 35 is 0.001642518793232739
# Epoch 35/1000
# 19/19 [==============================] - ETA: 0s - loss: 8.8363
# Epoch 00035: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 67ms/step - loss: 8.8363 - val_loss: 9.3607
#
# [20210302-1440-34] Learning rate for epoch 36 is 0.0016890636179596186
# Epoch 36/1000
# 19/19 [==============================] - ETA: 0s - loss: 8.6507
# Epoch 00036: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 69ms/step - loss: 8.6507 - val_loss: 8.9243
#
# [20210302-1440-40] Learning rate for epoch 37 is 0.0017355084419250488
# Epoch 37/1000
# 19/19 [==============================] - ETA: 0s - loss: 8.7329
# Epoch 00037: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 67ms/step - loss: 8.7329 - val_loss: 8.2505
#
# [20210302-1440-45] Learning rate for epoch 38 is 0.0017818533815443516
# Epoch 38/1000
# 19/19 [==============================] - ETA: 0s - loss: 8.5622
# Epoch 00038: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 68ms/step - loss: 8.5622 - val_loss: 7.5122
#
# [20210302-1440-51] Learning rate for epoch 39 is 0.0018280982039868832
# Epoch 39/1000
# 19/19 [==============================] - ETA: 0s - loss: 8.5151
# Epoch 00039: val_loss did not improve from 7.34982
# 19/19 [==============================] - 1s 69ms/step - loss: 8.5151 - val_loss: 7.7365
#
# [20210302-1440-57] Learning rate for epoch 40 is 0.0018742431420832872
# Epoch 40/1000
# 19/19 [==============================] - ETA: 0s - loss: 8.6742
# Epoch 00040: val_loss improved from 7.34982 to 7.00756, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 2s 96ms/step - loss: 8.6742 - val_loss: 7.0076
#
# [20210302-1441-03] Learning rate for epoch 41 is 0.0019202879630029202
# Epoch 41/1000
# 19/19 [==============================] - ETA: 0s - loss: 8.4556
# Epoch 00041: val_loss did not improve from 7.00756
# 19/19 [==============================] - 1s 69ms/step - loss: 8.4556 - val_loss: 7.2706
#
# [20210302-1441-09] Learning rate for epoch 42 is 0.0019662328995764256
# Epoch 42/1000
# 19/19 [==============================] - ETA: 0s - loss: 8.2307
# Epoch 00042: val_loss did not improve from 7.00756
# 19/19 [==============================] - 1s 68ms/step - loss: 8.2307 - val_loss: 8.0368
#
# [20210302-1441-14] Learning rate for epoch 43 is 0.00201207771897316
# Epoch 43/1000
# 19/19 [==============================] - ETA: 0s - loss: 8.2808
# Epoch 00043: val_loss did not improve from 7.00756
# 19/19 [==============================] - 1s 69ms/step - loss: 8.2808 - val_loss: 7.8669
#
# [20210302-1441-20] Learning rate for epoch 44 is 0.0020578226540237665
# Epoch 44/1000
# 19/19 [==============================] - ETA: 0s - loss: 8.2785
# Epoch 00044: val_loss did not improve from 7.00756
# 19/19 [==============================] - 1s 67ms/step - loss: 8.2785 - val_loss: 7.5225
#
# [20210302-1441-25] Learning rate for epoch 45 is 0.0021034677047282457
# Epoch 45/1000
# 19/19 [==============================] - ETA: 0s - loss: 8.3221
# Epoch 00045: val_loss did not improve from 7.00756
# 19/19 [==============================] - 1s 69ms/step - loss: 8.3221 - val_loss: 7.5043
#
# [20210302-1441-31] Learning rate for epoch 46 is 0.002149012638255954
# Epoch 46/1000
# 19/19 [==============================] - ETA: 0s - loss: 8.1386
# Epoch 00046: val_loss did not improve from 7.00756
# 19/19 [==============================] - 1s 68ms/step - loss: 8.1386 - val_loss: 7.9625
#
# [20210302-1441-37] Learning rate for epoch 47 is 0.0021944576874375343
# Epoch 47/1000
# 19/19 [==============================] - ETA: 0s - loss: 8.1378
# Epoch 00047: val_loss improved from 7.00756 to 6.56975, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 2s 97ms/step - loss: 8.1378 - val_loss: 6.5698
#
# [20210302-1441-43] Learning rate for epoch 48 is 0.0022398026194423437
# Epoch 48/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.7744
# Epoch 00048: val_loss did not improve from 6.56975
# 19/19 [==============================] - 1s 69ms/step - loss: 7.7744 - val_loss: 6.8577
#
# [20210302-1441-49] Learning rate for epoch 49 is 0.002285047434270382
# Epoch 49/1000
# 19/19 [==============================] - ETA: 0s - loss: 8.0624
# Epoch 00049: val_loss did not improve from 6.56975
# 19/19 [==============================] - 1s 67ms/step - loss: 8.0624 - val_loss: 6.9474
#
# [20210302-1441-55] Learning rate for epoch 50 is 0.0023301925975829363
# Epoch 50/1000
# 19/19 [==============================] - ETA: 0s - loss: 8.0891
# Epoch 00050: val_loss did not improve from 6.56975
# 19/19 [==============================] - 1s 68ms/step - loss: 8.0891 - val_loss: 6.8446
#
# [20210302-1442-00] Learning rate for epoch 51 is 0.002375237410888076
# Epoch 51/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.8504
# Epoch 00051: val_loss did not improve from 6.56975
# 19/19 [==============================] - 1s 67ms/step - loss: 7.8504 - val_loss: 7.0734
#
# [20210302-1442-06] Learning rate for epoch 52 is 0.0024201825726777315
# Epoch 52/1000
# 19/19 [==============================] - ETA: 0s - loss: 8.0219
# Epoch 00052: val_loss improved from 6.56975 to 6.46659, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 2s 96ms/step - loss: 8.0219 - val_loss: 6.4666
#
# [20210302-1442-12] Learning rate for epoch 53 is 0.002465027617290616
# Epoch 53/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.9562
# Epoch 00053: val_loss did not improve from 6.46659
# 19/19 [==============================] - 1s 67ms/step - loss: 7.9562 - val_loss: 6.7759
#
# [20210302-1442-18] Learning rate for epoch 54 is 0.0025097725447267294
# Epoch 54/1000
# 19/19 [==============================] - ETA: 0s - loss: 8.1279
# Epoch 00054: val_loss did not improve from 6.46659
# 19/19 [==============================] - 1s 69ms/step - loss: 8.1279 - val_loss: 7.0884
#
# [20210302-1442-24] Learning rate for epoch 55 is 0.0025544175878167152
# Epoch 55/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.9054
# Epoch 00055: val_loss did not improve from 6.46659
# 19/19 [==============================] - 1s 68ms/step - loss: 7.9054 - val_loss: 7.4812
#
# [20210302-1442-29] Learning rate for epoch 56 is 0.00259896251372993
# Epoch 56/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.8497
# Epoch 00056: val_loss improved from 6.46659 to 6.06344, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 2s 97ms/step - loss: 7.8497 - val_loss: 6.0634
#
# [20210302-1442-35] Learning rate for epoch 57 is 0.0026434077881276608
# Epoch 57/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.9408
# Epoch 00057: val_loss did not improve from 6.06344
# 19/19 [==============================] - 1s 69ms/step - loss: 7.9408 - val_loss: 6.8677
#
# [20210302-1442-41] Learning rate for epoch 58 is 0.0026877527125179768
# Epoch 58/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.7694
# Epoch 00058: val_loss did not improve from 6.06344
# 19/19 [==============================] - 1s 67ms/step - loss: 7.7694 - val_loss: 6.9434
#
# [20210302-1442-46] Learning rate for epoch 59 is 0.0027319977525621653
# Epoch 59/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.5609
# Epoch 00059: val_loss did not improve from 6.06344
# 19/19 [==============================] - 1s 68ms/step - loss: 7.5609 - val_loss: 6.3713
#
# [20210302-1442-52] Learning rate for epoch 60 is 0.0027761429082602262
# Epoch 60/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.9137
# Epoch 00060: val_loss did not improve from 6.06344
# 19/19 [==============================] - 1s 69ms/step - loss: 7.9137 - val_loss: 6.0989
#
# [20210302-1442-58] Learning rate for epoch 61 is 0.002820187946781516
# Epoch 61/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.7196
# Epoch 00061: val_loss did not improve from 6.06344
# 19/19 [==============================] - 1s 68ms/step - loss: 7.7196 - val_loss: 7.2908
#
# [20210302-1443-03] Learning rate for epoch 62 is 0.0028641331009566784
# Epoch 62/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.5603
# Epoch 00062: val_loss did not improve from 6.06344
# 19/19 [==============================] - 1s 70ms/step - loss: 7.5603 - val_loss: 6.6324
#
# [20210302-1443-09] Learning rate for epoch 63 is 0.0029079781379550695
# Epoch 63/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.7528
# Epoch 00063: val_loss did not improve from 6.06344
# 19/19 [==============================] - 1s 69ms/step - loss: 7.7528 - val_loss: 6.7194
#
# [20210302-1443-15] Learning rate for epoch 64 is 0.002951723290607333
# Epoch 64/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.5057
# Epoch 00064: val_loss did not improve from 6.06344
# 19/19 [==============================] - 1s 68ms/step - loss: 7.5057 - val_loss: 6.5846
#
# [20210302-1443-20] Learning rate for epoch 65 is 0.0029953685589134693
# Epoch 65/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.8107
# Epoch 00065: val_loss improved from 6.06344 to 6.02923, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 2s 101ms/step - loss: 7.8107 - val_loss: 6.0292
#
# [20210302-1443-26] Learning rate for epoch 66 is 0.0030389137100428343
# Epoch 66/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.5227
# Epoch 00066: val_loss did not improve from 6.02923
# 19/19 [==============================] - 1s 68ms/step - loss: 7.5227 - val_loss: 6.6295
#
# [20210302-1443-32] Learning rate for epoch 67 is 0.003082358743995428
# Epoch 67/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.9254
# Epoch 00067: val_loss did not improve from 6.02923
# 19/19 [==============================] - 1s 67ms/step - loss: 7.9254 - val_loss: 6.4957
#
# [20210302-1443-38] Learning rate for epoch 68 is 0.0031257038936018944
# Epoch 68/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.7721
# Epoch 00068: val_loss improved from 6.02923 to 5.97035, saving model to ./20210302-142936/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 19/19 [==============================] - 2s 97ms/step - loss: 7.7721 - val_loss: 5.9704
#
# [20210302-1443-44] Learning rate for epoch 69 is 0.003168949158862233
# Epoch 69/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.9437
# Epoch 00069: val_loss did not improve from 5.97035
# 19/19 [==============================] - 1s 69ms/step - loss: 7.9437 - val_loss: 6.1350
#
# [20210302-1443-49] Learning rate for epoch 70 is 0.0032120943069458008
# Epoch 70/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.6651
# Epoch 00070: val_loss did not improve from 5.97035
# 19/19 [==============================] - 1s 64ms/step - loss: 7.6651 - val_loss: 6.3985
#
# [20210302-1443-55] Learning rate for epoch 71 is 0.003255139570683241
# Epoch 71/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.8412
# Epoch 00071: val_loss did not improve from 5.97035
# 19/19 [==============================] - 1s 69ms/step - loss: 7.8412 - val_loss: 6.7994
#
# [20210302-1444-00] Learning rate for epoch 72 is 0.00329808471724391
# Epoch 72/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.5984
# Epoch 00072: val_loss did not improve from 5.97035
# 19/19 [==============================] - 1s 68ms/step - loss: 7.5984 - val_loss: 6.0525
#
# [20210302-1444-06] Learning rate for epoch 73 is 0.0033409299794584513
# Epoch 73/1000
# ...
# 19/19 [==============================] - ETA: 0s - loss: 6.2993
# Epoch 00160: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 6.2993 - val_loss: 5.7439
#
# [20210302-1452-19] Learning rate for epoch 161 is 0.001680252025835216
# Epoch 161/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.3884
# Epoch 00161: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 6.3884 - val_loss: 5.6407
#
# [20210302-1452-25] Learning rate for epoch 162 is 0.0018460348946973681
# Epoch 162/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.5592
# Epoch 00162: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 68ms/step - loss: 6.5592 - val_loss: 5.4544
#
# [20210302-1452-30] Learning rate for epoch 163 is 0.0020114178769290447
# Epoch 163/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.3352
# Epoch 00163: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 68ms/step - loss: 6.3352 - val_loss: 5.6033
#
# [20210302-1452-36] Learning rate for epoch 164 is 0.0021764009725302458
# Epoch 164/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.4725
# Epoch 00164: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 68ms/step - loss: 6.4725 - val_loss: 5.6004
#
# [20210302-1452-41] Learning rate for epoch 165 is 0.002340983832255006
# Epoch 165/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.6664
# Epoch 00165: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 6.6664 - val_loss: 5.8621
#
# [20210302-1452-47] Learning rate for epoch 166 is 0.002505166921764612
# Epoch 166/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.4614
# Epoch 00166: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 66ms/step - loss: 6.4614 - val_loss: 6.1909
#
# [20210302-1452-53] Learning rate for epoch 167 is 0.002668950008228421
# Epoch 167/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.5694
# Epoch 00167: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 66ms/step - loss: 6.5694 - val_loss: 6.0520
#
# [20210302-1452-58] Learning rate for epoch 168 is 0.0028323333244770765
# Epoch 168/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.7904
# Epoch 00168: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 63ms/step - loss: 6.7904 - val_loss: 6.1189
#
# [20210302-1453-04] Learning rate for epoch 169 is 0.002995316404849291
# Epoch 169/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.6010
# Epoch 00169: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 6.6010 - val_loss: 6.0782
#
# [20210302-1453-09] Learning rate for epoch 170 is 0.0031578997150063515
# Epoch 170/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.5281
# Epoch 00170: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 68ms/step - loss: 6.5281 - val_loss: 6.5450
#
# [20210302-1453-15] Learning rate for epoch 171 is 0.0033200830221176147
# Epoch 171/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.6383
# Epoch 00171: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 68ms/step - loss: 6.6383 - val_loss: 6.9174
#
# [20210302-1453-21] Learning rate for epoch 172 is 0.0034818663261830807
# Epoch 172/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.2970
# Epoch 00172: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 65ms/step - loss: 6.2970 - val_loss: 7.3981
#
# [20210302-1453-26] Learning rate for epoch 173 is 0.0036432496272027493
# Epoch 173/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.8936
# Epoch 00173: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 68ms/step - loss: 6.8936 - val_loss: 6.9590
#
# [20210302-1453-32] Learning rate for epoch 174 is 0.003804233158007264
# Epoch 174/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.6778
# Epoch 00174: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 6.6778 - val_loss: 6.2446
#
# [20210302-1453-37] Learning rate for epoch 175 is 0.003964816685765982
# Epoch 175/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.6702
# Epoch 00175: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 64ms/step - loss: 6.6702 - val_loss: 6.0631
#
# [20210302-1453-43] Learning rate for epoch 176 is 0.004124999977648258
# Epoch 176/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.7817
# Epoch 00176: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 6.7817 - val_loss: 6.4867
#
# [20210302-1453-49] Learning rate for epoch 177 is 0.003955216612666845
# Epoch 177/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.8397
# Epoch 00177: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 66ms/step - loss: 6.8397 - val_loss: 7.9295
#
# [20210302-1453-54] Learning rate for epoch 178 is 0.003785833017900586
# Epoch 178/1000
# 19/19 [==============================] - ETA: 0s - loss: 7.1560
# Epoch 00178: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 69ms/step - loss: 7.1560 - val_loss: 6.4014
#
# [20210302-1454-00] Learning rate for epoch 179 is 0.0036168494261801243
# Epoch 179/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.8982
# Epoch 00179: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 68ms/step - loss: 6.8982 - val_loss: 6.0516
#
# [20210302-1454-06] Learning rate for epoch 180 is 0.003448265604674816
# Epoch 180/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.6407
# Epoch 00180: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 6.6407 - val_loss: 6.4366
#
# [20210302-1454-11] Learning rate for epoch 181 is 0.003280082019045949
# Epoch 181/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.7099
# Epoch 00181: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 69ms/step - loss: 6.7099 - val_loss: 6.3300
#
# [20210302-1454-17] Learning rate for epoch 182 is 0.0031122982036322355
# Epoch 182/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.6238
# Epoch 00182: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 68ms/step - loss: 6.6238 - val_loss: 6.7024
#
# [20210302-1454-22] Learning rate for epoch 183 is 0.002944914624094963
# Epoch 183/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.6628
# Epoch 00183: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 6.6628 - val_loss: 6.2903
#
# [20210302-1454-28] Learning rate for epoch 184 is 0.0027779308147728443
# Epoch 184/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.5307
# Epoch 00184: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 6.5307 - val_loss: 6.2819
#
# [20210302-1454-34] Learning rate for epoch 185 is 0.0026113467756658792
# Epoch 185/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.4037
# Epoch 00185: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 6.4037 - val_loss: 6.2783
#
# [20210302-1454-39] Learning rate for epoch 186 is 0.002445162972435355
# Epoch 186/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.5105
# Epoch 00186: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 68ms/step - loss: 6.5105 - val_loss: 5.7080
#
# [20210302-1454-45] Learning rate for epoch 187 is 0.0022793791722506285
# Epoch 187/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.7107
# Epoch 00187: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 6.7107 - val_loss: 7.5731
#
# [20210302-1454-50] Learning rate for epoch 188 is 0.0021139951422810555
# Epoch 188/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.3986
# Epoch 00188: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 6.3986 - val_loss: 5.9835
#
# [20210302-1454-56] Learning rate for epoch 189 is 0.0019490111153572798
# Epoch 189/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.4465
# Epoch 00189: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 68ms/step - loss: 6.4465 - val_loss: 5.6182
#
# [20210302-1455-01] Learning rate for epoch 190 is 0.0017844270914793015
# Epoch 190/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.2983
# Epoch 00190: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 69ms/step - loss: 6.2983 - val_loss: 5.6483
#
# [20210302-1455-07] Learning rate for epoch 191 is 0.0016202429542317986
# Epoch 191/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.2540
# Epoch 00191: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 6.2540 - val_loss: 5.9707
#
# [20210302-1455-13] Learning rate for epoch 192 is 0.001456458936445415
# Epoch 192/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.2129
# Epoch 00192: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 6.2129 - val_loss: 5.7505
#
# [20210302-1455-18] Learning rate for epoch 193 is 0.001293074688874185
# Epoch 193/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.4295
# Epoch 00193: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 68ms/step - loss: 6.4295 - val_loss: 5.5684
#
# [20210302-1455-24] Learning rate for epoch 194 is 0.0011300905607640743
# Epoch 194/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.3284
# Epoch 00194: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 63ms/step - loss: 6.3284 - val_loss: 6.1015
#
# [20210302-1455-29] Learning rate for epoch 195 is 0.0009675062610767782
# Epoch 195/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.2679
# Epoch 00195: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 68ms/step - loss: 6.2679 - val_loss: 5.6892
#
# [20210302-1455-35] Learning rate for epoch 196 is 0.0008053220226429403
# Epoch 196/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.2114
# Epoch 00196: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 63ms/step - loss: 6.2114 - val_loss: 5.6063
#
# [20210302-1455-40] Learning rate for epoch 197 is 0.0006435376708395779
# Epoch 197/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.0542
# Epoch 00197: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 6.0542 - val_loss: 5.8879
#
# [20210302-1455-46] Learning rate for epoch 198 is 0.0004821533220820129
# Epoch 198/1000
# 19/19 [==============================] - ETA: 0s - loss: 5.9391
# Epoch 00198: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 5.9391 - val_loss: 5.5574
#
# [20210302-1455-52] Learning rate for epoch 199 is 0.0003211689181625843
# Epoch 199/1000
# 19/19 [==============================] - ETA: 0s - loss: 5.8364
# Epoch 00199: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 63ms/step - loss: 5.8364 - val_loss: 5.4839
#
# [20210302-1455-57] Learning rate for epoch 200 is 0.00016058447363320738
# Epoch 200/1000
# 19/19 [==============================] - ETA: 0s - loss: 5.8500
# Epoch 00200: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 5.8500 - val_loss: 5.4473
#
# [20210302-1456-03] Learning rate for epoch 201 is 4.0000000467443897e-07
# Epoch 201/1000
# 19/19 [==============================] - ETA: 0s - loss: 5.7947
# Epoch 00201: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 5.7947 - val_loss: 5.4370
#
# [20210302-1456-09] Learning rate for epoch 202 is 0.0001601835247129202
# Epoch 202/1000
# 19/19 [==============================] - ETA: 0s - loss: 5.9143
# Epoch 00202: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 5.9143 - val_loss: 5.4799
#
# [20210302-1456-14] Learning rate for epoch 203 is 0.00031956707243807614
# Epoch 203/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.0484
# Epoch 00203: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 68ms/step - loss: 6.0484 - val_loss: 5.4748
#
# [20210302-1456-20] Learning rate for epoch 204 is 0.00047855067532509565
# Epoch 204/1000
# 19/19 [==============================] - ETA: 0s - loss: 5.7666
# Epoch 00204: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 5.7666 - val_loss: 5.6049
#
# [20210302-1456-26] Learning rate for epoch 205 is 0.0006371343042701483
# Epoch 205/1000
# 19/19 [==============================] - ETA: 0s - loss: 5.7896
# Epoch 00205: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 68ms/step - loss: 5.7896 - val_loss: 5.5555
#
# [20210302-1456-31] Learning rate for epoch 206 is 0.0007953179883770645
# Epoch 206/1000
# 19/19 [==============================] - ETA: 0s - loss: 5.9228
# Epoch 00206: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 66ms/step - loss: 5.9228 - val_loss: 5.7308
#
# [20210302-1456-37] Learning rate for epoch 207 is 0.0009531017276458442
# Epoch 207/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.0729
# Epoch 00207: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 68ms/step - loss: 6.0729 - val_loss: 5.5387
#
# [20210302-1456-42] Learning rate for epoch 208 is 0.0011104855220764875
# Epoch 208/1000
# 19/19 [==============================] - ETA: 0s - loss: 5.9900
# Epoch 00208: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 5.9900 - val_loss: 5.5514
#
# [20210302-1456-48] Learning rate for epoch 209 is 0.0012674692552536726
# Epoch 209/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.1437
# Epoch 00209: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 6.1437 - val_loss: 5.8349
#
# [20210302-1456-53] Learning rate for epoch 210 is 0.0014240531018003821
# Epoch 210/1000
# 19/19 [==============================] - ETA: 0s - loss: 5.9872
# Epoch 00210: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 67ms/step - loss: 5.9872 - val_loss: 5.9068
#
# [20210302-1456-59] Learning rate for epoch 211 is 0.0015802369453012943
# Epoch 211/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.2392
# Epoch 00211: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 65ms/step - loss: 6.2392 - val_loss: 6.1945
#
# [20210302-1457-05] Learning rate for epoch 212 is 0.001736020902171731
# Epoch 212/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.0330
# Epoch 00212: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 69ms/step - loss: 6.0330 - val_loss: 5.7492
#
# [20210302-1457-10] Learning rate for epoch 213 is 0.0018914048559963703
# Epoch 213/1000
# 19/19 [==============================] - ETA: 0s - loss: 6.2865
# Epoch 00213: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 69ms/step - loss: 6.2865 - val_loss: 5.8710
#
# [20210302-1457-16] Learning rate for epoch 214 is 0.0020463888067752123
# Epoch 214/1000
# 19/19 [==============================] - ETA: 0s - loss: 5.9831
# Epoch 00214: val_loss did not improve from 5.26697
# 19/19 [==============================] - 1s 68ms/step - loss: 5.9831 - val_loss: 5.6321
#
# [20210302-1457-22] Learning rate for epoch 215 is 0.0022009729873389006
# Epoch 215/1000

# %%
#ED sum
def get_valloss(his_v_l):  
    return np.min(his_v_l), np.argmin(his_v_l)

t_vl = []
# h_vl = []
for k in range(KFlodNum):
    print(f'K:{k}')
    t_v, _ = get_valloss(history_toe_finetune[k].history['val_loss'])
#     h_v, _ = get_valloss(history_heel_finetune[k].history['val_loss'])
    
    t_vl.append(t_v)
#     h_vl.append(h_v)

# t_vl = np.mean(t_vl, axis=0)
# h_vl = np.mean(h_vl, axis=0)
# print(f'{round(t_vl,5)} + {round(h_vl,5)} = {round(t_vl + h_vl,5)}')

t_vl

# %%
np.savetxt(f'{log_dir_name}/toe_FNED.txt', t_vl)

# %%
# Sum plot losses toe-tl

plt.figure(figsize=(25, 10))

for k in range(KFlodNum):

    plt.plot(history_toe[k].history['loss'])
    plt.plot(history_toe[k].history['val_loss'])

    
plt.title('K-model ed loss toe-TL')
plt.ylabel('ed loss'), plt.ylim(5, 80)# for too large loss
plt.xlabel('epoch')
plt.legend(['k0 loss', 'k0 val_loss', 'k1 loss', 'k1 val_loss', 'k2 loss', 'k2 val_loss', 
            'k3 loss', 'k3 val_loss', 'k4 loss', 'k4 val_loss'], loc='upper left') 
# plt.show()

# save plot : comment plo.show in jupyter notebook.
plt.savefig(f'{log_dir_name}/{log_dir_name}_toe_Ksum_TL.png', bbox_inches = 'tight')

# %%
# Single plot loss toe-tl

for k in range(KFlodNum):
    plt.figure(figsize=(25, 10))
    plt.plot(history_toe[k].history['loss'])
    plt.plot(history_toe[k].history['val_loss'])
    plt.title('K-model ed loss toe-TL')
    plt.ylabel('ed loss'), plt.ylim(5, 20)# for too large loss
    plt.xlabel('epoch')
    plt.legend(['loss', 'val_loss'], loc='upper left') 
    # plt.show()

    # save plot : comment plo.show in jupyter notebook.
    def get_valloss(his_v_l):   
        return np.min(his_v_l), np.argmin(his_v_l)

    vl, ep = get_valloss(history_toe[k].history['val_loss'])
    plt.savefig(f'{log_dir_name}/{log_dir_name}_toe_K{k}_TL_clr_ed{round(vl,4)}@{ep}.png', bbox_inches = 'tight')

# %%
# check the loos the model trained.

def get_valloss(his_v_l):  
    return np.min(his_v_l), np.argmin(his_v_l)

t_vl = []
# h_vl = []
for k in range(KFlodNum):
    print(f'K:{k}')
    t_v, _ = get_valloss(history_toe_finetune[k].history['val_loss'])
#     h_v, _ = get_valloss(history_heel_finetune[k].history['val_loss'])
    
    t_vl.append(t_v)
    
# for different scales (different Y-axes)
# fig, ax1 = plt.subplots()
fig, ax1 = plt.subplots(figsize=(25, 10))

# nice to have this colorful tip.
color = 'tab:red'

ax1.set_title('[ toe_finetune ] \n ED loss')

ax1.set_xlabel('epoch')
ax1.set_ylabel('ed loss', color=color)

for k in range(KFlodNum):

    plt.plot(history_toe_finetune[k].history['loss'])
    plt.plot(history_toe_finetune[k].history['val_loss'])

ax1.tick_params(axis='y', labelcolor=color)
# ax1.legend(['loss', 'val_loss'], loc='upper center') # legend may ocvered by next ax ploting. moved to end.
ax1.legend(['k0 loss', 'k0 val_loss', 'k1 loss', 'k1 val_loss', 'k2 loss', 'k2 val_loss', 
            'k3 loss', 'k3 val_loss', 'k4 loss', 'k4 val_loss'], loc='upper left') 

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('learning rate', color=color)
ax2.plot(history_toe_finetune[0].history['lr'], color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.legend(['lr'], loc='upper right') 

# plt.show()

# # save plot : comment plo.show in jupyter notebook.
# def get_valloss(his_v_l):   
#     return np.min(his_v_l), np.argmin(his_v_l)

# vl, ep = get_valloss(history_toe_finetune.history['val_loss'])


t_vl = np.mean(t_vl, axis=0)
plt.savefig(f'{log_dir_name}/{log_dir_name}_toe_ft_Ksum-clr_ed{round(t_vl,4)}.png', bbox_inches = 'tight')

# %%
# Sum plot losses toe-ft

plt.figure(figsize=(25, 10))

for k in range(KFlodNum):

    plt.plot(history_toe_finetune[k].history['loss'])
    plt.plot(history_toe_finetune[k].history['val_loss'])

    
plt.title('K-model ed loss toe-FT')
plt.ylabel('ed loss'), plt.ylim(4, 20)# for too large loss
plt.xlabel('epoch')
plt.legend(['k0 loss', 'k0 val_loss', 'k1 loss', 'k1 val_loss', 'k2 loss', 'k2 val_loss', 
            'k3 loss', 'k3 val_loss', 'k4 loss', 'k4 val_loss'], loc='upper left') 
# plt.show()

# save plot : comment plo.show in jupyter notebook.
plt.savefig(f'{log_dir_name}/{log_dir_name}_toe_Ksum_FT.png', bbox_inches = 'tight')

# %%
# Single plot loss toe-FT

for k in range(KFlodNum):
    plt.figure(figsize=(25, 10))
    plt.plot(history_toe_finetune[k].history['loss'])
    plt.plot(history_toe_finetune[k].history['val_loss'])
    plt.title('K-model ed loss toe-FT')
    plt.ylabel('ed loss'), plt.ylim(4, 20)# for too large loss
    plt.xlabel('epoch')
    plt.legend(['loss', 'val_loss'], loc='upper left') 
    # plt.show()

    # save plot : comment plo.show in jupyter notebook.
    def get_valloss(his_v_l):   
        return np.min(his_v_l), np.argmin(his_v_l)

    vl, ep = get_valloss(history_toe_finetune[k].history['val_loss'])
    plt.savefig(f'{log_dir_name}/{log_dir_name}_toe_K{k}_FT_clr_ed{round(vl,4)}@{ep}.png', bbox_inches = 'tight')

# %% [markdown]
# ### Heel K-model removed

# %%
#ED sum
def get_valloss(his_v_l):  
    return np.min(his_v_l), np.argmin(his_v_l)

t_vl = []
# h_vl = []
for k in range(KFlodNum):
    print(f'K:{k}')
    t_v, _ = get_valloss(history_toe_finetune[k].history['val_loss'])
#     h_v, _ = get_valloss(history_heel_finetune[k].history['val_loss'])
    
    t_vl.append(t_v)
#     h_vl.append(h_v)

t_vl = np.mean(t_vl, axis=0)
# h_vl = np.mean(h_vl, axis=0)
# print(f'{round(t_vl,5)} + {round(h_vl,5)} = {round(t_vl + h_vl,5)}')
print(f'toe ED = {round(t_vl,5)}')

# %%
# K134520210224-114845.csv
# 5.63922 + 3.34466 = 8.98389 LB:8.4890610

# %%
t_vl

# %%
# h_vl

# %%
t_timer.toc() #Time elapsed since t.tic()
