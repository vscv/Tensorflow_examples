# %% [markdown]
# # 101 Course of transfer learning and Fine tune 2021-01-01

# %% [markdown]
# ## [How-to] 1. k-fold for cross validation
#
# #### Create a simple k-fold for train classification model.
#
# * In this short course you learned:
#
# * data pipline
#
# * transfer learning
#
# * fine tune
#
# * callbacks

# %% [markdown]
# todo: move to note.py

# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# plt.style.use("bmh")

import cv2
import tensorflow as tf

from datetime import datetime
import seaborn as sns

import errno

# albumentations
from functools import partial
# from albumentations import (
#     Compose, RandomBrightness, JpegCompression, HueSaturationValue, RandomContrast, HorizontalFlip,
#     Rotate
# )
import albumentations as A

# from adabelief_tf import AdaBeliefOptimizer

# %%
print(tf.__version__)
print(cv2.__version__)
# Out:
# 2.3.1
# 4.3.0

# %%
from pytictoc import TicToc

t_timer = TicToc() #create instance of class

t_timer.tic() #Start timer

# %% [markdown]
# ### 2. Parameters

# %% [markdown]
# #### Image size, Batch size, toe/heel-offset.

# %%
BATCH_SIZE = 64 # 16 #32 #64 #128 #32 #64 #todo: reduce the BS maybe help to reduce the loss
img_height = 120 #512 #224 #100
img_width = 120 #512 #224 #100

y_offset_toe = 80
y_offset_heel = 280 #400-120=280

# %% [markdown]
# #### tf MirroredStrategy seting

# %%
# tf MirroredStrategy seting
strategy = tf.distribute.MirroredStrategy()
REPLICAS = strategy.num_replicas_in_sync
print('\nNumber of REPLICAS: {}\n'.format(REPLICAS))


MULTI_BATCH_SIZE = BATCH_SIZE * strategy.num_replicas_in_sync
print('BATCH_SIZE: {}, MULTI_BATCH_SIZE: {}'.format(BATCH_SIZE, MULTI_BATCH_SIZE))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
#
# Number of REPLICAS: 1
#
# BATCH_SIZE: 64, MULTI_BATCH_SIZE: 64

# %%
# 自動調節tf.data管道
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %% [markdown]
# ### 3. Create the training dataset W/ croped

# %% [markdown]
# #### Load samples as data-farame

# %%
# # data-org #
# ann = 'annotation_1424_merge.csv'
# im_p = 'train/images/'
# CSVNAME = ""


# # data-org-augm#
# ann = 'annotation_2848_augm.csv'
# im_p = 'train_augm/images/'
# CSVNAME = ""


# data-train # # current best dataset.1424-79.
ann = 'annotation_1345_good.csv'
im_p = 'train/images/'
CSVNAME = "K1345"

# data-augm #
# ann = 'annotation_2690_augm.csv'
# im_p = 'train_augm/images/'
# CSVNAME = ""


# # data-train-HPL-1123
# ann = 'annotation_1123_HPL_Good.csv'
# im_p = 'train/images/'
# CSVNAME = ""


df = pd.read_csv(ann)
df[1120:]
# Out:
#               images  x1   y1  x2   y2
# 1120  image_6195.jpg  52  127  75  370
# 1121  image_6196.jpg  62  138  29  383
# 1122  image_6197.jpg  54  135  78  380
# 1123  image_6198.jpg  60  125  29  384
# 1124  image_6199.jpg  51  147  70  353
# ...              ...  ..  ...  ..  ...
# 1340  image_6419.jpg  60  135  70  381
# 1341  image_6421.jpg  53  157  76  376
# 1342  image_6422.jpg  49  154  33  375
# 1343  image_6423.jpg  64  149  76  381
# 1344  image_6424.jpg  55  147  36  385
#
# [225 rows x 5 columns]

# %%
len(df)
# Out:
# 1345

# %% [markdown]
# #### Shuffle and reset index

# %%
# reset index
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head(10)
# Out:
#            images  x1   y1  x2   y2
# 0  image_0898.png  57  127  75  363
# 1  image_0403.JPG  60  141  22  382
# 2  image_0974.png  63  119  74  382
# 3  image_6229.jpg  56  156  25  381
# 4  image_0307.png  55  131  86  383
# 5  image_6185.jpg  52  141  79  382
# 6  image_0424.png  66  122  39  368
# 7  image_0371.png  63  118  81  382
# 8  image_6282.jpg  54  141  35  383
# 9  image_0070.png  70  137  25  381

# %% [markdown]
# See, the image_####.jpg now are random.

# %% [markdown]
# #### Create tf.dataset (DS)

# %%
# from dataframe
list_ds = tf.data.Dataset.from_tensor_slices((df['images'], df['x1'], df['y1'], df['x2'], df['y2']))
# list_ds = list_ds.shuffle(image_count, reshuffle_each_iteration=True) #todo: move to ds_pre. see https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle

# %%
len(list_ds)#.shape() #take(1)
# Out:
# 1345

# %%
# check The type specification of an element of this dataset.
list_ds.element_spec
# Out:
# (TensorSpec(shape=(), dtype=tf.string, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None))

# %%
for f,x1,y1,x2,y2 in list_ds.take(5):
    print(f'take sample: {f} {x1} {y1} {x2} {y2}')
# Out:
# take sample: b'image_0898.png' 57 127 75 363
# take sample: b'image_0403.JPG' 60 141 22 382
# take sample: b'image_0974.png' 63 119 74 382
# take sample: b'image_6229.jpg' 56 156 25 381
# take sample: b'image_0307.png' 55 131 86 383

# %%
# use np decode to UTF-8
print(f.numpy().decode('UTF-8'))
# Out:
# image_0307.png

# %%
len(list_ds)
# Out:
# 1345

# %% [markdown]
# #### Check ds iterator for consuming

# %%
# create a Python iterator

it_list_ds = iter(list_ds) # Make sure iter ds only once.

# %%
# using iter and consuming its elements using next: every print different image name.

for i in range(4):
    image, x1, y1, x2, y2 = next(it_list_ds)
    print(image.numpy(), x1.numpy(), y1.numpy())
# Out:
# b'image_0898.png' 57 127
# b'image_0403.JPG' 60 141
# b'image_0974.png' 63 119
# b'image_6229.jpg' 56 156

# %%
# image_batch, label_batch = valid_ds_pre_s.as_numpy_iterator().next()
# pred = model.predict_on_batch(image_batch)


for i in range(4):
    image, x1, y1, x2, y2 = list_ds.as_numpy_iterator().next()# every time create a new iter, so need put iter out of above cell.
    print(image, x1, y1, x2, y2)
    
iter_test_list = list_ds.as_numpy_iterator()
print("===== Create iterator once and pull out to above cell. =====")
for i in range(4):
    image, x1, y1, x2, y2 = iter_test_list.next()
    print(image, x1, y1, x2, y2)
# Out:
# b'image_0898.png' 57 127 75 363
# b'image_0898.png' 57 127 75 363
# b'image_0898.png' 57 127 75 363
# b'image_0898.png' 57 127 75 363
# ===== Create iterator once and pull out to above cell. =====
# b'image_0898.png' 57 127 75 363
# b'image_0403.JPG' 60 141 22 382
# b'image_0974.png' 63 119 74 382
# b'image_6229.jpg' 56 156 25 381

# %% [markdown]
# #### Process path to image tensor in DS

# %%
'''
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    # The second to last is the class-directory
    boolen = parts[-2] == class_names
    #one_hot_num = np.array(boolen, dtype=np.int) not works should use tf.x repalced.
    one_hot_num = tf.dtypes.cast(boolen, tf.int64)
    one_num = tf.argmax(one_hot_num)
    print('one_num:', one_num)
    # Integer encode the label
    return one_num

def decode_img(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.io.decode_jpeg(img, channels=3)
    # resize the image to the desired size
#     return tf.image.resize(img, [img_height, img_width])# augment 已經resize過一次了 但這邊不先做會比較慢
    return tf.cast(tf.image.resize(img, [img_height, img_width]), tf.uint8)# 避免float over at augment
'''

#
# map list to ds, Toe part.
#

def decode_crop_png_toe(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.io.decode_png(img, channels=3)
    # crop the toe from top-left corner [image, offset_height y1, offset_width x1, target_height, target_width]
    y1=y_offset_toe;    x1=0;    h=img_height;    w=img_width # not the pp location
    img = tf.image.crop_to_bounding_box(img, int(y1), int(x1), h, w)
    #img = tf.image.crop_to_bounding_box(img, int(y1), int(x1), int(y2)-int(y1), int(x2)-int(x1))
    # resize the image to the desired size
    return img

def process_path_toe(file_path,x1,y1,x2,y2):
    file_path = im_p + file_path
    #label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)#can read the byte string paths b'image_0001.png'
    img = decode_crop_png_toe(img)
    return img, [x1,y1-y_offset_toe]#Original [0,120]
    #return img, x1, y1-y_offset_toe #Original [0,120] #貌似ed不用改，蛋mse變超大
    #return img, [x1/120,(y1-y_offset_toe)/120]#normalized [0,1] xy <dtype: 'float64'>, no help.
    #return img, [(x1-60)/60,((y1-y_offset_toe)-60)/60]#normalized [-1,1] , no help.

#
# map list to ds, Heel part.
#

def decode_crop_png_heel(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.io.decode_png(img, channels=3)
    # crop the toe from top-left corner [image, offset_height y1, offset_width x1, target_height, target_width]
    y2=y_offset_heel;    x2=0;    h=img_height;    w=img_width # not the pp location
    img = tf.image.crop_to_bounding_box(img, int(y2), int(x2), h, w)
    #img = tf.image.crop_to_bounding_box(img, int(y1), int(x1), int(y2)-int(y1), int(x2)-int(x1))
    # resize the image to the desired size
    return img

def process_path_heel(file_path,x1,y1,x2,y2):
    file_path = im_p + file_path
    #label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)#can read the byte string paths b'image_0001.png'
    img = decode_crop_png_heel(img)
    return img, [x2,y2-y_offset_heel]#Original [0,120]
    #return img, x2, y2-y_offset_heel #Original [0,120] #貌似ed不用改，蛋mse變超大
    #return img, [x2/120,(y2-y_offset_heel)/120]#normalized [0,1] xy <dtype: 'float64'>, no help.
    #return img, [(x2-60)/60,((y2-y_offset_heel)-60)/60]#normalized [-1,1] , no help.

#
# test how to put parameters to map
#

def t_ds_map(file_path,x1,y1,x2,y2):
#     img = get_img('train/images/' + str(file_path))
#     print(file_path)
    return file_path,x1,y1,x2,y2 #img, [x1,y1]

# %%
# Toe ds
train_ds_map_toe = list_ds.map(process_path_toe, num_parallel_calls=AUTOTUNE)

# Heel ds
train_ds_map_heel = list_ds.map(process_path_heel, num_parallel_calls=AUTOTUNE)

# %%
# for img, xy in train_ds_map_toe.take(1):
#     print(f'take sample: {xy}')
    
# print('f', f.dtype)
# print('xy', xy.dtype)

# for img, x, y in train_ds_map_toe.take(1):
#     print(f'take sample: {x} {y}')
    
# print('img', img.dtype)
# print('x', x.dtype)
# x

for img, [x, y] in train_ds_map_toe.take(1):
    print(f'take sample: {x} {y}')
    
print('f', f.dtype)
print('x', x.dtype)
# Out:
# take sample: 57 47
# f <dtype: 'string'>
# x <dtype: 'int64'>

# %%
x
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=57>

# %%
# for f,x1,y1,x2,y2 in train_ds_map.take(5):
#     print(f'take sample: {f} {x1} {y1} {x2} {y2}')

# %% [markdown]
# #### [new] Split train_ds_pre with ratio of validation %

# %% [markdown]
# [ToDo 20210201] keep orignal validation in 0.1, but augmenting train_ds in input layer or in the tf.ds.

# %% [markdown]
# [2021-02-23] New k-split ds

# %%
# # split Toe
# val_size = int(tf.data.experimental.cardinality(train_ds_map_toe).numpy() * 0.2)
# # val_size = int(tf.data.experimental.cardinality(train_ds_map_toe).numpy() * 0.1)#no help

# train_ds_map_toe_s = train_ds_map_toe.skip(val_size)
# valid_ds_map_toe_s = train_ds_map_toe.take(val_size)

# print(f'whole samples = {len(train_ds_map_toe)}')
# print(f'val_size = {val_size}')

# print('ds_train = ', tf.data.experimental.cardinality(train_ds_map_toe_s).numpy())
# print('ds_valid = ', tf.data.experimental.cardinality(valid_ds_map_toe_s).numpy())

# %%
# # split Heel
# val_size = int(tf.data.experimental.cardinality(train_ds_map_heel).numpy() * 0.2)
# # val_size = int(tf.data.experimental.cardinality(train_ds_map_heel).numpy() * 0.1)


# train_ds_map_heel_s = train_ds_map_heel.skip(val_size)
# valid_ds_map_heel_s = train_ds_map_heel.take(val_size)

# print(len(train_ds_map_heel))
# print(val_size)
# print(tf.data.experimental.cardinality(train_ds_map_heel_s).numpy())
# print(tf.data.experimental.cardinality(valid_ds_map_heel_s).numpy())

# %%
# ## testing cell
# kf = []
# for k in range(5):
#     kf.append(train_ds_map_heel.shard(num_shards=5, index=k))
#     print("k =", k,"num=", tf.data.experimental.cardinality(kf[k]).numpy())

# %%
# kf

# %%
# for img, [x,y] in kf[1].take(1):
#     print(f'take sample: {x} {y}')
    
# print('img', img.dtype)
# print('x', x.dtype)
# print('y', y.dtype)

# %%
# ## testing cell

# range_k_0 = train_ds_map_heel.window(5)

# print(len(range_k_0))
# print(tf.data.experimental.cardinality(range_k_0).numpy())

# %%
# ## testing cell

# def get_train_valid_k_split():
#     x = tf.data.Dataset.range(1000)
#     val_size = int(tf.data.experimental.cardinality(x).numpy() * 0.2)
    
#     for k in range(5):
#         train_num = x.take(val_size + k*val_size)
#         valid_num = x.skip(k*val_size)
        
#         print("k=", k)
#         print(tf.data.experimental.cardinality(train_num).numpy())
#         print(tf.data.experimental.cardinality(valid_num).numpy())
    
    
# get_train_valid_k_split()

# %%
## testing cell

# 
# tf.slice
# tf.data.experimental.choose_from_datasets


# x = list_ds
# val_size = int(tf.data.experimental.cardinality(list_ds).numpy() * 0.2)
x = tf.data.Dataset.range(10)

def check_KFold_ds(x, K=5):
    
    val_size = int(tf.data.experimental.cardinality(x).numpy() * 0.2)
    print("val_size=", val_size)
    
    for k in range(K):
#         k_train = x.take(val_size + k*val_size)
#         k_valid = x.skip(k*val_size)
#         k_train = tf.slice(x, k*val_size, val_size) #only for pure tensors not 
#         k_valid = x.skip(k*val_size)

        # may skip twicce to performe kflod
        t_take = x.take(k*val_size)
        t_skip = x.skip(k*val_size+val_size)
        k_train = t_take.concatenate(t_skip)
        
        v_skip = x.skip(k*val_size)
        k_valid = v_skip.take(val_size)

        print("k =", k,"k*val_size+val_size", k*val_size+val_size, "k_train num=", tf.data.experimental.cardinality(k_train).numpy())


        # x = tf.data.Dataset.range(10)
#         for n in k_train:
#             print(n.numpy())
#         for n in k_valid:
#             print(n.numpy())
        
        # list_ds
#         for img, x1, y1, x2, y2 in k_train:
#             print(x1, y1)

        # train_ds_map_toe
#         for img, (x, y) in k_train:
#             print(x.numpy(), y.numpy())

    
    
    
check_KFold_ds(x)
# check_KFold_ds(list_ds)    
# check_KFold_ds(train_ds_map_toe)
# Out:
# val_size= 2
# k = 0 k*val_size+val_size 2 k_train num= 8
# k = 1 k*val_size+val_size 4 k_train num= 8
# k = 2 k*val_size+val_size 6 k_train num= 8
# k = 3 k*val_size+val_size 8 k_train num= 8
# k = 4 k*val_size+val_size 10 k_train num= 8

# %%
# x = tf.data.Dataset.range(10)
# val_size = int(tf.data.experimental.cardinality(x).numpy() * 0.2)
# print("val_size=", val_size)

def get_KFold_ds(x, K=0):
        
    k = K
    # may skip twicce to perform kflod
    # train ds
    t_take = x.take(k*val_size)
    t_skip = x.skip(k*val_size+val_size)
    k_train = t_take.concatenate(t_skip)
    # val ds
    v_skip = x.skip(k*val_size)
    k_valid = v_skip.take(val_size)

    return k_train, k_valid

# %%
val_size = int(tf.data.experimental.cardinality(train_ds_map_toe).numpy() * 0.2)
t, v = get_KFold_ds(train_ds_map_toe, 1)

print(tf.data.experimental.cardinality(t).numpy())
print(tf.data.experimental.cardinality(v).numpy())

# for n in v:
#     print(n.numpy())
# Out:
# 1076
# 269

# %%
train_ds_map_toe
# Out:
# <ParallelMapDataset shapes: ((120, 120, 3), (2,)), types: (tf.uint8, tf.int64)>

# %%
v
# Out:
# <TakeDataset shapes: ((120, 120, 3), (2,)), types: (tf.uint8, tf.int64)>

# %% [markdown]
# # Albumentation pipeline

# %%
# # for NO keypoint augment
# transforms = A.Compose([
# #             A.RandomBrightness(limit=0.1, p=0.5),
#             A.JpegCompression(quality_lower=65, quality_upper=100, p=0.5),#A.JpegCompression(quality_lower=85, quality_upper=100, p=0.5)
#             A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
# #             A.RandomContrast(limit=0.2, p=0.5),
#             A.FancyPCA(alpha=0.1, always_apply=False, p=1),#A.FancyPCA(alpha=0.1, always_apply=False, p=0.5)
#             A.Downscale(scale_min=0.7, scale_max=0.9, interpolation=0, always_apply=False, p=0.5), #0.8~0.99 may better
#             A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, always_apply=False, p=0.5),
#             A.CLAHE(clip_limit=(1, 8), tile_grid_size=(8, 8), always_apply=False, p=0.5), #A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), always_apply=False, p=0.5)
# #             A.GlassBlur(sigma=0.9, max_delta=2, iterations=2, always_apply=False, mode='fast', p=0.5),
# #             A.GaussNoise(var_limit=(10.0, 50.0), mean=0, always_apply=False, p=0.5),
# #             A.GaussianBlur(blur_limit=(3, 7), sigma_limit=0, always_apply=False, p=0.5),
# #             A.HorizontalFlip(),
    
#             # try other augm, seems to strong...
#             A.RandomBrightnessContrast(always_apply=False, p=0.5, brightness_limit=(-0.2, 0.2), contrast_limit=(-0.2, 0.2), brightness_by_max=True),
#             A.Equalize(always_apply=False, p=0.5, mode='cv', by_channels=True),
#             A.MultiplicativeNoise(always_apply=False, p=0.5, multiplier=(0.8, 1.5), per_channel=False, elementwise=False),
#             A.RandomFog(always_apply=False, p=0.5, fog_coef_lower=0.2, fog_coef_upper=0.3, alpha_coef=0.25),

# ])


# def aug_fn(image, img_size):
#     data = {"image":image}
#     aug_data = transforms(**data)
#     aug_img = aug_data["image"]
# #     aug_img = tf.cast(aug_img/255.0, tf.float32)
#     aug_img = tf.cast(aug_img, tf.float32)
#     aug_img = tf.image.resize(aug_img, size=[img_size, img_size])
#     return aug_img

# def process_data(image, label, img_size):
#     aug_img = tf.numpy_function(func=aug_fn, inp=[image, img_size], Tout=tf.float32)
#     return aug_img, label

# def set_shapes(img, label, img_shape=(120,120,3)):
#     img.set_shape(img_shape)
# #     label.set_shape([]) # commited for go around error
#     return img, label





# # for NO keypoint augment AND for OneOf[] for better heel loss.
# transforms_oneof = A.Compose(A.OneOf([
#             A.RandomBrightness(limit=0.1, p=0.5),
#             A.JpegCompression(quality_lower=85, quality_upper=100, p=0.5),
#             A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
#             A.RandomContrast(limit=0.2, p=0.5),
#             A.FancyPCA(alpha=0.1, always_apply=False, p=0.5),
#             A.Downscale(scale_min=0.7, scale_max=0.9, interpolation=0, always_apply=False, p=0.5),
#             A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, always_apply=False, p=0.5),
#             A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), always_apply=False, p=0.5),
#             A.GlassBlur(sigma=0.9, max_delta=2, iterations=2, always_apply=False, mode='fast', p=0.5),
#             A.GaussNoise(var_limit=(10.0, 50.0), mean=0, always_apply=False, p=0.5),
#             A.GaussianBlur(blur_limit=(3, 7), sigma_limit=0, always_apply=False, p=.5)
# #             A.HorizontalFlip(),
#             ]),p=0.5)


# def aug_fn_oneof(image, img_size):
#     data = {"image":image}
#     aug_data = transforms_oneof(**data)
#     aug_img = aug_data["image"]
# #     aug_img = tf.cast(aug_img/255.0, tf.float32)
#     aug_img = tf.cast(aug_img, tf.float32)
#     aug_img = tf.image.resize(aug_img, size=[img_size, img_size])
#     return aug_img

# def process_data_oneof(image, label, img_size):
#     aug_img = tf.numpy_function(func=aug_fn_oneof, inp=[image, img_size], Tout=tf.float32)
#     return aug_img, label




# # Testing keypoints augment
# transforms = A.Compose([
#             A.RandomBrightness(limit=0.1, p=0.5),
#             A.JpegCompression(quality_lower=85, quality_upper=100, p=0.5),
#             A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
#             A.RandomContrast(limit=0.2, p=0.5),
#             A.FancyPCA (alpha=0.1, always_apply=False, p=1),
#             A.Downscale (scale_min=0.7, scale_max=0.9, interpolation=0, always_apply=False, p=0.5),
#             A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, always_apply=False, p=0.5),
#             A.CLAHE (clip_limit=4.0, tile_grid_size=(8, 8), always_apply=False, p=0.5),
#             A.HorizontalFlip(p=0.5),
#             ]
#             , 
#             keypoint_params=A.KeypointParams(format='xy'),  #currently not works for tf.ds yet.
#             )





# Testing keypoints augment
transforms = A.Compose([
            A.RandomBrightness(limit=0.1, p=0.5),
            A.JpegCompression(quality_lower=85, quality_upper=100, p=0.5),
            A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
            A.RandomContrast(limit=0.2, p=0.5),
            A.FancyPCA(alpha=0.1, always_apply=False, p=0.5),
            A.Downscale(scale_min=0.7, scale_max=0.9, interpolation=0, always_apply=False, p=0.5),
            A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, always_apply=False, p=0.5),
            A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), always_apply=False, p=0.5),
    
            A.HorizontalFlip(p=0.5),
            A.RandomResizedCrop(always_apply=False, height=120, width=120, scale=(0.9, 0.99), ratio=(1.0, 1.0), interpolation=0, p=0.5),#xy become double need change dtype of label. # pp will outside the image.
            A.IAAAffine(scale=0.9, translate_percent=None, translate_px=None, rotate=0.0, shear=0.0, order=1, cval=0, mode='reflect', always_apply=False, p=0.5),
#             A.ShiftScaleRotate(always_apply=False, p=0.5, shift_limit=(0.06, 0.06), scale_limit=(-0.1, 0.1), rotate_limit=(-5, 5), interpolation=1, border_mode=2, value=(0, 0, 0), mask_value=None),
    #2021-02-26
#             A.IAAPerspective(scale=(0.05, 0.1), keep_size=True, always_apply=False, p=0.5),#fallout image make train stop. NOT support keypoints!!!!!
            ]
            , 
            keypoint_params=A.KeypointParams(format='xy',remove_invisible=True),  #currently not works for tf.ds yet.
            )

# Testing keypoints augment
# @tf.function
def aug_fn(image, keypoints, img_size):
#     print('Check keypoints aug_fun 00:', keypoints) # Check keypoints aug_fun 00: [[53 58]]
#     data = {"image":image}
    aug_data = transforms(image=image, keypoints=keypoints)
    aug_img = aug_data["image"]
    aug_xy  = aug_data["keypoints"]
#     aug_img = tf.cast(aug_img/255.0, tf.float32)
    aug_img = tf.cast(aug_img, tf.float32)
    aug_img = tf.image.resize(aug_img, size=[img_size, img_size])
    
    aug_xy = tf.cast(aug_xy, tf.float32) #有些變形輸出是double
#     print('Check aug_xy:', aug_xy) # Check aug_xy: [(95, 45)] #印到這邊都是對的
    return aug_img, aug_xy 

# @tf.function
def process_data(image, keypoints, img_size):
    
    print('Check keypoints process01:', keypoints, np.shape(keypoints), type(keypoints))
        
#     keypoints = tf.make_ndarray(keypoints)
#     keypoints = np.array(keypoints)
#     keypoints = list(keypoints)
#     keypoints = np.asarray(keypoints, dtype=np.float32)
#     keypoints = tf.make_ndarray(keypoints.op.get_attr('value'))

#     keypoints = tf.reshape(keypoints, [1, 2])
    keypoints = tf.reshape(keypoints, [1, 2]) # for 'convert_keypoint_to_albumentations'
#     keypoints = np.reshape(keypoints, (1, 2))#not support tensor with np.call.

    print('Check keypoints process02:', keypoints, np.shape(keypoints), type(keypoints))

#     aug_img, aug_xy = tf.numpy_function(func=aug_fn, inp=[image, img_size], Tout=tf.float32)
#     aug_img, aug_xy = tf.py_function(func=aug_fn, inp=[image, keypoints, img_size], Tout=[tf.float32, tf.int64])#for tensors.
    aug_img, aug_xy = tf.numpy_function(func=aug_fn, inp=[image, keypoints, img_size], Tout=[tf.float32, tf.float32])
    print('Check keypoints process03:', aug_xy)
    
    aug_xy = tf.reshape(aug_xy, [2,]) # for 'tf ds tarining'
    print('Check keypoints process04:', aug_xy)
        
    return aug_img, aug_xy 








###  for AToe ###
# some pp will outside of image bcs p2 is close to 400.



# Testing keypoints augment
transforms_AToe = A.Compose([
#             A.RandomBrightness(limit=0.1, p=0.5),
#             A.JpegCompression(quality_lower=85, quality_upper=100, p=0.5),
#             A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
#             A.RandomContrast(limit=0.2, p=0.5),
#             A.FancyPCA(alpha=0.1, always_apply=False, p=0.5),
#             A.Downscale(scale_min=0.7, scale_max=0.9, interpolation=0, always_apply=False, p=0.5),
#             A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, always_apply=False, p=0.5),
#             A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), always_apply=False, p=0.5),
    
#             A.RandomBrightness(limit=0.1, p=0.5),
            A.JpegCompression(quality_lower=65, quality_upper=100, p=0.5),#A.JpegCompression(quality_lower=85, quality_upper=100, p=0.5)
            A.HueSaturationValue(hue_shift_limit=20, sat_shift_limit=30, val_shift_limit=20, p=0.5),
#             A.RandomContrast(limit=0.2, p=0.5),
            A.FancyPCA(alpha=0.1, always_apply=False, p=1),#A.FancyPCA(alpha=0.1, always_apply=False, p=0.5)
            A.Downscale(scale_min=0.7, scale_max=0.9, interpolation=0, always_apply=False, p=0.5), #0.8~0.99 may better
            A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, always_apply=False, p=0.5),
            A.CLAHE(clip_limit=(1, 8), tile_grid_size=(8, 8), always_apply=False, p=0.5), #A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), always_apply=False, p=0.5)
    
            A.HorizontalFlip(p=0.5),
#             A.RandomResizedCrop(always_apply=False, height=120, width=120, scale=(0.75, 0.9), ratio=(1.0, 1.0), interpolation=0, p=0.5),#xy become double need change dtype of label. # pp will outside the image.
            A.IAAAffine (scale=0.9, translate_percent=None, translate_px=None, rotate=0.0, shear=0.0, order=1, cval=0, mode='reflect', always_apply=False, p=0.5),
#             A.ShiftScaleRotate(always_apply=False, p=0.5, shift_limit=(0.06, 0.06), scale_limit=(-0.1, 0.1), rotate_limit=(-5, 5), interpolation=1, border_mode=2, value=(0, 0, 0), mask_value=None),
            ]
            , 
            keypoint_params=A.KeypointParams(format='xy',remove_invisible=True),  #currently not works for tf.ds yet.
            )


# Testing keypoints augment
# @tf.function
def aug_fn_AToe(image, keypoints, img_size):
#     print('Check keypoints aug_fun 00:', keypoints) # Check keypoints aug_fun 00: [[53 58]]
#     data = {"image":image}
    aug_data = transforms_AToe(image=image, keypoints=keypoints)
    aug_img = aug_data["image"]
    aug_xy  = aug_data["keypoints"]
#     aug_img = tf.cast(aug_img/255.0, tf.float32)
    aug_img = tf.cast(aug_img, tf.float32)
    aug_img = tf.image.resize(aug_img, size=[img_size, img_size])
    
    aug_xy = tf.cast(aug_xy, tf.float32) #有些變形輸出是double
#     print('Check aug_xy:', aug_xy) # Check aug_xy: [(95, 45)] #印到這邊都是對的
    return aug_img, aug_xy 

# @tf.function
def process_data_AToe(image, keypoints, img_size):
    
    print('Check keypoints process01:', keypoints, np.shape(keypoints), type(keypoints))
        
#     keypoints = tf.make_ndarray(keypoints)
#     keypoints = np.array(keypoints)
#     keypoints = list(keypoints)
#     keypoints = np.asarray(keypoints, dtype=np.float32)
#     keypoints = tf.make_ndarray(keypoints.op.get_attr('value'))

#     keypoints = tf.reshape(keypoints, [1, 2])
    keypoints = tf.reshape(keypoints, [1, 2]) # for 'convert_keypoint_to_albumentations'
#     keypoints = np.reshape(keypoints, (1, 2))#not support tensor with np.call.

    print('Check keypoints process02:', keypoints, np.shape(keypoints), type(keypoints))

#     aug_img, aug_xy = tf.numpy_function(func=aug_fn, inp=[image, img_size], Tout=tf.float32)
#     aug_img, aug_xy = tf.py_function(func=aug_fn, inp=[image, keypoints, img_size], Tout=[tf.float32, tf.int64])#for tensors.
    aug_img, aug_xy = tf.numpy_function(func=aug_fn_AToe, inp=[image, keypoints, img_size], Tout=[tf.float32, tf.float32])
    print('Check keypoints process03:', aug_xy)
    
    aug_xy = tf.reshape(aug_xy, [2,]) # for 'tf ds tarining'
    print('Check keypoints process04:', aug_xy)
        
    return aug_img, aug_xy 




def set_shapes(img, label, img_shape=(120,120,3)):
    img.set_shape(img_shape)
#     label.set_shape([]) # commited for go around error
    return img, label

# %% [markdown]
# #### prepare train_ds_prefetch

# %%
def configure_for_performance_cache_train(ds, cache=True, augment=False):

    
    """#TODO: need to check the parse logic of ds.cache.
    if cache:
        print("Check cache-f1 to file:", cache)
        if isinstance(cache, str):
            ds = ds.cache(cache)
            print("Check cache-f2 to file:", cache)
    else:
        ds = ds.cache()
        print("Check cache in memory:", cache)
    """    
    if cache:
        ds = ds.cache()
        print("Check cache in memory:Y", cache)
    else:
        print("Check cache in memory:N", cache)
        
    if augment:
        ds = ds.map(partial(process_data, img_size=120),num_parallel_calls=AUTOTUNE)
        ds = ds.map(set_shapes, num_parallel_calls=AUTOTUNE)
        print("Check augment :Y", augment)
    else:
        print("Check augment :N", augment)
    
    #ds = ds.repeat()#TODO:2020-12-14: test
    #ds = ds.shuffle(buffer_size=MULTI_BATCH_SIZE*2) # (buffer_size=MULTI_BATCH_SIZE*5) 6sec,buffer_size=1000 take few sec. or buffer_size=image_count <- take too long # each take ds take 30~45 sec, TODO!!
    ds = ds.shuffle(len(list_ds), reshuffle_each_iteration=True) #todo: move to ds_pre. see https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle
    ds = ds.batch(MULTI_BATCH_SIZE)#MULTI_BATCH_SIZE for multi-GPUs
    ds = ds.prefetch(buffer_size=AUTOTUNE) #buffer_size=AUTOTUNE seem no speed improve
    
    print("Check ds cache[{}] and augment[{}]".format(cache, augment))
    
    return ds


def configure_for_performance_cache_train_AToe(ds, cache=True, augment=False):

    
    """#TODO: need to check the parse logic of ds.cache.
    if cache:
        print("Check cache-f1 to file:", cache)
        if isinstance(cache, str):
            ds = ds.cache(cache)
            print("Check cache-f2 to file:", cache)
    else:
        ds = ds.cache()
        print("Check cache in memory:", cache)
    """    
    if cache:
        ds = ds.cache()
        print("Check cache in memory:Y", cache)
    else:
        print("Check cache in memory:N", cache)
        
    if augment:
        ds = ds.map(partial(process_data_AToe, img_size=120),num_parallel_calls=AUTOTUNE)
        ds = ds.map(set_shapes, num_parallel_calls=AUTOTUNE)
        print("Check augment :Y", augment)
    else:
        print("Check augment :N", augment)
    
    #ds = ds.repeat()#TODO:2020-12-14: test
    #ds = ds.shuffle(buffer_size=MULTI_BATCH_SIZE*2) # (buffer_size=MULTI_BATCH_SIZE*5) 6sec,buffer_size=1000 take few sec. or buffer_size=image_count <- take too long # each take ds take 30~45 sec, TODO!!
    ds = ds.shuffle(len(list_ds), reshuffle_each_iteration=True) #todo: move to ds_pre. see https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle
    ds = ds.batch(MULTI_BATCH_SIZE)#MULTI_BATCH_SIZE for multi-GPUs
    ds = ds.prefetch(buffer_size=AUTOTUNE) #buffer_size=AUTOTUNE seem no speed improve
    
    print("Check ds cache[{}] and augment[{}]".format(cache, augment))
    
    return ds





# def configure_for_performance_cache_train_oneof(ds, cache=True, augment=False):

    
#     """#TODO: need to check the parse logic of ds.cache.
#     if cache:
#         print("Check cache-f1 to file:", cache)
#         if isinstance(cache, str):
#             ds = ds.cache(cache)
#             print("Check cache-f2 to file:", cache)
#     else:
#         ds = ds.cache()
#         print("Check cache in memory:", cache)
#     """    
#     if cache:
#         ds = ds.cache()
#         print("Check cache in memory:Y", cache)
#     else:
#         print("Check cache in memory:N", cache)
        
#     if augment:
#         ds = ds.map(partial(process_data_oneof, img_size=120),num_parallel_calls=AUTOTUNE)
#         ds = ds.map(set_shapes, num_parallel_calls=AUTOTUNE)
#         print("Check augment :Y", augment)
#     else:
#         print("Check augment :N", augment)
    
#     #ds = ds.repeat()#TODO:2020-12-14: test
#     #ds = ds.shuffle(buffer_size=MULTI_BATCH_SIZE*2) # (buffer_size=MULTI_BATCH_SIZE*5) 6sec,buffer_size=1000 take few sec. or buffer_size=image_count <- take too long # each take ds take 30~45 sec, TODO!!
#     ds = ds.shuffle(len(list_ds), reshuffle_each_iteration=True) #todo: move to ds_pre. see https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle
#     ds = ds.batch(MULTI_BATCH_SIZE)#MULTI_BATCH_SIZE for multi-GPUs
#     ds = ds.prefetch(buffer_size=AUTOTUNE) #buffer_size=AUTOTUNE seem no speed improve
    
#     print("Check ds cache[{}] and augment[{}]".format(cache, augment))
    
#     return ds




def configure_for_performance_cache_val(ds, cache=True, augment=False):

    
    """#TODO: need to check the parse logic of ds.cache
    TODO:test remove ds.shuffle from val_ds.
    .
    if cache:
        print("Check cache-f1 to file:", cache)
        if isinstance(cache, str):
            ds = ds.cache(cache)
            print("Check cache-f2 to file:", cache)
    else:
        ds = ds.cache()
        print("Check cache in memory:", cache)
    """    
    if cache:
        ds = ds.cache()
        print("Check cache in memory:Y", cache)
    else:
        print("Check cache in memory:N", cache)
        
    if augment:
#         ds = ds.map(data_augment, num_parallel_calls=AUTOTUNE)
        ds = ds.map(AA, num_parallel_calls=AUTOTUNE)
#         ds = ds.map(RA, num_parallel_calls=AUTOTUNE)
        print("Check augment :Y", augment)
    else:
        print("Check augment :N", augment)
    
    #ds = ds.repeat()#TODO:2020-12-14: test
    #ds = ds.shuffle(buffer_size=MULTI_BATCH_SIZE*2) # (buffer_size=MULTI_BATCH_SIZE*5) 6sec,buffer_size=1000 take few sec. or buffer_size=image_count <- take too long # each take ds take 30~45 sec, TODO!!
#     ds = ds.shuffle(len(list_ds), reshuffle_each_iteration=False) #todo: move to ds_pre. see https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle
    ds = ds.batch(MULTI_BATCH_SIZE)#MULTI_BATCH_SIZE for multi-GPUs
    ds = ds.prefetch(buffer_size=AUTOTUNE) #buffer_size=AUTOTUNE seem no speed improve
    
    print("Check ds cache[{}] and augment[{}]".format(cache, augment))
    
    return ds

# %%
# """
# Prepare the ds properties (cache, augment, bs, shuffle, prefetch, etc.) for better performance.
# """
# # Toe ds_pre
# train_ds_pre_toe = configure_for_performance_cache_train(train_ds_map_toe)

# # Heel ds_pre
# train_ds_pre_heel = configure_for_performance_cache_val(train_ds_map_heel)

# %% [markdown]
# #### All split ds_prefetch
# * train_ds_map_toe_s = train_ds_map_toe.skip(val_size)
# * valid_ds_map_toe_s = train_ds_map_toe.take(val_size)
#
# * train_ds_map_heel_s = train_ds_map_heel.skip(val_size)
# * valid_ds_map_heel_s = train_ds_map_heel.take(val_size)

# %%
# """
# Prepare the ds properties (cache, augment, bs, shuffle, prefetch, etc.) for better performance.
# """
# # Toe ds_pre
# train_ds_pre_toe_s = configure_for_performance_cache_train(train_ds_map_toe_s, augment=True)
# valid_ds_pre_toe_s = configure_for_performance_cache_val(valid_ds_map_toe_s)

# # Heel ds_pre
# train_ds_pre_heel_s = configure_for_performance_cache_train(train_ds_map_heel_s, augment=True)
# valid_ds_pre_heel_s = configure_for_performance_cache_val(valid_ds_map_heel_s)

# %% [markdown]
# #### Check ds_prefetch samples

# %%
# # create it_ds once
# it_train_ds_pre_toe_s = iter(train_ds_pre_toe_s)

# %%
# %%time

# # for albu keypoint

# # for original return aug_img, , aug_xy 


# image_batch, label_batch = next(it_train_ds_pre_toe_s)

# fig = plt.figure(figsize=(8, 8))
# print('batch * multi:', len(label_batch), ', MULTI_BATCH_SIZE=', MULTI_BATCH_SIZE)
# for i in range(16):
#     ax = plt.subplot(4, 4, i + 1)
#     plt.imshow(image_batch[i].numpy().astype("uint8"))
#     plt.title(label_batch[i].numpy())
#     plt.axis("off")

#     plt.plot(label_batch[i].numpy()[0], label_batch[i].numpy()[1], 'r+', markersize=13, mew=2.5)

#     print(f'Check lables: {label_batch[i]}')

# %%
# # create it_ds once
# it_train_ds_pre_heel_s = iter(train_ds_pre_heel_s)

# %%
# %%time

# # for albu keypoint

# # for original return aug_img, , aug_xy 


# image_batch, label_batch = next(it_train_ds_pre_heel_s)

# fig = plt.figure(figsize=(8, 8))
# print('batch * multi:', len(label_batch), ', MULTI_BATCH_SIZE=', MULTI_BATCH_SIZE)
# for i in range(16):
#     ax = plt.subplot(4, 4, i + 1)
#     plt.imshow(image_batch[i].numpy().astype("uint8"))
#     plt.title(label_batch[i].numpy())
#     plt.axis("off")

#     plt.plot(label_batch[i].numpy()[0], label_batch[i].numpy()[1], 'r+', markersize=13, mew=2.5)

#     print(f'Check lables: {label_batch[i]}')

# %%
# # create it_ds once
# it_valid_ds_pre_toe_s = iter(valid_ds_pre_toe_s)

# %%
# %%time

# # for albu keypoint

# # for return aug_img, aug_xy 


# image_batch, label_batch = next(it_valid_ds_pre_toe_s)

# plt.figure(figsize=(8, 8))
# # for images, labels in valid_ds_pre_toe_s.take(1):
# print('batch * multi:', len(label_batch), ', MULTI_BATCH_SIZE=', MULTI_BATCH_SIZE)
# for i in range(16):
#     ax = plt.subplot(4, 4, i + 1)
#     plt.imshow(image_batch[i].numpy().astype("uint8"))
#     plt.title(label_batch[i].numpy())
#     plt.axis("off")

#     plt.plot(label_batch[i].numpy()[0], label_batch[i].numpy()[1], 'r+', markersize=13, mew=2.5)

#     print(f'Check lables: {label_batch[i]}')

# %% [markdown]
# ### 3.Loss function
#
# * mae
# * euclidean distance
# * others
#
#
#         # 'x' is [[1, 1, 1]
#         #         [1, 1, 1]]
#         tf.reduce_sum(x) ==> 6
#         tf.reduce_sum(x, 0) ==> [2, 2, 2]
#         tf.reduce_sum(x, 1) ==> [3, 3]
#         the function is default for 2-D array, therefor, in our 1-D [x1,y1] to [x2,y2] the axis should be '0' or just leave it.
#
#         tf.sqrt need 	A tf.Tensor of type bfloat16, half, float32, float64, complex64, complex128
#         so, convert it first.

# %% [markdown]
# should be -> tf.Tensor([56 39], shape=(2,), dtype=int64)

# %%
y_true = [10, 10]
y_pred = [10, 20]

# y_true = [1.00000000000000000000123, 10]
# y_pred = [1.0, 10.000000000000000000000000001]

# y_true = [1.0000123, 10]
# y_pred = [1.0, 10.0000321]

# %%
# mae

loss_mae = tf.keras.losses.MAE(
    y_true, y_pred
)

loss_mae
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=5>

# %%
# ed

# loss_ed = tf.sqrt(tf.reduce_sum(tf.square(tf.constant(y_true) - tf.constant(y_pred)), 0))

# loss_ed = tf.sqrt(tf.reduce_sum(tf.square(tf.Variable(y_true) - tf.Variable(y_pred)), 0))

loss_ed = tf.sqrt(tf.reduce_sum(tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32)), 0))

loss_ed
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=10.0>

# %%
def ed_loss(y_true, y_pred):
    return tf.sqrt(tf.reduce_sum(tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32)), 0))

# fix NaN in euclidean distance
# tf.maximum(d, 1e-9), to keep atlease is 1e-9.
# def ed_loss(y_true, y_pred):
#     return tf.sqrt(tf.maximum(tf.reduce_sum(tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32)), 0), 1e-9))

# %%
# check the euclidean distance loss
ed_loss(y_true, y_pred).numpy()
# Out:
# 10.0

# %%
ed_loss(y_true, y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=10.0>

# %% [markdown]
# #### mean Euclidean distance
#
# * here the y_true and y_pred is 2-D array. the axis use 1.
#
#
# * NOTE: LB評分的mean euclidean distance功能，應該跟model.evaluate()一樣so不需重新寫。evaluate()會自動用loss (model.metrics_names)計算後在自動平均，而模型loss我們是用ed-loss取代。

# %%
# y_true = [[60, 76],
#        [58, 49 ],
#        [63, 67 ],
#        [58 , 57]]
# y_pred = [[59.927303, 76.471214],
#        [58.056904, 49.98754 ],
#        [63.067844, 67.03861 ],
#        [58.70202 , 57.372707]]

y_true = [[60, 70],
       [70, 80]]
y_pred = [[61, 71],
       [72, 82]]

# y_true = [(60, 70),
#        (70, 80)]
# y_pred = [(61, 71),
#        (72, 82)]

# %%
tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32))
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[1., 1.],
#        [4., 4.]], dtype=float32)>

# %%
tf.reduce_sum(tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32)), 1)
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([2., 8.], dtype=float32)>

# %%
def ed_metric_2d(y_true, y_pred):
    return tf.sqrt(tf.reduce_sum(tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32)), 1))

# %%
ed_metric_2d(y_true, y_pred).numpy()
# Out:
# array([1.4142135, 2.828427 ], dtype=float32)

# %%
ed_metric_2d(y_true, y_pred)
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([1.4142135, 2.828427 ], dtype=float32)>

# %%
# 等於true, pred點位ed的平均，LB評分方式。(toe/heel即p1,p2要個別算ed一次再相加)
def ed_metric_2d_mean(y_true, y_pred):
    return tf.reduce_mean(tf.sqrt(tf.reduce_sum(tf.square(tf.cast(y_true, tf.float32) - tf.cast(y_pred, tf.float32)), 1)))

# %%
# for re-scale back xy 
# return img, [(x1-60)/60,((y1-y_offset_toe)-60)/60]#normalized [-1,1] 
# return img, [(x2-60)/60,((y2-y_offset_toe)-60)/60]#normalized [-1,1] 

# 等於true, pred點位ed的平均，LB評分方式。(toe/heel即p1,p2要個別算ed一次再相加)
def edRescal(y_true, y_pred):
    return tf.reduce_mean(tf.sqrt(tf.reduce_sum(tf.square(tf.cast((y_true*60)+60, tf.float32) - tf.cast((y_pred*60)+60, tf.float32)), 1)))

# %%
ed_metric_2d_mean(y_true, y_pred).numpy()
# Out:
# 2.1213202

# %%
ed_metric_2d_mean(y_true, y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=2.1213202>

# %% [markdown]
# # EFNE Training

# %% [markdown]
# maybe mae better than ed loss?

# %%
"""dump lr
"""
ep_num_transf = 500



def lrdump(epoch):
    
    #step_size = 100
    lr_max = 0.006
    lr_min = 0.001
    lr_start = 0.01

    lr_init_ep = 0
    lr_ramp_ep = 100
    lr_sus_ep  = 0
    lr_decay   = 0.8

    
    # warm up
    if epoch < lr_init_ep:
        lr = (lr_max - lr_min) / lr_ramp_ep * epoch + lr_min    
        
    elif lr_init_ep -1 < epoch < lr_ramp_ep:
        lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start

    elif epoch < lr_ramp_ep + lr_sus_ep:
        lr = lr_max

    else:
        lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min

    return lr

rng = [i for i in range(ep_num_transf)]
y = [lrdump(x) for x in rng]
sns.set(style='darkgrid')
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)

# %%
print('{} ~ {}'.format(min(y), max(y)))
# Out:
# 0.001 ~ 0.01

# %%
for e, lr in zip(rng,y):
    print('{}\t {}\n'.format(e, lr))
# Out:
# 0	 0.01
#
# 1	 0.00996
#
# 2	 0.00992
#
# 3	 0.00988
#
# 4	 0.00984
#
# 5	 0.0098
#
# 6	 0.00976
#
# 7	 0.00972
#
# 8	 0.00968
#
# 9	 0.009640000000000001
#
# 10	 0.009600000000000001
#
# 11	 0.00956
#
# 12	 0.00952
#
# 13	 0.00948
#
# 14	 0.00944
#
# 15	 0.0094
#
# 16	 0.00936
#
# 17	 0.00932
#
# 18	 0.00928
#
# 19	 0.00924
#
# 20	 0.0092
#
# 21	 0.00916
#
# 22	 0.00912
#
# 23	 0.00908
#
# 24	 0.00904
#
# 25	 0.009000000000000001
#
# 26	 0.00896
#
# 27	 0.00892
#
# 28	 0.00888
#
# 29	 0.00884
#
# 30	 0.0088
#
# 31	 0.00876
#
# 32	 0.00872
#
# 33	 0.00868
#
# 34	 0.00864
#
# 35	 0.0086
#
# 36	 0.00856
#
# 37	 0.00852
#
# 38	 0.00848
#
# 39	 0.00844
#
# 40	 0.0084
#
# 41	 0.00836
#
# 42	 0.008320000000000001
#
# 43	 0.00828
#
# 44	 0.00824
#
# 45	 0.0082
#
# 46	 0.00816
#
# 47	 0.00812
#
# 48	 0.00808
#
# 49	 0.00804
#
# 50	 0.008
#
# 51	 0.00796
#
# 52	 0.00792
#
# 53	 0.00788
#
# 54	 0.00784
#
# 55	 0.0078
#
# 56	 0.0077599999999999995
#
# 57	 0.007719999999999999
#
# 58	 0.00768
#
# 59	 0.00764
#
# 60	 0.0076
#
# 61	 0.00756
#
# 62	 0.007520000000000001
#
# 63	 0.0074800000000000005
#
# 64	 0.00744
#
# 65	 0.0074
#
# 66	 0.00736
#
# 67	 0.00732
#
# 68	 0.00728
#
# 69	 0.00724
#
# 70	 0.0072
#
# 71	 0.00716
#
# 72	 0.00712
#
# 73	 0.0070799999999999995
#
# 74	 0.007039999999999999
#
# 75	 0.007
#
# 76	 0.00696
#
# 77	 0.00692
#
# 78	 0.00688
#
# 79	 0.006840000000000001
#
# 80	 0.0068000000000000005
#
# 81	 0.00676
#
# 82	 0.00672
#
# 83	 0.00668
#
# 84	 0.00664
#
# 85	 0.0066
#
# 86	 0.00656
#
# 87	 0.00652
#
# 88	 0.00648
#
# 89	 0.0064399999999999995
#
# 90	 0.0063999999999999994
#
# 91	 0.006359999999999999
#
# 92	 0.00632
#
# 93	 0.00628
#
# 94	 0.00624
#
# 95	 0.0062
#
# 96	 0.00616
#
# 97	 0.0061200000000000004
#
# 98	 0.0060799999999999995
#
# 99	 0.00604
#
# 100	 0.006
#
# 101	 0.005
#
# 102	 0.004200000000000001
#
# 103	 0.0035600000000000007
#
# 104	 0.0030480000000000004
#
# 105	 0.0026384000000000004
#
# 106	 0.0023107200000000005
#
# 107	 0.0020485760000000007
#
# 108	 0.0018388608000000006
#
# 109	 0.0016710886400000003
#
# 110	 0.0015368709120000003
#
# 111	 0.0014294967296000004
#
# 112	 0.0013435973836800003
#
# 113	 0.0012748779069440002
#
# 114	 0.0012199023255552001
#
# 115	 0.0011759218604441603
#
# 116	 0.0011407374883553281
#
# 117	 0.0011125899906842625
#
# 118	 0.0010900719925474101
#
# 119	 0.001072057594037928
#
# 120	 0.0010576460752303425
#
# 121	 0.001046116860184274
#
# 122	 0.001036893488147419
#
# 123	 0.0010295147905179354
#
# 124	 0.0010236118324143482
#
# 125	 0.0010188894659314785
#
# 126	 0.0010151115727451828
#
# 127	 0.0010120892581961464
#
# 128	 0.001009671406556917
#
# 129	 0.0010077371252455336
#
# 130	 0.0010061897001964269
#
# 131	 0.0010049517601571415
#
# 132	 0.0010039614081257132
#
# 133	 0.0010031691265005706
#
# 134	 0.0010025353012004564
#
# 135	 0.0010020282409603652
#
# 136	 0.001001622592768292
#
# 137	 0.0010012980742146336
#
# 138	 0.001001038459371707
#
# 139	 0.0010008307674973657
#
# 140	 0.0010006646139978925
#
# 141	 0.001000531691198314
#
# 142	 0.0010004253529586511
#
# 143	 0.001000340282366921
#
# 144	 0.0010002722258935367
#
# 145	 0.0010002177807148294
#
# 146	 0.0010001742245718634
#
# 147	 0.001000139379657491
#
# 148	 0.0010001115037259927
#
# 149	 0.001000089202980794
#
# 150	 0.0010000713623846353
#
# 151	 0.0010000570899077082
#
# 152	 0.0010000456719261666
#
# 153	 0.0010000365375409334
#
# 154	 0.0010000292300327467
#
# 155	 0.0010000233840261974
#
# 156	 0.0010000187072209579
#
# 157	 0.0010000149657767663
#
# 158	 0.001000011972621413
#
# 159	 0.0010000095780971303
#
# 160	 0.0010000076624777044
#
# 161	 0.0010000061299821634
#
# 162	 0.0010000049039857308
#
# 163	 0.0010000039231885846
#
# 164	 0.0010000031385508678
#
# 165	 0.0010000025108406942
#
# 166	 0.0010000020086725553
#
# 167	 0.0010000016069380442
#
# 168	 0.0010000012855504354
#
# 169	 0.0010000010284403483
#
# 170	 0.0010000008227522787
#
# 171	 0.001000000658201823
#
# 172	 0.0010000005265614583
#
# 173	 0.0010000004212491666
#
# 174	 0.0010000003369993334
#
# 175	 0.0010000002695994667
#
# 176	 0.0010000002156795734
#
# 177	 0.0010000001725436586
#
# 178	 0.001000000138034927
#
# 179	 0.0010000001104279416
#
# 180	 0.0010000000883423532
#
# 181	 0.0010000000706738826
#
# 182	 0.001000000056539106
#
# 183	 0.0010000000452312849
#
# 184	 0.0010000000361850279
#
# 185	 0.0010000000289480224
#
# 186	 0.001000000023158418
#
# 187	 0.0010000000185267342
#
# 188	 0.0010000000148213874
#
# 189	 0.00100000001185711
#
# 190	 0.0010000000094856879
#
# 191	 0.0010000000075885505
#
# 192	 0.0010000000060708402
#
# 193	 0.0010000000048566722
#
# 194	 0.0010000000038853378
#
# 195	 0.0010000000031082702
#
# 196	 0.0010000000024866162
#
# 197	 0.0010000000019892929
#
# 198	 0.0010000000015914345
#
# 199	 0.0010000000012731474
#
# 200	 0.001000000001018518
#
# 201	 0.0010000000008148144
#
# 202	 0.0010000000006518516
#
# 203	 0.0010000000005214813
#
# 204	 0.001000000000417185
#
# 205	 0.001000000000333748
#
# 206	 0.0010000000002669985
#
# 207	 0.0010000000002135987
#
# 208	 0.001000000000170879
#
# 209	 0.0010000000001367032
#
# 210	 0.0010000000001093626
#
# 211	 0.0010000000000874901
#
# 212	 0.001000000000069992
#
# 213	 0.0010000000000559936
#
# 214	 0.001000000000044795
#
# 215	 0.001000000000035836
#
# 216	 0.0010000000000286687
#
# 217	 0.001000000000022935
#
# 218	 0.001000000000018348
#
# 219	 0.0010000000000146784
#
# 220	 0.0010000000000117428
#
# 221	 0.0010000000000093942
#
# 222	 0.0010000000000075153
#
# 223	 0.0010000000000060124
#
# 224	 0.0010000000000048098
#
# 225	 0.0010000000000038479
#
# 226	 0.0010000000000030783
#
# 227	 0.0010000000000024627
#
# 228	 0.00100000000000197
#
# 229	 0.001000000000001576
#
# 230	 0.001000000000001261
#
# 231	 0.0010000000000010088
#
# 232	 0.0010000000000008069
#
# 233	 0.0010000000000006456
#
# 234	 0.0010000000000005165
#
# 235	 0.001000000000000413
#
# 236	 0.0010000000000003305
#
# 237	 0.0010000000000002643
#
# 238	 0.0010000000000002117
#
# 239	 0.0010000000000001692
#
# 240	 0.0010000000000001353
#
# 241	 0.0010000000000001082
#
# 242	 0.0010000000000000868
#
# 243	 0.0010000000000000694
#
# 244	 0.0010000000000000555
#
# 245	 0.0010000000000000445
#
# 246	 0.0010000000000000356
#
# 247	 0.0010000000000000284
#
# 248	 0.0010000000000000228
#
# 249	 0.0010000000000000182
#
# 250	 0.0010000000000000145
#
# 251	 0.0010000000000000117
#
# 252	 0.0010000000000000093
#
# 253	 0.0010000000000000074
#
# 254	 0.0010000000000000059
#
# 255	 0.0010000000000000048
#
# 256	 0.001000000000000004
#
# 257	 0.001000000000000003
#
# 258	 0.0010000000000000024
#
# 259	 0.001000000000000002
#
# 260	 0.0010000000000000015
#
# 261	 0.0010000000000000013
#
# 262	 0.001000000000000001
#
# 263	 0.0010000000000000009
#
# 264	 0.0010000000000000007
#
# 265	 0.0010000000000000005
#
# 266	 0.0010000000000000005
#
# 267	 0.0010000000000000005
#
# 268	 0.0010000000000000002
#
# 269	 0.0010000000000000002
#
# 270	 0.0010000000000000002
#
# 271	 0.0010000000000000002
#
# 272	 0.001
#
# 273	 0.001
#
# 274	 0.001
#
# 275	 0.001
#
# 276	 0.001
#
# 277	 0.001
#
# 278	 0.001
#
# 279	 0.001
#
# 280	 0.001
#
# 281	 0.001
#
# 282	 0.001
#
# 283	 0.001
#
# 284	 0.001
#
# 285	 0.001
#
# 286	 0.001
#
# 287	 0.001
#
# 288	 0.001
#
# 289	 0.001
#
# 290	 0.001
#
# 291	 0.001
#
# 292	 0.001
#
# 293	 0.001
#
# 294	 0.001
#
# 295	 0.001
#
# 296	 0.001
#
# 297	 0.001
#
# 298	 0.001
#
# 299	 0.001
#
# 300	 0.001
#
# 301	 0.001
#
# 302	 0.001
#
# 303	 0.001
#
# 304	 0.001
#
# 305	 0.001
#
# 306	 0.001
#
# 307	 0.001
#
# 308	 0.001
#
# 309	 0.001
#
# 310	 0.001
#
# 311	 0.001
#
# 312	 0.001
#
# 313	 0.001
#
# 314	 0.001
#
# 315	 0.001
#
# 316	 0.001
#
# 317	 0.001
#
# 318	 0.001
#
# 319	 0.001
#
# 320	 0.001
#
# 321	 0.001
#
# 322	 0.001
#
# 323	 0.001
#
# 324	 0.001
#
# 325	 0.001
#
# 326	 0.001
#
# 327	 0.001
#
# 328	 0.001
#
# 329	 0.001
#
# 330	 0.001
#
# 331	 0.001
#
# 332	 0.001
#
# 333	 0.001
#
# 334	 0.001
#
# 335	 0.001
#
# 336	 0.001
#
# 337	 0.001
#
# 338	 0.001
#
# 339	 0.001
#
# 340	 0.001
#
# 341	 0.001
#
# 342	 0.001
#
# 343	 0.001
#
# 344	 0.001
#
# 345	 0.001
#
# 346	 0.001
#
# 347	 0.001
#
# 348	 0.001
#
# 349	 0.001
#
# 350	 0.001
#
# 351	 0.001
#
# 352	 0.001
#
# 353	 0.001
#
# 354	 0.001
#
# 355	 0.001
#
# 356	 0.001
#
# 357	 0.001
#
# 358	 0.001
#
# 359	 0.001
#
# 360	 0.001
#
# 361	 0.001
#
# 362	 0.001
#
# 363	 0.001
#
# 364	 0.001
#
# 365	 0.001
#
# 366	 0.001
#
# 367	 0.001
#
# 368	 0.001
#
# 369	 0.001
#
# 370	 0.001
#
# 371	 0.001
#
# 372	 0.001
#
# 373	 0.001
#
# 374	 0.001
#
# 375	 0.001
#
# 376	 0.001
#
# 377	 0.001
#
# 378	 0.001
#
# 379	 0.001
#
# 380	 0.001
#
# 381	 0.001
#
# 382	 0.001
#
# 383	 0.001
#
# 384	 0.001
#
# 385	 0.001
#
# 386	 0.001
#
# 387	 0.001
#
# 388	 0.001
#
# 389	 0.001
#
# 390	 0.001
#
# 391	 0.001
#
# 392	 0.001
#
# 393	 0.001
#
# 394	 0.001
#
# 395	 0.001
#
# 396	 0.001
#
# 397	 0.001
#
# 398	 0.001
#
# 399	 0.001
#
# 400	 0.001
#
# 401	 0.001
#
# 402	 0.001
#
# 403	 0.001
#
# 404	 0.001
#
# 405	 0.001
#
# 406	 0.001
#
# 407	 0.001
#
# 408	 0.001
#
# 409	 0.001
#
# 410	 0.001
#
# 411	 0.001
#
# 412	 0.001
#
# 413	 0.001
#
# 414	 0.001
#
# 415	 0.001
#
# 416	 0.001
#
# 417	 0.001
#
# 418	 0.001
#
# 419	 0.001
#
# 420	 0.001
#
# 421	 0.001
#
# 422	 0.001
#
# 423	 0.001
#
# 424	 0.001
#
# 425	 0.001
#
# 426	 0.001
#
# 427	 0.001
#
# 428	 0.001
#
# 429	 0.001
#
# 430	 0.001
#
# 431	 0.001
#
# 432	 0.001
#
# 433	 0.001
#
# 434	 0.001
#
# 435	 0.001
#
# 436	 0.001
#
# 437	 0.001
#
# 438	 0.001
#
# 439	 0.001
#
# 440	 0.001
#
# 441	 0.001
#
# 442	 0.001
#
# 443	 0.001
#
# 444	 0.001
#
# 445	 0.001
#
# 446	 0.001
#
# 447	 0.001
#
# 448	 0.001
#
# 449	 0.001
#
# 450	 0.001
#
# 451	 0.001
#
# 452	 0.001
#
# 453	 0.001
#
# 454	 0.001
#
# 455	 0.001
#
# 456	 0.001
#
# 457	 0.001
#
# 458	 0.001
#
# 459	 0.001
#
# 460	 0.001
#
# 461	 0.001
#
# 462	 0.001
#
# 463	 0.001
#
# 464	 0.001
#
# 465	 0.001
#
# 466	 0.001
#
# 467	 0.001
#
# 468	 0.001
#
# 469	 0.001
#
# 470	 0.001
#
# 471	 0.001
#
# 472	 0.001
#
# 473	 0.001
#
# 474	 0.001
#
# 475	 0.001
#
# 476	 0.001
#
# 477	 0.001
#
# 478	 0.001
#
# 479	 0.001
#
# 480	 0.001
#
# 481	 0.001
#
# 482	 0.001
#
# 483	 0.001
#
# 484	 0.001
#
# 485	 0.001
#
# 486	 0.001
#
# 487	 0.001
#
# 488	 0.001
#
# 489	 0.001
#
# 490	 0.001
#
# 491	 0.001
#
# 492	 0.001
#
# 493	 0.001
#
# 494	 0.001
#
# 495	 0.001
#
# 496	 0.001
#
# 497	 0.001
#
# 498	 0.001
#
# 499	 0.001

# %%
# clr3
# warm up 10% of epoch: it can reduce fall in local min in inital steps.


ep_num = 1000



def clr3(epoch):
    
    
    step_size = 25 # currently best for foot pp
    max_lr = 0.01 # currently best for foot pp
    base_lr = 1e-6 # 1e-6 1e-7

    # warm up
    lr_init_ep = 0
    lr_ramp_ep = 100
    lr_sus_ep  = 0
    lr_decay   = 0.5

    iterations = epoch
    cycle = np.floor(1+iterations/(2*step_size))
    x = np.abs(iterations/step_size - 2*cycle + 1)
    lr = base_lr + (max_lr-base_lr)*np.maximum(0, (1-x))
    
    #todo: boost the lr at initial setps.
#     initial_lr = lambda epoch: lr if epoch > step_size else max_lr
#     initial_lr = lambda epoch: lr if epoch > step_size else boost_lr
#     lr = initial_lr(epoch)
    #todo: boost the lr at fist step_size.
    
    # warm up
    if epoch < lr_ramp_ep:
        lr = (max_lr - base_lr) / lr_ramp_ep * epoch + base_lr
    
    decay = ((epoch+1)/ep_num)
    base_part = 1.001 #1.1
#     print(decay)
    return lr * (base_part-decay) * lr_decay # supressed the lr!


rng = [i for i in range(ep_num)]
y = [clr3(x) for x in rng]
sns.set(style='darkgrid')
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)

# %%
print('{} ~ {}'.format(min(y), max(y)))
# Out:
# 2.4999999999999966e-08 ~ 0.004459954505

# %%
# 2.4999999999999966e-08 ~ 0.004459954505 1e-2~1e-6

# %%
# %%time
# """
# cosine_decay_restarts是cosine_decay的cycle版本。
# first_decay_steps是指第一次完全下降的step數，
# t_mul是指每一次循環的步數都將乘以t_mul倍，
# m_mul指每一次循環重新開始時的初始lr是上一次循環初始值的m_mul倍。
# alpha
# """

# from matplotlib.ticker import FormatStrFormatter



# ep_num = 1000



# def CosineDecayCLRWarmUp(epoch):
    
#     #step_size = 25 # currently best for foot pp
#     max_lr = 1e-2 # currently best for foot pp
#     base_lr = 1e-8# 1e-6 1e-7

#     # warm up
#     lr_init_ep = 0
#     lr_ramp_ep = 100
#     lr_sus_ep  = 0
#     lr_decay   = 0.8


#     initial_learning_rate = 1e-2
#     first_decay_steps = 100


#     lr_decayed_fn = (
#       tf.keras.experimental.CosineDecayRestarts(
#           initial_learning_rate,
#           first_decay_steps,
#           t_mul=1.0,
#           m_mul=0.8,
#           alpha = 0.000001,
#           name="CCosineDecayRestarts"))
    
#     # warm up
#     if epoch < lr_ramp_ep:
#         lr = (max_lr - base_lr) / lr_ramp_ep * epoch + base_lr    
#     else:
#         lr = lr_decayed_fn(epoch)
#     return lr



# rng = [i for i in range(ep_num)]
# y = [CosineDecayCLRWarmUp(x) for x in rng]
# sns.set(style='darkgrid')
# fig, ax = plt.subplots(figsize=(20, 6))
# # plt.ylim(.0000000000000001, .01)# for too large loss
# ax.yaxis.set_major_formatter(FormatStrFormatter('%.12f'))# for too small loss
# plt.plot(rng, y)

# %%
# %%time
# """
# cosine_decay_restarts是cosine_decay的cycle版本。
# first_decay_steps是指第一次完全下降的step數，
# t_mul是指每一次循環的步數都將乘以t_mul倍，
# m_mul指每一次循環重新開始時的初始lr是上一次循環初始值的m_mul倍。
# alpha
# """

# from matplotlib.ticker import FormatStrFormatter



# ep_num = 1000



# def CosineDecayCLRWarmUpLSW(epoch):
    
#     #step_size = 25 # currently best for foot pp
#     max_lr = 1e-3 # currently best for foot pp
#     base_lr = 1e-6# 1e-6 1e-7

#     # warm up
#     lr_init_ep = 0
#     lr_ramp_ep = 20
#     lr_sus_ep  = 0
#     lr_decay   = 0.8


#     initial_learning_rate = 1e-3
#     first_decay_steps = 50


#     lr_decayed_fn = (
#       tf.keras.experimental.CosineDecayRestarts(
#           initial_learning_rate,
#           first_decay_steps,
#           t_mul=1.0,
#           m_mul=0.8,
#           alpha = 0.000001,
#           name="CCosineDecayRestarts"))
    
#     # warm up
#     if epoch < lr_ramp_ep:
#         lr = (max_lr - base_lr) / lr_ramp_ep * epoch + base_lr    
#     else:
#         lr = lr_decayed_fn(epoch-lr_ramp_ep)
#     return lr



# rng = [i for i in range(ep_num)]
# y = [CosineDecayCLRWarmUpLSW(x) for x in rng]
# sns.set(style='darkgrid')
# fig, ax = plt.subplots(figsize=(20, 6))
# # plt.ylim(.0000000000000001, .01)# for too large loss
# ax.yaxis.set_major_formatter(FormatStrFormatter('%.12f'))# for too small loss
# plt.plot(rng, y)

# %%
# %%time
"""
cosine_decay_restarts是cosine_decay的cycle版本。
first_decay_steps是指第一次完全下降的step數，
t_mul是指每一次循環的步數都將乘以t_mul倍，
m_mul指每一次循環重新開始時的初始lr是上一次循環初始值的m_mul倍。
alpha
"""

from matplotlib.ticker import FormatStrFormatter



ep_num = 1000



def CosineDecayCLRWarmUpLSW_2(epoch):
    
    #step_size = 25 # currently best for foot pp
    max_lr = 1e-2 # currently best for foot pp
    base_lr = 1e-6# 1e-6 1e-7

    # warm up
    lr_init_ep = 0
    lr_ramp_ep = 20
    lr_sus_ep  = 0
    #lr_decay   = 0.8


    initial_learning_rate = 1e-2
    first_decay_steps = 50


    lr_decayed_fn = (
      tf.keras.experimental.CosineDecayRestarts(
          initial_learning_rate,
          first_decay_steps,
          t_mul=1,
          m_mul=1,
          alpha = 0.000001,
          name="CCosineDecayRestarts"))
    
    # warm up
    if epoch < lr_ramp_ep:
        lr = (max_lr - base_lr) / lr_ramp_ep * epoch + base_lr    
    else:
        lr = lr_decayed_fn(epoch-lr_ramp_ep)
    return lr



rng = [i for i in range(ep_num)]
y = [CosineDecayCLRWarmUpLSW_2(x) for x in rng]
sns.set(style='darkgrid')
fig, ax = plt.subplots(figsize=(20, 6))
# plt.ylim(.0000000000000001, .01)# for too large loss
ax.yaxis.set_major_formatter(FormatStrFormatter('%.12f'))# for too small loss
plt.plot(rng, y)
# Out:
# CPU times: user 584 ms, sys: 81.5 ms, total: 666 ms
# Wall time: 559 ms

# %%
print('{} ~ {}'.format(min(y), max(y)))
# Out:
# 1e-06 ~ 0.009999999776482582

# %%
# 1.8774175103430935e-08 ~ 0.0010000000474974513 1e-3 1e-6

# %%
# lr_reduceonplateau = tf.keras.callbacks.ReduceLROnPlateau(monitor=monitor, factor=0.1, patience=5, verbose=1, mode='auto', min_delta=0.0001, cooldown=0, min_lr=1e-12)

# %%
# Callback for printing the LR at the end of each epoch.
class PrintLRtoe(tf.keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
#     def on_epoch_end(self, epoch, logs=None):
#         print('\n[{}] Learning rate for epoch {} is {}'.format(
#             datetime.now().strftime("%Y%m%d-%H%M-%S"), 
#             epoch + 1,
#             self.model.optimizer.lr.numpy()))
        print('\n[{}] Learning rate for epoch {} is {}'.format(
        datetime.now().strftime("%Y%m%d-%H%M-%S"), 
        epoch + 1,
        model_toe.optimizer._decayed_lr(tf.float32).numpy()))

# %%
# Callback for printing the LR at the end of each epoch.
class PrintLRheel(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
#         print('\nLearning rate for epoch {} is {}'.format(epoch + 1,
#                                               model_heel.optimizer.lr.numpy()))
        print('\n[{}] Learning rate for epoch {} is {}'.format(
        datetime.now().strftime("%Y%m%d-%H%M-%S"), 
        epoch + 1,
        model_heel.optimizer._decayed_lr(tf.float32).numpy()))

# %% [markdown]
# ### Output dir and models

# %%
def mk_log_dir(log_dir_name):
    try:
        os.makedirs(log_dir_name)
    except OSError as e:
        print("This log dir exist.")
        if e.errno != errno.EEXIST:
            raise ValueError("we got problem.")

# %%
monitor = 'val_loss' #'val_loss' 'val_accuracy' if use ed_loss it still the loss here.

log_dir_name = datetime.now().strftime("%Y%m%d-%H%M%S") 

# mk_log_dir(datetime.now().strftime("%Y%m%d-%H%M%S") )

# %%
# use once at the time
mk_log_dir(log_dir_name)

# %% [markdown]
# # Toe

# %%
model_name = 'EfficientNetB0'

# %%
#get_best_model_name

# best_model_name = './' + model_name + '_bs-' + str(BATCH_SIZE) + '_s-' + str(img_height) + '_' + "ep-{epoch:02d}-vloss-{val_loss:.2f}" +'_best-weight.h5'
# best_model_name = '{model_name}-ep{epoch:03d}-loss{loss:.3f}-val_loss{val_loss:.3f}.h5'
#best_model_name = './' + model_name + '_bs' + str(BATCH_SIZE) + '_w' + str(img_width) + '_' + monitor + '_best.h5'
# best_model_name = './Leaf_' + model_name + '_bs' + str(BATCH_SIZE) + '_w' + str(img_width) + '_' + datetime.now().strftime("%Y%m%d-%H%M%S") + '_best_' + monitor + '.h5'

# best_model_name = './cop' + model_name + '_bs' + str(BATCH_SIZE) + '_w' + str(img_width) + '_' + datetime.now().strftime("%Y%m%d-%H%M%S") + '_best_' + monitor + '.h5'

def get_best_model_name(th, K):
    return './' + log_dir_name + '/' + th + '_K' + K + '_' + model_name + '_bs' + str(BATCH_SIZE) + '_w' + str(img_width) + '_best_' + monitor + '.h5'

# th = 'toe'
# # th = 'heel'

# # print(get_best_model_name(th,K))

# best_model_name = get_best_model_name(th, K)


# best_model_save = tf.keras.callbacks.ModelCheckpoint(filepath=best_model_name, 
#                              save_best_only = True, 
#                              save_weights_only = False,
#                              monitor = monitor, 
#                              mode = 'auto', verbose = 1)
# print('best_model_name:', best_model_name)

# %%
logdir = log_dir_name + "/logs/toe/"

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
# callbacks = [
# #     tensorboard_callback,
#     best_model_save,
#     tf.keras.callbacks.EarlyStopping(monitor=monitor, patience=20), #patience=step_size or ep_num
# #     lr_reduceonplateau,
#     tf.keras.callbacks.LearningRateScheduler(lrdump),#lrdump, decay or lrfn or lrfn2. clr
#     PrintLRtoe()
# ]

# %%
# Transfer learning from pre-trained weights
def build_efn_model(outputnum, top_dropout_rate, drop_connect_rate):
    base_model = tf.keras.applications.EfficientNetB0(include_top=False, weights="imagenet", input_shape=(120,120,3),drop_connect_rate=drop_connect_rate) #{'imagenet', None}

    # Freeze the pretrained weights
    base_model.trainable = False
    print("base_model.trainable : ", base_model.trainable)

    # Rebuild top
    gap2d = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
    BNL = tf.keras.layers.BatchNormalization()(gap2d) #tood: remove#
    dropout = tf.keras.layers.Dropout(top_dropout_rate)(BNL)#tood: remove# J add dropout, for flood 0.2 is ok. for leaf 0.4 is better.
    outputs = tf.keras.layers.Dense(outputnum)(dropout)# remove activation for regression output (to default, the linear), , activation = 'relu' no help

    # Compile new model
    model = tf.keras.Model(base_model.input, outputs, name=model_name)


#     # unfreeze the top #fine_tune_at# layers while leaving BatchNorm layers frozen
#     fine_tune_at = 20 #10 #241 #20
#     print('[Note] Now create model fine tuneing at Top-{} layers!'.format(fine_tune_at))
#     for layer in model_toe.layers[-fine_tune_at:]:
#         if not isinstance(layer, tf.keras.layers.BatchNormalization):
#             layer.trainable = True

    model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),#RMSprop , Adam, SGD Adadelta(learning_rate=0.001), if set lr_callback the learning_rate=0.001 will not effeced.
                    loss=ed_metric_2d_mean)

    
    return model

# %%
"""Supervised pre-training 減少每次fold都要重新train的時間
只先改toe"""

# Transfer learning from pre-trained weights
def load_pretrained_efn_model():
    pre_model_toe_name = "20210224-200728/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5"
    model = tf.keras.models.load_model(pre_model_toe_name,compile=False)

    # Freeze the pretrained weights
    model.trainable = False
#     print("base_model.trainable : ", base_model.trainable)

#     # Rebuild top
#     gap2d = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
#     BNL = tf.keras.layers.BatchNormalization()(gap2d) #tood: remove#
#     dropout = tf.keras.layers.Dropout(top_dropout_rate)(BNL)#tood: remove# J add dropout, for flood 0.2 is ok. for leaf 0.4 is better.
#     outputs = tf.keras.layers.Dense(outputnum)(dropout)# remove activation for regression output (to default, the linear), , activation = 'relu' no help

#     # Compile new model
#     model = tf.keras.Model(base_model.input, outputs, name=model_name)


#     # unfreeze the top #fine_tune_at# layers while leaving BatchNorm layers frozen
    fine_tune_at = 4 #10 #241 #20
    print('[Note] Now create model fine tuneing at Top-{} layers!'.format(fine_tune_at))
    for layer in model.layers[-fine_tune_at:]:
        if not isinstance(layer, tf.keras.layers.BatchNormalization):
            print('layer trainable +1', layer.name)
            layer.trainable = True

    model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),#RMSprop , Adam, SGD Adadelta(learning_rate=0.001), if set lr_callback the learning_rate=0.001 will not effeced.
                    loss=ed_metric_2d_mean)

    
    return model

# %%
def unfreeze_model(model):
#
# EX: tt: 224, nt:17, total layers:241
#'block7a_expand_conv'20 'block6c_expand_conv'50 'block6a_expand_conv'79 'block5b_expand_conv'109 'block4a_expand_conv' 166  'block3a_expand_conv' 195 'block2a_expand_conv' 224
#
    model.trainable = True
    set_trainable = False
    for layer in model.layers:
        if layer.name == 'block2a_expand_conv': 
            set_trainable = True
        if set_trainable:
            layer.trainable = True
        else:
            layer.trainable = False

    model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),#RMSprop , Adam, SGD Adadelta(learning_rate=0.001), if set lr_callback the learning_rate=0.001 will not effeced.
                    loss=ed_metric_2d_mean)

# %%
# top_dropout_rate = 0.8 #less dp rate, say 0.1, train_loss will lower than val_loss
# drop_connect_rate = 0.9 #for efnet This parameter serves as a toggle for extra regularization in finetuning, but does not affect loaded weights.
# outputnum = 2
# with strategy.scope():
#     model_toe = build_efn_model(outputnum, top_dropout_rate, drop_connect_rate)

# %%
# len(model_toe.layers)

# %%
# tt = 0
# nt = 0
# for layer in model_toe.layers:
#     if layer.trainable:
#         tt +=1
#         print(f'{layer.name}')
#     else:
#         nt +=1
# print(f'tt: {tt}, nt:{nt}')

# %%
def count_model_trainOrNot_layers(model, printlayers=False):
    tt = 0
    nt = 0
    for layer in model.layers:
        if layer.trainable:
            tt +=1
            if printlayers:
                print(f'{layer.name}')
        else:
            nt +=1
    print('\n*********************************** Start fine tune ***********************************')
    print(f'tt: {tt}, nt:{nt}, total layers:{tt+nt}')
    print('*********************************** Start fine tune ***********************************')

# %%
# count_model_trainOrNot_layers(model_toe)

# %%
# model_toe.summary()

# %%
# %%time

# # fit the model on all data
# history_toe = model_toe.fit(train_ds_pre_toe_s, 
#                       verbose=1, 
#                       epochs=ep_num_transf, 
#                       validation_data=valid_ds_pre_toe_s, 
#                       callbacks=callbacks)#, validation_split=0.1)

# %%
# model_toe = build_efn_model(2, 0.2, 0.2)
# unfreeze_model(model_toe)
# count_model_trainOrNot_layers(model_toe)

# %% [markdown]
# # K-Fold Training
#
# 2021-02-23 v1

# %% [markdown]
# ### Toe K-model

# %%
# %%time

# big K = 5 (fold 0 ~ 4) 
KFlodNum = 5



history_toe = []
history_toe_finetune = []

#above until 'train_ds_map_toe now' to 'train_ds_map_toe_s', 'valid_ds_map_toe_s'
for k in range(KFlodNum):
    
    
    # Split data to train/valid with K-Fold #
    print("\n \n K = ", k, "\n")
    # Toe split
    train_ds_map_toe_s, valid_ds_map_toe_s = get_KFold_ds(train_ds_map_toe, K=k)
    
    # Toe ds_pre
    train_ds_pre_toe_s = configure_for_performance_cache_train(train_ds_map_toe_s, augment=True)
    valid_ds_pre_toe_s = configure_for_performance_cache_val(valid_ds_map_toe_s)
    
    
#     # heel split
#     train_ds_map_heel_s, valid_ds_map_heel_s = get_KFold_ds(train_ds_map_heel, K=k)
#     # Heel ds_pre
#     train_ds_pre_heel_s = configure_for_performance_cache_train(train_ds_map_heel_s, augment=True)
#     valid_ds_pre_heel_s = configure_for_performance_cache_val(valid_ds_map_heel_s)
    
    
    # Train K-Model with transfer learnling #
    
    # Toe model, TL
    th = 'toe'
    # th = 'heel'
    best_model_name = get_best_model_name(th, K=str(k))
    best_model_save = tf.keras.callbacks.ModelCheckpoint(filepath=best_model_name, 
                                 save_best_only = True, 
                                 save_weights_only = False,
                                 monitor = monitor, 
                                 mode = 'auto', verbose = 1)
    callbacks_toe_tl = [
                    #     tensorboard_callback,
                        best_model_save,
                        tf.keras.callbacks.EarlyStopping(monitor=monitor, patience=20), #patience=step_size or ep_num
                    #     lr_reduceonplateau,
                        tf.keras.callbacks.LearningRateScheduler(lrdump),#lrdump, decay or lrfn or lrfn2. clr
                        PrintLRtoe()
                        ]
    callbacks_toe_fn = [
                    #     tensorboard_callback,
                        best_model_save,
                        tf.keras.callbacks.EarlyStopping(monitor=monitor, patience=100), #patience=step_size or ep_num
                    #     lr_reduceonplateau,
                        tf.keras.callbacks.LearningRateScheduler(clr3),#lrdump, decay or lrfn or lrfn2. clr, CosineDecayCLRWarmUp, CosineDecayCLRWarmUpLSW
                        PrintLRtoe()
                    ]
    print('best_model_name:', best_model_name)


    top_dropout_rate = 0.8 #less dp rate, say 0.1, train_loss will lower than val_loss
    drop_connect_rate = 0.9 #for efnet This parameter serves as a toggle for extra regularization in finetuning, but does not affect loaded weights.
    outputnum = 2
    with strategy.scope():
        model_toe = build_efn_model(outputnum, top_dropout_rate, drop_connect_rate)
#         model_toe = load_pretrained_efn_model() # from 20210224-200728 ed5.3
#         count_model_trainOrNot_layers(model_toe)
        
    # fit the model on all data
    hist = model_toe.fit(train_ds_pre_toe_s, 
                          verbose=1, 
                          epochs=ep_num_transf, 
                          validation_data=valid_ds_pre_toe_s, 
                          callbacks=callbacks_toe_tl)#, validation_split=0.1)
    history_toe.append(hist)
    
      
    # Train K-Model with fine tune #
    
    # Toe model, FT
    unfreeze_model(model_toe)
    count_model_trainOrNot_layers(model_toe)
    # fit the model on all data
    hist = model_toe.fit(train_ds_pre_toe_s, 
                          verbose=1, 
                          epochs=ep_num, 
                          validation_data=valid_ds_pre_toe_s, 
                          callbacks=callbacks_toe_fn)#, validation_split=0.1)
    history_toe_finetune.append(hist)
# Out:
#
#  K =  0
#
# Check cache in memory:Y True
# Check keypoints process01: Tensor("args_1:0", shape=(2,), dtype=int64) (2,) <class 'tensorflow.python.framework.ops.Tensor'>
# Check keypoints process02: Tensor("Reshape:0", shape=(1, 2), dtype=int64) (1, 2) <class 'tensorflow.python.framework.ops.Tensor'>
# Check keypoints process03: Tensor("PyFunc:1", dtype=float32, device=/job:localhost/replica:0/task:0)
# Check keypoints process04: Tensor("Reshape_1:0", shape=(2,), dtype=float32)
# Check augment :Y True
# Check ds cache[True] and augment[True]
# Check cache in memory:Y True
# Check augment :N False
# Check ds cache[True] and augment[False]
# best_model_name: ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# base_model.trainable :  False
#
# [20210227-2154-04] Learning rate for epoch 1 is 0.009999999776482582
# Epoch 1/500
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/multi_device_iterator_ops.py:601: get_next_as_optional (from tensorflow.python.data.ops.iterator_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Iterator.get_next_as_optional()` instead.
# 17/17 [==============================] - ETA: 0s - loss: 75.9431
# Epoch 00001: val_loss improved from inf to 64.29707, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 13s 783ms/step - loss: 75.9431 - val_loss: 64.2971
#
# [20210227-2154-29] Learning rate for epoch 2 is 0.009960000403225422
# Epoch 2/500
# 16/17 [===========================>..] - ETA: 0s - loss: 42.6384
# Epoch 00002: val_loss improved from 64.29707 to 13.81302, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 41.6188 - val_loss: 13.8130
#
# [20210227-2154-33] Learning rate for epoch 3 is 0.009920000098645687
# Epoch 3/500
# 17/17 [==============================] - ETA: 0s - loss: 21.9947
# Epoch 00003: val_loss did not improve from 13.81302
# 17/17 [==============================] - 10s 615ms/step - loss: 21.9947 - val_loss: 14.5638
#
# [20210227-2154-46] Learning rate for epoch 4 is 0.009879999794065952
# Epoch 4/500
# 16/17 [===========================>..] - ETA: 0s - loss: 18.5100
# Epoch 00004: val_loss improved from 13.81302 to 12.50303, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 18.6006 - val_loss: 12.5030
#
# [20210227-2154-50] Learning rate for epoch 5 is 0.009840000420808792
# Epoch 5/500
# 16/17 [===========================>..] - ETA: 0s - loss: 17.9581
# Epoch 00005: val_loss improved from 12.50303 to 12.00396, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 17.9203 - val_loss: 12.0040
#
# [20210227-2154-53] Learning rate for epoch 6 is 0.009800000116229057
# Epoch 6/500
# 17/17 [==============================] - ETA: 0s - loss: 17.1802
# Epoch 00006: val_loss improved from 12.00396 to 11.88099, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 17.1802 - val_loss: 11.8810
#
# [20210227-2154-57] Learning rate for epoch 7 is 0.009759999811649323
# Epoch 7/500
# 16/17 [===========================>..] - ETA: 0s - loss: 17.7669
# Epoch 00007: val_loss did not improve from 11.88099
# 17/17 [==============================] - 0s 25ms/step - loss: 17.6713 - val_loss: 12.0640
#
# [20210227-2155-00] Learning rate for epoch 8 is 0.009720000438392162
# Epoch 8/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.2896
# Epoch 00008: val_loss improved from 11.88099 to 11.61389, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 45ms/step - loss: 16.2206 - val_loss: 11.6139
#
# [20210227-2155-04] Learning rate for epoch 9 is 0.009680000133812428
# Epoch 9/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.3267
# Epoch 00009: val_loss improved from 11.61389 to 11.45864, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 16.2518 - val_loss: 11.4586
#
# [20210227-2155-07] Learning rate for epoch 10 is 0.009639999829232693
# Epoch 10/500
# 17/17 [==============================] - ETA: 0s - loss: 16.1888
# Epoch 00010: val_loss improved from 11.45864 to 11.34216, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 16.1888 - val_loss: 11.3422
#
# [20210227-2155-11] Learning rate for epoch 11 is 0.009600000455975533
# Epoch 11/500
# 17/17 [==============================] - ETA: 0s - loss: 15.4425
# Epoch 00011: val_loss improved from 11.34216 to 11.28138, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 44ms/step - loss: 15.4425 - val_loss: 11.2814
#
# [20210227-2155-15] Learning rate for epoch 12 is 0.009560000151395798
# Epoch 12/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.6661
# Epoch 00012: val_loss improved from 11.28138 to 11.15304, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 15.6216 - val_loss: 11.1530
#
# [20210227-2155-18] Learning rate for epoch 13 is 0.009519999846816063
# Epoch 13/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.5846
# Epoch 00013: val_loss did not improve from 11.15304
# 17/17 [==============================] - 0s 24ms/step - loss: 15.5570 - val_loss: 11.2860
#
# [20210227-2155-22] Learning rate for epoch 14 is 0.009479999542236328
# Epoch 14/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.9439
# Epoch 00014: val_loss improved from 11.15304 to 11.01503, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 48ms/step - loss: 14.9687 - val_loss: 11.0150
#
# [20210227-2155-25] Learning rate for epoch 15 is 0.009440000168979168
# Epoch 15/500
# 14/17 [=======================>......] - ETA: 0s - loss: 15.3239
# Epoch 00015: val_loss improved from 11.01503 to 10.80642, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 15.2860 - val_loss: 10.8064
#
# [20210227-2155-29] Learning rate for epoch 16 is 0.009399999864399433
# Epoch 16/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.3035
# Epoch 00016: val_loss improved from 10.80642 to 10.64209, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 45ms/step - loss: 15.3486 - val_loss: 10.6421
#
# [20210227-2155-32] Learning rate for epoch 17 is 0.009359999559819698
# Epoch 17/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.0210
# Epoch 00017: val_loss did not improve from 10.64209
# 17/17 [==============================] - 0s 24ms/step - loss: 14.9353 - val_loss: 10.6779
#
# [20210227-2155-36] Learning rate for epoch 18 is 0.009320000186562538
# Epoch 18/500
# 17/17 [==============================] - ETA: 0s - loss: 15.2653
# Epoch 00018: val_loss did not improve from 10.64209
# 17/17 [==============================] - 0s 24ms/step - loss: 15.2653 - val_loss: 10.8020
#
# [20210227-2155-39] Learning rate for epoch 19 is 0.009279999881982803
# Epoch 19/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.0637
# Epoch 00019: val_loss improved from 10.64209 to 10.54972, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 64ms/step - loss: 14.9971 - val_loss: 10.5497
#
# [20210227-2155-43] Learning rate for epoch 20 is 0.009239999577403069
# Epoch 20/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.6828
# Epoch 00020: val_loss improved from 10.54972 to 10.42000, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 45ms/step - loss: 14.6547 - val_loss: 10.4200
#
# [20210227-2155-46] Learning rate for epoch 21 is 0.009200000204145908
# Epoch 21/500
# 17/17 [==============================] - ETA: 0s - loss: 14.6492
# Epoch 00021: val_loss did not improve from 10.42000
# 17/17 [==============================] - 0s 24ms/step - loss: 14.6492 - val_loss: 10.5192
#
# [20210227-2155-50] Learning rate for epoch 22 is 0.009159999899566174
# Epoch 22/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.8471
# Epoch 00022: val_loss did not improve from 10.42000
# 17/17 [==============================] - 0s 24ms/step - loss: 14.8549 - val_loss: 10.6700
#
# [20210227-2155-53] Learning rate for epoch 23 is 0.009119999594986439
# Epoch 23/500
# 17/17 [==============================] - ETA: 0s - loss: 14.4464
# Epoch 00023: val_loss did not improve from 10.42000
# 17/17 [==============================] - 0s 24ms/step - loss: 14.4464 - val_loss: 11.0341
#
# [20210227-2155-56] Learning rate for epoch 24 is 0.009080000221729279
# Epoch 24/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.4427
# Epoch 00024: val_loss did not improve from 10.42000
# 17/17 [==============================] - 1s 36ms/step - loss: 14.3152 - val_loss: 10.7035
#
# [20210227-2156-00] Learning rate for epoch 25 is 0.009039999917149544
# Epoch 25/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.3153
# Epoch 00025: val_loss improved from 10.42000 to 10.15727, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 14.3282 - val_loss: 10.1573
#
# [20210227-2156-03] Learning rate for epoch 26 is 0.008999999612569809
# Epoch 26/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.1799
# Epoch 00026: val_loss improved from 10.15727 to 10.09168, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 48ms/step - loss: 14.3113 - val_loss: 10.0917
#
# [20210227-2156-07] Learning rate for epoch 27 is 0.008960000239312649
# Epoch 27/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.0600
# Epoch 00027: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 24ms/step - loss: 14.0508 - val_loss: 10.3635
#
# [20210227-2156-10] Learning rate for epoch 28 is 0.008919999934732914
# Epoch 28/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.2084
# Epoch 00028: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 24ms/step - loss: 14.1444 - val_loss: 10.1663
#
# [20210227-2156-13] Learning rate for epoch 29 is 0.00887999963015318
# Epoch 29/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.5718
# Epoch 00029: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 25ms/step - loss: 14.5103 - val_loss: 10.1949
#
# [20210227-2156-17] Learning rate for epoch 30 is 0.008840000256896019
# Epoch 30/500
# 17/17 [==============================] - ETA: 0s - loss: 14.4584
# Epoch 00030: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 24ms/step - loss: 14.4584 - val_loss: 10.2331
#
# [20210227-2156-20] Learning rate for epoch 31 is 0.008799999952316284
# Epoch 31/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.4442
# Epoch 00031: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 25ms/step - loss: 14.4887 - val_loss: 10.4220
#
# [20210227-2156-23] Learning rate for epoch 32 is 0.00875999964773655
# Epoch 32/500
# 17/17 [==============================] - ETA: 0s - loss: 14.0531
# Epoch 00032: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 23ms/step - loss: 14.0531 - val_loss: 10.7223
#
# [20210227-2156-26] Learning rate for epoch 33 is 0.00872000027447939
# Epoch 33/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.2535
# Epoch 00033: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 24ms/step - loss: 14.2641 - val_loss: 10.7456
#
# [20210227-2156-29] Learning rate for epoch 34 is 0.008679999969899654
# Epoch 34/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.3646
# Epoch 00034: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 24ms/step - loss: 14.3108 - val_loss: 10.2285
#
# [20210227-2156-33] Learning rate for epoch 35 is 0.00863999966531992
# Epoch 35/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.0879
# Epoch 00035: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 24ms/step - loss: 14.1367 - val_loss: 10.9094
#
# [20210227-2156-36] Learning rate for epoch 36 is 0.00860000029206276
# Epoch 36/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.3187
# Epoch 00036: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 24ms/step - loss: 14.2577 - val_loss: 10.4862
#
# [20210227-2156-39] Learning rate for epoch 37 is 0.008559999987483025
# Epoch 37/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.6578
# Epoch 00037: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 24ms/step - loss: 13.6476 - val_loss: 10.4987
#
# [20210227-2156-43] Learning rate for epoch 38 is 0.00851999968290329
# Epoch 38/500
# 17/17 [==============================] - ETA: 0s - loss: 13.9186
# Epoch 00038: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 24ms/step - loss: 13.9186 - val_loss: 10.1848
#
# [20210227-2156-46] Learning rate for epoch 39 is 0.00848000030964613
# Epoch 39/500
# 17/17 [==============================] - ETA: 0s - loss: 14.3282
# Epoch 00039: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 24ms/step - loss: 14.3282 - val_loss: 10.9995
#
# [20210227-2156-49] Learning rate for epoch 40 is 0.008440000005066395
# Epoch 40/500
# 17/17 [==============================] - ETA: 0s - loss: 14.1302
# Epoch 00040: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 24ms/step - loss: 14.1302 - val_loss: 10.4801
#
# [20210227-2156-52] Learning rate for epoch 41 is 0.00839999970048666
# Epoch 41/500
# 16/17 [===========================>..] - ETA: 0s - loss: 14.0790
# Epoch 00041: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 24ms/step - loss: 13.9651 - val_loss: 10.3073
#
# [20210227-2156-55] Learning rate for epoch 42 is 0.0083600003272295
# Epoch 42/500
# 17/17 [==============================] - ETA: 0s - loss: 13.6205
# Epoch 00042: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 23ms/step - loss: 13.6205 - val_loss: 10.3492
#
# [20210227-2156-59] Learning rate for epoch 43 is 0.008320000022649765
# Epoch 43/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.7477
# Epoch 00043: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 25ms/step - loss: 13.7558 - val_loss: 10.5662
#
# [20210227-2157-02] Learning rate for epoch 44 is 0.00827999971807003
# Epoch 44/500
# 17/17 [==============================] - ETA: 0s - loss: 13.7432
# Epoch 00044: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 24ms/step - loss: 13.7432 - val_loss: 10.6762
#
# [20210227-2157-05] Learning rate for epoch 45 is 0.00824000034481287
# Epoch 45/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.9658
# Epoch 00045: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 25ms/step - loss: 13.9185 - val_loss: 11.0455
#
# [20210227-2157-08] Learning rate for epoch 46 is 0.008200000040233135
# Epoch 46/500
# 16/17 [===========================>..] - ETA: 0s - loss: 13.5986
# Epoch 00046: val_loss did not improve from 10.09168
# 17/17 [==============================] - 0s 24ms/step - loss: 13.5172 - val_loss: 10.1980
#
# *********************************** Start fine tune ***********************************
# tt: 224, nt:17, total layers:241
# *********************************** Start fine tune ***********************************
#
# [20210227-2157-12] Learning rate for epoch 1 is 4.999999987376214e-07
# Epoch 1/1000
# 17/17 [==============================] - ETA: 0s - loss: 15.5303
# Epoch 00001: val_loss did not improve from 10.09168
# 17/17 [==============================] - 40s 2s/step - loss: 15.5303 - val_loss: 10.1318
#
# [20210227-2158-10] Learning rate for epoch 2 is 5.044450517743826e-05
# Epoch 2/1000
# 17/17 [==============================] - ETA: 0s - loss: 15.4878
# Epoch 00002: val_loss did not improve from 10.09168
# 17/17 [==============================] - 1s 80ms/step - loss: 15.4878 - val_loss: 10.1725
#
# [20210227-2158-14] Learning rate for epoch 3 is 0.00010028902033809572
# Epoch 3/1000
# 17/17 [==============================] - ETA: 0s - loss: 14.8266
# Epoch 00003: val_loss did not improve from 10.09168
# 17/17 [==============================] - 34s 2s/step - loss: 14.8266 - val_loss: 10.3158
#
# [20210227-2158-51] Learning rate for epoch 4 is 0.00015003354928921908
# Epoch 4/1000
# 17/17 [==============================] - ETA: 0s - loss: 14.2879
# Epoch 00004: val_loss did not improve from 10.09168
# 17/17 [==============================] - 1s 82ms/step - loss: 14.2879 - val_loss: 10.7933
#
# [20210227-2158-56] Learning rate for epoch 5 is 0.0001996780774788931
# Epoch 5/1000
# 17/17 [==============================] - ETA: 0s - loss: 13.5304
# Epoch 00005: val_loss did not improve from 10.09168
# 17/17 [==============================] - 1s 79ms/step - loss: 13.5304 - val_loss: 10.8399
#
# [20210227-2159-00] Learning rate for epoch 6 is 0.000249222619459033
# Epoch 6/1000
# 17/17 [==============================] - ETA: 0s - loss: 13.2117
# Epoch 00006: val_loss did not improve from 10.09168
# 17/17 [==============================] - 1s 80ms/step - loss: 13.2117 - val_loss: 10.3019
#
# [20210227-2159-04] Learning rate for epoch 7 is 0.0002986671752296388
# Epoch 7/1000
# 17/17 [==============================] - ETA: 0s - loss: 12.8421
# Epoch 00007: val_loss improved from 10.09168 to 9.58941, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 112ms/step - loss: 12.8421 - val_loss: 9.5894
#
# [20210227-2159-09] Learning rate for epoch 8 is 0.00034801175934262574
# Epoch 8/1000
# 17/17 [==============================] - ETA: 0s - loss: 12.2358
# Epoch 00008: val_loss improved from 9.58941 to 9.51287, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 114ms/step - loss: 12.2358 - val_loss: 9.5129
#
# [20210227-2159-14] Learning rate for epoch 9 is 0.00039725631359033287
# Epoch 9/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.9169
# Epoch 00009: val_loss did not improve from 9.51287
# 17/17 [==============================] - 1s 79ms/step - loss: 11.9169 - val_loss: 9.6895
#
# [20210227-2159-18] Learning rate for epoch 10 is 0.0004464008961804211
# Epoch 10/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.8585
# Epoch 00010: val_loss improved from 9.51287 to 8.95343, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 113ms/step - loss: 11.8585 - val_loss: 8.9534
#
# [20210227-2159-23] Learning rate for epoch 11 is 0.0004954455071128905
# Epoch 11/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.5742
# Epoch 00011: val_loss improved from 8.95343 to 8.38954, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 115ms/step - loss: 11.5742 - val_loss: 8.3895
#
# [20210227-2159-28] Learning rate for epoch 12 is 0.0005443901172839105
# Epoch 12/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.4181
# Epoch 00012: val_loss improved from 8.38954 to 8.14242, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 112ms/step - loss: 11.4181 - val_loss: 8.1424
#
# [20210227-2159-33] Learning rate for epoch 13 is 0.0005932347266934812
# Epoch 13/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.3976
# Epoch 00013: val_loss did not improve from 8.14242
# 17/17 [==============================] - 1s 80ms/step - loss: 11.3976 - val_loss: 8.9070
#
# [20210227-2159-37] Learning rate for epoch 14 is 0.0006419793353416026
# Epoch 14/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.3062
# Epoch 00014: val_loss improved from 8.14242 to 7.99455, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 112ms/step - loss: 11.3062 - val_loss: 7.9946
#
# [20210227-2159-42] Learning rate for epoch 15 is 0.0006906240014359355
# Epoch 15/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.3205
# Epoch 00015: val_loss improved from 7.99455 to 7.74983, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 113ms/step - loss: 11.3205 - val_loss: 7.7498
#
# [20210227-2159-46] Learning rate for epoch 16 is 0.0007391686085611582
# Epoch 16/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.9484
# Epoch 00016: val_loss did not improve from 7.74983
# 17/17 [==============================] - 1s 78ms/step - loss: 10.9484 - val_loss: 8.1919
#
# [20210227-2159-51] Learning rate for epoch 17 is 0.0007876132731325924
# Epoch 17/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.8684
# Epoch 00017: val_loss did not improve from 7.74983
# 17/17 [==============================] - 1s 78ms/step - loss: 10.8684 - val_loss: 9.1483
#
# [20210227-2159-55] Learning rate for epoch 18 is 0.0008359579369425774
# Epoch 18/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.0716
# Epoch 00018: val_loss did not improve from 7.74983
# 17/17 [==============================] - 1s 80ms/step - loss: 11.0716 - val_loss: 8.0309
#
# [20210227-2159-59] Learning rate for epoch 19 is 0.000884202599991113
# Epoch 19/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.5467
# Epoch 00019: val_loss did not improve from 7.74983
# 17/17 [==============================] - 1s 78ms/step - loss: 10.5467 - val_loss: 8.2878
#
# [20210227-2200-03] Learning rate for epoch 20 is 0.0009323473204858601
# Epoch 20/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.8723
# Epoch 00020: val_loss improved from 7.74983 to 7.24402, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 114ms/step - loss: 10.8723 - val_loss: 7.2440
#
# [20210227-2200-08] Learning rate for epoch 21 is 0.000980391982011497
# Epoch 21/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.6878
# Epoch 00021: val_loss did not improve from 7.24402
# 17/17 [==============================] - 1s 79ms/step - loss: 10.6878 - val_loss: 7.7281
#
# [20210227-2200-12] Learning rate for epoch 22 is 0.0010283367009833455
# Epoch 22/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.3981
# Epoch 00022: val_loss did not improve from 7.24402
# 17/17 [==============================] - 1s 80ms/step - loss: 10.3981 - val_loss: 8.7227
#
# [20210227-2200-17] Learning rate for epoch 23 is 0.0010761814191937447
# Epoch 23/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.4921
# Epoch 00023: val_loss did not improve from 7.24402
# 17/17 [==============================] - 2s 95ms/step - loss: 10.4921 - val_loss: 7.9036
#
# [20210227-2200-21] Learning rate for epoch 24 is 0.0011239261366426945
# Epoch 24/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.5063
# Epoch 00024: val_loss did not improve from 7.24402
# 17/17 [==============================] - 1s 80ms/step - loss: 10.5063 - val_loss: 8.1869
#
# [20210227-2200-26] Learning rate for epoch 25 is 0.001171570853330195
# Epoch 25/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.2463
# Epoch 00025: val_loss did not improve from 7.24402
# 17/17 [==============================] - 1s 79ms/step - loss: 10.2463 - val_loss: 8.9454
#
# [20210227-2200-30] Learning rate for epoch 26 is 0.001219115569256246
# Epoch 26/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.1692
# Epoch 00026: val_loss did not improve from 7.24402
# 17/17 [==============================] - 1s 80ms/step - loss: 10.1692 - val_loss: 8.0855
#
# [20210227-2200-34] Learning rate for epoch 27 is 0.0012665604008361697
# Epoch 27/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.0540
# Epoch 00027: val_loss did not improve from 7.24402
# 17/17 [==============================] - 1s 81ms/step - loss: 10.0540 - val_loss: 8.1443
#
# [20210227-2200-38] Learning rate for epoch 28 is 0.0013139051152393222
# Epoch 28/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.6800
# Epoch 00028: val_loss did not improve from 7.24402
# 17/17 [==============================] - 1s 79ms/step - loss: 9.6800 - val_loss: 8.2216
#
# [20210227-2200-43] Learning rate for epoch 29 is 0.0013611499452963471
# Epoch 29/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.7187
# Epoch 00029: val_loss did not improve from 7.24402
# 17/17 [==============================] - 1s 80ms/step - loss: 9.7187 - val_loss: 7.4680
#
# [20210227-2200-47] Learning rate for epoch 30 is 0.001408294658176601
# Epoch 30/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.0383
# Epoch 00030: val_loss improved from 7.24402 to 7.03775, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 113ms/step - loss: 10.0383 - val_loss: 7.0377
#
# [20210227-2200-52] Learning rate for epoch 31 is 0.0014553394867107272
# Epoch 31/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.5996
# Epoch 00031: val_loss did not improve from 7.03775
# 17/17 [==============================] - 1s 79ms/step - loss: 9.5996 - val_loss: 9.7178
#
# [20210227-2200-56] Learning rate for epoch 32 is 0.0015022843144834042
# Epoch 32/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.5978
# Epoch 00032: val_loss did not improve from 7.03775
# 17/17 [==============================] - 1s 80ms/step - loss: 9.5978 - val_loss: 7.6146
#
# [20210227-2201-00] Learning rate for epoch 33 is 0.0015491291414946318
# Epoch 33/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.1779
# Epoch 00033: val_loss did not improve from 7.03775
# 17/17 [==============================] - 1s 78ms/step - loss: 9.1779 - val_loss: 7.6025
#
# [20210227-2201-04] Learning rate for epoch 34 is 0.00159587396774441
# Epoch 34/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.1914
# Epoch 00034: val_loss improved from 7.03775 to 6.80192, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 114ms/step - loss: 9.1914 - val_loss: 6.8019
#
# [20210227-2201-09] Learning rate for epoch 35 is 0.001642518793232739
# Epoch 35/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.3789
# Epoch 00035: val_loss improved from 6.80192 to 6.34876, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 115ms/step - loss: 9.3789 - val_loss: 6.3488
#
# [20210227-2201-14] Learning rate for epoch 36 is 0.0016890636179596186
# Epoch 36/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.2564
# Epoch 00036: val_loss did not improve from 6.34876
# 17/17 [==============================] - 1s 80ms/step - loss: 9.2564 - val_loss: 7.4249
#
# [20210227-2201-18] Learning rate for epoch 37 is 0.0017355084419250488
# Epoch 37/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.0683
# Epoch 00037: val_loss did not improve from 6.34876
# 17/17 [==============================] - 1s 80ms/step - loss: 9.0683 - val_loss: 7.2195
#
# [20210227-2201-23] Learning rate for epoch 38 is 0.0017818533815443516
# Epoch 38/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.8681
# Epoch 00038: val_loss did not improve from 6.34876
# 17/17 [==============================] - 1s 79ms/step - loss: 8.8681 - val_loss: 7.7344
#
# [20210227-2201-27] Learning rate for epoch 39 is 0.0018280982039868832
# Epoch 39/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.7502
# Epoch 00039: val_loss did not improve from 6.34876
# 17/17 [==============================] - 1s 80ms/step - loss: 8.7502 - val_loss: 6.3574
#
# [20210227-2201-31] Learning rate for epoch 40 is 0.0018742431420832872
# Epoch 40/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.9207
# Epoch 00040: val_loss did not improve from 6.34876
# 17/17 [==============================] - 1s 79ms/step - loss: 8.9207 - val_loss: 7.3581
#
# [20210227-2201-35] Learning rate for epoch 41 is 0.0019202879630029202
# Epoch 41/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.9183
# Epoch 00041: val_loss improved from 6.34876 to 6.25387, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 114ms/step - loss: 8.9183 - val_loss: 6.2539
#
# [20210227-2201-40] Learning rate for epoch 42 is 0.0019662328995764256
# Epoch 42/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.8083
# Epoch 00042: val_loss did not improve from 6.25387
# 17/17 [==============================] - 1s 78ms/step - loss: 8.8083 - val_loss: 6.2952
#
# [20210227-2201-44] Learning rate for epoch 43 is 0.00201207771897316
# Epoch 43/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.7163
# Epoch 00043: val_loss did not improve from 6.25387
# 17/17 [==============================] - 1s 79ms/step - loss: 8.7163 - val_loss: 6.6781
#
# [20210227-2201-49] Learning rate for epoch 44 is 0.0020578226540237665
# Epoch 44/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.5551
# Epoch 00044: val_loss did not improve from 6.25387
# 17/17 [==============================] - 1s 79ms/step - loss: 8.5551 - val_loss: 6.7364
#
# [20210227-2201-53] Learning rate for epoch 45 is 0.0021034677047282457
# Epoch 45/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.6782
# Epoch 00045: val_loss did not improve from 6.25387
# 17/17 [==============================] - 1s 79ms/step - loss: 8.6782 - val_loss: 6.7569
#
# [20210227-2201-57] Learning rate for epoch 46 is 0.002149012638255954
# Epoch 46/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.7905
# Epoch 00046: val_loss did not improve from 6.25387
# 17/17 [==============================] - 1s 79ms/step - loss: 8.7905 - val_loss: 6.7030
#
# [20210227-2202-01] Learning rate for epoch 47 is 0.0021944576874375343
# Epoch 47/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.6918
# Epoch 00047: val_loss did not improve from 6.25387
# 17/17 [==============================] - 1s 81ms/step - loss: 8.6918 - val_loss: 6.6011
#
# [20210227-2202-06] Learning rate for epoch 48 is 0.0022398026194423437
# Epoch 48/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.5231
# Epoch 00048: val_loss did not improve from 6.25387
# 17/17 [==============================] - 1s 80ms/step - loss: 8.5231 - val_loss: 6.6347
#
# [20210227-2202-10] Learning rate for epoch 49 is 0.002285047434270382
# Epoch 49/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.4998
# Epoch 00049: val_loss did not improve from 6.25387
# 17/17 [==============================] - 1s 79ms/step - loss: 8.4998 - val_loss: 8.2015
#
# [20210227-2202-14] Learning rate for epoch 50 is 0.0023301925975829363
# Epoch 50/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.4699
# Epoch 00050: val_loss did not improve from 6.25387
# 17/17 [==============================] - 1s 80ms/step - loss: 8.4699 - val_loss: 7.0190
#
# [20210227-2202-19] Learning rate for epoch 51 is 0.002375237410888076
# Epoch 51/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.1983
# Epoch 00051: val_loss did not improve from 6.25387
# 17/17 [==============================] - 1s 79ms/step - loss: 8.1983 - val_loss: 7.1514
#
# [20210227-2202-23] Learning rate for epoch 52 is 0.0024201825726777315
# Epoch 52/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.6210
# Epoch 00052: val_loss did not improve from 6.25387
# 17/17 [==============================] - 1s 80ms/step - loss: 8.6210 - val_loss: 7.5056
#
# [20210227-2202-27] Learning rate for epoch 53 is 0.002465027617290616
# Epoch 53/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.2119
# Epoch 00053: val_loss did not improve from 6.25387
# 17/17 [==============================] - 1s 79ms/step - loss: 8.2119 - val_loss: 10.7216
#
# [20210227-2202-31] Learning rate for epoch 54 is 0.0025097725447267294
# Epoch 54/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.6249
# Epoch 00054: val_loss did not improve from 6.25387
# 17/17 [==============================] - 1s 80ms/step - loss: 8.6249 - val_loss: 6.7740
#
# [20210227-2202-36] Learning rate for epoch 55 is 0.0025544175878167152
# Epoch 55/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.3852
# Epoch 00055: val_loss did not improve from 6.25387
# 17/17 [==============================] - 1s 78ms/step - loss: 8.3852 - val_loss: 6.5478
#
# [20210227-2202-40] Learning rate for epoch 56 is 0.00259896251372993
# Epoch 56/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.1030
# Epoch 00056: val_loss did not improve from 6.25387
# 17/17 [==============================] - 1s 79ms/step - loss: 8.1030 - val_loss: 6.5635
#
# [20210227-2202-44] Learning rate for epoch 57 is 0.0026434077881276608
# Epoch 57/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.2405
# Epoch 00057: val_loss did not improve from 6.25387
# 17/17 [==============================] - 1s 78ms/step - loss: 8.2405 - val_loss: 7.2152
#
# [20210227-2202-48] Learning rate for epoch 58 is 0.0026877527125179768
# Epoch 58/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.1481
# Epoch 00058: val_loss improved from 6.25387 to 6.19343, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 125ms/step - loss: 8.1481 - val_loss: 6.1934
#
# [20210227-2202-53] Learning rate for epoch 59 is 0.0027319977525621653
# Epoch 59/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.1975
# Epoch 00059: val_loss did not improve from 6.19343
# 17/17 [==============================] - 1s 80ms/step - loss: 8.1975 - val_loss: 6.3130
#
# [20210227-2202-58] Learning rate for epoch 60 is 0.0027761429082602262
# Epoch 60/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.2352
# Epoch 00060: val_loss improved from 6.19343 to 6.09926, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 113ms/step - loss: 8.2352 - val_loss: 6.0993
#
# [20210227-2203-02] Learning rate for epoch 61 is 0.002820187946781516
# Epoch 61/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.1762
# Epoch 00061: val_loss did not improve from 6.09926
# 17/17 [==============================] - 1s 78ms/step - loss: 8.1762 - val_loss: 7.3221
#
# [20210227-2203-07] Learning rate for epoch 62 is 0.0028641331009566784
# Epoch 62/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.3008
# Epoch 00062: val_loss did not improve from 6.09926
# 17/17 [==============================] - 2s 97ms/step - loss: 8.3008 - val_loss: 6.9560
#
# [20210227-2203-11] Learning rate for epoch 63 is 0.0029079781379550695
# Epoch 63/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.1129
# Epoch 00063: val_loss did not improve from 6.09926
# 17/17 [==============================] - 1s 79ms/step - loss: 8.1129 - val_loss: 6.9727
#
# [20210227-2203-16] Learning rate for epoch 64 is 0.002951723290607333
# Epoch 64/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.0655
# Epoch 00064: val_loss improved from 6.09926 to 6.01217, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 117ms/step - loss: 8.0655 - val_loss: 6.0122
#
# [20210227-2203-20] Learning rate for epoch 65 is 0.0029953685589134693
# Epoch 65/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.0005
# Epoch 00065: val_loss improved from 6.01217 to 5.82601, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 113ms/step - loss: 8.0005 - val_loss: 5.8260
#
# [20210227-2203-25] Learning rate for epoch 66 is 0.0030389137100428343
# Epoch 66/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.1467
# Epoch 00066: val_loss improved from 5.82601 to 5.72243, saving model to ./20210227-215401/toe_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 2s 111ms/step - loss: 8.1467 - val_loss: 5.7224
#
# [20210227-2203-30] Learning rate for epoch 67 is 0.003082358743995428
# Epoch 67/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.9325
# Epoch 00067: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 80ms/step - loss: 7.9325 - val_loss: 5.8237
#
# [20210227-2203-34] Learning rate for epoch 68 is 0.0031257038936018944
# Epoch 68/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.0527
# Epoch 00068: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 80ms/step - loss: 8.0527 - val_loss: 6.0606
#
# [20210227-2203-39] Learning rate for epoch 69 is 0.003168949158862233
# Epoch 69/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.9337
# Epoch 00069: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 80ms/step - loss: 7.9337 - val_loss: 6.5693
#
# [20210227-2203-43] Learning rate for epoch 70 is 0.0032120943069458008
# Epoch 70/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.0022
# Epoch 00070: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 79ms/step - loss: 8.0022 - val_loss: 6.4904
#
# [20210227-2203-47] Learning rate for epoch 71 is 0.003255139570683241
# Epoch 71/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.0298
# Epoch 00071: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 78ms/step - loss: 8.0298 - val_loss: 6.6322
#
# [20210227-2203-51] Learning rate for epoch 72 is 0.00329808471724391
# Epoch 72/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.4200
# Epoch 00072: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 79ms/step - loss: 8.4200 - val_loss: 6.6232
#
# [20210227-2203-56] Learning rate for epoch 73 is 0.0033409299794584513
# Epoch 73/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.9063
# Epoch 00073: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 79ms/step - loss: 7.9063 - val_loss: 5.9076
#
# [20210227-2204-00] Learning rate for epoch 74 is 0.0033836751244962215
# Epoch 74/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.8720
# Epoch 00074: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 79ms/step - loss: 7.8720 - val_loss: 5.9765
#
# [20210227-2204-04] Learning rate for epoch 75 is 0.0034263203851878643
# Epoch 75/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.8799
# Epoch 00075: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 79ms/step - loss: 7.8799 - val_loss: 5.7964
#
# [20210227-2204-08] Learning rate for epoch 76 is 0.003468865528702736
# Epoch 76/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.6917
# Epoch 00076: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 78ms/step - loss: 7.6917 - val_loss: 5.9390
#
# [20210227-2204-13] Learning rate for epoch 77 is 0.00351131078787148
# Epoch 77/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.6628
# Epoch 00077: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 80ms/step - loss: 7.6628 - val_loss: 7.0094
#
# [20210227-2204-17] Learning rate for epoch 78 is 0.0035536561626940966
# Epoch 78/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.2623
# Epoch 00078: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 78ms/step - loss: 8.2623 - val_loss: 5.9718
#
# [20210227-2204-21] Learning rate for epoch 79 is 0.003595901420339942
# Epoch 79/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.6493
# Epoch 00079: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 81ms/step - loss: 7.6493 - val_loss: 6.0234
#
# [20210227-2204-25] Learning rate for epoch 80 is 0.00363804679363966
# Epoch 80/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.8527
# Epoch 00080: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 79ms/step - loss: 7.8527 - val_loss: 6.0474
#
# [20210227-2204-30] Learning rate for epoch 81 is 0.0036800920497626066
# Epoch 81/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.9719
# Epoch 00081: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 79ms/step - loss: 7.9719 - val_loss: 6.4917
#
# [20210227-2204-34] Learning rate for epoch 82 is 0.003722037188708782
# Epoch 82/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.7001
# Epoch 00082: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 80ms/step - loss: 7.7001 - val_loss: 6.3845
#
# [20210227-2204-38] Learning rate for epoch 83 is 0.003763882676139474
# Epoch 83/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.7924
# Epoch 00083: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 80ms/step - loss: 7.7924 - val_loss: 7.5820
#
# [20210227-2204-42] Learning rate for epoch 84 is 0.0038056280463933945
# Epoch 84/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.0117
# Epoch 00084: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 81ms/step - loss: 8.0117 - val_loss: 6.0702
#
# [20210227-2204-47] Learning rate for epoch 85 is 0.003847273299470544
# Epoch 85/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.7774
# Epoch 00085: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 79ms/step - loss: 7.7774 - val_loss: 6.2957
#
# [20210227-2204-51] Learning rate for epoch 86 is 0.0038888186682015657
# Epoch 86/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.5824
# Epoch 00086: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 79ms/step - loss: 7.5824 - val_loss: 7.2256
#
# [20210227-2204-55] Learning rate for epoch 87 is 0.00393026415258646
# Epoch 87/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.6751
# Epoch 00087: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 78ms/step - loss: 7.6751 - val_loss: 6.5594
#
# [20210227-2205-00] Learning rate for epoch 88 is 0.00397160928696394
# Epoch 88/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.5586
# Epoch 00088: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 80ms/step - loss: 7.5586 - val_loss: 5.8570
#
# [20210227-2205-04] Learning rate for epoch 89 is 0.004012854769825935
# Epoch 89/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.5954
# Epoch 00089: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 80ms/step - loss: 7.5954 - val_loss: 5.9292
#
# [20210227-2205-08] Learning rate for epoch 90 is 0.00405400013551116
# Epoch 90/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.5968
# Epoch 00090: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 79ms/step - loss: 7.5968 - val_loss: 6.1382
#
# [20210227-2205-12] Learning rate for epoch 91 is 0.004095045384019613
# Epoch 91/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.8192
# Epoch 00091: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 80ms/step - loss: 7.8192 - val_loss: 6.2453
#
# [20210227-2205-17] Learning rate for epoch 92 is 0.004135990981012583
# Epoch 92/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.8449
# Epoch 00092: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 79ms/step - loss: 7.8449 - val_loss: 6.9980
#
# [20210227-2205-21] Learning rate for epoch 93 is 0.004176836460828781
# Epoch 93/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.8746
# Epoch 00093: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 80ms/step - loss: 7.8746 - val_loss: 6.4314
#
# [20210227-2205-25] Learning rate for epoch 94 is 0.004217581823468208
# Epoch 94/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.6165
# Epoch 00094: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 78ms/step - loss: 7.6165 - val_loss: 7.4011
#
# [20210227-2205-29] Learning rate for epoch 95 is 0.004258227068930864
# Epoch 95/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.5249
# Epoch 00095: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 79ms/step - loss: 7.5249 - val_loss: 7.7109
#
# [20210227-2205-34] Learning rate for epoch 96 is 0.0042987726628780365
# Epoch 96/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.3435
# Epoch 00096: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 79ms/step - loss: 7.3435 - val_loss: 6.3043
#
# [20210227-2205-38] Learning rate for epoch 97 is 0.0043392181396484375
# Epoch 97/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.8647
# Epoch 00097: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 78ms/step - loss: 7.8647 - val_loss: 8.5003
#
# [20210227-2205-42] Learning rate for epoch 98 is 0.004379563499242067
# Epoch 98/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.9443
# Epoch 00098: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 79ms/step - loss: 7.9443 - val_loss: 7.5255
#
# [20210227-2205-46] Learning rate for epoch 99 is 0.004419809207320213
# Epoch 99/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.4837
# Epoch 00099: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 79ms/step - loss: 7.4837 - val_loss: 7.0302
#
# [20210227-2205-51] Learning rate for epoch 100 is 0.004459954332560301
# Epoch 100/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.3866
# Epoch 00100: val_loss did not improve from 5.72243
# 17/17 [==============================] - 1s 80ms/step - loss: 7.3866 - val_loss: 6.2700
#
# ...
# 17/17 [==============================] - ETA: 0s - loss: 6.3804
# Epoch 00156: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.3804 - val_loss: 5.6163
#
# [20210227-2335-30] Learning rate for epoch 157 is 0.0010131207527592778
# Epoch 157/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.0969
# Epoch 00157: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.0969 - val_loss: 5.8940
#
# [20210227-2335-35] Learning rate for epoch 158 is 0.0011805035173892975
# Epoch 158/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.2404
# Epoch 00158: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.2404 - val_loss: 5.7098
#
# [20210227-2335-39] Learning rate for epoch 159 is 0.0013474862789735198
# Epoch 159/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.1438
# Epoch 00159: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 77ms/step - loss: 6.1438 - val_loss: 5.5726
#
# [20210227-2335-43] Learning rate for epoch 160 is 0.0015140691539272666
# Epoch 160/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.2348
# Epoch 00160: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 80ms/step - loss: 6.2348 - val_loss: 5.7944
#
# [20210227-2335-47] Learning rate for epoch 161 is 0.001680252025835216
# Epoch 161/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.2895
# Epoch 00161: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 78ms/step - loss: 6.2895 - val_loss: 5.8883
#
# [20210227-2335-51] Learning rate for epoch 162 is 0.0018460348946973681
# Epoch 162/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.5179
# Epoch 00162: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 80ms/step - loss: 6.5179 - val_loss: 5.5696
#
# [20210227-2335-56] Learning rate for epoch 163 is 0.0020114178769290447
# Epoch 163/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.2593
# Epoch 00163: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.2593 - val_loss: 5.4922
#
# [20210227-2336-00] Learning rate for epoch 164 is 0.0021764009725302458
# Epoch 164/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.5415
# Epoch 00164: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 80ms/step - loss: 6.5415 - val_loss: 5.9985
#
# [20210227-2336-04] Learning rate for epoch 165 is 0.002340983832255006
# Epoch 165/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.6454
# Epoch 00165: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.6454 - val_loss: 6.7384
#
# [20210227-2336-08] Learning rate for epoch 166 is 0.002505166921764612
# Epoch 166/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.9773
# Epoch 00166: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.9773 - val_loss: 5.5883
#
# [20210227-2336-13] Learning rate for epoch 167 is 0.002668950008228421
# Epoch 167/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.4930
# Epoch 00167: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.4930 - val_loss: 6.0012
#
# [20210227-2336-17] Learning rate for epoch 168 is 0.0028323333244770765
# Epoch 168/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.4530
# Epoch 00168: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.4530 - val_loss: 6.3691
#
# [20210227-2336-21] Learning rate for epoch 169 is 0.002995316404849291
# Epoch 169/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.9048
# Epoch 00169: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 78ms/step - loss: 6.9048 - val_loss: 6.3100
#
# [20210227-2336-25] Learning rate for epoch 170 is 0.0031578997150063515
# Epoch 170/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.6658
# Epoch 00170: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 80ms/step - loss: 6.6658 - val_loss: 6.3969
#
# [20210227-2336-30] Learning rate for epoch 171 is 0.0033200830221176147
# Epoch 171/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.4867
# Epoch 00171: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 80ms/step - loss: 6.4867 - val_loss: 6.4883
#
# [20210227-2336-34] Learning rate for epoch 172 is 0.0034818663261830807
# Epoch 172/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.6327
# Epoch 00172: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.6327 - val_loss: 6.5679
#
# [20210227-2336-38] Learning rate for epoch 173 is 0.0036432496272027493
# Epoch 173/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.6971
# Epoch 00173: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.6971 - val_loss: 6.4506
#
# [20210227-2336-42] Learning rate for epoch 174 is 0.003804233158007264
# Epoch 174/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.4506
# Epoch 00174: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 78ms/step - loss: 6.4506 - val_loss: 6.6497
#
# [20210227-2336-46] Learning rate for epoch 175 is 0.003964816685765982
# Epoch 175/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.8068
# Epoch 00175: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 80ms/step - loss: 6.8068 - val_loss: 6.1810
#
# [20210227-2336-51] Learning rate for epoch 176 is 0.004124999977648258
# Epoch 176/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.6231
# Epoch 00176: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 78ms/step - loss: 6.6231 - val_loss: 6.6173
#
# [20210227-2336-55] Learning rate for epoch 177 is 0.003955216612666845
# Epoch 177/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.7452
# Epoch 00177: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 80ms/step - loss: 6.7452 - val_loss: 7.9772
#
# [20210227-2336-59] Learning rate for epoch 178 is 0.003785833017900586
# Epoch 178/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.6384
# Epoch 00178: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 78ms/step - loss: 6.6384 - val_loss: 6.2235
#
# [20210227-2337-03] Learning rate for epoch 179 is 0.0036168494261801243
# Epoch 179/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.1263
# Epoch 00179: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 7.1263 - val_loss: 6.1399
#
# [20210227-2337-08] Learning rate for epoch 180 is 0.003448265604674816
# Epoch 180/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.6227
# Epoch 00180: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 78ms/step - loss: 6.6227 - val_loss: 6.3099
#
# [20210227-2337-12] Learning rate for epoch 181 is 0.003280082019045949
# Epoch 181/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.6353
# Epoch 00181: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.6353 - val_loss: 7.0133
#
# [20210227-2337-16] Learning rate for epoch 182 is 0.0031122982036322355
# Epoch 182/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.8504
# Epoch 00182: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.8504 - val_loss: 5.8432
#
# [20210227-2337-20] Learning rate for epoch 183 is 0.002944914624094963
# Epoch 183/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.3015
# Epoch 00183: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 80ms/step - loss: 6.3015 - val_loss: 6.0050
#
# [20210227-2337-24] Learning rate for epoch 184 is 0.0027779308147728443
# Epoch 184/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.7282
# Epoch 00184: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.7282 - val_loss: 6.4344
#
# [20210227-2337-29] Learning rate for epoch 185 is 0.0026113467756658792
# Epoch 185/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.6964
# Epoch 00185: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 78ms/step - loss: 6.6964 - val_loss: 5.8862
#
# [20210227-2337-33] Learning rate for epoch 186 is 0.002445162972435355
# Epoch 186/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.3985
# Epoch 00186: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.3985 - val_loss: 6.6151
#
# [20210227-2337-37] Learning rate for epoch 187 is 0.0022793791722506285
# Epoch 187/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.4994
# Epoch 00187: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 78ms/step - loss: 6.4994 - val_loss: 5.8108
#
# [20210227-2337-41] Learning rate for epoch 188 is 0.0021139951422810555
# Epoch 188/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.1658
# Epoch 00188: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.1658 - val_loss: 5.7859
#
# [20210227-2337-46] Learning rate for epoch 189 is 0.0019490111153572798
# Epoch 189/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.2173
# Epoch 00189: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 78ms/step - loss: 6.2173 - val_loss: 6.1513
#
# [20210227-2337-50] Learning rate for epoch 190 is 0.0017844270914793015
# Epoch 190/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.2339
# Epoch 00190: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.2339 - val_loss: 5.6978
#
# [20210227-2337-54] Learning rate for epoch 191 is 0.0016202429542317986
# Epoch 191/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.9661
# Epoch 00191: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 5.9661 - val_loss: 5.6824
#
# [20210227-2337-58] Learning rate for epoch 192 is 0.001456458936445415
# Epoch 192/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.2684
# Epoch 00192: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.2684 - val_loss: 5.5297
#
# [20210227-2338-02] Learning rate for epoch 193 is 0.001293074688874185
# Epoch 193/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.3294
# Epoch 00193: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 80ms/step - loss: 6.3294 - val_loss: 5.5480
#
# [20210227-2338-07] Learning rate for epoch 194 is 0.0011300905607640743
# Epoch 194/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.1766
# Epoch 00194: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 78ms/step - loss: 6.1766 - val_loss: 5.8315
#
# [20210227-2338-11] Learning rate for epoch 195 is 0.0009675062610767782
# Epoch 195/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.1380
# Epoch 00195: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.1380 - val_loss: 5.7305
#
# [20210227-2338-15] Learning rate for epoch 196 is 0.0008053220226429403
# Epoch 196/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.0724
# Epoch 00196: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 78ms/step - loss: 6.0724 - val_loss: 5.5784
#
# [20210227-2338-19] Learning rate for epoch 197 is 0.0006435376708395779
# Epoch 197/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.0575
# Epoch 00197: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 80ms/step - loss: 6.0575 - val_loss: 5.7459
#
# [20210227-2338-23] Learning rate for epoch 198 is 0.0004821533220820129
# Epoch 198/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.2660
# Epoch 00198: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 78ms/step - loss: 6.2660 - val_loss: 5.5922
#
# [20210227-2338-28] Learning rate for epoch 199 is 0.0003211689181625843
# Epoch 199/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.0600
# Epoch 00199: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.0600 - val_loss: 5.4659
#
# [20210227-2338-32] Learning rate for epoch 200 is 0.00016058447363320738
# Epoch 200/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.8087
# Epoch 00200: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 78ms/step - loss: 5.8087 - val_loss: 5.4868
#
# [20210227-2338-36] Learning rate for epoch 201 is 4.0000000467443897e-07
# Epoch 201/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.8405
# Epoch 00201: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 5.8405 - val_loss: 5.4737
#
# [20210227-2338-40] Learning rate for epoch 202 is 0.0001601835247129202
# Epoch 202/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.0403
# Epoch 00202: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.0403 - val_loss: 5.4345
#
# [20210227-2338-45] Learning rate for epoch 203 is 0.00031956707243807614
# Epoch 203/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.1006
# Epoch 00203: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 78ms/step - loss: 6.1006 - val_loss: 5.3875
#
# [20210227-2338-49] Learning rate for epoch 204 is 0.00047855067532509565
# Epoch 204/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.9931
# Epoch 00204: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 5.9931 - val_loss: 5.4844
#
# [20210227-2338-53] Learning rate for epoch 205 is 0.0006371343042701483
# Epoch 205/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.0199
# Epoch 00205: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 78ms/step - loss: 6.0199 - val_loss: 5.4850
#
# [20210227-2338-57] Learning rate for epoch 206 is 0.0007953179883770645
# Epoch 206/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.7824
# Epoch 00206: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 5.7824 - val_loss: 5.5160
#
# [20210227-2339-02] Learning rate for epoch 207 is 0.0009531017276458442
# Epoch 207/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.9426
# Epoch 00207: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 5.9426 - val_loss: 5.7061
#
# [20210227-2339-06] Learning rate for epoch 208 is 0.0011104855220764875
# Epoch 208/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.0340
# Epoch 00208: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 6.0340 - val_loss: 5.4619
#
# [20210227-2339-10] Learning rate for epoch 209 is 0.0012674692552536726
# Epoch 209/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.9252
# Epoch 00209: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 5.9252 - val_loss: 5.6809
#
# [20210227-2339-14] Learning rate for epoch 210 is 0.0014240531018003821
# Epoch 210/1000
# 17/17 [==============================] - ETA: 0s - loss: 5.8280
# Epoch 00210: val_loss did not improve from 5.23418
# 17/17 [==============================] - 1s 79ms/step - loss: 5.8280 - val_loss: 6.0053
# CPU times: user 2h 44min 45s, sys: 27min 51s, total: 3h 12min 36s
# Wall time: 1h 45min 17s

# %%
#ED sum
def get_valloss(his_v_l):  
    return np.min(his_v_l), np.argmin(his_v_l)

t_vl = []
# h_vl = []
for k in range(KFlodNum):
    print(f'K:{k}')
    t_v, _ = get_valloss(history_toe_finetune[k].history['val_loss'])
#     h_v, _ = get_valloss(history_heel_finetune[k].history['val_loss'])
    
    t_vl.append(t_v)
#     h_vl.append(h_v)

# t_vl = np.mean(t_vl, axis=0)
# h_vl = np.mean(h_vl, axis=0)
# print(f'{round(t_vl,5)} + {round(h_vl,5)} = {round(t_vl + h_vl,5)}')

t_vl
# Out:
# K:0
# K:1
# K:2
# K:3
# K:4
# [5.443403720855713,
#  5.258741855621338,
#  5.77152681350708,
#  5.366166591644287,
#  5.23417854309082]

# %%
np.savetxt(f'{log_dir_name}/toe_FNED.txt', t_vl)

# %%
# Sum plot losses toe-tl

plt.figure(figsize=(25, 10))

for k in range(KFlodNum):

    plt.plot(history_toe[k].history['loss'])
    plt.plot(history_toe[k].history['val_loss'])

    
plt.title('K-model ed loss toe-TL')
plt.ylabel('ed loss'), plt.ylim(5, 80)# for too large loss
plt.xlabel('epoch')
plt.legend(['k0 loss', 'k0 val_loss', 'k1 loss', 'k1 val_loss', 'k2 loss', 'k2 val_loss', 
            'k3 loss', 'k3 val_loss', 'k4 loss', 'k4 val_loss'], loc='upper left') 
# plt.show()

# save plot : comment plo.show in jupyter notebook.
plt.savefig(f'{log_dir_name}/{log_dir_name}_toe_Ksum_TL.png', bbox_inches = 'tight')

# %%
# Single plot loss toe-tl

for k in range(KFlodNum):
    plt.figure(figsize=(25, 10))
    plt.plot(history_toe[k].history['loss'])
    plt.plot(history_toe[k].history['val_loss'])
    plt.title('K-model ed loss toe-TL')
    plt.ylabel('ed loss'), plt.ylim(5, 20)# for too large loss
    plt.xlabel('epoch')
    plt.legend(['loss', 'val_loss'], loc='upper left') 
    # plt.show()

    # save plot : comment plo.show in jupyter notebook.
    def get_valloss(his_v_l):   
        return np.min(his_v_l), np.argmin(his_v_l)

    vl, ep = get_valloss(history_toe[k].history['val_loss'])
    plt.savefig(f'{log_dir_name}/{log_dir_name}_toe_K{k}_TL_clr_ed{round(vl,4)}@{ep}.png', bbox_inches = 'tight')

# %%
# check the loos the model trained.

def get_valloss(his_v_l):  
    return np.min(his_v_l), np.argmin(his_v_l)

t_vl = []
# h_vl = []
for k in range(KFlodNum):
    print(f'K:{k}')
    t_v, _ = get_valloss(history_toe_finetune[k].history['val_loss'])
#     h_v, _ = get_valloss(history_heel_finetune[k].history['val_loss'])
    
    t_vl.append(t_v)
    
# for different scales (different Y-axes)
# fig, ax1 = plt.subplots()
fig, ax1 = plt.subplots(figsize=(25, 10))

# nice to have this colorful tip.
color = 'tab:red'

ax1.set_title('[ toe_finetune ] \n ED loss')

ax1.set_xlabel('epoch')
ax1.set_ylabel('ed loss', color=color)

for k in range(KFlodNum):

    plt.plot(history_toe_finetune[k].history['loss'])
    plt.plot(history_toe_finetune[k].history['val_loss'])

ax1.tick_params(axis='y', labelcolor=color)
# ax1.legend(['loss', 'val_loss'], loc='upper center') # legend may ocvered by next ax ploting. moved to end.
ax1.legend(['k0 loss', 'k0 val_loss', 'k1 loss', 'k1 val_loss', 'k2 loss', 'k2 val_loss', 
            'k3 loss', 'k3 val_loss', 'k4 loss', 'k4 val_loss'], loc='upper left') 

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('learning rate', color=color)
ax2.plot(history_toe_finetune[0].history['lr'], color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.legend(['lr'], loc='upper right') 

# plt.show()

# # save plot : comment plo.show in jupyter notebook.
# def get_valloss(his_v_l):   
#     return np.min(his_v_l), np.argmin(his_v_l)

# vl, ep = get_valloss(history_toe_finetune.history['val_loss'])


t_vl = np.mean(t_vl, axis=0)
plt.savefig(f'{log_dir_name}/{log_dir_name}_toe_ft_Ksum-clr_ed{round(t_vl,4)}.png', bbox_inches = 'tight')
# Out:
# K:0
# K:1
# K:2
# K:3
# K:4

# %%
# Sum plot losses toe-ft

plt.figure(figsize=(25, 10))

for k in range(KFlodNum):

    plt.plot(history_toe_finetune[k].history['loss'])
    plt.plot(history_toe_finetune[k].history['val_loss'])

    
plt.title('K-model ed loss toe-FT')
plt.ylabel('ed loss'), plt.ylim(4, 20)# for too large loss
plt.xlabel('epoch')
plt.legend(['k0 loss', 'k0 val_loss', 'k1 loss', 'k1 val_loss', 'k2 loss', 'k2 val_loss', 
            'k3 loss', 'k3 val_loss', 'k4 loss', 'k4 val_loss'], loc='upper left') 
# plt.show()

# save plot : comment plo.show in jupyter notebook.
plt.savefig(f'{log_dir_name}/{log_dir_name}_toe_Ksum_FT.png', bbox_inches = 'tight')

# %%
# Single plot loss toe-FT

for k in range(KFlodNum):
    plt.figure(figsize=(25, 10))
    plt.plot(history_toe_finetune[k].history['loss'])
    plt.plot(history_toe_finetune[k].history['val_loss'])
    plt.title('K-model ed loss toe-FT')
    plt.ylabel('ed loss'), plt.ylim(4, 20)# for too large loss
    plt.xlabel('epoch')
    plt.legend(['loss', 'val_loss'], loc='upper left') 
    # plt.show()

    # save plot : comment plo.show in jupyter notebook.
    def get_valloss(his_v_l):   
        return np.min(his_v_l), np.argmin(his_v_l)

    vl, ep = get_valloss(history_toe_finetune[k].history['val_loss'])
    plt.savefig(f'{log_dir_name}/{log_dir_name}_toe_K{k}_FT_clr_ed{round(vl,4)}@{ep}.png', bbox_inches = 'tight')

# %% [markdown]
# ### Heel K-model

# %%
# %%time

# big K = 5 (fold 0 ~ 4) 
# KFlodNum = 5 # follow Toe's K.



history_heel = []
history_heel_finetune = []

#above until 'train_ds_map_toe now' to 'train_ds_map_toe_s', 'valid_ds_map_toe_s'
for k in range(KFlodNum):
    
    
    # Split data to train/valid with K-Fold #
    print("K=", k)
#     # Toe split
#     train_ds_map_toe_s, valid_ds_map_toe_s = get_KFold_ds(train_ds_map_toe, K=k)
    
#     # Toe ds_pre
#     train_ds_pre_toe_s = configure_for_performance_cache_train(train_ds_map_toe_s, augment=True)
#     valid_ds_pre_toe_s = configure_for_performance_cache_val(valid_ds_map_toe_s)
    
    
    # heel split
    train_ds_map_heel_s, valid_ds_map_heel_s = get_KFold_ds(train_ds_map_heel, K=k)
    # Heel ds_pre
    train_ds_pre_heel_s = configure_for_performance_cache_train_AToe(train_ds_map_heel_s, augment=True)
    valid_ds_pre_heel_s = configure_for_performance_cache_val(valid_ds_map_heel_s)
    
    
    # Train K-Model with transfer learnling #
    
    # Toe model, TL
    #th = 'toe'
    th = 'heel'
    best_model_name = get_best_model_name(th, K=str(k))
    best_model_save = tf.keras.callbacks.ModelCheckpoint(filepath=best_model_name, 
                                 save_best_only = True, 
                                 save_weights_only = False,
                                 monitor = monitor, 
                                 mode = 'auto', verbose = 1)
    callbacks_heel_tl = [
                    #     tensorboard_callback,
                        best_model_save,
                        tf.keras.callbacks.EarlyStopping(monitor=monitor, patience=20), #patience=step_size or ep_num
                    #     lr_reduceonplateau,
                        tf.keras.callbacks.LearningRateScheduler(lrdump),#lrdump, decay or lrfn or lrfn2. clr
                        PrintLRtoe()
                        ]
    callbacks_heel_fn = [
                    #     tensorboard_callback,
                        best_model_save,
                        tf.keras.callbacks.EarlyStopping(monitor=monitor, patience=100), #patience=step_size or ep_num
                    #     lr_reduceonplateau,
                        tf.keras.callbacks.LearningRateScheduler(clr3),#lrdump, decay or lrfn or lrfn2. clr, CosineDecayCLRWarmUp, CosineDecayCLRWarmUpLSW
                        PrintLRheel()
                    ]
    print('best_model_name:', best_model_name)


    top_dropout_rate = 0.4 #less dp rate, say 0.1, train_loss will lower than val_loss
    drop_connect_rate = 0.4 #for efnet This parameter serves as a toggle for extra regularization in finetuning, but does not affect loaded weights.
    outputnum = 2
    with strategy.scope():
        model_heel = build_efn_model(outputnum, top_dropout_rate, drop_connect_rate)
    # fit the model on all data
    hist = model_heel.fit(train_ds_pre_heel_s, 
                          verbose=1, 
                          epochs=ep_num_transf, 
                          validation_data=valid_ds_pre_heel_s, 
                          callbacks=callbacks_heel_tl)#, validation_split=0.1)
    history_heel.append(hist)
    
      
    # Train K-Model with fine tune #
    
    # Toe model, FT
    unfreeze_model(model_heel)
    count_model_trainOrNot_layers(model_heel)
    # fit the model on all data
    hist = model_heel.fit(train_ds_pre_heel_s, 
                          verbose=1, 
                          epochs=ep_num, 
                          validation_data=valid_ds_pre_heel_s, 
                          callbacks=callbacks_heel_fn)#, validation_split=0.1)
    history_heel_finetune.append(hist)
# Out:
# K= 0
# Check cache in memory:Y True
# Check keypoints process01: Tensor("args_1:0", shape=(2,), dtype=int64) (2,) <class 'tensorflow.python.framework.ops.Tensor'>
# Check keypoints process02: Tensor("Reshape:0", shape=(1, 2), dtype=int64) (1, 2) <class 'tensorflow.python.framework.ops.Tensor'>
# Check keypoints process03: Tensor("PyFunc:1", dtype=float32, device=/job:localhost/replica:0/task:0)
# Check keypoints process04: Tensor("Reshape_1:0", shape=(2,), dtype=float32)
# Check augment :Y True
# Check ds cache[True] and augment[True]
# Check cache in memory:Y True
# Check augment :N False
# Check ds cache[True] and augment[False]
# best_model_name: ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# base_model.trainable :  False
#
# [20210227-2339-32] Learning rate for epoch 1 is 0.0014240531018003821
# Epoch 1/500
# 15/17 [=========================>....] - ETA: 0s - loss: 110.0064
# Epoch 00001: val_loss improved from inf to 91.25970, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 11s 630ms/step - loss: 108.4832 - val_loss: 91.2597
#
# [20210227-2339-52] Learning rate for epoch 2 is 0.0014240531018003821
# Epoch 2/500
# 16/17 [===========================>..] - ETA: 0s - loss: 54.0850
# Epoch 00002: val_loss improved from 91.25970 to 27.70116, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 52.8340 - val_loss: 27.7012
#
# [20210227-2339-55] Learning rate for epoch 3 is 0.0014240531018003821
# Epoch 3/500
# 17/17 [==============================] - ETA: 0s - loss: 27.2716
# Epoch 00003: val_loss improved from 27.70116 to 25.47238, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 8s 493ms/step - loss: 27.2716 - val_loss: 25.4724
#
# [20210227-2340-07] Learning rate for epoch 4 is 0.0014240531018003821
# Epoch 4/500
# 17/17 [==============================] - ETA: 0s - loss: 21.7393
# Epoch 00004: val_loss improved from 25.47238 to 22.35877, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 48ms/step - loss: 21.7393 - val_loss: 22.3588
#
# [20210227-2340-11] Learning rate for epoch 5 is 0.0014240531018003821
# Epoch 5/500
# 16/17 [===========================>..] - ETA: 0s - loss: 20.3949
# Epoch 00005: val_loss improved from 22.35877 to 21.54363, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 20.4669 - val_loss: 21.5436
#
# [20210227-2340-15] Learning rate for epoch 6 is 0.0014240531018003821
# Epoch 6/500
# 16/17 [===========================>..] - ETA: 0s - loss: 19.4342
# Epoch 00006: val_loss improved from 21.54363 to 21.00297, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 45ms/step - loss: 19.3468 - val_loss: 21.0030
#
# [20210227-2340-18] Learning rate for epoch 7 is 0.0014240531018003821
# Epoch 7/500
# 17/17 [==============================] - ETA: 0s - loss: 19.0466
# Epoch 00007: val_loss improved from 21.00297 to 20.52845, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 19.0466 - val_loss: 20.5285
#
# [20210227-2340-22] Learning rate for epoch 8 is 0.0014240531018003821
# Epoch 8/500
# 17/17 [==============================] - ETA: 0s - loss: 18.4865
# Epoch 00008: val_loss improved from 20.52845 to 19.90832, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 58ms/step - loss: 18.4865 - val_loss: 19.9083
#
# [20210227-2340-26] Learning rate for epoch 9 is 0.0014240531018003821
# Epoch 9/500
# 16/17 [===========================>..] - ETA: 0s - loss: 17.6808
# Epoch 00009: val_loss did not improve from 19.90832
# 17/17 [==============================] - 0s 24ms/step - loss: 17.6412 - val_loss: 20.0183
#
# [20210227-2340-29] Learning rate for epoch 10 is 0.0014240531018003821
# Epoch 10/500
# 16/17 [===========================>..] - ETA: 0s - loss: 18.1128
# Epoch 00010: val_loss improved from 19.90832 to 19.34124, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 18.1627 - val_loss: 19.3412
#
# [20210227-2340-33] Learning rate for epoch 11 is 0.0014240531018003821
# Epoch 11/500
# 16/17 [===========================>..] - ETA: 0s - loss: 17.5671
# Epoch 00011: val_loss improved from 19.34124 to 19.31622, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 17.5350 - val_loss: 19.3162
#
# [20210227-2340-37] Learning rate for epoch 12 is 0.0014240531018003821
# Epoch 12/500
# 16/17 [===========================>..] - ETA: 0s - loss: 17.7943
# Epoch 00012: val_loss improved from 19.31622 to 18.90133, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 52ms/step - loss: 17.7192 - val_loss: 18.9013
#
# [20210227-2340-41] Learning rate for epoch 13 is 0.0014240531018003821
# Epoch 13/500
# 16/17 [===========================>..] - ETA: 0s - loss: 17.4680
# Epoch 00013: val_loss improved from 18.90133 to 18.19307, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 17.4469 - val_loss: 18.1931
#
# [20210227-2340-45] Learning rate for epoch 14 is 0.0014240531018003821
# Epoch 14/500
# 16/17 [===========================>..] - ETA: 0s - loss: 17.0708
# Epoch 00014: val_loss improved from 18.19307 to 17.42467, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 17.0510 - val_loss: 17.4247
#
# [20210227-2340-48] Learning rate for epoch 15 is 0.0014240531018003821
# Epoch 15/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.6064
# Epoch 00015: val_loss improved from 17.42467 to 17.34791, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 16.6047 - val_loss: 17.3479
#
# [20210227-2340-53] Learning rate for epoch 16 is 0.0014240531018003821
# Epoch 16/500
# 16/17 [===========================>..] - ETA: 0s - loss: 17.4835
# Epoch 00016: val_loss improved from 17.34791 to 17.28951, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 48ms/step - loss: 17.3597 - val_loss: 17.2895
#
# [20210227-2340-57] Learning rate for epoch 17 is 0.0014240531018003821
# Epoch 17/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.9794
# Epoch 00017: val_loss improved from 17.28951 to 16.80945, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 55ms/step - loss: 17.0610 - val_loss: 16.8095
#
# [20210227-2341-01] Learning rate for epoch 18 is 0.0014240531018003821
# Epoch 18/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.6709
# Epoch 00018: val_loss improved from 16.80945 to 16.54453, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 16.6440 - val_loss: 16.5445
#
# [20210227-2341-05] Learning rate for epoch 19 is 0.0014240531018003821
# Epoch 19/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.6256
# Epoch 00019: val_loss improved from 16.54453 to 15.86625, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 16.6025 - val_loss: 15.8663
#
# [20210227-2341-09] Learning rate for epoch 20 is 0.0014240531018003821
# Epoch 20/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.8220
# Epoch 00020: val_loss improved from 15.86625 to 15.53133, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 48ms/step - loss: 16.8439 - val_loss: 15.5313
#
# [20210227-2341-13] Learning rate for epoch 21 is 0.0014240531018003821
# Epoch 21/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.5587
# Epoch 00021: val_loss improved from 15.53133 to 15.07008, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 16.4644 - val_loss: 15.0701
#
# [20210227-2341-16] Learning rate for epoch 22 is 0.0014240531018003821
# Epoch 22/500
# 17/17 [==============================] - ETA: 0s - loss: 16.7109
# Epoch 00022: val_loss improved from 15.07008 to 14.98842, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 16.7109 - val_loss: 14.9884
#
# [20210227-2341-20] Learning rate for epoch 23 is 0.0014240531018003821
# Epoch 23/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.0741
# Epoch 00023: val_loss improved from 14.98842 to 14.75736, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 15.9977 - val_loss: 14.7574
#
# [20210227-2341-24] Learning rate for epoch 24 is 0.0014240531018003821
# Epoch 24/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.4603
# Epoch 00024: val_loss improved from 14.75736 to 14.34961, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 16.5235 - val_loss: 14.3496
#
# [20210227-2341-28] Learning rate for epoch 25 is 0.0014240531018003821
# Epoch 25/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.4472
# Epoch 00025: val_loss improved from 14.34961 to 13.94926, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 16.4977 - val_loss: 13.9493
#
# [20210227-2341-32] Learning rate for epoch 26 is 0.0014240531018003821
# Epoch 26/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.9335
# Epoch 00026: val_loss improved from 13.94926 to 13.62636, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 17.0065 - val_loss: 13.6264
#
# [20210227-2341-35] Learning rate for epoch 27 is 0.0014240531018003821
# Epoch 27/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.0983
# Epoch 00027: val_loss improved from 13.62636 to 13.58413, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 16.1856 - val_loss: 13.5841
#
# [20210227-2341-39] Learning rate for epoch 28 is 0.0014240531018003821
# Epoch 28/500
# 17/17 [==============================] - ETA: 0s - loss: 15.9540
# Epoch 00028: val_loss improved from 13.58413 to 12.85526, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 45ms/step - loss: 15.9540 - val_loss: 12.8553
#
# [20210227-2341-43] Learning rate for epoch 29 is 0.0014240531018003821
# Epoch 29/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.1150
# Epoch 00029: val_loss did not improve from 12.85526
# 17/17 [==============================] - 0s 25ms/step - loss: 16.0863 - val_loss: 12.9677
#
# [20210227-2341-46] Learning rate for epoch 30 is 0.0014240531018003821
# Epoch 30/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.1561
# Epoch 00030: val_loss improved from 12.85526 to 12.47395, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 16.0482 - val_loss: 12.4739
#
# [20210227-2341-50] Learning rate for epoch 31 is 0.0014240531018003821
# Epoch 31/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.5031
# Epoch 00031: val_loss improved from 12.47395 to 12.09560, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 49ms/step - loss: 16.5004 - val_loss: 12.0956
#
# [20210227-2341-54] Learning rate for epoch 32 is 0.0014240531018003821
# Epoch 32/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.0686
# Epoch 00032: val_loss improved from 12.09560 to 11.66973, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 16.1747 - val_loss: 11.6697
#
# [20210227-2341-58] Learning rate for epoch 33 is 0.0014240531018003821
# Epoch 33/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.4907
# Epoch 00033: val_loss did not improve from 11.66973
# 17/17 [==============================] - 0s 24ms/step - loss: 16.4106 - val_loss: 12.8862
#
# [20210227-2342-01] Learning rate for epoch 34 is 0.0014240531018003821
# Epoch 34/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.6596
# Epoch 00034: val_loss did not improve from 11.66973
# 17/17 [==============================] - 0s 24ms/step - loss: 16.6076 - val_loss: 11.8644
#
# [20210227-2342-04] Learning rate for epoch 35 is 0.0014240531018003821
# Epoch 35/500
# 17/17 [==============================] - ETA: 0s - loss: 16.6332
# Epoch 00035: val_loss improved from 11.66973 to 11.46279, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 16.6332 - val_loss: 11.4628
#
# [20210227-2342-08] Learning rate for epoch 36 is 0.0014240531018003821
# Epoch 36/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.4591
# Epoch 00036: val_loss improved from 11.46279 to 11.31924, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 16.5199 - val_loss: 11.3192
#
# [20210227-2342-12] Learning rate for epoch 37 is 0.0014240531018003821
# Epoch 37/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.4099
# Epoch 00037: val_loss improved from 11.31924 to 10.82037, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 16.3370 - val_loss: 10.8204
#
# [20210227-2342-16] Learning rate for epoch 38 is 0.0014240531018003821
# Epoch 38/500
# 17/17 [==============================] - ETA: 0s - loss: 15.9337
# Epoch 00038: val_loss did not improve from 10.82037
# 17/17 [==============================] - 0s 24ms/step - loss: 15.9337 - val_loss: 11.5240
#
# [20210227-2342-19] Learning rate for epoch 39 is 0.0014240531018003821
# Epoch 39/500
# 17/17 [==============================] - ETA: 0s - loss: 15.5403
# Epoch 00039: val_loss did not improve from 10.82037
# 17/17 [==============================] - 0s 24ms/step - loss: 15.5403 - val_loss: 10.9795
#
# [20210227-2342-23] Learning rate for epoch 40 is 0.0014240531018003821
# Epoch 40/500
# 17/17 [==============================] - ETA: 0s - loss: 15.8010
# Epoch 00040: val_loss improved from 10.82037 to 10.60984, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 58ms/step - loss: 15.8010 - val_loss: 10.6098
#
# [20210227-2342-26] Learning rate for epoch 41 is 0.0014240531018003821
# Epoch 41/500
# 17/17 [==============================] - ETA: 0s - loss: 15.9463
# Epoch 00041: val_loss improved from 10.60984 to 10.59427, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 45ms/step - loss: 15.9463 - val_loss: 10.5943
#
# [20210227-2342-30] Learning rate for epoch 42 is 0.0014240531018003821
# Epoch 42/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.0765
# Epoch 00042: val_loss improved from 10.59427 to 10.31310, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 16.2504 - val_loss: 10.3131
#
# [20210227-2342-34] Learning rate for epoch 43 is 0.0014240531018003821
# Epoch 43/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.7408
# Epoch 00043: val_loss did not improve from 10.31310
# 17/17 [==============================] - 0s 24ms/step - loss: 15.7024 - val_loss: 10.9732
#
# [20210227-2342-37] Learning rate for epoch 44 is 0.0014240531018003821
# Epoch 44/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.1128
# Epoch 00044: val_loss improved from 10.31310 to 9.44699, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 16.1226 - val_loss: 9.4470
#
# [20210227-2342-41] Learning rate for epoch 45 is 0.0014240531018003821
# Epoch 45/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.9712
# Epoch 00045: val_loss did not improve from 9.44699
# 17/17 [==============================] - 0s 25ms/step - loss: 16.8669 - val_loss: 9.7543
#
# [20210227-2342-45] Learning rate for epoch 46 is 0.0014240531018003821
# Epoch 46/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.0431
# Epoch 00046: val_loss did not improve from 9.44699
# 17/17 [==============================] - 0s 25ms/step - loss: 16.0703 - val_loss: 10.0553
#
# [20210227-2342-48] Learning rate for epoch 47 is 0.0014240531018003821
# Epoch 47/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.8725
# Epoch 00047: val_loss did not improve from 9.44699
# 17/17 [==============================] - 0s 24ms/step - loss: 15.9362 - val_loss: 11.1862
#
# [20210227-2342-52] Learning rate for epoch 48 is 0.0014240531018003821
# Epoch 48/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.6544
# Epoch 00048: val_loss did not improve from 9.44699
# 17/17 [==============================] - 0s 24ms/step - loss: 15.6541 - val_loss: 9.8136
#
# [20210227-2342-55] Learning rate for epoch 49 is 0.0014240531018003821
# Epoch 49/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.0728
# Epoch 00049: val_loss did not improve from 9.44699
# 17/17 [==============================] - 0s 24ms/step - loss: 16.0364 - val_loss: 9.5355
#
# [20210227-2342-58] Learning rate for epoch 50 is 0.0014240531018003821
# Epoch 50/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.0101
# Epoch 00050: val_loss did not improve from 9.44699
# 17/17 [==============================] - 0s 24ms/step - loss: 15.9832 - val_loss: 9.6570
#
# [20210227-2343-02] Learning rate for epoch 51 is 0.0014240531018003821
# Epoch 51/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.4285
# Epoch 00051: val_loss did not improve from 9.44699
# 17/17 [==============================] - 0s 25ms/step - loss: 15.3821 - val_loss: 9.7680
#
# [20210227-2343-05] Learning rate for epoch 52 is 0.0014240531018003821
# Epoch 52/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.0869
# Epoch 00052: val_loss did not improve from 9.44699
# 17/17 [==============================] - 0s 24ms/step - loss: 16.1073 - val_loss: 9.7994
#
# [20210227-2343-09] Learning rate for epoch 53 is 0.0014240531018003821
# Epoch 53/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.8829
# Epoch 00053: val_loss did not improve from 9.44699
# 17/17 [==============================] - 0s 25ms/step - loss: 15.9450 - val_loss: 9.5707
#
# [20210227-2343-12] Learning rate for epoch 54 is 0.0014240531018003821
# Epoch 54/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.6730
# Epoch 00054: val_loss did not improve from 9.44699
# 17/17 [==============================] - 0s 24ms/step - loss: 16.6102 - val_loss: 9.6142
#
# [20210227-2343-16] Learning rate for epoch 55 is 0.0014240531018003821
# Epoch 55/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.8352
# Epoch 00055: val_loss did not improve from 9.44699
# 17/17 [==============================] - 0s 24ms/step - loss: 15.8791 - val_loss: 9.7945
#
# [20210227-2343-19] Learning rate for epoch 56 is 0.0014240531018003821
# Epoch 56/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.5002
# Epoch 00056: val_loss did not improve from 9.44699
# 17/17 [==============================] - 0s 25ms/step - loss: 15.5661 - val_loss: 10.3427
#
# [20210227-2343-22] Learning rate for epoch 57 is 0.0014240531018003821
# Epoch 57/500
# 17/17 [==============================] - ETA: 0s - loss: 15.6168
# Epoch 00057: val_loss did not improve from 9.44699
# 17/17 [==============================] - 0s 24ms/step - loss: 15.6168 - val_loss: 9.8418
#
# [20210227-2343-26] Learning rate for epoch 58 is 0.0014240531018003821
# Epoch 58/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.9908
# Epoch 00058: val_loss did not improve from 9.44699
# 17/17 [==============================] - 0s 25ms/step - loss: 15.9856 - val_loss: 11.7312
#
# [20210227-2343-29] Learning rate for epoch 59 is 0.0014240531018003821
# Epoch 59/500
# 17/17 [==============================] - ETA: 0s - loss: 15.5775
# Epoch 00059: val_loss did not improve from 9.44699
# 17/17 [==============================] - 0s 25ms/step - loss: 15.5775 - val_loss: 10.3021
#
# [20210227-2343-33] Learning rate for epoch 60 is 0.0014240531018003821
# Epoch 60/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.4615
# Epoch 00060: val_loss did not improve from 9.44699
# 17/17 [==============================] - 0s 24ms/step - loss: 16.4406 - val_loss: 9.9001
#
# [20210227-2343-36] Learning rate for epoch 61 is 0.0014240531018003821
# Epoch 61/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.1931
# Epoch 00061: val_loss did not improve from 9.44699
# 17/17 [==============================] - 0s 24ms/step - loss: 15.2340 - val_loss: 9.6352
#
# [20210227-2343-39] Learning rate for epoch 62 is 0.0014240531018003821
# Epoch 62/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.8247
# Epoch 00062: val_loss did not improve from 9.44699
# 17/17 [==============================] - 0s 24ms/step - loss: 15.7663 - val_loss: 9.4780
#
# [20210227-2343-43] Learning rate for epoch 63 is 0.0014240531018003821
# Epoch 63/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.6670
# Epoch 00063: val_loss did not improve from 9.44699
# 17/17 [==============================] - 0s 24ms/step - loss: 15.8370 - val_loss: 10.3365
#
# [20210227-2343-46] Learning rate for epoch 64 is 0.0014240531018003821
# Epoch 64/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.9210
# Epoch 00064: val_loss improved from 9.44699 to 9.26856, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 47ms/step - loss: 15.8789 - val_loss: 9.2686
#
# [20210227-2343-50] Learning rate for epoch 65 is 0.0014240531018003821
# Epoch 65/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.0654
# Epoch 00065: val_loss did not improve from 9.26856
# 17/17 [==============================] - 0s 25ms/step - loss: 15.9998 - val_loss: 9.4407
#
# [20210227-2343-53] Learning rate for epoch 66 is 0.0014240531018003821
# Epoch 66/500
# 17/17 [==============================] - ETA: 0s - loss: 15.8791
# Epoch 00066: val_loss did not improve from 9.26856
# 17/17 [==============================] - 0s 24ms/step - loss: 15.8791 - val_loss: 10.8004
#
# [20210227-2343-57] Learning rate for epoch 67 is 0.0014240531018003821
# Epoch 67/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.9707
# Epoch 00067: val_loss did not improve from 9.26856
# 17/17 [==============================] - 0s 25ms/step - loss: 15.9980 - val_loss: 11.0611
#
# [20210227-2344-00] Learning rate for epoch 68 is 0.0014240531018003821
# Epoch 68/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.0605
# Epoch 00068: val_loss improved from 9.26856 to 9.17431, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
# 17/17 [==============================] - 1s 46ms/step - loss: 16.2255 - val_loss: 9.1743
#
# [20210227-2344-04] Learning rate for epoch 69 is 0.0014240531018003821
# Epoch 69/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.6874
# Epoch 00069: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 24ms/step - loss: 15.5875 - val_loss: 9.8807
#
# [20210227-2344-07] Learning rate for epoch 70 is 0.0014240531018003821
# Epoch 70/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.5668
# Epoch 00070: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 24ms/step - loss: 15.5875 - val_loss: 9.6204
#
# [20210227-2344-11] Learning rate for epoch 71 is 0.0014240531018003821
# Epoch 71/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.7725
# Epoch 00071: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 25ms/step - loss: 15.6189 - val_loss: 9.5616
#
# [20210227-2344-14] Learning rate for epoch 72 is 0.0014240531018003821
# Epoch 72/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.7221
# Epoch 00072: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 24ms/step - loss: 15.7256 - val_loss: 9.2986
#
# [20210227-2344-18] Learning rate for epoch 73 is 0.0014240531018003821
# Epoch 73/500
# 17/17 [==============================] - ETA: 0s - loss: 16.2395
# Epoch 00073: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 24ms/step - loss: 16.2395 - val_loss: 9.3444
#
# [20210227-2344-21] Learning rate for epoch 74 is 0.0014240531018003821
# Epoch 74/500
# 16/17 [===========================>..] - ETA: 0s - loss: 16.0213
# Epoch 00074: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 25ms/step - loss: 15.9739 - val_loss: 10.4955
#
# [20210227-2344-25] Learning rate for epoch 75 is 0.0014240531018003821
# Epoch 75/500
# 17/17 [==============================] - ETA: 0s - loss: 16.1258
# Epoch 00075: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 24ms/step - loss: 16.1258 - val_loss: 10.3490
#
# [20210227-2344-28] Learning rate for epoch 76 is 0.0014240531018003821
# Epoch 76/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.5896
# Epoch 00076: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 24ms/step - loss: 15.6194 - val_loss: 9.7360
#
# [20210227-2344-31] Learning rate for epoch 77 is 0.0014240531018003821
# Epoch 77/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.0880
# Epoch 00077: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 24ms/step - loss: 15.0613 - val_loss: 10.8821
#
# [20210227-2344-35] Learning rate for epoch 78 is 0.0014240531018003821
# Epoch 78/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.7634
# Epoch 00078: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 25ms/step - loss: 15.7432 - val_loss: 9.3163
#
# [20210227-2344-38] Learning rate for epoch 79 is 0.0014240531018003821
# Epoch 79/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.1844
# Epoch 00079: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 24ms/step - loss: 15.2050 - val_loss: 11.3325
#
# [20210227-2344-42] Learning rate for epoch 80 is 0.0014240531018003821
# Epoch 80/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.6994
# Epoch 00080: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 24ms/step - loss: 15.6486 - val_loss: 9.6552
#
# [20210227-2344-45] Learning rate for epoch 81 is 0.0014240531018003821
# Epoch 81/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.4763
# Epoch 00081: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 24ms/step - loss: 15.5890 - val_loss: 9.8819
#
# [20210227-2344-48] Learning rate for epoch 82 is 0.0014240531018003821
# Epoch 82/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.6343
# Epoch 00082: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 24ms/step - loss: 15.6072 - val_loss: 9.8035
#
# [20210227-2344-52] Learning rate for epoch 83 is 0.0014240531018003821
# Epoch 83/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.3155
# Epoch 00083: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 25ms/step - loss: 15.3770 - val_loss: 9.5708
#
# [20210227-2344-55] Learning rate for epoch 84 is 0.0014240531018003821
# Epoch 84/500
# 17/17 [==============================] - ETA: 0s - loss: 15.9707
# Epoch 00084: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 24ms/step - loss: 15.9707 - val_loss: 9.4251
#
# [20210227-2344-59] Learning rate for epoch 85 is 0.0014240531018003821
# Epoch 85/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.2783
# Epoch 00085: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 24ms/step - loss: 15.2810 - val_loss: 9.1744
#
# [20210227-2345-02] Learning rate for epoch 86 is 0.0014240531018003821
# Epoch 86/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.4412
# Epoch 00086: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 24ms/step - loss: 15.2806 - val_loss: 9.4713
#
# [20210227-2345-06] Learning rate for epoch 87 is 0.0014240531018003821
# Epoch 87/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.7071
# Epoch 00087: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 24ms/step - loss: 15.9713 - val_loss: 9.8231
#
# [20210227-2345-09] Learning rate for epoch 88 is 0.0014240531018003821
# Epoch 88/500
# 16/17 [===========================>..] - ETA: 0s - loss: 15.9235
# Epoch 00088: val_loss did not improve from 9.17431
# 17/17 [==============================] - 0s 24ms/step - loss: 15.9661 - val_loss: 9.6934
#
# *********************************** Start fine tune ***********************************
# tt: 224, nt:17, total layers:241
# *********************************** Start fine tune ***********************************
# Epoch 1/1000
# 17/17 [==============================] - ETA: 0s - loss: 25.1685
# Epoch 00001: val_loss did not improve from 9.17431
#
# [20210227-2345-51] Learning rate for epoch 1 is 4.999999987376214e-07
# 17/17 [==============================] - 21s 1s/step - loss: 25.1685 - val_loss: 16.5273
# Epoch 2/1000
# 17/17 [==============================] - ETA: 0s - loss: 22.8455
# Epoch 00002: val_loss did not improve from 9.17431
#
# [20210227-2345-55] Learning rate for epoch 2 is 5.044450517743826e-05
# 17/17 [==============================] - 1s 80ms/step - loss: 22.8455 - val_loss: 17.7570
# Epoch 3/1000
# 17/17 [==============================] - ETA: 0s - loss: 17.9788
# Epoch 00003: val_loss did not improve from 9.17431
#
# [20210227-2346-17] Learning rate for epoch 3 is 0.00010028902033809572
# 17/17 [==============================] - 19s 1s/step - loss: 17.9788 - val_loss: 14.8665
# Epoch 4/1000
# 17/17 [==============================] - ETA: 0s - loss: 15.4196
# Epoch 00004: val_loss did not improve from 9.17431
#
# [20210227-2346-22] Learning rate for epoch 4 is 0.00015003354928921908
# 17/17 [==============================] - 1s 78ms/step - loss: 15.4196 - val_loss: 15.7066
# Epoch 5/1000
# 17/17 [==============================] - ETA: 0s - loss: 15.3810
# Epoch 00005: val_loss did not improve from 9.17431
#
# [20210227-2346-26] Learning rate for epoch 5 is 0.0001996780774788931
# 17/17 [==============================] - 1s 79ms/step - loss: 15.3810 - val_loss: 12.9015
# Epoch 6/1000
# 17/17 [==============================] - ETA: 0s - loss: 13.9238
# Epoch 00006: val_loss did not improve from 9.17431
#
# [20210227-2346-31] Learning rate for epoch 6 is 0.000249222619459033
# 17/17 [==============================] - 1s 78ms/step - loss: 13.9238 - val_loss: 11.1653
# Epoch 7/1000
# 17/17 [==============================] - ETA: 0s - loss: 13.5837
# Epoch 00007: val_loss did not improve from 9.17431
#
# [20210227-2346-35] Learning rate for epoch 7 is 0.0002986671752296388
# 17/17 [==============================] - 1s 80ms/step - loss: 13.5837 - val_loss: 10.0070
# Epoch 8/1000
# 17/17 [==============================] - ETA: 0s - loss: 13.3093
# Epoch 00008: val_loss did not improve from 9.17431
#
# [20210227-2346-39] Learning rate for epoch 8 is 0.00034801175934262574
# 17/17 [==============================] - 1s 78ms/step - loss: 13.3093 - val_loss: 10.8666
# Epoch 9/1000
# 17/17 [==============================] - ETA: 0s - loss: 12.8092
# Epoch 00009: val_loss improved from 9.17431 to 9.02445, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
#
# [20210227-2346-44] Learning rate for epoch 9 is 0.00039725631359033287
# 17/17 [==============================] - 2s 114ms/step - loss: 12.8092 - val_loss: 9.0245
# Epoch 10/1000
# 17/17 [==============================] - ETA: 0s - loss: 12.7193
# Epoch 00010: val_loss improved from 9.02445 to 8.84675, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
#
# [20210227-2346-49] Learning rate for epoch 10 is 0.0004464008961804211
# 17/17 [==============================] - 2s 112ms/step - loss: 12.7193 - val_loss: 8.8467
# Epoch 11/1000
# 17/17 [==============================] - ETA: 0s - loss: 12.4682
# Epoch 00011: val_loss improved from 8.84675 to 8.37651, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
#
# [20210227-2346-54] Learning rate for epoch 11 is 0.0004954455071128905
# 17/17 [==============================] - 2s 112ms/step - loss: 12.4682 - val_loss: 8.3765
# Epoch 12/1000
# 17/17 [==============================] - ETA: 0s - loss: 12.1557
# Epoch 00012: val_loss improved from 8.37651 to 7.18298, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
#
# [20210227-2346-59] Learning rate for epoch 12 is 0.0005443901172839105
# 17/17 [==============================] - 2s 111ms/step - loss: 12.1557 - val_loss: 7.1830
# Epoch 13/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.9046
# Epoch 00013: val_loss improved from 7.18298 to 6.46407, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
#
# [20210227-2347-04] Learning rate for epoch 13 is 0.0005932347266934812
# 17/17 [==============================] - 2s 113ms/step - loss: 11.9046 - val_loss: 6.4641
# Epoch 14/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.9289
# Epoch 00014: val_loss did not improve from 6.46407
#
# [20210227-2347-09] Learning rate for epoch 14 is 0.0006419793353416026
# 17/17 [==============================] - 1s 78ms/step - loss: 11.9289 - val_loss: 8.0219
# Epoch 15/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.2819
# Epoch 00015: val_loss did not improve from 6.46407
#
# [20210227-2347-13] Learning rate for epoch 15 is 0.0006906240014359355
# 17/17 [==============================] - 1s 80ms/step - loss: 11.2819 - val_loss: 7.2866
# Epoch 16/1000
# 17/17 [==============================] - ETA: 0s - loss: 11.0513
# Epoch 00016: val_loss improved from 6.46407 to 5.52849, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
#
# [20210227-2347-18] Learning rate for epoch 16 is 0.0007391686085611582
# 17/17 [==============================] - 2s 111ms/step - loss: 11.0513 - val_loss: 5.5285
# Epoch 17/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.4005
# Epoch 00017: val_loss improved from 5.52849 to 5.10138, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
#
# [20210227-2347-24] Learning rate for epoch 17 is 0.0007876132731325924
# 17/17 [==============================] - 2s 115ms/step - loss: 10.4005 - val_loss: 5.1014
# Epoch 18/1000
# 17/17 [==============================] - ETA: 0s - loss: 10.3618
# Epoch 00018: val_loss improved from 5.10138 to 4.06919, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
#
# [20210227-2347-29] Learning rate for epoch 18 is 0.0008359579369425774
# 17/17 [==============================] - 2s 114ms/step - loss: 10.3618 - val_loss: 4.0692
# Epoch 19/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.6038
# Epoch 00019: val_loss did not improve from 4.06919
#
# [20210227-2347-34] Learning rate for epoch 19 is 0.000884202599991113
# 17/17 [==============================] - 1s 79ms/step - loss: 9.6038 - val_loss: 8.2525
# Epoch 20/1000
# 17/17 [==============================] - ETA: 0s - loss: 9.0921
# Epoch 00020: val_loss did not improve from 4.06919
#
# [20210227-2347-38] Learning rate for epoch 20 is 0.0009323473204858601
# 17/17 [==============================] - 1s 80ms/step - loss: 9.0921 - val_loss: 7.3760
# Epoch 21/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.8693
# Epoch 00021: val_loss did not improve from 4.06919
#
# [20210227-2347-43] Learning rate for epoch 21 is 0.000980391982011497
# 17/17 [==============================] - 1s 79ms/step - loss: 8.8693 - val_loss: 14.3954
# Epoch 22/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.9952
# Epoch 00022: val_loss did not improve from 4.06919
#
# [20210227-2347-47] Learning rate for epoch 22 is 0.0010283367009833455
# 17/17 [==============================] - 1s 79ms/step - loss: 8.9952 - val_loss: 7.6930
# Epoch 23/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.4521
# Epoch 00023: val_loss did not improve from 4.06919
#
# [20210227-2347-52] Learning rate for epoch 23 is 0.0010761814191937447
# 17/17 [==============================] - 1s 80ms/step - loss: 8.4521 - val_loss: 6.0024
# Epoch 24/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.8263
# Epoch 00024: val_loss did not improve from 4.06919
#
# [20210227-2347-56] Learning rate for epoch 24 is 0.0011239261366426945
# 17/17 [==============================] - 1s 78ms/step - loss: 7.8263 - val_loss: 5.5298
# Epoch 25/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.2965
# Epoch 00025: val_loss did not improve from 4.06919
#
# [20210227-2348-00] Learning rate for epoch 25 is 0.001171570853330195
# 17/17 [==============================] - 1s 79ms/step - loss: 8.2965 - val_loss: 7.2141
# Epoch 26/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.8914
# Epoch 00026: val_loss improved from 4.06919 to 3.65974, saving model to ./20210227-215401/heel_K0_EfficientNetB0_bs64_w120_best_val_loss.h5
#
# [20210227-2348-05] Learning rate for epoch 26 is 0.001219115569256246
# 17/17 [==============================] - 2s 113ms/step - loss: 7.8914 - val_loss: 3.6597
# Epoch 27/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.8006
# Epoch 00027: val_loss did not improve from 3.65974
#
# [20210227-2348-10] Learning rate for epoch 27 is 0.0012665604008361697
# 17/17 [==============================] - 1s 80ms/step - loss: 7.8006 - val_loss: 5.5924
# Epoch 28/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.1510
# Epoch 00028: val_loss did not improve from 3.65974
#
# [20210227-2348-14] Learning rate for epoch 28 is 0.0013139051152393222
# 17/17 [==============================] - 1s 80ms/step - loss: 8.1510 - val_loss: 18.6037
# Epoch 29/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.3310
# Epoch 00029: val_loss did not improve from 3.65974
#
# [20210227-2348-19] Learning rate for epoch 29 is 0.0013611499452963471
# 17/17 [==============================] - 1s 78ms/step - loss: 8.3310 - val_loss: 8.2449
# Epoch 30/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.1316
# Epoch 00030: val_loss did not improve from 3.65974
#
# [20210227-2348-23] Learning rate for epoch 30 is 0.001408294658176601
# 17/17 [==============================] - 1s 80ms/step - loss: 8.1316 - val_loss: 5.0042
# Epoch 31/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.6748
# Epoch 00031: val_loss did not improve from 3.65974
#
# [20210227-2348-27] Learning rate for epoch 31 is 0.0014553394867107272
# 17/17 [==============================] - 1s 79ms/step - loss: 7.6748 - val_loss: 10.4553
# Epoch 32/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.8623
# Epoch 00032: val_loss did not improve from 3.65974
#
# [20210227-2348-32] Learning rate for epoch 32 is 0.0015022843144834042
# 17/17 [==============================] - 1s 79ms/step - loss: 7.8623 - val_loss: 26.0527
# Epoch 33/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.7664
# Epoch 00033: val_loss did not improve from 3.65974
#
# [20210227-2348-36] Learning rate for epoch 33 is 0.0015491291414946318
# 17/17 [==============================] - 1s 80ms/step - loss: 7.7664 - val_loss: 16.9410
# Epoch 34/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.4888
# Epoch 00034: val_loss did not improve from 3.65974
#
# [20210227-2348-41] Learning rate for epoch 34 is 0.00159587396774441
# 17/17 [==============================] - 1s 79ms/step - loss: 7.4888 - val_loss: 6.3353
# Epoch 35/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.3550
# Epoch 00035: val_loss did not improve from 3.65974
#
# [20210227-2348-45] Learning rate for epoch 35 is 0.001642518793232739
# 17/17 [==============================] - 1s 80ms/step - loss: 7.3550 - val_loss: 6.3180
# Epoch 36/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.7648
# Epoch 00036: val_loss did not improve from 3.65974
#
# [20210227-2348-50] Learning rate for epoch 36 is 0.0016890636179596186
# 17/17 [==============================] - 1s 78ms/step - loss: 7.7648 - val_loss: 113.5508
# Epoch 37/1000
# 17/17 [==============================] - ETA: 0s - loss: 8.2670
# Epoch 00037: val_loss did not improve from 3.65974
#
# [20210227-2348-54] Learning rate for epoch 37 is 0.0017355084419250488
# 17/17 [==============================] - 1s 80ms/step - loss: 8.2670 - val_loss: 8.0258
# Epoch 38/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.2807
# Epoch 00038: val_loss did not improve from 3.65974
#
# [20210227-2348-58] Learning rate for epoch 38 is 0.0017818533815443516
# 17/17 [==============================] - 1s 78ms/step - loss: 7.2807 - val_loss: 7.2957
# Epoch 39/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.4249
# Epoch 00039: val_loss did not improve from 3.65974
#
# [20210227-2349-03] Learning rate for epoch 39 is 0.0018280982039868832
# 17/17 [==============================] - 1s 78ms/step - loss: 7.4249 - val_loss: 6.4667
# Epoch 40/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.4063
# Epoch 00040: val_loss did not improve from 3.65974
#
# [20210227-2349-07] Learning rate for epoch 40 is 0.0018742431420832872
# 17/17 [==============================] - 1s 79ms/step - loss: 7.4063 - val_loss: 10.2543
# Epoch 41/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.6901
# Epoch 00041: val_loss did not improve from 3.65974
#
# [20210227-2349-12] Learning rate for epoch 41 is 0.0019202879630029202
# 17/17 [==============================] - 1s 78ms/step - loss: 7.6901 - val_loss: 9.1690
# Epoch 42/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.0703
# Epoch 00042: val_loss did not improve from 3.65974
#
# [20210227-2349-16] Learning rate for epoch 42 is 0.0019662328995764256
# 17/17 [==============================] - 1s 82ms/step - loss: 7.0703 - val_loss: 7.5899
# Epoch 43/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.1567
# Epoch 00043: val_loss did not improve from 3.65974
#
# [20210227-2349-21] Learning rate for epoch 43 is 0.00201207771897316
# 17/17 [==============================] - 1s 79ms/step - loss: 7.1567 - val_loss: 4.8892
# Epoch 44/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.2358
# Epoch 00044: val_loss did not improve from 3.65974
#
# [20210227-2349-25] Learning rate for epoch 44 is 0.0020578226540237665
# 17/17 [==============================] - 1s 79ms/step - loss: 7.2358 - val_loss: 8.4608
# Epoch 45/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.8135
# Epoch 00045: val_loss did not improve from 3.65974
#
# [20210227-2349-29] Learning rate for epoch 45 is 0.0021034677047282457
# 17/17 [==============================] - 1s 78ms/step - loss: 6.8135 - val_loss: 7.3052
# Epoch 46/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.6959
# Epoch 00046: val_loss did not improve from 3.65974
#
# [20210227-2349-34] Learning rate for epoch 46 is 0.002149012638255954
# 17/17 [==============================] - 1s 78ms/step - loss: 7.6959 - val_loss: 5.9385
# Epoch 47/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.2320
# Epoch 00047: val_loss did not improve from 3.65974
#
# [20210227-2349-38] Learning rate for epoch 47 is 0.0021944576874375343
# 17/17 [==============================] - 1s 79ms/step - loss: 7.2320 - val_loss: 9.7324
# Epoch 48/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.4312
# Epoch 00048: val_loss did not improve from 3.65974
#
# [20210227-2349-43] Learning rate for epoch 48 is 0.0022398026194423437
# 17/17 [==============================] - 1s 78ms/step - loss: 7.4312 - val_loss: 7.7634
# Epoch 49/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.5048
# Epoch 00049: val_loss did not improve from 3.65974
#
# [20210227-2349-47] Learning rate for epoch 49 is 0.002285047434270382
# 17/17 [==============================] - 1s 79ms/step - loss: 7.5048 - val_loss: 7.3546
# Epoch 50/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.5501
# Epoch 00050: val_loss did not improve from 3.65974
#
# [20210227-2349-52] Learning rate for epoch 50 is 0.0023301925975829363
# 17/17 [==============================] - 1s 78ms/step - loss: 7.5501 - val_loss: 5.3992
# Epoch 51/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.5162
# Epoch 00051: val_loss did not improve from 3.65974
#
# [20210227-2349-56] Learning rate for epoch 51 is 0.002375237410888076
# 17/17 [==============================] - 1s 79ms/step - loss: 7.5162 - val_loss: 6.2803
# Epoch 52/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.3995
# Epoch 00052: val_loss did not improve from 3.65974
#
# [20210227-2350-00] Learning rate for epoch 52 is 0.0024201825726777315
# 17/17 [==============================] - 1s 79ms/step - loss: 7.3995 - val_loss: 7.8364
# Epoch 53/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.7029
# Epoch 00053: val_loss did not improve from 3.65974
#
# [20210227-2350-05] Learning rate for epoch 53 is 0.002465027617290616
# 17/17 [==============================] - 1s 79ms/step - loss: 7.7029 - val_loss: 6.7320
# Epoch 54/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.2227
# Epoch 00054: val_loss did not improve from 3.65974
#
# [20210227-2350-09] Learning rate for epoch 54 is 0.0025097725447267294
# 17/17 [==============================] - 1s 79ms/step - loss: 7.2227 - val_loss: 5.2049
# Epoch 55/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.8252
# Epoch 00055: val_loss did not improve from 3.65974
#
# [20210227-2350-14] Learning rate for epoch 55 is 0.0025544175878167152
# 17/17 [==============================] - 1s 79ms/step - loss: 6.8252 - val_loss: 5.1757
# Epoch 56/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.5408
# Epoch 00056: val_loss did not improve from 3.65974
#
# [20210227-2350-18] Learning rate for epoch 56 is 0.00259896251372993
# 17/17 [==============================] - 1s 79ms/step - loss: 7.5408 - val_loss: 7.4516
# Epoch 57/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.3357
# Epoch 00057: val_loss did not improve from 3.65974
#
# [20210227-2350-23] Learning rate for epoch 57 is 0.0026434077881276608
# 17/17 [==============================] - 1s 79ms/step - loss: 7.3357 - val_loss: 5.1393
# Epoch 58/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.0802
# Epoch 00058: val_loss did not improve from 3.65974
#
# [20210227-2350-27] Learning rate for epoch 58 is 0.0026877527125179768
# 17/17 [==============================] - 1s 79ms/step - loss: 7.0802 - val_loss: 7.7495
# Epoch 59/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.6429
# Epoch 00059: val_loss did not improve from 3.65974
#
# [20210227-2350-31] Learning rate for epoch 59 is 0.0027319977525621653
# 17/17 [==============================] - 1s 78ms/step - loss: 6.6429 - val_loss: 11.2060
# Epoch 60/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.0794
# Epoch 00060: val_loss did not improve from 3.65974
#
# [20210227-2350-36] Learning rate for epoch 60 is 0.0027761429082602262
# 17/17 [==============================] - 1s 78ms/step - loss: 7.0794 - val_loss: 17.3400
# Epoch 61/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.7816
# Epoch 00061: val_loss did not improve from 3.65974
#
# [20210227-2350-40] Learning rate for epoch 61 is 0.002820187946781516
# 17/17 [==============================] - 1s 79ms/step - loss: 6.7816 - val_loss: 15.5123
# Epoch 62/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.4209
# Epoch 00062: val_loss did not improve from 3.65974
#
# [20210227-2350-45] Learning rate for epoch 62 is 0.0028641331009566784
# 17/17 [==============================] - 1s 78ms/step - loss: 7.4209 - val_loss: 9.7319
# Epoch 63/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.2507
# Epoch 00063: val_loss did not improve from 3.65974
#
# [20210227-2350-49] Learning rate for epoch 63 is 0.0029079781379550695
# 17/17 [==============================] - 1s 79ms/step - loss: 7.2507 - val_loss: 8.9362
# Epoch 64/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.0589
# Epoch 00064: val_loss did not improve from 3.65974
#
# [20210227-2350-53] Learning rate for epoch 64 is 0.002951723290607333
# 17/17 [==============================] - 1s 78ms/step - loss: 7.0589 - val_loss: 5.1023
# Epoch 65/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.3878
# Epoch 00065: val_loss did not improve from 3.65974
#
# [20210227-2350-58] Learning rate for epoch 65 is 0.0029953685589134693
# 17/17 [==============================] - 1s 78ms/step - loss: 7.3878 - val_loss: 6.1116
# Epoch 66/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.0192
# Epoch 00066: val_loss did not improve from 3.65974
#
# [20210227-2351-02] Learning rate for epoch 66 is 0.0030389137100428343
# 17/17 [==============================] - 1s 78ms/step - loss: 7.0192 - val_loss: 8.5690
# Epoch 67/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.1580
# Epoch 00067: val_loss did not improve from 3.65974
#
# [20210227-2351-07] Learning rate for epoch 67 is 0.003082358743995428
# 17/17 [==============================] - 1s 79ms/step - loss: 7.1580 - val_loss: 9.1266
# Epoch 68/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.4878
# Epoch 00068: val_loss did not improve from 3.65974
#
# [20210227-2351-11] Learning rate for epoch 68 is 0.0031257038936018944
# 17/17 [==============================] - 1s 79ms/step - loss: 7.4878 - val_loss: 10.3850
# Epoch 69/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.5828
# Epoch 00069: val_loss did not improve from 3.65974
#
# [20210227-2351-16] Learning rate for epoch 69 is 0.003168949158862233
# 17/17 [==============================] - 1s 79ms/step - loss: 7.5828 - val_loss: 8.1032
# Epoch 70/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.8768
# Epoch 00070: val_loss did not improve from 3.65974
#
# [20210227-2351-20] Learning rate for epoch 70 is 0.0032120943069458008
# 17/17 [==============================] - 1s 78ms/step - loss: 6.8768 - val_loss: 10.0860
# Epoch 71/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.1574
# Epoch 00071: val_loss did not improve from 3.65974
#
# [20210227-2351-24] Learning rate for epoch 71 is 0.003255139570683241
# 17/17 [==============================] - 1s 78ms/step - loss: 7.1574 - val_loss: 8.2349
# Epoch 72/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.5943
# Epoch 00072: val_loss did not improve from 3.65974
#
# [20210227-2351-29] Learning rate for epoch 72 is 0.00329808471724391
# 17/17 [==============================] - 1s 78ms/step - loss: 7.5943 - val_loss: 7.8704
# Epoch 73/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.2593
# Epoch 00073: val_loss did not improve from 3.65974
#
# [20210227-2351-33] Learning rate for epoch 73 is 0.0033409299794584513
# 17/17 [==============================] - 1s 79ms/step - loss: 7.2593 - val_loss: 5.3606
# Epoch 74/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.0486
# Epoch 00074: val_loss did not improve from 3.65974
#
# [20210227-2351-38] Learning rate for epoch 74 is 0.0033836751244962215
# 17/17 [==============================] - 1s 77ms/step - loss: 7.0486 - val_loss: 5.0247
# Epoch 75/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.3601
# Epoch 00075: val_loss did not improve from 3.65974
#
# [20210227-2351-42] Learning rate for epoch 75 is 0.0034263203851878643
# 17/17 [==============================] - 1s 80ms/step - loss: 6.3601 - val_loss: 8.5115
# Epoch 76/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.1845
# Epoch 00076: val_loss did not improve from 3.65974
#
# [20210227-2351-46] Learning rate for epoch 76 is 0.003468865528702736
# 17/17 [==============================] - 1s 78ms/step - loss: 7.1845 - val_loss: 6.8588
# Epoch 77/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.6472
# Epoch 00077: val_loss did not improve from 3.65974
#
# [20210227-2351-51] Learning rate for epoch 77 is 0.00351131078787148
# 17/17 [==============================] - 1s 79ms/step - loss: 6.6472 - val_loss: 5.1684
# Epoch 78/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.8293
# Epoch 00078: val_loss did not improve from 3.65974
#
# [20210227-2351-55] Learning rate for epoch 78 is 0.0035536561626940966
# 17/17 [==============================] - 1s 79ms/step - loss: 6.8293 - val_loss: 4.6703
# Epoch 79/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.8862
# Epoch 00079: val_loss did not improve from 3.65974
#
# [20210227-2352-00] Learning rate for epoch 79 is 0.003595901420339942
# 17/17 [==============================] - 1s 79ms/step - loss: 6.8862 - val_loss: 4.1869
# Epoch 80/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.2339
# Epoch 00080: val_loss did not improve from 3.65974
#
# [20210227-2352-04] Learning rate for epoch 80 is 0.00363804679363966
# 17/17 [==============================] - 1s 79ms/step - loss: 6.2339 - val_loss: 4.6598
# Epoch 81/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.1862
# Epoch 00081: val_loss did not improve from 3.65974
#
# [20210227-2352-08] Learning rate for epoch 81 is 0.0036800920497626066
# 17/17 [==============================] - 1s 78ms/step - loss: 6.1862 - val_loss: 6.4793
# Epoch 82/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.6935
# Epoch 00082: val_loss did not improve from 3.65974
#
# [20210227-2352-13] Learning rate for epoch 82 is 0.003722037188708782
# 17/17 [==============================] - 1s 79ms/step - loss: 6.6935 - val_loss: 19.0842
# Epoch 83/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.1073
# Epoch 00083: val_loss did not improve from 3.65974
#
# [20210227-2352-17] Learning rate for epoch 83 is 0.003763882676139474
# 17/17 [==============================] - 1s 78ms/step - loss: 7.1073 - val_loss: 27.0414
# Epoch 84/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.9449
# Epoch 00084: val_loss did not improve from 3.65974
#
# [20210227-2352-22] Learning rate for epoch 84 is 0.0038056280463933945
# 17/17 [==============================] - 1s 79ms/step - loss: 6.9449 - val_loss: 10.3332
# Epoch 85/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.9942
# Epoch 00085: val_loss did not improve from 3.65974
#
# [20210227-2352-26] Learning rate for epoch 85 is 0.003847273299470544
# 17/17 [==============================] - 1s 79ms/step - loss: 6.9942 - val_loss: 6.8991
# Epoch 86/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.1046
# Epoch 00086: val_loss did not improve from 3.65974
#
# [20210227-2352-30] Learning rate for epoch 86 is 0.0038888186682015657
# 17/17 [==============================] - 1s 79ms/step - loss: 7.1046 - val_loss: 6.3409
# Epoch 87/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.8724
# Epoch 00087: val_loss did not improve from 3.65974
#
# [20210227-2352-35] Learning rate for epoch 87 is 0.00393026415258646
# 17/17 [==============================] - 1s 79ms/step - loss: 6.8724 - val_loss: 4.5707
# Epoch 88/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.4434
# Epoch 00088: val_loss did not improve from 3.65974
#
# [20210227-2352-39] Learning rate for epoch 88 is 0.00397160928696394
# 17/17 [==============================] - 1s 78ms/step - loss: 6.4434 - val_loss: 5.3619
# Epoch 89/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.0192
# Epoch 00089: val_loss did not improve from 3.65974
#
# [20210227-2352-44] Learning rate for epoch 89 is 0.004012854769825935
# 17/17 [==============================] - 1s 79ms/step - loss: 7.0192 - val_loss: 4.1034
# Epoch 90/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.4605
# Epoch 00090: val_loss did not improve from 3.65974
#
# [20210227-2352-48] Learning rate for epoch 90 is 0.00405400013551116
# 17/17 [==============================] - 1s 79ms/step - loss: 6.4605 - val_loss: 4.5187
# Epoch 91/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.4159
# Epoch 00091: val_loss did not improve from 3.65974
#
# [20210227-2352-52] Learning rate for epoch 91 is 0.004095045384019613
# 17/17 [==============================] - 1s 79ms/step - loss: 7.4159 - val_loss: 4.7818
# Epoch 92/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.4382
# Epoch 00092: val_loss did not improve from 3.65974
#
# [20210227-2352-57] Learning rate for epoch 92 is 0.004135990981012583
# 17/17 [==============================] - 1s 79ms/step - loss: 6.4382 - val_loss: 5.5164
# Epoch 93/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.2513
# Epoch 00093: val_loss did not improve from 3.65974
#
# [20210227-2353-01] Learning rate for epoch 93 is 0.004176836460828781
# 17/17 [==============================] - 1s 79ms/step - loss: 6.2513 - val_loss: 4.3498
# Epoch 94/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.0571
# Epoch 00094: val_loss did not improve from 3.65974
#
# [20210227-2353-06] Learning rate for epoch 94 is 0.004217581823468208
# 17/17 [==============================] - 1s 79ms/step - loss: 6.0571 - val_loss: 3.8754
# Epoch 95/1000
# 17/17 [==============================] - ETA: 0s - loss: 6.8760
# Epoch 00095: val_loss did not improve from 3.65974
#
# [20210227-2353-10] Learning rate for epoch 95 is 0.004258227068930864
# 17/17 [==============================] - 1s 77ms/step - loss: 6.8760 - val_loss: 6.1076
# Epoch 96/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.4361
# Epoch 00096: val_loss did not improve from 3.65974
#
# [20210227-2353-14] Learning rate for epoch 96 is 0.0042987726628780365
# 17/17 [==============================] - 1s 79ms/step - loss: 7.4361 - val_loss: 4.0141
# Epoch 97/1000
# 17/17 [==============================] - ETA: 0s - loss: 7.0506
# Epoch 00097: val_loss did not improve from 3.65974
#
# [20210227-2353-19] Learning rate for epoch 97 is 0.0043392181396484375
# 17/17 [==============================] - 1s 78ms/step - loss: 7.0506 - val_loss: 3.6629
# Epoch 98/1000

# %%
#ED sum
def get_valloss(his_v_l):  
    return np.min(his_v_l), np.argmin(his_v_l)

# t_vl = []
h_vl = []
for k in range(KFlodNum):
    print(f'K:{k}')
#     t_v, _ = get_valloss(history_toe_finetune[k].history['val_loss'])
    h_v, _ = get_valloss(history_heel_finetune[k].history['val_loss'])
    
#     t_vl.append(t_v)
    h_vl.append(h_v)

# t_vl = np.mean(t_vl, axis=0)
# h_vl = np.mean(h_vl, axis=0)
# print(f'{round(t_vl,5)} + {round(h_vl,5)} = {round(t_vl + h_vl,5)}')

# t_vl
h_vl

# %%
np.savetxt(f'{log_dir_name}/heel_FNED.txt', h_vl)

# %%
# Sum plot losses heel-tl

plt.figure(figsize=(25, 10))

for k in range(KFlodNum):

    plt.plot(history_heel[k].history['loss'])
    plt.plot(history_heel[k].history['val_loss'])

    
plt.title('K-model ed loss heel-TL')
plt.ylabel('ed loss'), plt.ylim(5, 50)# for too large loss
plt.xlabel('epoch')
plt.legend(['k0 loss', 'k0 val_loss', 'k1 loss', 'k1 val_loss', 'k2 loss', 'k2 val_loss', 
            'k3 loss', 'k3 val_loss', 'k4 loss', 'k4 val_loss'], loc='upper left') 
# plt.show()

# save plot : comment plo.show in jupyter notebook.
plt.savefig(f'{log_dir_name}/{log_dir_name}_heel_Ksum_TL.png', bbox_inches = 'tight')

# %%
# Single plot loss heel-tl

for k in range(KFlodNum):
    plt.figure(figsize=(25, 10))
    plt.plot(history_heel[k].history['loss'])
    plt.plot(history_heel[k].history['val_loss'])
    plt.title('K-model ed loss heel-TL')
    plt.ylabel('ed loss'), plt.ylim(5, 80)# for too large loss
    plt.xlabel('epoch')
    plt.legend(['loss', 'val_loss'], loc='upper left') 
    # plt.show()

    # save plot : comment plo.show in jupyter notebook.
    def get_valloss(his_v_l):   
        return np.min(his_v_l), np.argmin(his_v_l)

    vl, ep = get_valloss(history_heel[k].history['val_loss'])
    plt.savefig(f'{log_dir_name}/{log_dir_name}_heel_K{k}_TL_clr_ed{round(vl,4)}@{ep}.png', bbox_inches = 'tight')

# %%
# check the loos the model trained.

def get_valloss(his_v_l):  
    return np.min(his_v_l), np.argmin(his_v_l)

# t_vl = []
h_vl = []
for k in range(KFlodNum):
    print(f'K:{k}')
#     t_v, _ = get_valloss(history_toe_finetune[k].history['val_loss'])
    h_v, _ = get_valloss(history_heel_finetune[k].history['val_loss'])
    
    h_vl.append(h_v)
    
# for different scales (different Y-axes)
# fig, ax1 = plt.subplots()
fig, ax1 = plt.subplots(figsize=(25, 10))

# nice to have this colorful tip.
color = 'tab:red'

ax1.set_title('[ heel_finetune ] \n ED loss')

ax1.set_xlabel('epoch')
ax1.set_ylabel('ed loss', color=color)

for k in range(KFlodNum):

    plt.plot(history_heel_finetune[k].history['loss'])
    plt.plot(history_heel_finetune[k].history['val_loss'])

ax1.tick_params(axis='y', labelcolor=color)
# ax1.legend(['loss', 'val_loss'], loc='upper center') # legend may ocvered by next ax ploting. moved to end.
ax1.legend(['k0 loss', 'k0 val_loss', 'k1 loss', 'k1 val_loss', 'k2 loss', 'k2 val_loss', 
            'k3 loss', 'k3 val_loss', 'k4 loss', 'k4 val_loss'], loc='upper right') 

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('learning rate', color=color)
ax2.plot(history_heel_finetune[0].history['lr'], color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.legend(['lr'], loc='upper right') 

# plt.show()

# # save plot : comment plo.show in jupyter notebook.
# def get_valloss(his_v_l):   
#     return np.min(his_v_l), np.argmin(his_v_l)

# vl, ep = get_valloss(history_toe_finetune.history['val_loss'])


# t_vl = np.mean(t_vl, axis=0)
h_vl = np.mean(h_vl, axis=0)
plt.savefig(f'{log_dir_name}/{log_dir_name}_heel_ft_Ksum-clr_ed{round(h_vl,4)}.png', bbox_inches = 'tight')

# %%
# Sum plot losses heel-ft

plt.figure(figsize=(25, 10))

for k in range(KFlodNum):

    plt.plot(history_heel_finetune[k].history['loss'])
    plt.plot(history_heel_finetune[k].history['val_loss'])

    
plt.title('K-model ed loss heel-FT')
plt.ylabel('ed loss'), plt.ylim(2, 20)# for too large loss
plt.xlabel('epoch')
plt.legend(['k0 loss', 'k0 val_loss', 'k1 loss', 'k1 val_loss', 'k2 loss', 'k2 val_loss', 
            'k3 loss', 'k3 val_loss', 'k4 loss', 'k4 val_loss'], loc='upper left') 
# plt.show()

# save plot : comment plo.show in jupyter notebook.
plt.savefig(f'{log_dir_name}/{log_dir_name}_heel_Ksum_FT.png', bbox_inches = 'tight')

# %%
# Single plot loss heel-FT

for k in range(KFlodNum):
    plt.figure(figsize=(25, 10))
    plt.plot(history_heel_finetune[k].history['loss'])
    plt.plot(history_heel_finetune[k].history['val_loss'])
    plt.title('K-model ed loss heel-FT')
    plt.ylabel('ed loss'), plt.ylim(2, 20)# for too large loss
    plt.xlabel('epoch')
    plt.legend(['loss', 'val_loss'], loc='upper left') 
    # plt.show()

    # save plot : comment plo.show in jupyter notebook.
    def get_valloss(his_v_l):   
        return np.min(his_v_l), np.argmin(his_v_l)

    vl, ep = get_valloss(history_heel_finetune[k].history['val_loss'])
    plt.savefig(f'{log_dir_name}/{log_dir_name}_heel_K{k}_FT_clr_ed{round(vl,4)}@{ep}.png', bbox_inches = 'tight')

# %% [markdown]
# ### Ploting your model

# %%
# model_toe.summary()

# %%
# # show after modl.fit
# model_toe.metrics_names

# %%
# # check metrics the model have.
# history_toe.history.keys()

# %%
# tf.keras.utils.plot_model(model_toe, show_shapes=True)

# %%
# from tensorflow.keras.utils import plot_model
# plot_model(model_toe, to_file='model_toe_conv_layer_blocks.png', show_shapes=True)
# from IPython.display import Image
# Image(filename='model_toe_conv_layer_blocks.png')

# %% [markdown]
# ## show pp pred
#
# * we can switch toe/hell by comment it

# %% [markdown]
# ### EFN Toe

# %%
# it_valid_ds_pre_toe_s = iter(valid_ds_pre_toe_s)
# # it_valid_ds_pre_heel_s = iter(valid_ds_pre_heel_s)

# %%
# %%time

# # image_batch, label_batch = next(valid_ds_pre_toe_s)

# image_batch, label_batch = next(it_valid_ds_pre_toe_s)
# # image_batch, label_batch = next(it_valid_ds_pre_heel_s)


# pred = model_toe.predict_on_batch(image_batch) #predictions
# # pred = model.predict_on_batch(image_batch) #Simple 2D CNN model predictions

# plt.figure(figsize=(20, 20))
# for i in range(64):
#     ax = plt.subplot(8, 8, i + 1)
#     plt.imshow(image_batch[i])
#     plt.title(label_batch[i].numpy())
#     plt.axis("off")
    
#     # note: y_offset_toe for ds image
    
#     #ground truth
#     plt.plot(label_batch[i].numpy()[0], label_batch[i].numpy()[1], 'r+', markersize=15, mew=2)

#     #pred
#     plt.plot(pred[i][0], pred[i][1], 'k+', markersize=15, mew=2)

# %%
# #test_ds一次做完即可不用分batch
# neg = label_batch - pred
# neg[:5]

# %%
# np.abs(neg)[:5]

# %%
# neg_abs = np.abs(neg)
# neg_abs.mean(axis=0)#所有x 所有y個別平均  neg.mean(axis=0)#所有x 所有y個別平均

# %% [markdown]
# #### ED 2D

# %%
# # y_pred = neg_abs.mean(axis=0)
# ed_metric_2d([0,0], [neg_abs.mean(axis=0)]).numpy()

# %% [markdown]
# ### EFN Heel

# %%
# # it_valid_ds_pre_toe_s = iter(valid_ds_pre_toe_s)
# it_valid_ds_pre_heel_s = iter(valid_ds_pre_heel_s)

# %%
# %%time

# # image_batch, label_batch = next(valid_ds_pre_toe_s)

# # image_batch, label_batch = next(it_valid_ds_pre_toe_s)
# image_batch, label_batch = next(it_valid_ds_pre_heel_s)


# pred = model_heel.predict_on_batch(image_batch) #predictions
# # pred = model.predict_on_batch(image_batch) #Simple 2D CNN model predictions

# plt.figure(figsize=(20, 20))
# for i in range(64):
#     ax = plt.subplot(8, 8, i + 1)
#     plt.imshow(image_batch[i])
#     plt.title(label_batch[i].numpy())
#     plt.axis("off")
    
#     # note: y_offset_toe for ds image
    
#     #ground truth
#     plt.plot(label_batch[i].numpy()[0], label_batch[i].numpy()[1], 'r+', markersize=15, mew=2)

#     #pred
#     plt.plot(pred[i][0], pred[i][1], 'k+', markersize=15, mew=2)

# %%
# pred[:5]

# %%
# label_batch[:5]

# %%
# #test_ds一次做完即可不用分batch
# neg = label_batch - pred
# neg[:10]

# %%
# np.abs(neg)[:10]

# %%
# neg_abs = np.abs(neg)
# neg_abs.mean(axis=0)#所有x 所有y個別平均  neg.mean(axis=0)#所有x 所有y個別平均

# %% [markdown]
# #### ED 2d

# %%
# # y_pred = neg_abs.mean(axis=0)
# ed_metric_2d([0,0], [neg_abs.mean(axis=0)]).numpy()

# %% [markdown]
# # Merg Toe/Heel model and predict the Test data at once

# %% [markdown]
# ### Create TEST DS

# %%
ts = 'test_submission.csv'
df_ts = pd.read_csv(ts)
df_ts.head(5)

# %%
df_ts['images']

# %%
# from dataframe
list_ds_test = tf.data.Dataset.from_tensor_slices(df_ts['images'])

# %%
len(list_ds_test)#.shape() #take(1)

# %%
# check The type specification of an element of this dataset.
list_ds_test.element_spec

# %%
for f in list_ds_test.take(5):
    print(f'take test sample: {f}')

# %% [markdown]
# ### TEST DS: Process TEST path to image tensor

# %%
## TEST-DS: re-used from train/val-ds

im_test = 'test_images/'

'''
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    # The second to last is the class-directory
    boolen = parts[-2] == class_names
    #one_hot_num = np.array(boolen, dtype=np.int) not works should use tf.x repalced.
    one_hot_num = tf.dtypes.cast(boolen, tf.int64)
    one_num = tf.argmax(one_hot_num)
    print('one_num:', one_num)
    # Integer encode the label
    return one_num

def decode_img(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.io.decode_jpeg(img, channels=3)
    # resize the image to the desired size
#     return tf.image.resize(img, [img_height, img_width])# augment 已經resize過一次了 但這邊不先做會比較慢
    return tf.cast(tf.image.resize(img, [img_height, img_width]), tf.uint8)# 避免float over at augment
'''

#
# map list to ds, Toe part.
#

def decode_crop_png_toe_test(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.io.decode_png(img, channels=3)
    # crop the toe from top-left corner [image, offset_height y1, offset_width x1, target_height, target_width]
    y1=y_offset_toe;    x1=0;    h=img_height;    w=img_width # not the pp location
    img = tf.image.crop_to_bounding_box(img, int(y1), int(x1), h, w)
    #img = tf.image.crop_to_bounding_box(img, int(y1), int(x1), int(y2)-int(y1), int(x2)-int(x1))
    # resize the image to the desired size
    return img

def process_path_toe_test(file_name):
    file_path = im_test + file_name
    #label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)#can read the byte string paths b'image_0001.png'
    img = decode_crop_png_toe_test(img)
    return img, file_name

#
# map list to ds, Heel part.
#

def decode_crop_png_heel_test(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.io.decode_png(img, channels=3)
    # crop the toe from top-left corner [image, offset_height y1, offset_width x1, target_height, target_width]
    y2=y_offset_heel;    x2=0;    h=img_height;    w=img_width # not the pp location
    img = tf.image.crop_to_bounding_box(img, int(y2), int(x2), h, w)
    #img = tf.image.crop_to_bounding_box(img, int(y1), int(x1), int(y2)-int(y1), int(x2)-int(x1))
    # resize the image to the desired size
    return img

def process_path_heel_test(file_name):
    file_path = im_test + file_name
    #label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)#can read the byte string paths b'image_0001.png'
    img = decode_crop_png_heel_test(img)
    return img, file_name


#
# test how to put parameters to map
#

def t_ds_map(file_path,x1,y1,x2,y2):
#     img = get_img('train/images/' + str(file_path))
#     print(file_path)
    return file_path,x1,y1,x2,y2 #img, [x1,y1]

# %%
# TEST Toe ds
test_ds_map_toe = list_ds_test.map(process_path_toe_test, num_parallel_calls=AUTOTUNE)

# TEST Heel ds
test_ds_map_heel = list_ds_test.map(process_path_heel_test, num_parallel_calls=AUTOTUNE)

# %%
for img, file_name in test_ds_map_toe.take(5):
    print(f'take sample: {img.shape} {file_name}')
    
# print('f', f.dtype)
# print('xy', xy.dtype)

# %% [markdown]
# ### prepare TEST_ds_pre

# %%
def configure_for_performance_cache_test(ds, cache=True):

    if cache:
        ds = ds.cache()
        print("Check cache in memory:Y", cache)
    else:
        print("Check cache in memory:N", cache)
        
#     if augment:
# #         ds = ds.map(data_augment, num_parallel_calls=AUTOTUNE)
#         ds = ds.map(AA, num_parallel_calls=AUTOTUNE)
# #         ds = ds.map(RA, num_parallel_calls=AUTOTUNE)
#         print("Check augment :Y", augment)
#     else:
#         print("Check augment :N", augment)
    
#     #ds = ds.repeat()#TODO:2020-12-14: test
#     ds = ds.shuffle(buffer_size=MULTI_BATCH_SIZE*2) # (buffer_size=MULTI_BATCH_SIZE*5) 6sec,buffer_size=1000 take few sec. or buffer_size=image_count <- take too long # each take ds take 30~45 sec, TODO!!
#     ds = ds.shuffle(len(list_ds), reshuffle_each_iteration=False) #todo: move to ds_pre. see https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle
    ds = ds.batch(1000)# 1k for foot test images #MULTI_BATCH_SIZE for multi-GPUs
    ds = ds.prefetch(buffer_size=AUTOTUNE) #buffer_size=AUTOTUNE seem no speed improve
    
    return ds

# %%
"""
Prepare the ds properties (cache, augment, bs, shuffle, prefetch, etc.) for better performance.
"""
# TEST Toe ds_pre
test_ds_pre_toe = configure_for_performance_cache_test(test_ds_map_toe)

# TEST Heel ds_pre
test_ds_pre_heel = configure_for_performance_cache_test(test_ds_map_heel)

# %% [markdown]
# # Load Best-K-models

# %%
# if K-models are in last time frame
# best_model_name = get_best_model_name(th, K=str(k))

predictions_toe = []
predictions_heel = []

for k in range(KFlodNum):
    print(f'K:{k}')
    best_model_toe_name = get_best_model_name('toe', K=str(k))
    best_model_heel_name = get_best_model_name('heel', K=str(k))

# # if models are in last time frame
# best_model_toe_name = get_best_model_name('toe')
# best_model_heel_name = get_best_model_name('heel')

# # if toe/heel are in different time frame
# best_model_toe_name = '20210118-212454/toe_EfficientNetB0_bs64_w120_best_val_loss.h5'#6.3318 @e393
# best_model_heel_name = '20210122-084854/heel_EfficientNetB0_bs64_w120_best_val_loss.h5'#3.27979@152




    print(best_model_toe_name)
    print(best_model_heel_name)
    # log_dir_name + '/' + 'leaf-2020-12-01-EfficientNetB7_top-layer50_lr_lrfn_val-acc.8352_wh512_e37.h5'

    best_model_toe = tf.keras.models.load_model(best_model_toe_name,compile=False)
    best_model_heel = tf.keras.models.load_model(best_model_heel_name,compile=False)
    
    best_model_toe.compile(optimizer = tf.keras.optimizers.Adam(),#RMSprop , Adam
                loss=ed_metric_2d_mean)#, ed_loss ed_metric_2d ed_metric_2d_mean            
                #metrics=['mae', 'accuracy'])
    best_model_heel.compile(optimizer = tf.keras.optimizers.Adam(),#RMSprop , Adam
                loss=ed_metric_2d_mean)#, ed_loss ed_metric_2d ed_metric_2d_mean            
                #metrics=['mae', 'accuracy'])
        
        
    pred_toe = best_model_toe.predict(test_ds_pre_toe)
    pred_toe[:,1] = pred_toe[:,1] + y_offset_toe
    predictions_toe.append(pred_toe)
    
    pred_heel = best_model_heel.predict(test_ds_pre_heel)
    pred_heel[:,1] = pred_heel[:,1] + y_offset_heel
    predictions_heel.append(pred_heel)

# %%
len(predictions_toe[0])

# %%
# make sure we got the k-pred as k models.
for i, _ in enumerate(predictions_toe):
    print(i)

# %%
np.shape(predictions_toe)

# %%
predictions_toe[0]

# %%
predictions_toe[1]

# %%
predictions_heel[0]

# %%
predictions_heel[1]

# %%
# mean the k-predictions
k_predictions_toe = np.mean(predictions_toe, axis=0)
k_predictions_toe

# %%
np.shape(k_predictions_toe)

# %%
# mean the k-predictions
k_predictions_heel = np.mean(predictions_heel, axis=0)
k_predictions_heel

# %% [markdown]
# ### Merge toe/hell pred

# %%
predictions_th = np.append(k_predictions_toe, k_predictions_heel, axis=1)#左右接
predictions_th.shape

# %%
images_name = np.expand_dims(df_ts['images'], axis=1)
images_name.shape

# %%
predictions_merge = np.append(images_name, predictions_th, axis=1)#左右接
predictions_merge.shape

# %%
df_submission = pd.DataFrame(predictions_merge)
df_submission.columns = ['images','x1','y1','x2','y2']

# %%
submi_name = CSVNAME + '.' + log_dir_name +'.csv'

df_submission.to_csv(submi_name, index=False)
print('Save {} as submission CSV.'.format(submi_name))

# %%
df_submission.head()

# %%
#ED sum
def get_valloss(his_v_l):  
    return np.min(his_v_l), np.argmin(his_v_l)

t_vl = []
h_vl = []
for k in range(KFlodNum):
    print(f'K:{k}')
    t_v, _ = get_valloss(history_toe_finetune[k].history['val_loss'])
    h_v, _ = get_valloss(history_heel_finetune[k].history['val_loss'])
    
    t_vl.append(t_v)
    h_vl.append(h_v)

t_vl = np.mean(t_vl, axis=0)
h_vl = np.mean(h_vl, axis=0)
print(f'{round(t_vl,5)} + {round(h_vl,5)} = {round(t_vl + h_vl,5)}')
# Out:
# K:0
# K:1
# K:2
# K:3
# K:4
# 5.4148 + 3.32386 = 8.73867

# %%
# K134520210224-114845.csv
# 5.63922 + 3.34466 = 8.98389 LB:8.4890610

# %%
t_vl

# %%
h_vl

# %%
t_timer.toc() #Time elapsed since t.tic()

# %% [markdown]
# ### compile the model separately afterwards. to load model with custom loss function
#
# * https://github.com/tensorflow/tensorflow/issues/32348

# %%
# best_model_toe.compile(optimizer = tf.keras.optimizers.Adam(),#RMSprop , Adam
#                 loss=ed_metric_2d_mean)#, ed_loss ed_metric_2d ed_metric_2d_mean            
#                 #metrics=['mae', 'accuracy'])
# best_model_heel.compile(optimizer = tf.keras.optimizers.Adam(),#RMSprop , Adam
#                 loss=ed_metric_2d_mean)#, ed_loss ed_metric_2d ed_metric_2d_mean            
#                 #metrics=['mae', 'accuracy'])

# best_model_toe.compile(optimizer = tf.keras.optimizers.Adam(),#RMSprop , Adam
#                 loss=tf.keras.losses.MeanSquaredError())#, ed_loss ed_metric_2d ed_metric_2d_mean            
#                 #metrics=['mae', 'accuracy'])
# best_model_heel.compile(optimizer = tf.keras.optimizers.Adam(),#RMSprop , Adam
#                 loss=tf.keras.losses.MeanSquaredError())#, ed_loss ed_metric_2d ed_metric_2d_mean            
#                 #metrics=['mae', 'accuracy'])

# %%
# %%time
# # inference all test_ds once
# predictions_toe = best_model_toe.predict(test_ds_pre_toe)
# predictions_toe.shape

# %% [markdown]
# ### Offset Toe

# %%
# predictions_toe[:,1] = predictions_toe[:,1] + y_offset_toe

# # for [0,1]
# # predictions_toe[:,0] = predictions_toe[:,0]*120
# # predictions_toe[:,1] = predictions_toe[:,1]*120 + y_offset_toe

# # # for [-1,1]
# # # for re-scale back xy 
# # # return img, [(x1-60)/60,((y1-y_offset_toe)-60)/60]#normalized [-1,1] 
# # # return img, [(x2-60)/60,((y2-y_offset_heel)-60)/60]#normalized [-1,1] 
# # predictions_toe[:,0] = (predictions_toe[:,0]*60)+60
# # predictions_toe[:,1] = (predictions_toe[:,1]*60)+60 + y_offset_toe

# predictions_toe

# %%
# %%time
# # inference all test_ds once
# predictions_heel = best_model_heel.predict(test_ds_pre_heel)
# predictions_heel.shape

# %% [markdown]
# ### Offset Heel

# %%
# predictions_heel[:,1] = predictions_heel[:,1] + y_offset_heel

# # for [0,1]
# # predictions_heel[:,0] = predictions_heel[:,0]*120
# # predictions_heel[:,1] = predictions_heel[:,1]*120 + y_offset_heel

# # # for [-1,1]
# # predictions_heel[:,0] = (predictions_heel[:,0]*60)+60
# # predictions_heel[:,1] = (predictions_heel[:,1]*60)+60 + y_offset_heel

# predictions_heel

# %% [markdown]
# ### Merge toe/hell pred

# %%
# predictions_th = np.append(predictions_toe, predictions_heel, axis=1)#左右接
# predictions_th.shape

# %%
# images_name = np.expand_dims(df_ts['images'], axis=1)
# images_name.shape

# %%
# predictions_merge = np.append(images_name, predictions_th, axis=1)#左右接
# predictions_merge.shape

# %%
# df_submission = pd.DataFrame(predictions_merge)
# df_submission.columns = ['images','x1','y1','x2','y2']

# %%
# submi_name = '0000_ft_' + log_dir_name +'.csv'
# # submi_name = 'Bth_clr3_2690_XYnorm[0-1]_' + log_dir_name +'.csv'
# df_submission.to_csv(submi_name, index=False)
# print('Save {} as submission CSV.'.format(submi_name))

# %%
#Bth_clr3_2690_ed_findtune_20210202-141718.csv

#toe.9.9/heel.4.4 109 trainable LB:9.3411759 比heel保持top-20略高0.04 (9.3084957)

# %%
# df_submission.head()

# %%
# #ED sum
# def get_valloss(his_v_l):  
#     return np.min(his_v_l), np.argmin(his_v_l)

# t_vl, _ = get_valloss(history_toe_finetune.history['val_loss'])
# h_vl, _ = get_valloss(history_heel_finetune.history['val_loss'])

# print(f'{round(t_vl,5)} + {round(h_vl,5)} = {round(t_vl + h_vl,5)}')

# %%
#

# %% [markdown]
# ## save model

# %%
# best_model_name = './cop_' + model_name + '_bs' + str(BATCH_SIZE) + '_w' + str(img_width) + '_e' + str(ep_num) + '_' + datetime.now().strftime("%Y%m%d-%H%M%S") + '_.h5'
# # model.save(best_model_name)
# print("Save model: ", best_model_name)

# %% [markdown]
# ## Reference
#
# multi output model:
# https://navoshta.com/end-to-end-deep-learning/
